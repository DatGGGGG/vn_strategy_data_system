# %%
import pandas as pd
import numpy as np
import requests
from pprint import pprint
from math import ceil
import copy
import random
from datetime import datetime, timedelta, date
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import ast
import json

# %%
pd.set_option('display.float_format', '{:.0f}'.format)

# %% [markdown]
# # Guidelines (DON'T edit on 2 files at once)
#
# 1. Common Tables
# - For canonical data/unified app data, use "df_game_full_info"
# - For app info (aka local app info), use "df_all_app_info_list"
# - For mapping unified_app_id : list of local apps, use "list_of_dicts_game_app_list"
# - For flattened version of mapping unified_app_id : list of local apps, use "list_of_dicts_game_app_list_flattened"
# - For mapping publisher_id : revenue_multiplier, use "dict_publisher_id_revenue_multiplier"
# - For full-info table of apps requiring rev adjustment: "df_app_requiring_rev_adjustment"
# - For list of app ids requiring rev adjustment: "list_app_id_requiring_rev_adjustment"
# - For list of game ids (unified ids) requiring rev adjustment: "list_game_ids_requiring_rev_adjustment"

# %% [markdown]
# # API Credentials

# %%
# api_key = 
# base_url = 'https://api.sensortower.com'
# using authentication token from chi Tram's account

# %% [markdown]
# # Supporting Functions

# %%
def chunk_list(lst, chunk_size):
    """
    Splits a list into chunks of specified size.
    
    Parameters:
        lst (list): The list to split.
        chunk_size (int): The maximum size of each chunk.
        
    Returns:
        generator: A generator that yields chunks of the list.
    """
    for i in range(0, len(lst), chunk_size):
        yield lst[i:i + chunk_size]

# %%
def parse_string_to_list(input_string):
    """
    Converts a string representation of a list into an actual Python list.

    Args:
        input_string (str): The input string representing a list, e.g., 
                            "['US', 'AU', 'CA']".

    Returns:
        list: A Python list parsed from the input string.
    """
    # Use eval to safely parse the string into a list
    try:
        result = eval(input_string)
        if isinstance(result, list):
            return result
        else:
            raise ValueError("Input string does not represent a valid list.")
    except Exception as e:
        raise ValueError(f"Failed to parse input string: {e}")

# %%
def string_to_timestamp(date_string):
    """
    Converts an ISO 8601 date string into a Unix timestamp.
    
    Args:
        date_string (str): The date string in ISO 8601 format, e.g., "2010-05-29T00:00:00Z".
    
    Returns:
        int: The Unix timestamp (seconds since epoch).
    """
    # Parse the date string to a datetime object
    dt = datetime.strptime(date_string, "%Y-%m-%dT%H:%M:%SZ")
    
    # Convert to a timestamp
    return int(dt.timestamp())

# %%
def string_to_timestamp_v2(date_string):
    """
    Converts a date string in 'YYYY/MM/DD' format into a Unix timestamp.
    
    Args:
        date_string (str): The date string in 'YYYY/MM/DD' format, e.g., "2013/02/25".
    
    Returns:
        int: The Unix timestamp (seconds since epoch).
    """
    # Parse the date string to a datetime object
    dt = datetime.strptime(date_string, "%Y/%m/%d")
    
    # Convert to a timestamp
    return int(dt.timestamp())

# %%
def timestamp_to_string(timestamp):
    """
    Converts a Unix timestamp into a date string in 'YYYY/MM/DD' format.
    
    Args:
        timestamp (int): The Unix timestamp to convert.
    
    Returns:
        str: The formatted date string, e.g., "2013/02/25".
    """
    # Convert the timestamp to a datetime object
    dt = datetime.fromtimestamp(timestamp)
    
    # Format the datetime object as a string
    date_string = dt.strftime("%Y/%m/%d")
    
    return date_string

# %%
def add_days_to_date(date_str, days_to_add):
    """
    Adds a certain number of days to a given date string.

    Args:
        date_str (str): The input date string in the format "YYYY-MM-DD".
        days_to_add (int): The number of days to add.

    Returns:
        str: The resulting date string in the format "YYYY-MM-DD".
    """
    # Parse the input date string to a datetime object
    date_obj = datetime.strptime(date_str, "%Y-%m-%d")
    # Add the specified number of days
    new_date_obj = date_obj + timedelta(days=days_to_add)
    # Convert back to a string and return
    return new_date_obj.strftime("%Y-%m-%d")

# %%
def get_unified_app_data(api_key, base_url, app_ids):
    """
    Fetch unified app data from the SensorTower API in batches of 100 IDs per request.
    
    Parameters:
        api_key (str): Your SensorTower API key.
        base_url (str): The base URL for the API.
        app_ids (list[str]): List of unified app IDs to fetch.
        
    Returns:
        list[dict]: Combined response data from all requests.
    """
    
    # API endpoint
    endpoint = "/v1/unified/apps"
    url = f"{base_url}{endpoint}"
    
    headers = {
        'Authorization': f'Bearer {api_key}'
    }
    
    all_responses = []
    chunk_size = 100
    count = 1
    
    # Split the list of app_ids into chunks of 100
    for app_id_chunk in chunk_list(app_ids, chunk_size):
        params = {
            'app_id_type': 'unified',
            'app_ids': ','.join(app_id_chunk)
        }
        
        print('making call for chunk number {}'.format(count))
        
        # Make the API request for this chunk
        response = requests.get(url, headers=headers, params=params)
        
        if response.status_code == 200:
            print('call successful!')
            all_responses.extend(response.json().get('apps', []))
        else:
            print(f"Request failed with status code {response.status_code}: {response.text}")
        
        count += 1
    
    return all_responses

# %%
def get_required_tags(api_key, base_url, app_ids):


    # API endpoint
    endpoint = "/v1/app_tag/tags_for_apps"
    url = f"{base_url}{endpoint}"

    headers = {
        'Authorization': f'Bearer {api_key}'
    }
    
    
    all_responses = []
    chunk_size = 100
    count = 1
    
    # Split the list of app_ids into chunks of 100
    for app_id_chunk in chunk_list(app_ids, chunk_size):
        # params = {
        #     'app_ids': 'eu.nordeus.topeleven.android',
        #     'field_categories[]':'gaming',  
        #     'field_categories[]':'release_info',  
        # }

        # params = {
        #     'app_ids': 'eu.nordeus.topeleven.android',
        #     'field_categories[]':['gaming', 'release_info']  
        # }

        params = {
            'app_ids': ','.join(app_id_chunk),
            'fields[]':['Game Class', 
                        'Game Genre', 
                        'Game Sub-genre',
                        'Game Art Style',
                        'Game Camera POV',
                        'Game Setting',
                        'Game Theme',
                        'Game Product Model',
                        'IP: Corporate Parent',
                        'IP: IP Operator',
                        'IP: Media Type',
                        'IP: Licensed IP',
                        'Earliest Release Date',
                        'Release Date (WW)',
                        'Release Date (US)',
                        'Release Date (JP)',
                        'Release Date (CN)'
                       ]  
        }
        
        print('making call for chunk number {}'.format(count))
        
        # Make the API request for this chunk
        response = requests.get(url, headers=headers, params=params)
        
        if response.status_code == 200:
            print('call successful!')
            all_responses.extend(response.json().get('data', []))
        else:
            print(f"Request failed with status code {response.status_code}: {response.text}")
        
        count += 1
    
    return all_responses

# %%
def find_row_cell_value(row_name, tag_list):
    try:
        return list(filter(lambda x: x['name'] == row_name, tag_list))[0]['exact_value']
    except:
        return None

# %%
def get_tags_table(tags_data):
    
    tags_table = []

    for raw_row in tags_data:

        current_tag_list = raw_row['tags']

        new_row = dict()
        new_row['canonical_app_id'] = raw_row['app_id']
        new_row['game_class'] = find_row_cell_value('Game Class', current_tag_list)
        new_row['game_genre'] = find_row_cell_value('Game Genre', current_tag_list)
        new_row['game_subgenre'] = find_row_cell_value('Game Sub-genre', current_tag_list)
        new_row['game_art_style'] = find_row_cell_value('Game Art Style', current_tag_list)
        new_row['game_camera_pov'] = find_row_cell_value('Game Camera POV', current_tag_list)
        new_row['game_setting'] = find_row_cell_value('Game Setting', current_tag_list)
        new_row['game_theme'] = find_row_cell_value('Game Theme', current_tag_list)
        new_row['game_product_model'] = find_row_cell_value('Game Product Model', current_tag_list)
        new_row['game_ip_corporate_parent'] = find_row_cell_value('IP: Corporate Parent', current_tag_list)
        new_row['game_ip_operator'] = find_row_cell_value('IP: IP Operator', current_tag_list)
        new_row['game_ip_media_type'] = find_row_cell_value('IP: Media Type', current_tag_list)
        new_row['game_licensed_ip'] = find_row_cell_value('IP: Licensed IP', current_tag_list)
        new_row['game_earliest_release_date'] = find_row_cell_value('Earliest Release Date', current_tag_list)
        new_row['game_release_date_ww'] = find_row_cell_value('Release Date (WW)', current_tag_list)
        new_row['game_release_date_us'] = find_row_cell_value('Release Date (US)', current_tag_list)
        new_row['game_release_date_jp'] = find_row_cell_value('Release Date (JP)', current_tag_list)
        new_row['game_release_date_cn'] = find_row_cell_value('Release Date (CN)', current_tag_list) 
        tags_table.append(new_row)
    
    return tags_table

# %%
def extract_app_ids(list_of_dict):
    return list(map(lambda d: d['app_id'], list_of_dict))

# %%
def get_app_id_lists(unified_app_data):
#     also known as canonical data, cuz it also contains canonical id thingy
    itunes_app_id_list = []
    android_app_id_list = []
    
    for app in unified_app_data:
        current_app_itunes_app_ids = app['itunes_apps']
        current_app_android_app_ids = app['android_apps']
        itunes_app_id_list.extend(extract_app_ids(current_app_itunes_app_ids))
        android_app_id_list.extend(extract_app_ids(current_app_android_app_ids))
    
#     ios app id list needs to be adjusted (but not for android app id list)
    itunes_app_id_list_adjusted = list(map(lambda x: str(x),itunes_app_id_list))
    
    result_list = []
    
    for app_id in itunes_app_id_list_adjusted:
        result_list.append(
            {
                'os':'ios',
                'app_id':app_id
            }
        
        )

    for app_id in android_app_id_list:
        result_list.append(
            {
                'os':'android',
                'app_id':app_id
            }
        
        )
    
    return result_list

# %%
def get_local_app_info(api_key, base_url, os, app_ids):
    
    # API endpoint
    endpoint = "/v1/{}/apps".format(os)
    url = f"{base_url}{endpoint}"
    
    headers = {
        'Authorization': f'Bearer {api_key}'
    }
    
    all_responses = []
    chunk_size = 100
    count = 1
    
    # Split the list of app_ids into chunks of 100
    for app_id_chunk in chunk_list(app_ids, chunk_size):
        params = {
            'app_ids': ','.join(app_id_chunk)
        }
        
        print('making call for chunk number {}'.format(count))
        
        # Make the API request for this chunk
        response = requests.get(url, headers=headers, params=params)
        
        if response.status_code == 200:
            print('call successful!')
            all_responses.extend(response.json().get('apps', []))
        else:
            print(f"Request failed with status code {response.status_code}: {response.text}")
        
        count += 1
    
    return all_responses

# %%
def get_unified_id(local_app_id):
    return list(filter(lambda x: x['app_id'] == local_app_id, local_id_to_unified_id_mapping))[0]['unified_app_id']

# %%
def get_apps_performance(api_key, base_url, os, app_ids, country_code, granularity, max_periods, start_date, end_date):
    
    def split_date_range(start_date, end_date, granularity, max_periods):
        
        current_start = datetime.strptime(start_date, '%Y-%m-%d')
        final_end = datetime.strptime(end_date, '%Y-%m-%d')
        date_ranges = []
        
        day_count_per_granularity = {
            'daily': 1,
            'weekly': 7,
            'monthly': 30,
            'quarterly': 91
        }

        while current_start < final_end:
            
            # Calculate the end date for the current range
            current_end = current_start + timedelta(days=max_periods * day_count_per_granularity[granularity])
            # Ensure current_end does not exceed final_end
            current_end = min(current_end, final_end)
            
            if granularity == 'daily':
                date_ranges.append((current_start.strftime('%Y-%m-%d'), current_end.strftime('%Y-%m-%d')))
                current_start = current_end + timedelta(days=1)
            elif granularity == 'weekly':
                current_end = current_end + timedelta(days=(6 - current_end.weekday()))
                date_ranges.append((current_start.strftime('%Y-%m-%d'), current_end.strftime('%Y-%m-%d')))
                current_start = current_end + timedelta(days=1)
            elif granularity == 'monthly':
                current_end = (current_end.replace(day=1) + timedelta(days=32)).replace(day=1) - timedelta(days=1)
                date_ranges.append((current_start.strftime('%Y-%m-%d'), current_end.strftime('%Y-%m-%d')))
                current_start = (current_end + timedelta(days=1)).replace(day=1)
            elif granularity == 'quarterly':
                # Move current_end to the last day of the quarter
                quarter = (current_end.month - 1) // 3 + 1  # Calculate current quarter (1, 2, 3, or 4)
                next_quarter_start_month = quarter * 3 + 1  # Month of the next quarter's first day
                if next_quarter_start_month > 12:
                    next_quarter_start = current_end.replace(year=current_end.year + 1, month=1, day=1)
                else:
                    next_quarter_start = current_end.replace(month=next_quarter_start_month, day=1)
                current_end = next_quarter_start - timedelta(days=1)  # Move to the last day of the current quarter
                date_ranges.append((current_start.strftime('%Y-%m-%d'), current_end.strftime('%Y-%m-%d')))
                current_start = (current_end + timedelta(days=1)).replace(day=1)
#                 print('current_start: {}'.format(current_start))

        return date_ranges

    
    # API endpoint   
    endpoint = "/v1/{}/sales_report_estimates".format(os)
    url = f"{base_url}{endpoint}"
    headers = {
        'Authorization': f'Bearer {api_key}'
    }
    
    date_ranges = split_date_range(start_date, end_date, granularity, max_periods)
    print("Date ranges: {}".format(date_ranges))
    
    all_results = []
    chunk_size = 100

    for start, end in date_ranges:
        
        print("Requesting Data for Range:", start, "to", end)
        count = 1
        
        # Split the list of app_ids into chunks of 100
        for app_id_chunk in chunk_list(app_ids, chunk_size):

            params = {
                'os': os,
                'app_ids': ','.join(app_id_chunk),
                'countries': country_code,
                'date_granularity': granularity,
                'start_date': start,
                'end_date': end,
            }

            print('making call for chunk number {}'.format(count))

            request = requests.Request("GET", url, headers=headers, params=params)
            prepared_request = request.prepare()

            response = requests.get(url, headers=headers, params=params)

            if response.status_code == 200:
                print(f"Data retrieved for {start} to {end}")
                json_data = response.json()
                if isinstance(json_data, list):  # If the response is a list
                    all_results.extend(json_data)
                elif isinstance(json_data, dict):  # If the response is a dictionary
                    all_results.extend(json_data.get('data', []))
                else:
                    print(f"Unexpected response format for {start} to {end}: {json_data}")
            else:
                print(f"Failed for {start} to {end}. Status Code: {response.status_code}")
                print(response.text)

            count += 1
        
    return all_results

# %%
def get_monthly_app_performance_single_app_id(api_key, base_url, os, app_id, country_code, start_date, end_date):
    """
    Query monthly app performance data in 12-month segments if the range exceeds 12 months.
    """
    
    def split_date_range(start_date, end_date, max_months=12):
        """
        Split a date range into non-overlapping segments of up to `max_months` months.
        """
        current_start = datetime.strptime(start_date, '%Y-%m-%d')
        final_end = datetime.strptime(end_date, '%Y-%m-%d')
        date_ranges = []

        while current_start < final_end:
            # Calculate the end date for the current range
            current_end = current_start + timedelta(days=max_months * 30)  # Approximate 12 months
            # Ensure current_end does not exceed final_end
            current_end = min(current_end, final_end)
            # Adjust current_end to the last day of the month
            current_end = (current_end.replace(day=1) + timedelta(days=32)).replace(day=1) - timedelta(days=1)

            # Add the range to the list
            date_ranges.append((current_start.strftime('%Y-%m-%d'), current_end.strftime('%Y-%m-%d')))

            # Move current_start to the first day of the next month after current_end
            current_start = (current_end + timedelta(days=1)).replace(day=1)

        return date_ranges
    
    print("Getting performance data for app id {}".format(app_id))

    endpoint = "/v1/{}/sales_report_estimates".format(os)
    url = f"{base_url}{endpoint}"

    headers = {
        'Authorization': f'Bearer {api_key}'
    }

    date_ranges = split_date_range(start_date, end_date)
    
#     print("Date Ranges")
#     print(date_ranges)
    
    
    all_results = []

    for start, end in date_ranges:
        params = {
            'os': os,
            'app_ids': app_id,
            'countries': country_code,
            'date_granularity': 'monthly',
            'start_date': start,
            'end_date': end,
        }

        request = requests.Request("GET", url, headers=headers, params=params)
        prepared_request = request.prepare()

#         print("Requesting Data for Range:", start, "to", end)
#         print("Full Request URL:", prepared_request.url)

        response = requests.get(url, headers=headers, params=params)

        if response.status_code == 200:
            print(f"Data retrieved for {start} to {end}")
            json_data = response.json()
            if isinstance(json_data, list):  # If the response is a list
                all_results.extend(json_data)
            elif isinstance(json_data, dict):  # If the response is a dictionary
                all_results.extend(json_data.get('data', []))
            else:
                print(f"Unexpected response format for {start} to {end}: {json_data}")
        else:
            print(f"Failed for {start} to {end}. Status Code: {response.status_code}")
            print(response.text)
    
    return all_results

# %%
def get_performance_streams_from_list_of_app_ids(api_key, base_url, country_code, start_date, end_date, list_app_ids):
#     currently only get monthly performance
    result = []
    
    for app in list_app_ids:
        os = app["os"]
        app_id = app["app_id"]
        app_performance = get_monthly_app_performance_single_app_id(
            api_key, 
            base_url, 
            os, 
            app_id, 
            country_code,
            start_date, 
            end_date
        )
        result.append(
            {
                'app_id': app_id,
                'os': os,
                'app_performance': app_performance
            }
        )

    return result

# %%
def get_unique_dates(performance_streams_data):
    result = []
    for app in performance_streams_data:
        for record in app['app_performance']:
            if not(record['d'] in result):
                result.append(record['d'])
    return sorted(result)

# %%
def get_app_ids_from_performance_stream_data(performance_stream_data):
    return list(map(lambda x: x['app_id'], performance_stream_data))

# %%
def fill_performance_streams_df(blank_df, performance_streams_data):
    for row in performance_streams_data:
        if row['os'] == 'ios':
            for record in row['app_performance']:
                revenue_ar = record['ar']/100 if 'ar' in record else 0
                revenue_ir = record['ir']/100 if 'ir' in record else 0
                blank_df.at[row['app_id'], record['d']] = revenue_ar + revenue_ir
        elif row['os'] == 'android':
            for record in row['app_performance']:        
                blank_df.at[row['app_id'], record['d']] = record['r']/100 if 'r' in record else 0
    return blank_df

# %%
def generate_performance_streams_df(performance_streams_data):
#     prepare blank dataframe
    unique_dates = get_unique_dates(performance_streams_data)
    app_ids = get_app_ids_from_performance_stream_data(performance_streams_data)
    df = pd.DataFrame(index=app_ids, columns=unique_dates)
    
# fill the data
    return fill_performance_streams_df(df, performance_streams_data)

# %%
def get_daily_app_performance_single_unified_id(api_key, base_url, unified_id, country_code, start_date, end_date):
    """
    Fetch unified app data from the SensorTower API in batches of 100 IDs per request.
    
    Parameters:
        api_key (str): Your SensorTower API key.
        base_url (str): The base URL for the API.
        app_ids (list[str]): List of unified app IDs to fetch.
        
    Returns:
        list[dict]: Combined response data from all requests.
    """
    
    # API endpoint
    endpoint = "/v1/unified/sales_report_estimates"
    url = f"{base_url}{endpoint}"
    
    headers = {
        'Authorization': f'Bearer {api_key}'
    }

    params = {
        'app_ids': unified_id,
        'countries': country_code,
        'date_granularity': 'daily',
        'start_date': start_date,
        'end_date': end_date,
    }
    
    response = requests.get(url, headers=headers, params=params)
    
    return response.json()

# %%
def calc_download_revenue_sum_from_sales_report_estimates(sales_report):
    unified_id = sales_report[0]['app_id']
    start_date = sales_report[0]['date']
    end_date = sales_report[-1]['date']
    
    download_sum = 0
    revenue_sum = 0
    for row in sales_report:
        download_sum = download_sum + row['unified_units']
        revenue_sum = revenue_sum + row['unified_revenue']
    return {
        'unified_id': unified_id,
        'start_date': start_date,
        'end_date': end_date,
        'download': download_sum,
        'revenue': revenue_sum/100
    }

# %%
def get_first_n_day_sum_performance_single_unified_id(api_key, base_url, unified_id, country_code, release_date, n):

    query_result = get_daily_app_performance_single_unified_id(
        api_key = api_key, 
        base_url = base_url, 
        unified_id = unified_id, 
        country_code = country_code, 
        start_date = release_date, 
        end_date = add_days_to_date(start_date, n)
    )
    
    print(query_result)
    
    return calc_download_revenue_sum_from_sales_report_estimates(query_result)

# %%
def transform_df_local_app_info_to_dict_unified_id_local_app_info(df_local_app_info):
    table_app_ids = df_local_app_info.to_dict(orient='records')
    
    # get the list of unique unified_ids
    set_unified_ids = set(map(lambda x: x['unified_app_id'], table_app_ids))
    
    # Initiate the data structure unified_id: list of app of id info
    dict_unified_id_app_ids = dict()    
    
    for unified_id in set_unified_ids:
        dict_unified_id_app_ids[unified_id] = list(filter(lambda x: x['unified_app_id'] == unified_id, table_app_ids))
    
    return dict_unified_id_app_ids

# %%
def filter_vn_app_id(app_id_list):
    result = []
    for app in app_id_list:
        if 'VN' in parse_string_to_list(app['valid_countries']) or 'VN' in parse_string_to_list(app['top_countries']):
            result.append(app)
    return result

# %%
def get_top_games_by_year(df, percentile):
    """
    Get top games (Unified ID) contributing 90% of total revenue for each year.
    
    Args:
        df (DataFrame): Input DataFrame containing game performance data.
    
    Returns:
        dict: Dictionary with years as keys and lists of Unified IDs as values.
    """
    # Ensure the 'Date' column is datetime format
    df['Date'] = pd.to_datetime(df['Date'])
    
    # Extract the year from the 'Date' column
    df['Year'] = df['Date'].dt.year

    # Initialize result dictionary
    top_games_by_year = {}

    # Iterate through each year in the dataset
    for year, group in df.groupby('Year'):
        # Total revenue for the year
        total_revenue = group['Revenue (Absolute, $)'].sum()

        # Sort by revenue in descending order
        group = group.sort_values(by='Revenue (Absolute, $)', ascending=False)

        # Calculate cumulative revenue and cumulative percentage
        group['Cumulative Revenue'] = group['Revenue (Absolute, $)'].cumsum()
        group['Cumulative %'] = group['Cumulative Revenue'] / total_revenue

        # Get the IDs that contribute up to <percentile>% of the revenue
        top_ids = group.loc[group['Cumulative %'] <= percentile, 'Unified ID'].tolist()

        # Store the result for the year
        top_games_by_year[year] = top_ids

    return top_games_by_year

# %%
def extract_all_values(dictionary):
    """
    Extract all values from a dictionary into a single list.
    
    Args:
        dictionary (dict): Input dictionary with values being lists.
    
    Returns:
        list: A list containing all values across all keys.
    """
    return [value for values in dictionary.values() for value in values]

# %%
# A function that takes in the set of unified_id 
# then output the full-info table of those unified_id (canonical, game tags and stuff)

def retrieve_full_info_game_table(api_key, base_url, set_unified_ids):
    
    print("Get canonical app data...")
    
    canonical_app_data = get_unified_app_data(
        api_key = api_key, 
        base_url = base_url, 
        app_ids = list(set_unified_ids)
    )
    
    df_canonical_app_data = pd.DataFrame(canonical_app_data)
    
    canonical_id_list = list(df_canonical_app_data['canonical_app_id'])
    
    canonical_id_list_fixed = [str(item) for item in canonical_id_list]
    
    print("Get game tags...")
    
    tags_data = get_required_tags(
        api_key, 
        base_url, 
        canonical_id_list_fixed
    )
    
    
    
    tags_table = get_tags_table(tags_data)
    
    df_tags_table = pd.DataFrame(tags_table)
    
    df_game_full_info = pd.merge(
        df_tags_table,
        df_canonical_app_data,
        how = 'left',
        on = 'canonical_app_id'
    )
    
    new_order = [
        'unified_app_id',
        'canonical_app_id',
        'name',
        'cohort_id',
        'itunes_apps',
        'android_apps',
        'unified_publisher_ids',
        'itunes_publisher_ids',
        'android_publisher_ids',
        'game_class',
        'game_genre',
        'game_subgenre',
        'game_art_style',
        'game_camera_pov',
        'game_setting',
        'game_theme',
        'game_product_model',
        'game_ip_corporate_parent',
        'game_ip_operator',
        'game_ip_media_type',
        'game_licensed_ip',
        'game_earliest_release_date',
        'game_release_date_ww',
        'game_release_date_us',
        'game_release_date_jp',
        'game_release_date_cn'
    ]
    
    return df_game_full_info[new_order]

# %%
def compare_dataframes(df1, df2):
    """
    Compare two DataFrames cell by cell and record differences.

    Args:
        df1 (DataFrame): First DataFrame to compare.
        df2 (DataFrame): Second DataFrame to compare.

    Returns:
        list: A list of dictionaries containing the differences with details.
    """
    # Ensure both DataFrames have the same shape
    if df1.shape != df2.shape:
        raise ValueError("DataFrames do not have the same shape.")

    differences = []

    # Iterate over each cell in the DataFrame
    for row_idx in range(len(df1)):
        for col in df1.columns:
            if df1.at[row_idx, col] != df2.at[row_idx, col]:
                differences.append({
                    'Row': row_idx,
                    'Column': col,
                    'Value_df1': df1.at[row_idx, col],
                    'Value_df2': df2.at[row_idx, col]
                })
    
    return differences

# %%
def flatten_app_list_of_dicts(list_of_dict):
    result = []
    for item in list_of_dict:
        result.append(str(item['app_id']))
    return result

# %%
def plot_performance_streams_df(df_original):
    
    df = df_original.copy()
    
#     # Convert columns to datetime for proper handling
#     df.columns = pd.to_datetime(df.columns)

#     # Plot individual app revenue time series
#     plt.figure(figsize=(12, 6))
#     for app in df.index:
#         plt.plot(df.columns, df.loc[app], marker='o', label=f'{app}')
#         # Add data labels to each point
#         for x, y in zip(df.columns, df.loc[app]):
#             plt.annotate(f'{y}', (x, y), textcoords="offset points", xytext=(0, 5), ha='center')

#     # Plot total revenue time series
#     total_revenue = df.sum(axis=0)
#     plt.plot(df.columns, total_revenue, marker='o', linestyle='--', color='black', label='Total Revenue')
#     # Add data labels for total revenue
#     for x, y in zip(df.columns, total_revenue):
#         plt.annotate(f'{y}', (x, y), textcoords="offset points", xytext=(0, 5), ha='center')

#     # Customize the plot
#     plt.title('Revenue Trends of Individual Apps and Total Revenue')
#     plt.xlabel('Time')
#     plt.ylabel('Revenue')
#     plt.xticks(df.columns, rotation=45)
#     plt.legend()
#     plt.tight_layout()
#     plt.grid(True)

#     # Show the plot
#     plt.show()
    
    
    
    # Convert column names (quarters) to datetime
    df.columns = pd.to_datetime(df.columns)

    # Transpose for easier time-based plotting
    df_transposed = df.T

    # Plot each app's time series
    plt.figure(figsize=(12, 6))
    for app_id in df_transposed.columns:
        plt.plot(df_transposed.index, df_transposed[app_id], label=f'App: {app_id}')

    # Calculate and plot total revenue
    total_revenue = df_transposed.sum(axis=1)
    plt.plot(df_transposed.index, total_revenue, label='Total Revenue', color='black', linewidth=2, linestyle='--')

    # Add plot labels and legend
    plt.title('Revenue Time Series of Apps')
    plt.xlabel('Time')
    plt.ylabel('Revenue')
    plt.legend()
    plt.grid(True)
    plt.tight_layout()

    # Show the plot
    plt.show()

# %%
def plot_interactive_performance_streams_df(df_original):
    
    df = df_original.copy()
    
    # Create a Plotly Figure
    fig = go.Figure()

    # Add lines for individual apps
    for app in df.index:
        fig.add_trace(go.Scatter(
            x=df.columns, 
            y=df.loc[app], 
            mode='lines+markers', 
            name=f'{app}',
            text=df.loc[app],
            hovertemplate='App: %{name}<br>Date: %{x}<br>Revenue: %{y}<extra></extra>'
        ))

    # Add a line for total revenue
    total_revenue = df.sum(axis=0)
    fig.add_trace(go.Scatter(
        x=df.columns, 
        y=total_revenue, 
        mode='lines+markers', 
        name='Total Revenue',
        line=dict(dash='dot', color='black'),
        text=total_revenue,
        hovertemplate='Total Revenue<br>Date: %{x}<br>Revenue: %{y}<extra></extra>'
    ))

    # Customize layout
    fig.update_layout(
        title='Revenue Trends of Individual Apps and Total Revenue',
        xaxis_title='Time',
        yaxis_title='Revenue',
        xaxis=dict(rangeslider=dict(visible=True), type='date'),
        hovermode='x unified',
        template='plotly_white',
        legend=dict(title="Apps"),
    )

    # Show interactive plot
    fig.show()

# %%
def get_adjusted_yearly_revenue(revenue_df, app_info_df):
    
    def get_revenue_multiplier_of_app_id(app_id):
        return list(app_info_df[
            app_info_df[
                'app_id'].astype(str) == str(app_id)
        ]['revenue_multiplier'])[0]
    
    revenue_multiplier_vector = list(
        map(
            lambda x: get_revenue_multiplier_of_app_id(x),
            list(revenue_df.index)
        )
    )
    
    revenue_df_adjusted = revenue_df.mul(revenue_multiplier_vector, axis=0)
    
    revenue_df_adjusted_sum = revenue_df_adjusted.fillna(0).sum(axis=0)
    
    # Convert index to datetime
    revenue_df_adjusted_sum.index = pd.to_datetime(revenue_df_adjusted_sum.index)

    # Group by year and sum the revenue for each year
    yearly_revenue = revenue_df_adjusted_sum.resample('Y').sum()

    # Convert the index to year only
    yearly_revenue.index = yearly_revenue.index.year
    
    return yearly_revenue

# %%
def get_yearly_revenue_no_multiplier(revenue_df, app_info_df):
    
    revenue_df_sum = revenue_df.fillna(0).sum(axis=0)
    
    # Convert index to datetime
    revenue_df_sum.index = pd.to_datetime(revenue_df_sum.index)

    # Group by year and sum the revenue for each year
    yearly_revenue = revenue_df_sum.resample('Y').sum()

    # Convert the index to year only
    yearly_revenue.index = yearly_revenue.index.year
    
    return yearly_revenue

# %%
def get_adjusted_daily_revenue(revenue_df, app_info_df):
    
    def get_revenue_multiplier_of_app_id(app_id):
        return list(app_info_df[
            app_info_df[
                'app_id'].astype(str) == str(app_id)
        ]['revenue_multiplier'])[0]
    
    revenue_multiplier_vector = list(
        map(
            lambda x: get_revenue_multiplier_of_app_id(x),
            list(revenue_df.index)
        )
    )
    
    revenue_df_adjusted = revenue_df.mul(revenue_multiplier_vector, axis=0)
    
    revenue_df_adjusted_sum = revenue_df_adjusted.fillna(0).sum(axis=0)
    
    # Convert index to datetime
    revenue_df_adjusted_sum.index = pd.to_datetime(revenue_df_adjusted_sum.index)

    # Convert the index to date format (YYYY-MM-DD)
    revenue_df_adjusted_sum.index = revenue_df_adjusted_sum.index.date
    
    return revenue_df_adjusted_sum

# %%
def get_daily_revenue_no_multiplier(revenue_df):
    
    revenue_df_sum = revenue_df.fillna(0).sum(axis=0)
    
    # Convert index to datetime
    revenue_df_sum.index = pd.to_datetime(revenue_df_sum.index)

    # Convert the index to date format (YYYY-MM-DD)
    revenue_df_sum.index = revenue_df_sum.index.date
    
    return revenue_df_sum

# %%
def transform_raw_revenue_dataframe(df_input):
    
    df = df_input.copy()
    
    # Ensure the 'Date' column is in datetime format
    df['Date'] = pd.to_datetime(df['Date'])
    
    # Extract the year from the 'Date' column
    df['Year'] = df['Date'].dt.year
    
    # Pivot the DataFrame
    transformed_df = df.pivot(index='Unified ID', columns='Year', values='Revenue (Absolute, $)')
    
    # Sort columns chronologically (ascending order by year)
    transformed_df = transformed_df.sort_index(axis=1, ascending=True)
    
    # Reset the column names (optional, to remove "Year" label)
    transformed_df.columns.name = None
    
    # Sort by the latest year (the last column after sorting columns by year)
    latest_year = transformed_df.columns[-1]  # Get the latest year
    transformed_df = transformed_df.sort_values(by=latest_year, ascending=False)
    
    return transformed_df

# %%
def adjust_revenue_df(original_df, replacement_data):
    """
    Replace the revenue series for specific game IDs in a DataFrame.
    
    Parameters:
    - original_df: The original DataFrame where index is 'unified_app_id' and columns are years.
    - replacement_data: A list of dictionaries with 'unified_app_id' and 'yearly_sum_performance_series'.
    
    Returns:
    - A new DataFrame with updated revenue values.
    """
    # Create a copy to avoid modifying the original DataFrame
    updated_df = original_df.copy()
    
    for replacement in replacement_data:
        unified_app_id = replacement['unified_app_id']
        new_series = replacement['yearly_sum_performance_series']
        
        # Replace the row corresponding to the unified_app_id with the new series
        for year, value in new_series.items():
            updated_df.at[unified_app_id, year] = value
            
    return updated_df

# %%
def get_top_items_contributing_x_pct_from_series(series_input, x):
    s = series_input.copy()
    total = s.sum()
    s = s.sort_values(ascending = False)
    s_cumsum = s.fillna(0).cumsum()
    s_cumulative_pct = s_cumsum/total
    return list(s_cumulative_pct[s_cumulative_pct <= x].index)

# %%
def get_unified_ids_contributing_x_pct_revenue_each_year(df_game_revenue_adjusted, x):
    
    top_items_contributing_x_pct_revenue_per_year = dict()

    for year in df_game_revenue_adjusted.columns:
        top_items_contributing_x_pct_revenue_per_year[year] = get_top_items_contributing_x_pct_from_series(df_game_revenue_adjusted[year], x)
    
    all_year_set = set()

    for id_list in top_items_contributing_x_pct_revenue_per_year.values():
        all_year_set.update(id_list)

    top_items_contributing_x_pct_revenue_per_year['all_year'] = list(all_year_set)
    
    return top_items_contributing_x_pct_revenue_per_year

# %%
def process_game_taxonomy(file_path):
    # Read the Excel file with the given path
    taxonomy_tree = pd.read_excel(file_path, sheet_name='taxonomy_tree')
    definition = pd.read_excel(file_path, sheet_name='definition')

    # Create a dictionary with a composite key of (item, level)
    definition_dict = {(row['item'], row['level']): row['definition'] for _, row in definition.iterrows()}

    # Process the data into the nested structure
    st_game_taxonomy = []

    # Group by game_class to start building the hierarchy
    for game_class, class_group in taxonomy_tree.groupby('game_class'):
        game_class_key = (game_class, 'game_class')
        game_class_dict = {
            'game_class': game_class,
            'definition': definition_dict.get(game_class_key, ''),
            'genres': []
        }
        
        # Group by game_genre within the game_class
        for game_genre, genre_group in class_group.groupby('game_genre'):
            game_genre_key = (game_genre, 'game_genre')
            game_genre_dict = {
                'game_genre': game_genre,
                'definition': definition_dict.get(game_genre_key, ''),
                'subgenres': []
            }
            
            # Add subgenres to the genre
            for _, row in genre_group.iterrows():
                game_subgenre_key = (row['game_subgenre'], 'game_subgenre')
                game_subgenre_dict = {
                    'game_subgenre': row['game_subgenre'],
                    'definition': definition_dict.get(game_subgenre_key, '')
                }
                game_genre_dict['subgenres'].append(game_subgenre_dict)
            
            game_class_dict['genres'].append(game_genre_dict)
        
        st_game_taxonomy.append(game_class_dict)
    
    return st_game_taxonomy

# %%
def transform_df_local_app_info_to_dict_unified_id_local_app_info(df_local_app_info):
    table_app_ids = df_local_app_info.to_dict(orient='records')
    
    # get the list of unique unified_ids
    set_unified_ids = set(map(lambda x: x['unified_app_id'], table_app_ids))
    
    # Initiate the data structure unified_id: list of app of id info
    dict_unified_id_app_ids = dict()    
    
    for unified_id in set_unified_ids:
        dict_unified_id_app_ids[unified_id] = list(filter(lambda x: x['unified_app_id'] == unified_id, table_app_ids))
    
    return dict_unified_id_app_ids

# %%
def filter_vn_app_id(app_id_list):
    result = []
    for app in app_id_list:
        if 'VN' in parse_string_to_list(app['valid_countries']) or 'VN' in parse_string_to_list(app['top_countries']):
            result.append(app)
    return result

# %%
def get_release_date_from_unified_id(df_local_app_info, df_unified_full_info, unified_id):
    
#     deprecated due to old algorithm

    dict_unified_id_local_app_info = transform_df_local_app_info_to_dict_unified_id_local_app_info(df_local_app_info)
    
    list_local_app_info_vn = filter_vn_app_id(dict_unified_id_local_app_info[unified_id])
    
    if not list_local_app_info_vn:
        return string_to_timestamp_v2(df_unified_full_info[df_unified_full_info['unified_app_id'] == unified_id]['game_earliest_release_date'])
    else:
        return min(list(map(lambda x: string_to_timestamp(x['country_release_date']), list_local_app_info_vn)))

# %%
def get_release_year(dataframe, unified_id):
    
#     Input dataframe = df_game_revenue_adjusted (index being the unified ids, columns being the years)

    """
    Finds the starting year of the revenue time series for a specific game.

    Args:
        dataframe (pd.DataFrame): The input table with revenue time series data, 
                                  with Unified ID as the index.
        unified_id (str): The Unified ID of the game.

    Returns:
        int: The starting year (release year) of the game, or None if no revenue is found.
    """
    # Check if the Unified ID exists in the index
    if unified_id not in dataframe.index:
        print(f"Game with Unified ID {unified_id} not found.")
        return None

    # Extract the revenue time series for the given Unified ID
    row_revenue = dataframe.loc[unified_id]

    # Find the first year with non-NaN and non-zero revenue
    for year, revenue in row_revenue.items():
        if not pd.isna(revenue) and revenue > 0:
            return int(year)

    # If no revenue is found, return None
    return None

# %%
def get_release_date_from_daily_game_performance_table(table, unified_id):
#     not the full revenue table like input of the function get_release_year
    
    print("Processing unified app id: {}".format(unified_id))
    
    date_series = list(
        filter(
            lambda x: x['unified_app_id'] == unified_id,
            table
        )
    )[0]['daily_adjusted_revenue_series']
    
    if date_series.empty:
        return None
    
    return date_series.index[0]

# %%
# Previous version

# def calculate_first_n_day_revenue(daily_sum_performance_df_for_games, unified_app_id, n):
#     """
#     Calculate the first N-day revenue for a specific game.

#     Args:
#         daily_sum_performance_df_for_games (list): List of dictionaries containing game data.
#         unified_app_id (str): The unified app ID of the game.
#         n (int): The number of days (N) to calculate the revenue for.

#     Returns:
#         float or None: The first N-day revenue for the specified game, or None if the game is not found
#                        or doesn't have enough data points.
#     """
#     # Find the game with the specified unified_app_id
#     for game_data in daily_sum_performance_df_for_games:
#         if game_data['unified_app_id'] == unified_app_id:
#             # Get the Pandas Series for the game's daily revenue
#             daily_revenue_series = game_data['daily_adjusted_revenue_series']
            
#             # Sort the Series by the index to ensure chronological order
#             daily_revenue_series = daily_revenue_series.sort_index()
            
#             # Check if the revenue series has at least N data points
#             if len(daily_revenue_series) < n:
#                 print(f"Game {unified_app_id} does not have enough data points for {n}-day revenue.")
#                 return None
            
#             # Calculate the first N-day revenue
#             first_n_day_revenue = daily_revenue_series.head(n).sum()
#             return first_n_day_revenue
    
#     # Return None if the game with the specified ID is not found
#     print(f"Game with unified_app_id {unified_app_id} not found.")
#     return None

def calculate_first_n_day_revenue(daily_sum_performance_df_for_games, unified_app_id, n):
    """
    Calculate the first N-day revenue for a specific game, accounting for gaps in data.

    Args:
        daily_sum_performance_df_for_games (list): List of dictionaries containing game data.
        unified_app_id (str): The unified app ID of the game.
        n (int): The number of days (N) to calculate the revenue for.

    Returns:
        float or None: The first N-day revenue for the specified game, or None if the game is not found
                       or the date range does not span N days.
    """
    
    print("Processing for unified app id {}".format(unified_app_id))
    
    for game_data in daily_sum_performance_df_for_games:
        if game_data['unified_app_id'] == unified_app_id:
            # Get the Pandas Series for the game's daily revenue
            daily_revenue_series = game_data['daily_adjusted_revenue_series']
            
            # Check whether the series is empty
            if daily_revenue_series.empty:
                print(f"Game {unified_app_id} revenue series is empty.")
                return None
            
            # Sort the Series by the index to ensure chronological order
            daily_revenue_series = daily_revenue_series.sort_index()

            # Get the first and last date in the series
            start_date = daily_revenue_series.index.min()
            end_date = daily_revenue_series.index.max()
            
            # Get today date
            today_date = date.today()

            # Check if the date range spans at least N days
            date_range_days = (end_date - start_date).days + 1
            if date_range_days < n:
                if (today_date - start_date).days + 1 >= n:
                    return daily_revenue_series.sum()
                else:
                    print(f"Game {unified_app_id} does not have a date range spanning {n} days.")
                    return None

            # Calculate the first N-day revenue based on the date range
            valid_revenue = daily_revenue_series[start_date: start_date + pd.Timedelta(days=n-1)]
            first_n_day_revenue = valid_revenue.sum()
            return first_n_day_revenue

    # Return None if the game with the specified ID is not found
    print(f"Game with unified_app_id {unified_app_id} not found.")
    return None

# %%
def calculate_performance_for_new_games(daily_sum_performance_df_for_games, new_games_ids):
    """
    Calculate the first 7-day, 30-day, and 90-day revenue for new games.

    Args:
        daily_sum_performance_df_for_games (list): List of dictionaries containing game data.
        new_games_ids (list): List of unified_app_id for new games.

    Returns:
        list: A list of dictionaries containing unified_app_id and calculated revenue metrics.
    """
    performance_list = []

    for game_id in new_games_ids:
        # Initialize the dictionary for the game
        game_performance = {'unified_app_id': game_id}
        
        # Calculate revenue for 7-day, 30-day, and 90-day
        game_performance['first 7-day revenue'] = calculate_first_n_day_revenue(daily_sum_performance_df_for_games, game_id, 7)
        game_performance['first 30-day revenue'] = calculate_first_n_day_revenue(daily_sum_performance_df_for_games, game_id, 30)
        game_performance['first 90-day revenue'] = calculate_first_n_day_revenue(daily_sum_performance_df_for_games, game_id, 90)
        
        # Add the result to the list
        performance_list.append(game_performance)

    return performance_list

# %%
def update_game_classification(df_input, df_genre_validation_gpt_output_manually_corrected):
    """
    Updates the 'game_class', 'game_genre', and 'game_subgenre' columns in `df_game_full_info` 
    based on the corrected classifications in `df_genre_validation_gpt_output_manually_corrected`.

    Args:
        df_game_full_info (pd.DataFrame): The main dataframe containing game information.
        df_genre_validation_gpt_output_manually_corrected (pd.DataFrame): 
            The dataframe with corrected classification data.

    Returns:
        pd.DataFrame: Updated `df_game_full_info` with corrected classification for certain games.
    """
    
    df_game_full_info = df_input.copy()
    
    # Create a mapping of game_id to the finalized classifications
    corrected_classifications = df_genre_validation_gpt_output_manually_corrected[
        ['game_id', 'finalized_game_class', 'finalized_game_genre', 'finalized_game_subgenre']
    ].set_index('game_id')

    # Ensure game_id exists in both DataFrames
    df_game_full_info.set_index('unified_app_id', inplace=True)
    
    # Update the game_class, game_genre, and game_subgenre based on the corrected data
    df_game_full_info.update(corrected_classifications.rename(columns={
        'finalized_game_class': 'game_class',
        'finalized_game_genre': 'game_genre',
        'finalized_game_subgenre': 'game_subgenre'
    }))
    
    # Reset index to preserve the original structure
    df_game_full_info.reset_index(inplace=True)
    
    return df_game_full_info

# %%
def update_game_classification_for_revenue_df(df_input, additional_genre_data):
    """
    Updates the genre classification information in a DataFrame with additional data.

    Args:
        df (pd.DataFrame): The DataFrame containing game revenue and classification info.
        additional_genre_data (list of dict): List of dictionaries with additional genre data.

    Returns:
        pd.DataFrame: Updated DataFrame with genre classification information.
    """
    
    df = df_input.copy()
    
    # Convert the list of dictionaries to a temporary DataFrame
    additional_genre_df = pd.DataFrame(additional_genre_data)
    
    # Rename columns in the temporary DataFrame to match the target DataFrame
    additional_genre_df.rename(columns={
        'game_id': 'Unified ID',
        'finalized_game_class': 'game_class',
        'finalized_game_genre': 'game_genre',
        'finalized_game_subgenre': 'game_subgenre'
    }, inplace=True)
    
    # Set 'Unified ID' as the index for both DataFrames to facilitate alignment
    additional_genre_df.set_index('Unified ID', inplace=True)
    
    # Update the main DataFrame with the additional genre data
    df.update(additional_genre_df)

    return df

# %%
def join_game_genres_to_revenue(df_game_revenue_adjusted, df_game_full_info_with_corrected_genres):
    """
    Joins the fields 'game_class', 'game_genre', and 'game_subgenre' from the 
    df_game_full_info_with_corrected_genres dataframe to the df_game_revenue_adjusted dataframe
    and moves the newly added columns to the leftmost position.

    Args:
        df_game_revenue_adjusted (pd.DataFrame): The dataframe with revenue data by year.
        df_game_full_info_with_corrected_genres (pd.DataFrame): 
            The dataframe with game information.
        
    Returns:
        pd.DataFrame: Updated dataframe with 'game_class', 'game_genre', and 'game_subgenre' 
                      fields added at the leftmost position.
    """
    # Ensure 'unified_app_id' is the index in df_game_full_info_with_corrected_genres
    df_genres = df_game_full_info_with_corrected_genres.set_index('unified_app_id')[
        ['game_class', 'game_genre', 'game_subgenre']
    ]

    # Join the genre information to the revenue dataframe
    df_merged = df_game_revenue_adjusted.join(df_genres, how='left')

    # Move the new columns to the leftmost position
    new_columns = ['game_class', 'game_genre', 'game_subgenre']
    reordered_columns = new_columns + [col for col in df_merged.columns if col not in new_columns]
    df_merged = df_merged[reordered_columns]

    return df_merged

# %%
def get_monthly_revenue_series(daily_sum_performance, unified_app_id):
    """
    Convert the daily revenue series of a game to a monthly revenue series.

    Args:
        daily_sum_performance (list of dict): The data structure containing game daily revenue.
        unified_app_id (str): The unified_app_id of the game.

    Returns:
        dict: A dictionary with 'unified_app_id' and 'monthly_adjusted_revenue_series'.
    """
    # Find the game with the specified unified_app_id
    for game_data in daily_sum_performance:
        if game_data['unified_app_id'] == unified_app_id:
            # Get the daily revenue series
            daily_series = game_data['daily_adjusted_revenue_series']
            
            # Ensure the index is a datetime index
            daily_series.index = pd.to_datetime(daily_series.index)
            
            # Resample to monthly frequency and sum the revenues
            monthly_series = daily_series.resample('M').sum()
            
            return {
                'unified_app_id': unified_app_id,
                'monthly_adjusted_revenue_series': monthly_series
            }
    
    # If the game is not found, return None or raise an exception
    print(f"Game with unified_app_id '{unified_app_id}' not found.")
    return None

# %%
def calculate_average_30_day_revenue(daily_sum_performance, unified_app_id):
    """
    Calculate the 30-day average revenue for a game based on daily data.
    
    Args:
        daily_sum_performance (list of dict): List of dictionaries with daily revenue series.
        unified_app_id (str): The unified_app_id of the game.
    
    Returns:
        dict: A dictionary containing:
            - 'unified_app_id': The game ID.
            - 'average_30_day_revenue': The average 30-day revenue or None if not enough data.
    """
    
    # Find the game with the specified unified_app_id
    for game_data in daily_sum_performance:
        if game_data['unified_app_id'] == unified_app_id:
            # Get the daily revenue series
            daily_series = game_data['daily_adjusted_revenue_series']
            
            # Check if there are at least 180 data points
            if len(daily_series) >= 180:
                # Calculate the average daily revenue
                avg_daily_revenue = daily_series.mean()
                # Calculate the average 30-day revenue
                avg_30_day_revenue = avg_daily_revenue * 30
                return {
                    'unified_app_id': unified_app_id,
                    'average_30_day_revenue': avg_30_day_revenue
                }
            else:
                # Not enough data to calculate the average
                return {
                    'unified_app_id': unified_app_id,
                    'average_30_day_revenue': None
                }
    
    # If the game is not found, return None
    print(f"Game with unified_app_id '{unified_app_id}' not found.")
    return None

# %%
def fill_download_streams_df(blank_df, performance_streams_data):
    for row in performance_streams_data:
        if row['os'] == 'ios':
            for record in row['app_performance']:
                download_iu = record['iu'] if 'iu' in record else 0
                download_au = record['au'] if 'au' in record else 0
                blank_df.at[row['app_id'], record['d']] = download_iu + download_au
        elif row['os'] == 'android':
            for record in row['app_performance']:        
                blank_df.at[row['app_id'], record['d']] = record['u'] if 'u' in record else 0
    return blank_df

# %%
def generate_download_streams_df(performance_streams_data):
#     prepare blank dataframe
    unique_dates = get_unique_dates(performance_streams_data)
    app_ids = get_app_ids_from_performance_stream_data(performance_streams_data)
    df = pd.DataFrame(index=app_ids, columns=unique_dates)
    
# fill the data
    return fill_download_streams_df(df, performance_streams_data)

# %%
def get_daily_download(download_df):
    
    # Sum across the downloads of different apps of the same game
    download_df_sum = download_df.fillna(0).sum(axis=0)
    
    # Convert index to datetime
    download_df_sum.index = pd.to_datetime(download_df_sum.index)

    # Convert the index to date format (YYYY-MM-DD)
    download_df_sum.index = download_df_sum.index.date

    return download_df_sum

# %%
def transform_game_download_list_of_dict_to_dataframe(the_list):
    
# the input list can be in the form of [
#     {
#      'unified_app_id',
#      'daily_download_series'
#     }
# ]
    
    # Convert list of dictionaries to a dictionary of Series
    the_dict = {entry['unified_app_id']: entry['daily_download_series'] for entry in the_list}
    
    # Convert to DataFrame
    download_df = pd.DataFrame(the_dict).T  # Transpose to make game IDs rows
    
    return download_df

# %%
def calculate_first_n_day_download(daily_sum_download_df_for_games, unified_app_id, n):
    
    print("Processing for unified app id {}".format(unified_app_id))
    
    for game_data in daily_sum_download_df_for_games:
        if game_data['unified_app_id'] == unified_app_id:
            # Get the Pandas Series for the game's daily revenue
            daily_download_series = game_data['daily_download_series']
            
            # Check whether the series is empty
            if daily_download_series.empty:
                print(f"Game {unified_app_id} download series is empty.")
                return None
            
            # Sort the Series by the index to ensure chronological order
            daily_download_series = daily_download_series.sort_index()

            # Get the first and last date in the series
            start_date = daily_download_series.index.min()
            end_date = daily_download_series.index.max()
            
            # Get today date
            today_date = date.today()

            # Check if the date range spans at least N days
            date_range_days = (end_date - start_date).days + 1
            if date_range_days < n:
                if (today_date - start_date).days + 1 >= n:
                    return daily_download_series.sum()
                else:
                    print(f"Game {unified_app_id} does not have a date range spanning {n} days.")
                    return None

            # Calculate the first N-day revenue based on the date range
            valid_download = daily_download_series[start_date: start_date + pd.Timedelta(days=n-1)]
            first_n_day_download = valid_download.sum()
            return first_n_day_download

    # Return None if the game with the specified ID is not found
    print(f"Game with unified_app_id {unified_app_id} not found.")
    return None

# %%
def get_release_date_from_daily_game_download_table(table, unified_id):
#     not the full revenue table like input of the function get_release_year
    
    print("Processing unified app id: {}".format(unified_id))
    
    date_series = list(
        filter(
            lambda x: x['unified_app_id'] == unified_id,
            table
        )
    )[0]['daily_download_series']
    
    if date_series.empty:
        return None
    
    return date_series.index[0]

# %% [markdown]
# # Testing Supporting Functions

# %%
# Test performance data query

# %%
test_app_id_set = [
    '1160056295',
    '1428475506',
    '6468942281',
    '1354260888',
    '1483025097',
    '1574489575'
]

# %%
# test_performance_result = get_apps_performance(
#     api_key, 
#     base_url, 
#     os = 'ios', 
#     app_ids = test_app_id_set, 
#     country_code = 'VN', 
#     granularity = 'quarterly', 
#     max_periods = 8, 
#     start_date = '2014-01-01', 
#     end_date = '2024-10-31')

# %% [markdown]
# # Task Adhoc - Load Downloaded Yearly Performance Data & Create Game Info Table

# %%
# Load data
raw_game_data_df = pd.read_excel("data/output/st_game_data_2014_2024.xlsx")

# %%
set_unified_ids_full = set(list(raw_game_data_df["Unified ID"]))

# %%
df_game_full_info = retrieve_full_info_game_table(
    api_key, 
    base_url, 
    list(set_unified_ids_full)
)
# Out:
# Get canonical app data...
# making call for chunk number 1
# call successful!
# making call for chunk number 2
# call successful!
# making call for chunk number 3
# call successful!
# making call for chunk number 4
# call successful!
# making call for chunk number 5
# call successful!
# making call for chunk number 6
# call successful!
# making call for chunk number 7
# call successful!
# making call for chunk number 8
# call successful!
# making call for chunk number 9
# call successful!
# making call for chunk number 10
# call successful!
# making call for chunk number 11
# call successful!
# making call for chunk number 12
# call successful!
# making call for chunk number 13
# call successful!
# making call for chunk number 14
# call successful!
# making call for chunk number 15
# call successful!
# making call for chunk number 16
# call successful!
# making call for chunk number 17
# call successful!
# making call for chunk number 18
# call successful!
# making call for chunk number 19
# call successful!
# making call for chunk number 20
# call successful!
# making call for chunk number 21
# call successful!
# making call for chunk number 22
# call successful!
# making call for chunk number 23
# call successful!
# making call for chunk number 24
# call successful!
# making call for chunk number 25
# call successful!
# making call for chunk number 26
# call successful!
# making call for chunk number 27
# call successful!
# making call for chunk number 28
# call successful!
# making call for chunk number 29
# call successful!
# making call for chunk number 30
# call successful!
# making call for chunk number 31
# call successful!
# making call for chunk number 32
# call successful!
# making call for chunk number 33
# call successful!
# making call for chunk number 34
# call successful!
# making call for chunk number 35
# call successful!
# making call for chunk number 36
# call successful!
# making call for chunk number 37
# call successful!
# making call for chunk number 38
# call successful!
# making call for chunk number 39
# call successful!
# making call for chunk number 40
# call successful!
# making call for chunk number 41
# call successful!
# making call for chunk number 42
# call successful!
# making call for chunk number 43
# call successful!
# making call for chunk number 44
# call successful!
# making call for chunk number 45
# call successful!
# making call for chunk number 46
# call successful!
# making call for chunk number 47
# call successful!
# making call for chunk number 48
# call successful!
# making call for chunk number 49
# call successful!
# making call for chunk number 50
# call successful!
# making call for chunk number 51
# call successful!
# making call for chunk number 52
# call successful!
# making call for chunk number 53
# call successful!
# making call for chunk number 54
# call successful!
# making call for chunk number 55
# call successful!
# making call for chunk number 56
# call successful!
# making call for chunk number 57
# call successful!
# making call for chunk number 58
# call successful!
# making call for chunk number 59
# call successful!
# making call for chunk number 60
# call successful!
# making call for chunk number 61
# call successful!
# making call for chunk number 62
# call successful!
# making call for chunk number 63
# call successful!
# making call for chunk number 64
# call successful!
# making call for chunk number 65
# call successful!
# making call for chunk number 66
# call successful!
# making call for chunk number 67
# call successful!
# making call for chunk number 68
# call successful!
# making call for chunk number 69
# call successful!
# making call for chunk number 70
# call successful!
# making call for chunk number 71
# call successful!
# making call for chunk number 72
# call successful!
# making call for chunk number 73
# call successful!
# making call for chunk number 74
# call successful!
# making call for chunk number 75
# call successful!
# making call for chunk number 76
# call successful!
# making call for chunk number 77
# call successful!
# making call for chunk number 78
# call successful!
# making call for chunk number 79
# call successful!
# making call for chunk number 80
# call successful!
# making call for chunk number 81
# call successful!
# making call for chunk number 82
# call successful!
# making call for chunk number 83
# call successful!
# making call for chunk number 84
# call successful!
# making call for chunk number 85
# call successful!
# making call for chunk number 86
# call successful!
# making call for chunk number 87
# call successful!
# making call for chunk number 88
# call successful!
# making call for chunk number 89
# call successful!
# making call for chunk number 90
# call successful!
# making call for chunk number 91
# call successful!
# making call for chunk number 92
# call successful!
# making call for chunk number 93
# call successful!
# making call for chunk number 94
# call successful!
# making call for chunk number 95
# call successful!
# making call for chunk number 96
# call successful!
# making call for chunk number 97
# call successful!
# making call for chunk number 98
# call successful!
# making call for chunk number 99
# call successful!
# making call for chunk number 100
# call successful!
# making call for chunk number 101
# call successful!
# making call for chunk number 102
# call successful!
# making call for chunk number 103
# call successful!
# making call for chunk number 104
# call successful!
# making call for chunk number 105
# call successful!
# making call for chunk number 106
# call successful!
# making call for chunk number 107
# call successful!
# making call for chunk number 108
# call successful!
# making call for chunk number 109
# call successful!
# making call for chunk number 110
# call successful!
# making call for chunk number 111
# call successful!
# making call for chunk number 112
# call successful!
# making call for chunk number 113
# call successful!
# making call for chunk number 114
# call successful!
# making call for chunk number 115
# call successful!
# making call for chunk number 116
# call successful!
# making call for chunk number 117
# call successful!
# making call for chunk number 118
# call successful!
# making call for chunk number 119
# call successful!
# making call for chunk number 120
# call successful!
# making call for chunk number 121
# call successful!
# making call for chunk number 122
# call successful!
# making call for chunk number 123
# call successful!
# making call for chunk number 124
# call successful!
# making call for chunk number 125
# call successful!
# making call for chunk number 126
# call successful!
# making call for chunk number 127
# call successful!
# making call for chunk number 128
# call successful!
# making call for chunk number 129
# call successful!
# making call for chunk number 130
# call successful!
# making call for chunk number 131
# call successful!
# making call for chunk number 132
# call successful!
# making call for chunk number 133
# call successful!
# making call for chunk number 134
# call successful!
# making call for chunk number 135
# call successful!
# making call for chunk number 136
# call successful!
# making call for chunk number 137
# call successful!
# making call for chunk number 138
# call successful!
# making call for chunk number 139
# call successful!
# making call for chunk number 140
# call successful!
# making call for chunk number 141
# call successful!
# making call for chunk number 142
# call successful!
# making call for chunk number 143
# call successful!
# making call for chunk number 144
# call successful!
# making call for chunk number 145
# call successful!
# making call for chunk number 146
# call successful!
# making call for chunk number 147
# call successful!
# making call for chunk number 148
# call successful!
# making call for chunk number 149
# call successful!
# making call for chunk number 150
# call successful!
# making call for chunk number 151
# call successful!
# making call for chunk number 152
# call successful!
# making call for chunk number 153
# call successful!
# making call for chunk number 154
# call successful!
# making call for chunk number 155
# call successful!
# making call for chunk number 156
# call successful!
# making call for chunk number 157
# call successful!
# making call for chunk number 158
# call successful!
# making call for chunk number 159
# call successful!
# making call for chunk number 160
# call successful!
# making call for chunk number 161
# call successful!
# making call for chunk number 162
# call successful!
# making call for chunk number 163
# call successful!
# making call for chunk number 164
# call successful!
# making call for chunk number 165
# call successful!
# making call for chunk number 166
# call successful!
# making call for chunk number 167
# call successful!
# making call for chunk number 168
# call successful!
# making call for chunk number 169
# call successful!
# making call for chunk number 170
# call successful!
# making call for chunk number 171
# call successful!
# making call for chunk number 172
# call successful!
# making call for chunk number 173
# call successful!
# making call for chunk number 174
# call successful!
# making call for chunk number 175
# call successful!
# making call for chunk number 176
# call successful!
# making call for chunk number 177
# call successful!
# making call for chunk number 178
# call successful!
# making call for chunk number 179
# call successful!
# making call for chunk number 180
# call successful!
# making call for chunk number 181
# call successful!
# making call for chunk number 182
# call successful!
# making call for chunk number 183
# call successful!
# making call for chunk number 184
# call successful!
# making call for chunk number 185
# call successful!
# making call for chunk number 186
# call successful!
# making call for chunk number 187
# call successful!
# making call for chunk number 188
# call successful!
# making call for chunk number 189
# call successful!
# making call for chunk number 190
# call successful!
# making call for chunk number 191
# call successful!
# making call for chunk number 192
# call successful!
# making call for chunk number 193
# call successful!
# making call for chunk number 194
# call successful!
# making call for chunk number 195
# call successful!
# making call for chunk number 196
# call successful!
# making call for chunk number 197
# call successful!
# making call for chunk number 198
# call successful!
# making call for chunk number 199
# call successful!
# making call for chunk number 200
# call successful!
# making call for chunk number 201
# call successful!
# making call for chunk number 202
# call successful!
# making call for chunk number 203
# call successful!
# making call for chunk number 204
# call successful!
# making call for chunk number 205
# call successful!
# making call for chunk number 206
# call successful!
# making call for chunk number 207
# call successful!
# making call for chunk number 208
# call successful!
# making call for chunk number 209
# call successful!
# making call for chunk number 210
# call successful!
# making call for chunk number 211
# call successful!
# making call for chunk number 212
# call successful!
# making call for chunk number 213
# call successful!
# making call for chunk number 214
# call successful!
# making call for chunk number 215
# call successful!
# making call for chunk number 216
# call successful!
# making call for chunk number 217
# call successful!
# making call for chunk number 218
# call successful!
# making call for chunk number 219
# call successful!
# making call for chunk number 220
# call successful!
# making call for chunk number 221
# call successful!
# making call for chunk number 222
# call successful!
# making call for chunk number 223
# call successful!
# making call for chunk number 224
# call successful!
# making call for chunk number 225
# call successful!
# making call for chunk number 226
# call successful!
# making call for chunk number 227
# call successful!
# making call for chunk number 228
# call successful!
# making call for chunk number 229
# call successful!
# making call for chunk number 230
# call successful!
# making call for chunk number 231
# call successful!
# making call for chunk number 232
# call successful!
# making call for chunk number 233
# call successful!
# making call for chunk number 234
# call successful!
# making call for chunk number 235
# call successful!
# making call for chunk number 236
# call successful!
# making call for chunk number 237
# call successful!
# making call for chunk number 238
# call successful!
# making call for chunk number 239
# call successful!
# making call for chunk number 240
# call successful!
# making call for chunk number 241
# call successful!
# making call for chunk number 242
# call successful!
# making call for chunk number 243
# call successful!
# making call for chunk number 244
# call successful!
# making call for chunk number 245
# call successful!
# making call for chunk number 246
# call successful!
# making call for chunk number 247
# call successful!
# making call for chunk number 248
# call successful!
# making call for chunk number 249
# call successful!
# making call for chunk number 250
# call successful!
# making call for chunk number 251
# call successful!
# making call for chunk number 252
# call successful!
# making call for chunk number 253
# call successful!
# making call for chunk number 254
# call successful!
# making call for chunk number 255
# call successful!
# making call for chunk number 256
# call successful!
# making call for chunk number 257
# call successful!
# making call for chunk number 258
# call successful!
# making call for chunk number 259
# call successful!
# making call for chunk number 260
# call successful!
# making call for chunk number 261
# call successful!
# making call for chunk number 262
# call successful!
# making call for chunk number 263
# call successful!
# making call for chunk number 264
# call successful!
# making call for chunk number 265
# call successful!
# making call for chunk number 266
# call successful!
# making call for chunk number 267
# call successful!
# making call for chunk number 268
# call successful!
# making call for chunk number 269
# call successful!
# Get game tags...
# making call for chunk number 1
# call successful!
# making call for chunk number 2
# call successful!
# making call for chunk number 3
# call successful!
# making call for chunk number 4
# call successful!
# making call for chunk number 5
# call successful!
# making call for chunk number 6
# call successful!
# making call for chunk number 7
# call successful!
# making call for chunk number 8
# call successful!
# making call for chunk number 9
# call successful!
# making call for chunk number 10
# call successful!
# making call for chunk number 11
# call successful!
# making call for chunk number 12
# call successful!
# making call for chunk number 13
# call successful!
# making call for chunk number 14
# call successful!
# making call for chunk number 15
# call successful!
# making call for chunk number 16
# call successful!
# making call for chunk number 17
# call successful!
# making call for chunk number 18
# call successful!
# making call for chunk number 19
# call successful!
# making call for chunk number 20
# call successful!
# making call for chunk number 21
# call successful!
# making call for chunk number 22
# call successful!
# making call for chunk number 23
# call successful!
# making call for chunk number 24
# call successful!
# making call for chunk number 25
# call successful!
# making call for chunk number 26
# call successful!
# making call for chunk number 27
# call successful!
# making call for chunk number 28
# call successful!
# making call for chunk number 29
# call successful!
# making call for chunk number 30
# call successful!
# making call for chunk number 31
# call successful!
# making call for chunk number 32
# call successful!
# making call for chunk number 33
# call successful!
# making call for chunk number 34
# call successful!
# making call for chunk number 35
# call successful!
# making call for chunk number 36
# call successful!
# making call for chunk number 37
# call successful!
# making call for chunk number 38
# call successful!
# making call for chunk number 39
# call successful!
# making call for chunk number 40
# call successful!
# making call for chunk number 41
# call successful!
# making call for chunk number 42
# call successful!
# making call for chunk number 43
# call successful!
# making call for chunk number 44
# call successful!
# making call for chunk number 45
# call successful!
# making call for chunk number 46
# call successful!
# making call for chunk number 47
# call successful!
# making call for chunk number 48
# call successful!
# making call for chunk number 49
# call successful!
# making call for chunk number 50
# call successful!
# making call for chunk number 51
# call successful!
# making call for chunk number 52
# call successful!
# making call for chunk number 53
# call successful!
# making call for chunk number 54
# call successful!
# making call for chunk number 55
# call successful!
# making call for chunk number 56
# call successful!
# making call for chunk number 57
# call successful!
# making call for chunk number 58
# call successful!
# making call for chunk number 59
# call successful!
# making call for chunk number 60
# call successful!
# making call for chunk number 61
# call successful!
# making call for chunk number 62
# call successful!
# making call for chunk number 63
# call successful!
# making call for chunk number 64
# call successful!
# making call for chunk number 65
# call successful!
# making call for chunk number 66
# call successful!
# making call for chunk number 67
# call successful!
# making call for chunk number 68
# call successful!
# making call for chunk number 69
# call successful!
# making call for chunk number 70
# call successful!
# making call for chunk number 71
# call successful!
# making call for chunk number 72
# call successful!
# making call for chunk number 73
# call successful!
# making call for chunk number 74
# call successful!
# making call for chunk number 75
# call successful!
# making call for chunk number 76
# call successful!
# making call for chunk number 77
# call successful!
# making call for chunk number 78
# call successful!
# making call for chunk number 79
# call successful!
# making call for chunk number 80
# call successful!
# making call for chunk number 81
# call successful!
# making call for chunk number 82
# call successful!
# making call for chunk number 83
# call successful!
# making call for chunk number 84
# call successful!
# making call for chunk number 85
# call successful!
# making call for chunk number 86
# call successful!
# making call for chunk number 87
# call successful!
# making call for chunk number 88
# call successful!
# making call for chunk number 89
# call successful!
# making call for chunk number 90
# call successful!
# making call for chunk number 91
# call successful!
# making call for chunk number 92
# call successful!
# making call for chunk number 93
# call successful!
# making call for chunk number 94
# call successful!
# making call for chunk number 95
# call successful!
# making call for chunk number 96
# call successful!
# making call for chunk number 97
# call successful!
# making call for chunk number 98
# call successful!
# making call for chunk number 99
# call successful!
# making call for chunk number 100
# call successful!
# making call for chunk number 101
# call successful!
# making call for chunk number 102
# call successful!
# making call for chunk number 103
# call successful!
# making call for chunk number 104
# call successful!
# making call for chunk number 105
# call successful!
# making call for chunk number 106
# call successful!
# making call for chunk number 107
# call successful!
# making call for chunk number 108
# call successful!
# making call for chunk number 109
# call successful!
# making call for chunk number 110
# call successful!
# making call for chunk number 111
# call successful!
# making call for chunk number 112
# call successful!
# making call for chunk number 113
# call successful!
# making call for chunk number 114
# call successful!
# making call for chunk number 115
# call successful!
# making call for chunk number 116
# call successful!
# making call for chunk number 117
# call successful!
# making call for chunk number 118
# call successful!
# making call for chunk number 119
# call successful!
# making call for chunk number 120
# call successful!
# making call for chunk number 121
# call successful!
# making call for chunk number 122
# call successful!
# making call for chunk number 123
# call successful!
# making call for chunk number 124
# call successful!
# making call for chunk number 125
# call successful!
# making call for chunk number 126
# call successful!
# making call for chunk number 127
# call successful!
# making call for chunk number 128
# call successful!
# making call for chunk number 129
# call successful!
# making call for chunk number 130
# call successful!
# making call for chunk number 131
# call successful!
# making call for chunk number 132
# call successful!
# making call for chunk number 133
# call successful!
# making call for chunk number 134
# call successful!
# making call for chunk number 135
# call successful!
# making call for chunk number 136
# call successful!
# making call for chunk number 137
# call successful!
# making call for chunk number 138
# call successful!
# making call for chunk number 139
# call successful!
# making call for chunk number 140
# call successful!
# making call for chunk number 141
# call successful!
# making call for chunk number 142
# call successful!
# making call for chunk number 143
# call successful!
# making call for chunk number 144
# call successful!
# making call for chunk number 145
# call successful!
# making call for chunk number 146
# call successful!
# making call for chunk number 147
# call successful!
# making call for chunk number 148
# call successful!
# making call for chunk number 149
# call successful!
# making call for chunk number 150
# call successful!
# making call for chunk number 151
# call successful!
# making call for chunk number 152
# call successful!
# making call for chunk number 153
# call successful!
# making call for chunk number 154
# call successful!
# making call for chunk number 155
# call successful!
# making call for chunk number 156
# call successful!
# making call for chunk number 157
# call successful!
# making call for chunk number 158
# call successful!
# making call for chunk number 159
# call successful!
# making call for chunk number 160
# call successful!
# making call for chunk number 161
# call successful!
# making call for chunk number 162
# call successful!
# making call for chunk number 163
# call successful!
# making call for chunk number 164
# call successful!
# making call for chunk number 165
# call successful!
# making call for chunk number 166
# call successful!
# making call for chunk number 167
# call successful!
# making call for chunk number 168
# call successful!
# making call for chunk number 169
# call successful!
# making call for chunk number 170
# call successful!
# making call for chunk number 171
# call successful!
# making call for chunk number 172
# call successful!
# making call for chunk number 173
# call successful!
# making call for chunk number 174
# call successful!
# making call for chunk number 175
# call successful!
# making call for chunk number 176
# call successful!
# making call for chunk number 177
# call successful!
# making call for chunk number 178
# call successful!
# making call for chunk number 179
# call successful!
# making call for chunk number 180
# call successful!
# making call for chunk number 181
# call successful!
# making call for chunk number 182
# call successful!
# making call for chunk number 183
# call successful!
# making call for chunk number 184
# call successful!
# making call for chunk number 185
# call successful!
# making call for chunk number 186
# call successful!
# making call for chunk number 187
# call successful!
# making call for chunk number 188
# call successful!
# making call for chunk number 189
# call successful!
# making call for chunk number 190
# call successful!
# making call for chunk number 191
# call successful!
# making call for chunk number 192
# call successful!
# making call for chunk number 193
# call successful!
# making call for chunk number 194
# call successful!
# making call for chunk number 195
# call successful!
# making call for chunk number 196
# call successful!
# making call for chunk number 197
# call successful!
# making call for chunk number 198
# call successful!
# making call for chunk number 199
# call successful!
# making call for chunk number 200
# call successful!
# making call for chunk number 201
# call successful!
# making call for chunk number 202
# call successful!
# making call for chunk number 203
# call successful!
# making call for chunk number 204
# call successful!
# making call for chunk number 205
# call successful!
# making call for chunk number 206
# call successful!
# making call for chunk number 207
# call successful!
# making call for chunk number 208
# call successful!
# making call for chunk number 209
# call successful!
# making call for chunk number 210
# call successful!
# making call for chunk number 211
# call successful!
# making call for chunk number 212
# call successful!
# making call for chunk number 213
# call successful!
# making call for chunk number 214
# call successful!
# making call for chunk number 215
# call successful!
# making call for chunk number 216
# call successful!
# making call for chunk number 217
# call successful!
# making call for chunk number 218
# call successful!
# making call for chunk number 219
# call successful!
# making call for chunk number 220
# call successful!
# making call for chunk number 221
# call successful!
# making call for chunk number 222
# call successful!
# making call for chunk number 223
# call successful!
# making call for chunk number 224
# call successful!
# making call for chunk number 225
# call successful!
# making call for chunk number 226
# call successful!
# making call for chunk number 227
# call successful!
# making call for chunk number 228
# call successful!
# making call for chunk number 229
# call successful!
# making call for chunk number 230
# call successful!
# making call for chunk number 231
# call successful!
# making call for chunk number 232
# call successful!
# making call for chunk number 233
# call successful!
# making call for chunk number 234
# call successful!
# making call for chunk number 235
# call successful!
# making call for chunk number 236
# call successful!
# making call for chunk number 237
# call successful!
# making call for chunk number 238
# call successful!
# making call for chunk number 239
# call successful!
# making call for chunk number 240
# call successful!
# making call for chunk number 241
# call successful!
# making call for chunk number 242
# call successful!
# making call for chunk number 243
# call successful!
# making call for chunk number 244
# call successful!
# making call for chunk number 245
# call successful!
# making call for chunk number 246
# call successful!
# making call for chunk number 247
# call successful!
# making call for chunk number 248
# call successful!
# making call for chunk number 249
# call successful!
# making call for chunk number 250
# call successful!
# making call for chunk number 251
# call successful!
# making call for chunk number 252
# call successful!
# making call for chunk number 253
# call successful!
# making call for chunk number 254
# call successful!
# making call for chunk number 255
# call successful!
# making call for chunk number 256
# call successful!
# making call for chunk number 257
# call successful!
# making call for chunk number 258
# call successful!
# making call for chunk number 259
# call successful!
# making call for chunk number 260
# call successful!
# making call for chunk number 261
# call successful!
# making call for chunk number 262
# call successful!
# making call for chunk number 263
# call successful!
# making call for chunk number 264
# call successful!
# making call for chunk number 265
# call successful!
# making call for chunk number 266
# call successful!
# making call for chunk number 267
# call successful!
# making call for chunk number 268
# call successful!
# making call for chunk number 269
# call successful!

# %%
# Export to Excel

df_game_full_info.to_excel('data/output/df_game_full_info_2014_20241127.xlsx', index=False)

# %%
# Option: Read df_game_full_info from excel file
# df_game_full_info = pd.read_excel('data/output/df_game_full_info_2014_20241127.xlsx')

# %% [markdown]
# # Task Adhoc - Assign revenue multiplier to app_id

# %%
# Top-down file processing

# %%
df_store_account_data_top_down_manual_cleaning = pd.read_csv('data/input/store_account_data_top_down_manual_cleaning.csv')

# %%
lod_store_account_data_top_down_manual_cleaning = df_store_account_data_top_down_manual_cleaning.to_dict(orient='records')

# %%
ios_app_id_list_store_account_top_down_manual_cleaning = list(map(lambda x: x['app_id_trimmed'], list(filter(lambda x: x['os'] == 'ios', lod_store_account_data_top_down_manual_cleaning))))
android_app_id_list_store_account_top_down_manual_cleaning = list(map(lambda x: x['app_id_trimmed'], list(filter(lambda x: x['os'] == 'android', lod_store_account_data_top_down_manual_cleaning))))

# %%
ios_app_info_list_store_account_top_down_manual_cleaning = get_local_app_info(api_key, base_url, "ios", ios_app_id_list_store_account_top_down_manual_cleaning )
android_app_info_list_store_account_top_down_manual_cleaning = get_local_app_info(api_key, base_url, "android", android_app_id_list_store_account_top_down_manual_cleaning)
# Out:
# making call for chunk number 1
# call successful!
# making call for chunk number 2
# call successful!
# making call for chunk number 3
# call successful!
# making call for chunk number 1
# call successful!
# making call for chunk number 2
# call successful!
# making call for chunk number 3
# call successful!

# %%
df_all_app_info_store_account_top_down_manual_cleaning = pd.concat(
    [
        pd.DataFrame(ios_app_info_list_store_account_top_down_manual_cleaning),
        pd.DataFrame(android_app_info_list_store_account_top_down_manual_cleaning)
    ],
    ignore_index=True
)

# %%
df_all_app_info_store_account_top_down_manual_cleaning['app_id'] = df_all_app_info_store_account_top_down_manual_cleaning['app_id'].astype(str)

# %%
df_store_account_data_top_down = pd.merge(
    df_store_account_data_top_down_manual_cleaning,
    df_all_app_info_store_account_top_down_manual_cleaning,
    left_on = "app_id_trimmed",
    right_on = "app_id",
    how = "left"
)[['os_x', 'cleaned_publisher_name', 'game_name', 'sensor_tower_link', 'app_id_trimmed', 'publisher_id', 'publisher_name']]

# %%
df_store_account_data_top_down.to_excel('data/output/df_store_account_data_top_down.xlsx')

# %%
# Bottom-up file processing

# %%
data_types = {
    "cleaned_publisher_name": "string",
    "publisher_id": "string",
    "publisher_name": "string",
    "revenue_multiplier": "int64"
}

# %%
df_revenue_multiplier = pd.read_csv(
    "data/input/revenue_multiplier_bottom_up.csv",
    dtype = data_types
)

# %%
# Get cleaned_publisher_name : revenue_multiplier mapping

# %%
df_mapping_cleaned_publisher_name_to_revenue_multiplier = df_revenue_multiplier[['cleaned_publisher_name', 'revenue_multiplier']].drop_duplicates().reset_index(drop = True)

# %%
# Create the df_revenue_multiplier_top_down_cleaning

# %%
df_revenue_multiplier_top_down_cleaning = pd.merge(
    df_store_account_data_top_down,
    df_mapping_cleaned_publisher_name_to_revenue_multiplier,
    on = 'cleaned_publisher_name',
    how = 'left'
)[['cleaned_publisher_name', 'publisher_id', 'publisher_name', 'revenue_multiplier']].drop_duplicates()

# %%
# Concatenate 2 revenue_multiplier tables together (one top down and the other bottom up)

# %%
df_revenue_multiplier_full = pd.concat(
    [df_revenue_multiplier, df_revenue_multiplier_top_down_cleaning]
).drop_duplicates().reset_index(drop=True)

# %%
df_revenue_multiplier_full.to_csv('data/output/df_revenue_multiplier_full.csv', index=False)

# %%
# Get the mapping table publisher_id - cleaned_publisher_name

# %%
dict_publisher_id_cleaned_publisher_name = dict()

for index, row in df_revenue_multiplier_full.iterrows():
    dict_publisher_id_cleaned_publisher_name[str(row['publisher_id'])] = row['cleaned_publisher_name']

# %%
# Get the mapping table publisher_id - multiplier

# %%
dict_publisher_id_revenue_multiplier = dict()

for index, row in df_revenue_multiplier_full.iterrows():
    dict_publisher_id_revenue_multiplier[str(row['publisher_id'])] = row['revenue_multiplier']

# %%
# Keep only the publisher ids having multiplier > 1

dict_publisher_id_revenue_multiplier = {str(key): value for key, value in dict_publisher_id_revenue_multiplier.items() if value > 1}

# %% [markdown]
# # Task ID-000-001

# %%
# Get all the app_id and their respective publisher_id

# %%
# Read the excel data file that has been created and exported using workbook "load_game_characteristics"

df_game_full_info = pd.read_excel("data/output/df_game_full_info_2014_20241127.xlsx")

# %%
list_of_dicts_game_app_list = []

for index,row in df_game_full_info.iterrows():
    list_of_dicts_game_app_list.append(
        {
            'unified_app_id': row['unified_app_id'],
            'itunes_apps': ast.literal_eval(str(row['itunes_apps'])),
            'android_apps': ast.literal_eval(str(row['android_apps'])),
            'itunes_publisher_ids': ast.literal_eval(str(row['itunes_publisher_ids'])),
            'android_publisher_ids': ast.literal_eval(str(row['android_publisher_ids'])),
        }
    )

# %%
all_app_ids = get_app_id_lists(list_of_dicts_game_app_list)

# %%
ios_app_id_list = list(map(lambda x: x['app_id'], list(filter(lambda x: x['os'] == 'ios', all_app_ids))))

# %%
android_app_id_list = list(map(lambda x: x['app_id'], list(filter(lambda x: x['os'] == 'android', all_app_ids))))

# %%
print("Getting iOS apps info...")
ios_app_info_list = get_local_app_info(api_key, base_url, "ios", ios_app_id_list)

print("Getting Android apps info...")
android_app_info_list = get_local_app_info(api_key, base_url, "android", android_app_id_list)
# Out:
# Getting iOS apps info...
# making call for chunk number 1
# call successful!
# making call for chunk number 2
# call successful!
# making call for chunk number 3
# call successful!
# making call for chunk number 4
# call successful!
# making call for chunk number 5
# call successful!
# making call for chunk number 6
# call successful!
# making call for chunk number 7
# call successful!
# making call for chunk number 8
# call successful!
# making call for chunk number 9
# call successful!
# making call for chunk number 10
# call successful!
# making call for chunk number 11
# call successful!
# making call for chunk number 12
# call successful!
# making call for chunk number 13
# call successful!
# making call for chunk number 14
# call successful!
# making call for chunk number 15
# call successful!
# making call for chunk number 16
# call successful!
# making call for chunk number 17
# call successful!
# making call for chunk number 18
# call successful!
# making call for chunk number 19
# call successful!
# making call for chunk number 20
# call successful!
# making call for chunk number 21
# call successful!
# making call for chunk number 22
# call successful!
# making call for chunk number 23
# call successful!
# making call for chunk number 24
# call successful!
# making call for chunk number 25
# call successful!
# making call for chunk number 26
# call successful!
# making call for chunk number 27
# call successful!
# making call for chunk number 28
# call successful!
# making call for chunk number 29
# call successful!
# making call for chunk number 30
# call successful!
# making call for chunk number 31
# call successful!
# making call for chunk number 32
# call successful!
# making call for chunk number 33
# call successful!
# making call for chunk number 34
# call successful!
# making call for chunk number 35
# call successful!
# making call for chunk number 36
# call successful!
# making call for chunk number 37
# call successful!
# making call for chunk number 38
# call successful!
# making call for chunk number 39
# call successful!
# making call for chunk number 40
# call successful!
# making call for chunk number 41
# call successful!
# making call for chunk number 42
# call successful!
# making call for chunk number 43
# call successful!
# making call for chunk number 44
# call successful!
# making call for chunk number 45
# call successful!
# making call for chunk number 46
# call successful!
# making call for chunk number 47
# call successful!
# making call for chunk number 48
# call successful!
# making call for chunk number 49
# call successful!
# making call for chunk number 50
# call successful!
# making call for chunk number 51
# call successful!
# making call for chunk number 52
# call successful!
# making call for chunk number 53
# call successful!
# making call for chunk number 54
# call successful!
# making call for chunk number 55
# call successful!
# making call for chunk number 56
# call successful!
# making call for chunk number 57
# call successful!
# making call for chunk number 58
# call successful!
# making call for chunk number 59
# call successful!
# making call for chunk number 60
# call successful!
# making call for chunk number 61
# call successful!
# making call for chunk number 62
# call successful!
# making call for chunk number 63
# call successful!
# making call for chunk number 64
# call successful!
# making call for chunk number 65
# call successful!
# making call for chunk number 66
# call successful!
# making call for chunk number 67
# call successful!
# making call for chunk number 68
# call successful!
# making call for chunk number 69
# call successful!
# making call for chunk number 70
# call successful!
# making call for chunk number 71
# call successful!
# making call for chunk number 72
# call successful!
# making call for chunk number 73
# call successful!
# making call for chunk number 74
# call successful!
# making call for chunk number 75
# call successful!
# making call for chunk number 76
# call successful!
# making call for chunk number 77
# call successful!
# making call for chunk number 78
# call successful!
# making call for chunk number 79
# call successful!
# making call for chunk number 80
# call successful!
# making call for chunk number 81
# call successful!
# making call for chunk number 82
# call successful!
# making call for chunk number 83
# call successful!
# making call for chunk number 84
# call successful!
# making call for chunk number 85
# call successful!
# making call for chunk number 86
# call successful!
# making call for chunk number 87
# call successful!
# making call for chunk number 88
# call successful!
# making call for chunk number 89
# call successful!
# making call for chunk number 90
# call successful!
# making call for chunk number 91
# call successful!
# making call for chunk number 92
# call successful!
# making call for chunk number 93
# call successful!
# making call for chunk number 94
# call successful!
# making call for chunk number 95
# call successful!
# making call for chunk number 96
# call successful!
# making call for chunk number 97
# call successful!
# making call for chunk number 98
# call successful!
# making call for chunk number 99
# call successful!
# making call for chunk number 100
# call successful!
# making call for chunk number 101
# call successful!
# making call for chunk number 102
# call successful!
# making call for chunk number 103
# call successful!
# making call for chunk number 104
# call successful!
# making call for chunk number 105
# call successful!
# making call for chunk number 106
# call successful!
# making call for chunk number 107
# call successful!
# making call for chunk number 108
# call successful!
# making call for chunk number 109
# call successful!
# making call for chunk number 110
# call successful!
# making call for chunk number 111
# call successful!
# making call for chunk number 112
# call successful!
# making call for chunk number 113
# call successful!
# making call for chunk number 114
# call successful!
# making call for chunk number 115
# call successful!
# making call for chunk number 116
# call successful!
# making call for chunk number 117
# call successful!
# making call for chunk number 118
# call successful!
# making call for chunk number 119
# call successful!
# making call for chunk number 120
# call successful!
# making call for chunk number 121
# call successful!
# making call for chunk number 122
# call successful!
# making call for chunk number 123
# call successful!
# making call for chunk number 124
# call successful!
# making call for chunk number 125
# call successful!
# making call for chunk number 126
# call successful!
# making call for chunk number 127
# call successful!
# making call for chunk number 128
# call successful!
# making call for chunk number 129
# call successful!
# making call for chunk number 130
# call successful!
# making call for chunk number 131
# call successful!
# making call for chunk number 132
# call successful!
# making call for chunk number 133
# call successful!
# making call for chunk number 134
# call successful!
# making call for chunk number 135
# call successful!
# making call for chunk number 136
# call successful!
# making call for chunk number 137
# call successful!
# making call for chunk number 138
# call successful!
# making call for chunk number 139
# call successful!
# making call for chunk number 140
# call successful!
# making call for chunk number 141
# call successful!
# making call for chunk number 142
# call successful!
# making call for chunk number 143
# call successful!
# making call for chunk number 144
# call successful!
# making call for chunk number 145
# call successful!
# making call for chunk number 146
# call successful!
# making call for chunk number 147
# call successful!
# making call for chunk number 148
# call successful!
# making call for chunk number 149
# call successful!
# making call for chunk number 150
# call successful!
# making call for chunk number 151
# call successful!
# making call for chunk number 152
# call successful!
# making call for chunk number 153
# call successful!
# making call for chunk number 154
# call successful!
# making call for chunk number 155
# call successful!
# making call for chunk number 156
# call successful!
# making call for chunk number 157
# call successful!
# making call for chunk number 158
# call successful!
# making call for chunk number 159
# call successful!
# making call for chunk number 160
# call successful!
# making call for chunk number 161
# call successful!
# making call for chunk number 162
# call successful!
# making call for chunk number 163
# call successful!
# making call for chunk number 164
# call successful!
# making call for chunk number 165
# call successful!
# making call for chunk number 166
# call successful!
# making call for chunk number 167
# call successful!
# making call for chunk number 168
# call successful!
# making call for chunk number 169
# call successful!
# making call for chunk number 170
# call successful!
# making call for chunk number 171
# call successful!
# making call for chunk number 172
# call successful!
# making call for chunk number 173
# call successful!
# making call for chunk number 174
# call successful!
# making call for chunk number 175
# call successful!
# making call for chunk number 176
# call successful!
# making call for chunk number 177
# call successful!
# making call for chunk number 178
# call successful!
# making call for chunk number 179
# call successful!
# making call for chunk number 180
# call successful!
# making call for chunk number 181
# call successful!
# making call for chunk number 182
# call successful!
# making call for chunk number 183
# call successful!
# making call for chunk number 184
# call successful!
# making call for chunk number 185
# call successful!
# making call for chunk number 186
# call successful!
# making call for chunk number 187
# call successful!
# making call for chunk number 188
# call successful!
# making call for chunk number 189
# call successful!
# making call for chunk number 190
# call successful!
# making call for chunk number 191
# call successful!
# making call for chunk number 192
# call successful!
# making call for chunk number 193
# call successful!
# making call for chunk number 194
# call successful!
# making call for chunk number 195
# call successful!
# making call for chunk number 196
# call successful!
# making call for chunk number 197
# call successful!
# making call for chunk number 198
# call successful!
# making call for chunk number 199
# call successful!
# making call for chunk number 200
# call successful!
# making call for chunk number 201
# call successful!
# making call for chunk number 202
# call successful!
# making call for chunk number 203
# call successful!
# making call for chunk number 204
# call successful!
# making call for chunk number 205
# call successful!
# making call for chunk number 206
# call successful!
# making call for chunk number 207
# call successful!
# making call for chunk number 208
# call successful!
# making call for chunk number 209
# call successful!
# making call for chunk number 210
# call successful!
# making call for chunk number 211
# call successful!
# making call for chunk number 212
# call successful!
# making call for chunk number 213
# call successful!
# making call for chunk number 214
# call successful!
# making call for chunk number 215
# call successful!
# making call for chunk number 216
# call successful!
# making call for chunk number 217
# call successful!
# making call for chunk number 218
# call successful!
# making call for chunk number 219
# call successful!
# making call for chunk number 220
# call successful!
# making call for chunk number 221
# call successful!
# making call for chunk number 222
# call successful!
# making call for chunk number 223
# call successful!
# making call for chunk number 224
# call successful!
# making call for chunk number 225
# call successful!
# making call for chunk number 226
# call successful!
# making call for chunk number 227
# call successful!
# making call for chunk number 228
# call successful!
# making call for chunk number 229
# call successful!
# making call for chunk number 230
# call successful!
# making call for chunk number 231
# call successful!
# making call for chunk number 232
# call successful!
# making call for chunk number 233
# call successful!
# making call for chunk number 234
# call successful!
# making call for chunk number 235
# call successful!
# making call for chunk number 236
# call successful!
# making call for chunk number 237
# call successful!
# making call for chunk number 238
# call successful!
# making call for chunk number 239
# call successful!
# making call for chunk number 240
# call successful!
# making call for chunk number 241
# call successful!
# making call for chunk number 242
# call successful!
# making call for chunk number 243
# call successful!
# making call for chunk number 244
# call successful!
# making call for chunk number 245
# call successful!
# making call for chunk number 246
# call successful!
# making call for chunk number 247
# call successful!
# making call for chunk number 248
# call successful!
# making call for chunk number 249
# call successful!
# making call for chunk number 250
# call successful!
# making call for chunk number 251
# call successful!
# making call for chunk number 252
# call successful!
# making call for chunk number 253
# call successful!
# making call for chunk number 254
# call successful!
# making call for chunk number 255
# call successful!
# making call for chunk number 256
# call successful!
# making call for chunk number 257
# call successful!
# making call for chunk number 258
# call successful!
# making call for chunk number 259
# call successful!
# making call for chunk number 260
# call successful!
# making call for chunk number 261
# call successful!
# making call for chunk number 262
# call successful!
# making call for chunk number 263
# call successful!
# making call for chunk number 264
# call successful!
# making call for chunk number 265
# call successful!
# making call for chunk number 266
# call successful!
# making call for chunk number 267
# call successful!
# making call for chunk number 268
# call successful!
# making call for chunk number 269
# call successful!
# making call for chunk number 270
# call successful!
# making call for chunk number 271
# call successful!
# making call for chunk number 272
# call successful!
# making call for chunk number 273
# call successful!
# making call for chunk number 274
# call successful!
# making call for chunk number 275
# call successful!
# making call for chunk number 276
# call successful!
# making call for chunk number 277
# call successful!
# making call for chunk number 278
# call successful!
# making call for chunk number 279
# call successful!
# making call for chunk number 280
# call successful!
# making call for chunk number 281
# call successful!
# making call for chunk number 282
# call successful!
# making call for chunk number 283
# call successful!
# making call for chunk number 284
# call successful!
# making call for chunk number 285
# call successful!
# making call for chunk number 286
# call successful!
# making call for chunk number 287
# call successful!
# Getting Android apps info...
# making call for chunk number 1
# call successful!
# making call for chunk number 2
# call successful!
# making call for chunk number 3
# call successful!
# making call for chunk number 4
# call successful!
# making call for chunk number 5
# call successful!
# making call for chunk number 6
# call successful!
# making call for chunk number 7
# call successful!
# making call for chunk number 8
# call successful!
# making call for chunk number 9
# call successful!
# making call for chunk number 10
# call successful!
# making call for chunk number 11
# call successful!
# making call for chunk number 12
# call successful!
# making call for chunk number 13
# call successful!
# making call for chunk number 14
# call successful!
# making call for chunk number 15
# call successful!
# making call for chunk number 16
# call successful!
# making call for chunk number 17
# call successful!
# making call for chunk number 18
# call successful!
# making call for chunk number 19
# call successful!
# making call for chunk number 20
# call successful!
# making call for chunk number 21
# call successful!
# making call for chunk number 22
# call successful!
# making call for chunk number 23
# call successful!
# making call for chunk number 24
# call successful!
# making call for chunk number 25
# call successful!
# making call for chunk number 26
# call successful!
# making call for chunk number 27
# call successful!
# making call for chunk number 28
# call successful!
# making call for chunk number 29
# call successful!
# making call for chunk number 30
# call successful!
# making call for chunk number 31
# call successful!
# making call for chunk number 32
# call successful!
# making call for chunk number 33
# call successful!
# making call for chunk number 34
# call successful!
# making call for chunk number 35
# call successful!
# making call for chunk number 36
# call successful!
# making call for chunk number 37
# call successful!
# making call for chunk number 38
# call successful!
# making call for chunk number 39
# call successful!
# making call for chunk number 40
# call successful!
# making call for chunk number 41
# call successful!
# making call for chunk number 42
# call successful!
# making call for chunk number 43
# call successful!
# making call for chunk number 44
# call successful!
# making call for chunk number 45
# call successful!
# making call for chunk number 46
# call successful!
# making call for chunk number 47
# call successful!
# making call for chunk number 48
# call successful!
# making call for chunk number 49
# call successful!
# making call for chunk number 50
# call successful!
# making call for chunk number 51
# call successful!
# making call for chunk number 52
# call successful!
# making call for chunk number 53
# call successful!
# making call for chunk number 54
# call successful!
# making call for chunk number 55
# call successful!
# making call for chunk number 56
# call successful!
# making call for chunk number 57
# call successful!
# making call for chunk number 58
# call successful!
# making call for chunk number 59
# call successful!
# making call for chunk number 60
# call successful!
# making call for chunk number 61
# call successful!
# making call for chunk number 62
# call successful!
# making call for chunk number 63
# call successful!
# making call for chunk number 64
# call successful!
# making call for chunk number 65
# call successful!
# making call for chunk number 66
# call successful!
# making call for chunk number 67
# call successful!
# making call for chunk number 68
# call successful!
# making call for chunk number 69
# call successful!
# making call for chunk number 70
# call successful!
# making call for chunk number 71
# call successful!
# making call for chunk number 72
# call successful!
# making call for chunk number 73
# call successful!
# making call for chunk number 74
# call successful!
# making call for chunk number 75
# call successful!
# making call for chunk number 76
# call successful!
# making call for chunk number 77
# call successful!
# making call for chunk number 78
# call successful!
# making call for chunk number 79
# call successful!
# making call for chunk number 80
# call successful!
# making call for chunk number 81
# call successful!
# making call for chunk number 82
# call successful!
# making call for chunk number 83
# call successful!
# making call for chunk number 84
# call successful!
# making call for chunk number 85
# call successful!
# making call for chunk number 86
# call successful!
# making call for chunk number 87
# call successful!
# making call for chunk number 88
# call successful!
# making call for chunk number 89
# call successful!
# making call for chunk number 90
# call successful!
# making call for chunk number 91
# call successful!
# making call for chunk number 92
# call successful!
# making call for chunk number 93
# call successful!
# making call for chunk number 94
# call successful!
# making call for chunk number 95
# call successful!
# making call for chunk number 96
# call successful!
# making call for chunk number 97
# call successful!
# making call for chunk number 98
# call successful!
# making call for chunk number 99
# call successful!
# making call for chunk number 100
# call successful!
# making call for chunk number 101
# call successful!
# making call for chunk number 102
# call successful!
# making call for chunk number 103
# call successful!
# making call for chunk number 104
# call successful!
# making call for chunk number 105
# call successful!
# making call for chunk number 106
# call successful!
# making call for chunk number 107
# call successful!
# making call for chunk number 108
# call successful!
# making call for chunk number 109
# call successful!
# making call for chunk number 110
# call successful!
# making call for chunk number 111
# call successful!
# making call for chunk number 112
# call successful!
# making call for chunk number 113
# call successful!
# making call for chunk number 114
# call successful!
# making call for chunk number 115
# call successful!
# making call for chunk number 116
# call successful!
# making call for chunk number 117
# call successful!
# making call for chunk number 118
# call successful!
# making call for chunk number 119
# call successful!
# making call for chunk number 120
# call successful!
# making call for chunk number 121
# call successful!
# making call for chunk number 122
# call successful!
# making call for chunk number 123
# call successful!
# making call for chunk number 124
# call successful!
# making call for chunk number 125
# call successful!
# making call for chunk number 126
# call successful!
# making call for chunk number 127
# call successful!
# making call for chunk number 128
# call successful!
# making call for chunk number 129
# call successful!
# making call for chunk number 130
# call successful!
# making call for chunk number 131
# call successful!
# making call for chunk number 132
# call successful!
# making call for chunk number 133
# call successful!
# making call for chunk number 134
# call successful!
# making call for chunk number 135
# call successful!
# making call for chunk number 136
# call successful!
# making call for chunk number 137
# call successful!
# making call for chunk number 138
# call successful!
# making call for chunk number 139
# call successful!
# making call for chunk number 140
# call successful!
# making call for chunk number 141
# call successful!
# making call for chunk number 142
# call successful!
# making call for chunk number 143
# call successful!
# making call for chunk number 144
# call successful!
# making call for chunk number 145
# call successful!
# making call for chunk number 146
# call successful!
# making call for chunk number 147
# call successful!
# making call for chunk number 148
# call successful!
# making call for chunk number 149
# call successful!
# making call for chunk number 150
# call successful!
# making call for chunk number 151
# call successful!
# making call for chunk number 152
# call successful!
# making call for chunk number 153
# call successful!
# making call for chunk number 154
# call successful!
# making call for chunk number 155
# call successful!
# making call for chunk number 156
# call successful!
# making call for chunk number 157
# call successful!
# making call for chunk number 158
# call successful!
# making call for chunk number 159
# call successful!
# making call for chunk number 160
# call successful!
# making call for chunk number 161
# call successful!
# making call for chunk number 162
# call successful!
# making call for chunk number 163
# call successful!
# making call for chunk number 164
# call successful!
# making call for chunk number 165
# call successful!
# making call for chunk number 166
# call successful!
# making call for chunk number 167
# call successful!
# making call for chunk number 168
# call successful!
# making call for chunk number 169
# call successful!
# making call for chunk number 170
# call successful!
# making call for chunk number 171
# call successful!
# making call for chunk number 172
# call successful!
# making call for chunk number 173
# call successful!
# making call for chunk number 174
# call successful!
# making call for chunk number 175
# call successful!
# making call for chunk number 176
# call successful!
# making call for chunk number 177
# call successful!
# making call for chunk number 178
# call successful!
# making call for chunk number 179
# call successful!
# making call for chunk number 180
# call successful!
# making call for chunk number 181
# call successful!
# making call for chunk number 182
# call successful!
# making call for chunk number 183
# call successful!
# making call for chunk number 184
# call successful!
# making call for chunk number 185
# call successful!
# making call for chunk number 186
# call successful!
# making call for chunk number 187
# call successful!
# making call for chunk number 188
# call successful!
# making call for chunk number 189
# call successful!
# making call for chunk number 190
# call successful!
# making call for chunk number 191
# call successful!
# making call for chunk number 192
# call successful!
# making call for chunk number 193
# call successful!
# making call for chunk number 194
# call successful!
# making call for chunk number 195
# call successful!
# making call for chunk number 196
# call successful!
# making call for chunk number 197
# call successful!
# making call for chunk number 198
# call successful!
# making call for chunk number 199
# call successful!
# making call for chunk number 200
# call successful!
# making call for chunk number 201
# call successful!
# making call for chunk number 202
# call successful!
# making call for chunk number 203
# call successful!
# making call for chunk number 204
# call successful!
# making call for chunk number 205
# call successful!
# making call for chunk number 206
# call successful!
# making call for chunk number 207
# call successful!
# making call for chunk number 208
# call successful!
# making call for chunk number 209
# call successful!
# making call for chunk number 210
# call successful!
# making call for chunk number 211
# call successful!
# making call for chunk number 212
# call successful!
# making call for chunk number 213
# call successful!
# making call for chunk number 214
# call successful!
# making call for chunk number 215
# call successful!
# making call for chunk number 216
# call successful!
# making call for chunk number 217
# call successful!
# making call for chunk number 218
# call successful!
# making call for chunk number 219
# call successful!
# making call for chunk number 220
# call successful!
# making call for chunk number 221
# call successful!
# making call for chunk number 222
# call successful!
# making call for chunk number 223
# call successful!
# making call for chunk number 224
# call successful!
# making call for chunk number 225
# call successful!
# making call for chunk number 226
# call successful!
# making call for chunk number 227
# call successful!
# making call for chunk number 228
# call successful!
# making call for chunk number 229
# call successful!
# making call for chunk number 230
# call successful!
# making call for chunk number 231
# call successful!
# making call for chunk number 232
# call successful!
# making call for chunk number 233
# call successful!
# making call for chunk number 234
# call successful!
# making call for chunk number 235
# call successful!
# making call for chunk number 236
# call successful!
# making call for chunk number 237
# call successful!
# making call for chunk number 238
# call successful!
# making call for chunk number 239
# call successful!
# making call for chunk number 240
# call successful!
# making call for chunk number 241
# call successful!
# making call for chunk number 242
# call successful!
# making call for chunk number 243
# call successful!
# making call for chunk number 244
# call successful!
# making call for chunk number 245
# call successful!
# making call for chunk number 246
# call successful!
# making call for chunk number 247
# call successful!
# making call for chunk number 248
# call successful!
# making call for chunk number 249
# call successful!
# making call for chunk number 250
# call successful!
# making call for chunk number 251
# call successful!
# making call for chunk number 252
# call successful!
# making call for chunk number 253
# call successful!
# making call for chunk number 254
# call successful!
# making call for chunk number 255
# call successful!
# making call for chunk number 256
# call successful!
# making call for chunk number 257
# call successful!

# %%
df_ios_app_info_list = pd.DataFrame(ios_app_info_list)
df_android_app_info_list = pd.DataFrame(android_app_info_list)

# %%
df_all_app_info_list = pd.concat(
    [df_ios_app_info_list, df_android_app_info_list],
    ignore_index=True
)

# %%
# Add column cleaned_publisher_name to df_all_app_info_list

# %%
def cast_cleaned_publisher_name(row):
    if str(row['publisher_id']) in dict_publisher_id_cleaned_publisher_name.keys():
        return dict_publisher_id_cleaned_publisher_name[str(row['publisher_id'])]
    else:
        return ""

# %%
df_all_app_info_list['cleaned_publisher_name'] = df_all_app_info_list.apply(cast_cleaned_publisher_name, axis=1)

# %%
# Add column revenue_multiplier to df_all_app_info_list

# %%
# Modify ZingPlay apps' revenue multiplier to 20
# Source: https://docs.google.com/spreadsheets/d/1YeWQ3gbehiLV5pr9PxFHbR4gXNNU9cqtYGqjgx_M95Q/edit?gid=1409559985#gid=1409559985
zingplay_app_ids = ['1528287521', '799319182', '887752917', '904890205', '908617867', '894956701', '853000739', '445297616', '6477903252', '1277551859', 'gsn.game.zingplaynew', 'com.gsn.zps.full', 'gsn.game.zingplaytala', 'gsn.game.zingplaynew3', 'gsn.game.talanew3', 'gsn.game.talanew', 'gsn.game.zingplaynew1', 'gsn.game.zingplaynew2', 'gsn.game.tienlenNew', 'gsn.game.capsaSusun', 'gsn.game.tienlennew', 'gsn.game.binhnew', 'gsn.zingplay.cotuong', 'gsn.zingplay.cotuong.zoom', 'chess.gsn.portalnew', 'com.gsn.zpb', 'com.zps.ctp2', 'gsn.zps.ccn']
zingplay_multiplier = 20

# %%
def cast_revenue_multiplier(row):
    if str(row['publisher_id']) in dict_publisher_id_revenue_multiplier.keys():
        if str(row['app_id']) in zingplay_app_ids:
            return zingplay_multiplier
        else:
            return dict_publisher_id_revenue_multiplier[str(row['publisher_id'])]
    else:
        return 1

# %%
df_all_app_info_list['revenue_multiplier'] = df_all_app_info_list.apply(cast_revenue_multiplier, axis=1)

# %%
# This version contains revenue multiplier for each app
df_all_app_info_list.to_csv('data/output/df_all_app_info_list.csv', index = False)

# %%
# Read df_all_app_info_list from csv
# df_all_app_info_list = pd.read_csv('data/output/df_all_app_info_list.csv')
# Out:
# /var/folders/6w/zwls9wgj6r56601508fjs1rm0000gn/T/ipykernel_55207/4230308040.py:2: DtypeWarning: Columns (0,4,25,26,27,34,35,36,39,40,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_all_app_info_list = pd.read_csv('data/output/df_all_app_info_list.csv')

# %%
# Get the list of app ids whose revenue_multiplier > 1 (requiring revenue adjustment)

# %%
list_app_ids_requiring_revenue_adjustment = list(
    map(
        lambda x: str(x),
        list(
            df_all_app_info_list[
              df_all_app_info_list['revenue_multiplier'] > 1  
            ]['app_id']
        )
    )
)

# %%
# Get the list of unified_app_ids of these app_ids

# %%
list_unified_ids_requiring_revenue_adjustment = list(
    df_all_app_info_list[
       df_all_app_info_list['app_id'].astype(str).isin(list_app_ids_requiring_revenue_adjustment) 
    ]['unified_app_id'].drop_duplicates()
)

# %%
# Get the full list of app_ids requiring individual app performance data query

# %%
df_app_info_requiring_app_performance_data_query = df_all_app_info_list[
    df_all_app_info_list['unified_app_id'].isin(list_unified_ids_requiring_revenue_adjustment)
]

# %%
## get the ios app_ids

# %%
list_app_ids_requiring_app_performance_data_query_ios = list(
    map(lambda x: str(x),
        list(
                df_app_info_requiring_app_performance_data_query[
                    df_app_info_requiring_app_performance_data_query['os'] == 'ios'
                ]['app_id']
            )
        )
    )

# %%
## get the android app_ids

# %%
list_app_ids_requiring_app_performance_data_query_android = list(
    map(lambda x: str(x),
        list(
                df_app_info_requiring_app_performance_data_query[
                    df_app_info_requiring_app_performance_data_query['os'] == 'android'
                ]['app_id']
            )
        )
    )

# %%
# Query the app performance data (performance piece - each in a period, for an app)

# %%
## query for ios apps

# %%
app_performance_data_ios = get_apps_performance(
    api_key, 
    base_url, 
    os = 'ios', 
    app_ids = list_app_ids_requiring_app_performance_data_query_ios, 
    country_code = 'VN', 
    granularity = 'quarterly', 
    max_periods = 1000, 
    start_date = '2014-01-01', 
    end_date = '2024-11-28'
)
# Out:
# Date ranges: [('2014-01-01', '2024-12-31')]
# Requesting Data for Range: 2014-01-01 to 2024-12-31
# making call for chunk number 1
# Data retrieved for 2014-01-01 to 2024-12-31
# making call for chunk number 2
# Data retrieved for 2014-01-01 to 2024-12-31
# making call for chunk number 3
# Data retrieved for 2014-01-01 to 2024-12-31
# making call for chunk number 4
# Data retrieved for 2014-01-01 to 2024-12-31
# making call for chunk number 5
# Data retrieved for 2014-01-01 to 2024-12-31
# making call for chunk number 6
# Data retrieved for 2014-01-01 to 2024-12-31
# making call for chunk number 7
# Data retrieved for 2014-01-01 to 2024-12-31
# making call for chunk number 8
# Data retrieved for 2014-01-01 to 2024-12-31

# %%
## query for android apps

# %%
app_performance_data_android = get_apps_performance(
    api_key, 
    base_url, 
    os = 'android', 
    app_ids = list_app_ids_requiring_app_performance_data_query_android, 
    country_code = 'VN', 
    granularity = 'quarterly', 
    max_periods = 1000, 
    start_date = '2014-01-01', 
    end_date = '2024-11-28'
)
# Out:
# Date ranges: [('2014-01-01', '2024-12-31')]
# Requesting Data for Range: 2014-01-01 to 2024-12-31
# making call for chunk number 1
# Data retrieved for 2014-01-01 to 2024-12-31
# making call for chunk number 2
# Data retrieved for 2014-01-01 to 2024-12-31
# making call for chunk number 3
# Data retrieved for 2014-01-01 to 2024-12-31
# making call for chunk number 4
# Data retrieved for 2014-01-01 to 2024-12-31
# making call for chunk number 5
# Data retrieved for 2014-01-01 to 2024-12-31
# making call for chunk number 6
# Data retrieved for 2014-01-01 to 2024-12-31
# making call for chunk number 7
# Data retrieved for 2014-01-01 to 2024-12-31
# making call for chunk number 8
# Data retrieved for 2014-01-01 to 2024-12-31

# %%
## join the 2 lists of performance data together

# %%
app_performance_data = app_performance_data_ios + app_performance_data_android

# %%
### Save to JSON file
with open('data/output/app_performance_data.json', 'w', encoding='utf-8') as file:
    json.dump(app_performance_data, file, ensure_ascii=False, indent=4)  # `ensure_ascii=False` keeps non-ASCII characters readable

# %%
# Optional Read app_performance_data from json file
with open('data/output/app_performance_data.json', 'r') as file:
    app_performance_data = json.load(file)

# %%
# Order the performance pieces into app performance data

# %%
## Create a list of dictionaries in the format [{'app_id', 'os', 'app_performance':[...]}] for iOS apps

# %%
app_performance_data_grouped_by_app_ios = []

for app_id in list_app_ids_requiring_app_performance_data_query_ios:
    app_performance_data_grouped_by_app_ios.append(
        {
            'app_id': app_id,
            'os': 'ios',
            'unified_app_id': list(
                df_all_app_info_list[
                    df_all_app_info_list['app_id'].astype(str) == str(app_id)
                ]['unified_app_id']
            )[0],
            'app_performance': sorted(
                list(
                    filter(
                        lambda x: str(x['aid']) == app_id,
                        app_performance_data
                    )
                ),
                key = lambda x: x['d']
            )
        }
    )

# %%
## Create a list of dictionaries in the format [{'app_id', 'os', 'app_performance':[...]}] for Android apps

# %%
app_performance_data_grouped_by_app_android = []

for app_id in list_app_ids_requiring_app_performance_data_query_android:
    app_performance_data_grouped_by_app_android.append(
        {
            'app_id': app_id,
            'os': 'android',
            'unified_app_id': list(
                df_all_app_info_list[
                    df_all_app_info_list['app_id'].astype(str) == str(app_id)
                ]['unified_app_id']
            )[0],
            'app_performance': sorted(
                list(
                    filter(
                        lambda x: str(x['aid']) == app_id,
                        app_performance_data
                    )
                ),
                key = lambda x: x['d']
            )
        }
    )

# %%
## Combine the 2 lists

# %%
app_performance_data_grouped_by_app = app_performance_data_grouped_by_app_ios + app_performance_data_grouped_by_app_android

# %%
### Save to JSON file
with open('data/output/app_performance_data_grouped_by_app.json', 'w', encoding='utf-8') as file:
    json.dump(app_performance_data_grouped_by_app, file, ensure_ascii=False, indent=4)  # `ensure_ascii=False` keeps non-ASCII characters readable

# %%
# Order the app performance data into game performance data

# %%
## Create list of dictionaries of performance per game that requires revenue adjustment

# %%
game_performance_data_for_games_requiring_revenue_adjustment = []

for unified_app_id in list_unified_ids_requiring_revenue_adjustment:
    game_performance_data_for_games_requiring_revenue_adjustment.append(
        {
            'unified_app_id': unified_app_id,
            'performance_streams': list(
                filter(
                    lambda x: x['unified_app_id'] == unified_app_id,
                    app_performance_data_grouped_by_app
                )
            )
        }
    )

# %%
### Save to JSON file
with open('data/output/game_performance_data_for_games_requiring_revenue_adjustment.json', 'w', encoding='utf-8') as file:
    json.dump(game_performance_data_for_games_requiring_revenue_adjustment, file, ensure_ascii=False, indent=4)  # `ensure_ascii=False` keeps non-ASCII characters readable

# %%
# Create the performance dataframe for each game

# %%
performance_df_for_games_requiring_revenue_adjustment = []

for game in game_performance_data_for_games_requiring_revenue_adjustment:
    performance_df_for_games_requiring_revenue_adjustment.append(
        {
            'unified_app_id': game['unified_app_id'],
            'performance_df': generate_performance_streams_df(game['performance_streams'])
        }
    )

# %%
# Calculate the full adjusted revenue of each game

# %%
yearly_sum_performance_df_for_games_requiring_revenue_adjustment = []

for game in performance_df_for_games_requiring_revenue_adjustment:
    yearly_sum_performance_df_for_games_requiring_revenue_adjustment.append(
        {
            'unified_app_id': game['unified_app_id'],
            'yearly_sum_performance_series': get_adjusted_yearly_revenue(game['performance_df'], df_all_app_info_list)
        }
    )

# %%
# test_df = list(
#     filter(
#         lambda x: x['unified_app_id'] == '61a54e681800977bed4c561d',
#         performance_df_for_games_requiring_revenue_adjustment
#     )
# )[0]['performance_df']

# %%
# list(
#     filter(
#         lambda x: x['unified_app_id'] == '61a54e681800977bed4c561d',
#         yearly_sum_performance_df_for_games_requiring_revenue_adjustment
#     )
# )[0]

# %%
# Reconcile adjusted yearly revenue of games requiring 
# so with full revenue table

# %%
## Get the full table

# %%
df_game_revenue = transform_raw_revenue_dataframe(raw_game_data_df)

# %%
## Replace revenue of games requiring adjustment

# %%
df_game_revenue_adjusted = adjust_revenue_df(
    df_game_revenue,
    yearly_sum_performance_df_for_games_requiring_revenue_adjustment
)

# %%
## Adjust 2024 data (simple adjustment)

# %%
# Convert end date to datetime
end_date = pd.to_datetime(f"2024-11-27")

# Get the start date for the year 2024
start_date = pd.to_datetime(f"2024-01-01")

# Calculate the number of days from Jan 1, 2024 to the given end date
days_in_data_period = (end_date - start_date).days + 1  # Including the end date

# Total number of days in the year 2024 (leap year)
total_days_in_2024 = 366

# Calculate the annualization factor
annualization_factor = total_days_in_2024 / days_in_data_period

# %%
df_game_revenue_adjusted[2024] = df_game_revenue_adjusted[2024]*annualization_factor

# %%
df_game_revenue_adjusted.to_csv('data/output/df_game_revenue_adjusted.csv')

# %% [markdown]
# # Task: get the list of games requiring genre data cleaning

# %%
unified_ids_requiring_genre_cleaning = get_unified_ids_contributing_x_pct_revenue_each_year(
    df_game_revenue_adjusted,
    0.8
)

# %%
len(unified_ids_requiring_genre_cleaning['all_year'])
# Out:
# 242

# %%
df_game_requiring_genre_cleaning = df_game_full_info[
    df_game_full_info['unified_app_id'].isin(unified_ids_requiring_genre_cleaning['all_year'])
]

# %%
df_game_requiring_genre_cleaning
# Out:
#                  unified_app_id       canonical_app_id  \
# 9      55c5013e02ac64f9c0001f1c              399648212
# 527    55d93e8f02ac645ad210a5fd              726652663
# 666    5d5609e88125b80b6f4a2657  com.qjzj4399kr.google
# 807    5570f7715a3b416e6a000261    com.Wooriline.Samco
# 863    5b220c230e64c70b3e4d02d4             1273957743
# ...                         ...                    ...
# 26459  5d09e4b03ea9836770c1cf5a             1449688300
# 26469  5e8d8cbef228a334d5f1beb6          com.pg1.tghmm
# 26587  63e5633fded9c9175b7fca1e             1523037824
# 26606  55c502b302ac64f9c0001fdb              370339723
# 26784  63578bb99d838447746c5887     com.redriver.shjjc
#
#                                    name                        cohort_id  \
# 9                       Smurfs' Village                              NaN
# 527                                攻城掠地                              NaN
# 666                               기적의 검  cohort_62e2628e57f50091935e13ea
# 807    Ongame Sám cô - Xì tố Poker 7 lá                              NaN
# 863               EA SPORTS FC Online M  cohort_63f9137057f50059c45d8836
# ...                                 ...                              ...
# 26459                         一拳超人：最强之男  cohort_66bb1b1b6ea867b3916d3046
# 26469                 Perfect World VNG                              NaN
# 26587                           崩坏：星穹铁道  cohort_64c3de7157f5008915f0f927
# 26606     Texas Hold'em Poker: Pokerist  cohort_9a33a3b1ac4b6dacb25a080b
# 26784                       IDLE GOG VN                              NaN
#
#                                              itunes_apps  \
# 9      [{'app_id': 399648212}, {'app_id': 904062466},...
# 527    [{'app_id': 726652663}, {'app_id': 1104208930}...
# 666    [{'app_id': 1499305228}, {'app_id': 1442478849...
# 807                              [{'app_id': 590218388}]
# 863    [{'app_id': 1273957743}, {'app_id': 1387396500...
# ...                                                  ...
# 26459  [{'app_id': 1449688300}, {'app_id': 1478096431...
# 26469                           [{'app_id': 1480667271}]
# 26587  [{'app_id': 1523037824}, {'app_id': 1599719154...
# 26606  [{'app_id': 370339723}, {'app_id': 397553707},...
# 26784                           [{'app_id': 6443444765}]
#
#                                             android_apps  \
# 9      [{'app_id': 'com.capcom.smurfsandroid'}, {'app...
# 527    [{'app_id': 'com.ujoy.gcldxmnew'}, {'app_id': ...
# 666    [{'app_id': 'com.qjzj4399kr.google'}, {'app_id...
# 807                  [{'app_id': 'com.Wooriline.Samco'}]
# 863    [{'app_id': 'com.nexon.fo4m'}, {'app_id': 'com...
# ...                                                  ...
# 26459  [{'app_id': 'com.onepunchman.ggplay.tw'}, {'ap...
# 26469                      [{'app_id': 'com.pg1.tghmm'}]
# 26587  [{'app_id': 'com.HoYoverse.hkrpgoversea'}, {'a...
# 26606  [{'app_id': 'com.kamagames.pokerist'}, {'app_i...
# 26784                 [{'app_id': 'com.redriver.shjjc'}]
#
#                                    unified_publisher_ids  \
# 9      ['560c7a668ac350643902e31a', '665722b2f85b7766...
# 527    ['5615384d3f07e25d29036c05', '561dbb363f07e2c9...
# 666    ['55f894148ac350426b03b9ce', '62c7caa5b9e7d979...
# 807    ['55f892128ac350426b0315ea', '5fe24494ef618870...
# 863    ['5614b2f53f07e2077c000059', '56180ad702ac645b...
# ...                                                  ...
# 26459  ['562890fe02ac648b2800231f', '592882fdacd63e66...
# 26469                       ['562890fe02ac648b2800231f']
# 26587  ['57ef5b4f0211a6aed3000136', '65260c523590e869...
# 26606  ['55fb04018ac350da40030f05', '5840c2760211a64f...
# 26784  ['5bc8740ca2750e2e014a1c19', '61176426ca971556...
#
#                                     itunes_publisher_ids  \
# 9                                [1748851750, 441481846]
# 527    [820040969, 832223463, 1104208929, 1441093238,...
# 666      [1442187340, 1631320611, 1435995183, 797345902]
# 807                                          [568271609]
# 863       [1047094789, 523546006, 1096472396, 446324237]
# ...                                                  ...
# 26459  [999708042, 1444994195, 886118053, 910435102, ...
# 26469                                        [717106260]
# 26587               [1599719156, 1467190250, 1698469667]
# 26606                                        [312479206]
# 26784                                       [1438383758]
#
#                                    android_publisher_ids          game_class  \
# 9      ['Garden+City+Games', 'Beeline+Interactive+Jap...  Lifestyle & Puzzle
# 527    ['YUTE+Chen', 'UJOY+INTERACTIVE+ENTERTAINMENT'...   Action & Strategy
# 666    ['4399+KOREA', '4399+Games', 'SPOTLIGHT+NETWOR...   Action & Strategy
# 807                                    ['Onsmart+Games']              Casino
# 863    ['Garena+Mobile+Private', 'NEXON+Company', 'Go...     Sports & Racing
# ...                                                  ...                 ...
# 26459  ['FingerFun+Limited.', 'VNG+Corporation', 'Moo...   Action & Strategy
# 26469                         ['VNGGames+International']   Action & Strategy
# 26587  ['COGNOSPHERE+PTE.+LTD.', '3T+Online+Entertain...   Action & Strategy
# 26606                        ['KamaGames', 'Mild+Right']              Casino
# 26784  ['Công+ty+cổ+phần+phát+triển+công+nghệ+số+Hồng...   Action & Strategy
#
#        ... game_product_model game_ip_corporate_parent game_ip_operator  \
# 9      ...             Casual        Independent Brand             Peyo
# 527    ...           Mid-core                      NaN              NaN
# 666    ...           Mid-core                      NaN              NaN
# 807    ...             Casual                      NaN              NaN
# 863    ...           Mid-core                      NaN              NaN
# ...    ...                ...                      ...              ...
# 26459  ...           Mid-core       Hitotsubashi Group         Shueisha
# 26469  ...           Mid-core                      NaN              NaN
# 26587  ...           Mid-core                      NaN              NaN
# 26606  ...             Casual                      NaN              NaN
# 26784  ...           Mid-core                      NaN              NaN
#
#       game_ip_media_type game_licensed_ip game_earliest_release_date  \
# 9                 Comics       The Smurfs                 2010/11/07
# 527                  NaN              NaN                 2014/03/15
# 666                  NaN              NaN                 2019/09/08
# 807                  NaN              NaN                 2012/12/24
# 863                  NaN              NaN                 2018/07/25
# ...                  ...              ...                        ...
# 26459      Anime / Manga    One-Punch Man                 2019/06/19
# 26469                NaN              NaN                 2019/07/25
# 26587                NaN              NaN                 2023/04/22
# 26606                NaN              NaN                 2010/05/29
# 26784                NaN              NaN                 2022/10/28
#
#       game_release_date_ww game_release_date_us game_release_date_jp  \
# 9               2010/11/11           2010/11/11           2010/11/11
# 527                    NaN                  NaN                  NaN
# 666             2019/09/08           2019/09/08           2019/09/08
# 807             2012/12/24           2012/12/24           2012/12/24
# 863                    NaN                  NaN                  NaN
# ...                    ...                  ...                  ...
# 26459                  NaN                  NaN                  NaN
# 26469                  NaN                  NaN                  NaN
# 26587                  NaN                  NaN                  NaN
# 26606           2010/05/29           2010/05/29           2010/05/29
# 26784                  NaN                  NaN                  NaN
#
#       game_release_date_cn
# 9               2010/11/11
# 527             2014/03/15
# 666             2019/09/08
# 807             2020/12/24
# 863                    NaN
# ...                    ...
# 26459           2019/06/19
# 26469                  NaN
# 26587           2023/04/22
# 26606           2010/05/29
# 26784                  NaN
#
# [242 rows x 26 columns]

# %%
df_game_requiring_genre_cleaning.to_excel('data/output/df_game_requiring_genre_cleaning_80.xlsx', index = False)

# %% [markdown]
# # Task: ChatGPT to clean genre data

# %%
# Prepare input data for all entries

# %% [markdown]
# Required fields
# - game info: unified id
# - game info: name
# - app_info: short_description
# - app info: description
# - app info: subtitle
# - app info: promo_text
# - game info: class
# - game info: genre
# - game info: subgenre

# %%
df_game_requiring_genre_cleaning_90_pct = pd.read_excel('data/output/df_game_requiring_genre_cleaning_85.xlsx')

# %%
input_data_for_gpt_genre_cleaning = []

for index, row in df_game_requiring_genre_cleaning_90_pct.iterrows():
    new_data = {
        'game_id': row['unified_app_id'],
        'game_name': row['name'],
        'game_class': row['game_class'],
        'game_genre': row['game_genre'],
        'game_subgenre': row['game_subgenre'],
        'individual_app_info': df_all_app_info_list[
            df_all_app_info_list['unified_app_id'] == row['unified_app_id']
        ][
            ['app_id', 'name', 'short_description', 'description', 'subtitle', 'promo_text']
        ].to_dict(orient='records')
    }
    input_data_for_gpt_genre_cleaning.append(new_data)

# %%
with open('data/output/input_data_for_gpt_genre_cleaning_85.json', 'w', encoding='utf-8') as file:
    json.dump(input_data_for_gpt_genre_cleaning, file, ensure_ascii=False, indent=4)  # `ensure_ascii=False` keeps non-ASCII characters readable

# %%
# Prepare ST Classification JSON

# %%
## Example output 

# st_game_taxonomy = [
#     {
#         'game_class': 'Action & Strategy',
#         'definition': 'Action & Strategy class is a collection of genres which appeal to a more dedicated gaming audience. They typically require a significant time investment by the player and have complex mechanics.',
#         'genres': [
#             {
#                 'game_genre': 'Action',
#                 'definition': 'Action games test the player\'s reflexes and timing through physical challenges, often through fighting. Players must complete levels by maintaining forward momentum, usually requiring defeating enemies without losing health, or completing objectives.'
#                 'subgenres': [
#                     {
#                         'game_subgenre': 'Action Sandbox',
#                         'definition': 'Action games where the player explores and engages in combat in an open world without defined goals or rules. Examples: Grand Theft Auto: San Andreas, Gangstar Vegas - Mafia action, Bully: Anniversary Edition'
#                     },
#                     {
#                         'game_subgenre': 'Asymmetric Battle',
#                         'definition': 'Action games where players compete under different win conditions. In most cases, teams do not have the same number of players, and one team must survive while the other team tries to win via elimination. Examples: Identity V, , Dead by Daylight Mobile, , Mimicry: Online Horror Action'       
#                     },
#                     ...
#                 ]
#             },
#             {
#                 'game_genre': 'RPG',
#                 'definition': 'RPG mobile games usually follow the common elements of RPG games in other mediums: character levelling/customization, a combat system, and an emphasis on story-telling.',
#                 'subgenres': [
#                     ...
#                 ]
#             },...
#         ]
#     },
#     {
#         'game_class': 'Casino',
#         'definition': 'The Casino class is comprised of casino games of all kinds. Casino games attempt to replicate the success of real-life casinos with a focus on gambling mechanics and traditional tabletop gameplay, and rewarding players on a consistent basis. Casino games may allow players to earn or bet real-world currency, but more commonly retain player spend as in-game currency.',
#         'genres': [
#             ...
#         ]
#     }
# ]

# %%
# Specify the path to your file
file_path = 'data/input/st_game_taxonomy.xlsx'

# Process the file
taxonomy_structure = process_game_taxonomy(file_path)

# %%
taxonomy_structure
# Out:
# [{'game_class': 'Action & Strategy',
#   'definition': 'Action & Strategy class is a collection of genres which appeal to a more dedicated gaming audience. They typically require a significant time investment by the player and have complex mechanics.',
#   'genres': [{'game_genre': 'Action',
#     'definition': "Action games test the player's reflexes and timing through physical challenges, often through fighting. Players must complete levels by maintaining forward momentum, usually requiring defeating enemies without losing health, or completing objectives.",
#     'subgenres': [{'game_subgenre': 'Action Sandbox',
#       'definition': 'Action games where the player explores and engages in combat in an open world without defined goals or rules. Examples: Grand Theft Auto: San Andreas, Gangstar Vegas - Mafia action, Bully: Anniversary Edition'},
#      {'game_subgenre': 'Asymmetric Battle',
#       'definition': 'Action games where players compete under different win conditions. In most cases, teams do not have the same number of players, and one team must survive while the other team tries to win via elimination. Examples: Identity V, , Dead by Daylight Mobile, , Mimicry: Online Horror Action'},
#      {'game_subgenre': "Beat 'em Up",
#       'definition': 'Action games based on classic 2D side scrolling fighting games. Examples: The King of Fighters ALLSTAR, Date A Live: Spirit Pledge, Bangbang Rabbit!'},
#      {'game_subgenre': 'Fighting',
#       'definition': 'Action games where the player fights other players in one-on-one combat. Examples: Mortal Combat, Brawlhalla, Dragon Ball Legends'},
#      {'game_subgenre': 'Hack and Slash',
#       'definition': 'Action games with a focus on chaining combos against waves of AI enemies. Examples: Honkai Impact 3rd, Disney Mirrorverse, Dynasty Legends：Warriors Unite'},
#      {'game_subgenre': "Shoot 'em Up",
#       'definition': "Action games based on classic 2D shoot 'em up games, where the player shoots waves of enemies. Examples: Archero, Galaxy Attack: Alien Shooter, Azur Lane"}]},
#    {'game_genre': 'RPG',
#     'definition': 'RPG mobile games usually follow the common elements of RPG games in other mediums: character levelling/customization, a combat system, and an emphasis on story-telling.',
#     'subgenres': [{'game_subgenre': 'Action RPG',
#       'definition': 'Role-playing games where the player resolves combat in real-time, with an active control scheme on screen to control a character. Examples: MARVEL Future Revolution, MHA: The Strongest Hero, Stranger Things: 1984'},
#      {'game_subgenre': 'Idle RPG',
#       'definition': 'Role-playing games focused on idle mechanics, where the player makes progress even while not actively playing the game. Examples: Hero Wars - Fantasy idle RPG, Idle Heroes - Idle Games, Ulala: Idle Adventure'},
#      {'game_subgenre': 'MMORPG',
#       'definition': 'Role-playing games with a persistent online multiplayer world, where the player can see other players in the same game map. Examples: MU ORIGIN 3, Ragnarok Origin, Lineage2M'},
#      {'game_subgenre': 'Open World Adventure',
#       'definition': 'RPG games with an open world map, where the player engages in a non-linear adventure and makes progress through quests and exploration. Examples: Genshin Impact, Sky: Children of the Light, Tower of Fantasy'},
#      {'game_subgenre': 'Puzzle RPG',
#       'definition': 'Role-playing games where combat is resolved through puzzle-solving. Examples: Empires & Puzzles: Match-3 RPG, DRAGON BALL Z DOKKAN BATTLE, Puzzle & Dragons'},
#      {'game_subgenre': 'Squad RPG',
#       'definition': 'Role-playing games that challenge the player to create a synergistic team of characters which engage in turn-based combat. The player can manually play the combat but auto-battle mode is present and encouraged. Examples: Summoners War, RAID: Shadow Legends, Dislyte'},
#      {'game_subgenre': 'Survival',
#       'definition': 'Role-playing games that challenge the player to survive in a hostile environment. Examples: LifeAfter, Last Day on Earth: Survival, ARK: Survival Evolved'},
#      {'game_subgenre': 'Turn-based RPG',
#       'definition': 'Role-playing games with turn-based combat, allowing players to think before they act. Examples: Fate/Grand Order, Evertale, Knighthood'}]},
#    {'game_genre': 'Shooter',
#     'definition': 'Shooter games use guns or other long-range weapons as a primary mechanic. Typically, players are challenged on their reflexes and spatial awareness to fight computer AI or other players.',
#     'subgenres': [{'game_subgenre': 'Battle Royale',
#       'definition': 'Shooter games where the player is dropped unequipped onto a large map, and is challenged to be the last person alive. Examples: PUBG MOBILE, Garena Free Fire, Apex Legends Mobile'},
#      {'game_subgenre': 'FPS / 3PS',
#       'definition': 'Shooter games in first or third person perspective, where the player shoots real or AI enemies. Examples: Call of Duty®: Mobile, Pixel Gun 3D: Online Shooter, Critical Ops: Online PvP FPS'},
#      {'game_subgenre': 'Sniper',
#       'definition': 'Shooter games where the player is challenged to aim and shoot at a distant enemy with a sniper rifle. Examples: Sniper 3D: Gun Shooting Games, Sniper Arena: PvP Army Shooter, Sniper Strike: Shooting Games'},
#      {'game_subgenre': 'Vehicular Shooter',
#       'definition': 'Shooter games where the player controls a large vehicle instead of a character. Examples: War Robots Multiplayer Battles, World of Tanks Blitz - 3D War, War Machines：Tanks Battle Game'}]},
#    {'game_genre': 'Strategy',
#     'definition': "Strategy games rely on the player's decision-making skills to make strategic choices. Typically, games are slower paced and more mechanically complex than other mobile genres.",
#     'subgenres': [{'game_subgenre': '4X Strategy',
#       'definition': 'Strategy games where the player controls a growing civilization that improves over time, making progress by moving troops in an over-world. Examples: Rise of Kingdoms, Lords Mobile: Tower Defense, Kingdom Maker'},
#      {'game_subgenre': 'Build & Battle',
#       'definition': "Strategy games where the player creates, improves, and defends a base. Combat resolves asynchronously in real-time against other players' bases. Examples: Clash of Clans, Boom Beach, Castle Clash: World Ruler"},
#      {'game_subgenre': 'Card Battler',
#       'definition': "Strategy games that replicate real-life trading/collectible card games, where the player creates a deck of cards with unique properties to battle against other players' decks. Examples: Hearthstone, Magic: The Gathering Arena, Yu-Gi-Oh! Duel Links"},
#      {'game_subgenre': 'Empire Simulation',
#       'definition': "Strategy games with a focus on narrative and character relationships, where the player role-plays a powerful character like a king, emperor or CEO. Examples: King's Choice, Game of Sultans - Royal Pets, King's Throne"},
#      {'game_subgenre': 'MOBA',
#       'definition': 'Strategy games where the player controls one character in a team of heroes, who fight and complete objectives against other teams of players. Examples: Mobile Legends: Bang Bang, League of Legends: Wild Rift, Pokémon UNITE'},
#      {'game_subgenre': 'Other Strategy',
#       'definition': 'Strategy games that do not fit in other Strategy sub-genres. Examples: First Strike, Rebel Inc, Escapists 2: Pocket Breakout'},
#      {'game_subgenre': 'Real-Time Strategy',
#       'definition': 'Strategy games with synchronous real-time combat, where the player summons units on a battlefield. Examples: Clash Royale, The Battle Cats, Art of War: Legions'},
#      {'game_subgenre': 'Tower Defense',
#       'definition': 'Strategy games where the player defends a base against waves of enemies on a defined path by building towers or creating units. Examples: Kingdom Guard:Tower Defense TD, Rush Royale: Tower Defense TD, Bloons TD 6'},
#      {'game_subgenre': 'Turn-Based Tactics',
#       'definition': 'Strategy games where players have to make tactical decisions in turns for combat. They are typically focused on specific battles, with management of individual units, rather than an overarching conflict. Examples: Tank Stars, Clash Quest, Phobies'}]}]},
#  {'game_class': 'Casino',
#   'definition': 'The Casino class is comprised of casino games of all kinds. Casino games attempt to replicate the success of real-life casinos with a focus on gambling mechanics and traditional tabletop gameplay, and rewarding players on a consistent basis. Casino games may allow players to earn or bet real-world currency, but more commonly retain player spend as in-game currency.',
#   'genres': [{'game_genre': 'Casino',
#     'definition': 'The casino genre is based on real-life casino games (slots, bingo, poker, etc.), often involving some form of gambling and real-money investment.',
#     'subgenres': [{'game_subgenre': 'Bingo',
#       'definition': 'Casino games based on real-life Bingo, where players fill out a grid of numbers. Examples: Bingo Blitz™ - BINGO games, Bingo Party - Slots Bingo Game, Bingo Bash'},
#      {'game_subgenre': 'Casino Cards',
#       'definition': 'Casino games that offer cards or other tabletop games with gambling elements not classfied by our taxonomy like for example Bellotte, Blackjack and others. Examples: Blackjack, Tiến Lên - Tien Len, Gin Rummy Stars - Card Game'},
#      {'game_subgenre': 'Coin Looters',
#       'definition': 'Casino games with a random-based mechanic at the center of the game experience, that are casualized with meta features such as base building and decoration. These games usually have an art style that appeals to casual audiences. Examples: MONOPOLY GO!, Coin Master, Dice Dreams™'},
#      {'game_subgenre': 'Coin Pusher',
#       'definition': 'Casino games that mimic real life Coin Pusher machine, where players drop coins in order to push more coins, medals or other prizes off the edge to win. Examples: Coin Dozer - Carnival Prizes, Coin Dozer: Casino, Coin Mania: Farm Dozer'},
#      {'game_subgenre': 'Fish Shooting',
#       'definition': 'Casino games where Players use in-game currency to buy ammunitions and shoot fish with others. The more fish you can shoot the more currency you win. Examples: 捕鱼大作战-欢乐真人千炮捕鱼游戏王者，柳岩推荐, 途游休闲捕鱼-次世代千炮3D捕鱼游戏, 捕鱼大咖-畅爽3D街机捕鱼游戏'},
#      {'game_subgenre': 'Mahjong',
#       'definition': 'Casino games featuring Chinese Mahjong, where players aim to win by forming combinations of tiles based on various rules and conditions. Examples: 腾讯欢乐麻将全集, 雀魂 -じゃんたま-, 麻將 神來也麻將－台灣16張、麻雀'},
#      {'game_subgenre': 'Other Casino',
#       'definition': 'Casino games that do not fit into other Casino sub-genres. Examples: Coin Dozer: Sweepstakes, Blitz - Win Cash, Pocket7Games: Win Cash'},
#      {'game_subgenre': 'Poker',
#       'definition': "Casino games with a focus on Poker and its variations such as Omaha, Hi-Lo and others. Examples: WSOP Poker: Texas Holdem Game, Zynga Poker ™ - Texas Hold'em, Governor of Poker 3 - Texas"},
#      {'game_subgenre': 'Slots',
#       'definition': 'Casino games based on real-life slot machines. Examples: DoubleDown™ Casino -Slots Game, Jackpot Party - Casino Slots, Slotomania™ Slots Vegas Casino'},
#      {'game_subgenre': 'Teen Patti',
#       'definition': 'Casino games with a focus on the Indian card game Teen Patti and its variations. Examples: Teen Patti Go, Teen Patti Crown'},
#      {'game_subgenre': 'Virtual Casino',
#       'definition': 'Casino games that mimic the experience of an actual real life casino with a wide variety of games (Slots, Roulettes, Blackjack, Craps,...) Examples: FanDuel Casino - Real Money, DraftKings Casino - Real Money, Betway – Casino Games'}]}]},
#  {'game_class': 'Lifestyle & Puzzle',
#   'definition': 'Lifestyle & Puzzle class is a collection of genres that appeal to a mass market with simple gameplay mechanics. These games typically have easy controls and short play sessions.',
#   'genres': [{'game_genre': 'Arcade',
#     'definition': 'Originating from the arcade games of the 80s, the mobile arcade genre is largely comprised of action-oriented games, often featuring high scores and simple controls with sparse story elements.',
#     'subgenres': [{'game_subgenre': 'Arcade Combat',
#       'definition': 'Arcade games where the player battles enemies with various weapons and tools. Examples: Stickman Ragdoll Fighter: Bash, Merge Archers: Bow and Arrow, Draw Joust!'},
#      {'game_subgenre': 'Arcade Driving',
#       'definition': 'Arcade games where the player drives vehicles without real simulation mechanics. Examples: Bike Race: Free Style Games, Rocket League Sideswipe, Drive Ahead!'},
#      {'game_subgenre': 'Music / Rhythm',
#       'definition': "Arcade games that challenge the player’s sense of rhythm by pressing buttons in time with music. Examples: Just Dance Now, Rhythm Realms: Funkin' RPG, Magic Tiles 3: Piano Game"},
#      {'game_subgenre': 'Other Arcade',
#       'definition': 'Arcade games that do not fit into other Arcade sub-genres. Examples: PunBall, World Flipper, Fruit Ninja'},
#      {'game_subgenre': 'Pinball / Brick Breaker',
#       'definition': 'Arcade games that challenge players to adjust the angle and trajectory of a bouncing ball off a paddle and find the optimal path to hit the targets or bricks. Examples: PunBall, Bricks n Balls, Pinball - Smash Arcade'},
#      {'game_subgenre': 'Platformer / Runner',
#       'definition': 'Arcade games that challenge the player to run and/or jump across platforms, avoiding obstacles and collecting items. Examples: Subway Surfers, Geometry Dash Lite, Temple Run 2'},
#      {'game_subgenre': 'Social Party',
#       'definition': 'Arcade games that facilitate participation in real-world activities within a social group. Examples: Among Us!, Picolo Party Game, Suspects: Mystery Mansion'}]},
#    {'game_genre': 'Geolocation',
#     'definition': 'Games that generate unique gameplay and content based on user location. Players can typically experience augmented reality events or in-game encounters by exploring various real-world locations. These games are typically built in the style of Ingress and Pokemon Go.',
#     'subgenres': [{'game_subgenre': 'Geolocation',
#       'definition': 'Geolocation games where the player physically moves to different real world locations to interact with the game. Examples: Pokémon GO, Jurassic World Alive, Pikmin Bloom'}]},
#    {'game_genre': 'Lifestyle',
#     'definition': 'Lifestyle games allow players to participate in light-hearted life experiences, such as decorating, taking care of animals, or directing an emotional story. The appeal of these games is often in role-playing scenarios. These games are often played by a casual and more female audience.',
#     'subgenres': [{'game_subgenre': 'Customization',
#       'definition': "Lifestyle games where the player's main input is to decorate or customize their desired home, garden, or character. Examples: Toca Life World: Build Stories, Design Home: Dream Makeover, Covet Fashion: Model Makeover"},
#      {'game_subgenre': 'Interactive Story',
#       'definition': "Lifestyle games with a focus on stories and narrative content, where the player's main input is to choose between multiple dialogue options. Examples: Chapters: Interactive Stories, Episode - Choose your Story, Choices: Stories you Play"},
#      {'game_subgenre': 'Virtual Pet',
#       'definition': 'Lifestyle games where the player interacts with a virtual pet or friend. Examples: My Talking Tom 2, My Tamagotchi Forever, My Talking Angela'}]},
#    {'game_genre': 'Puzzle',
#     'definition': 'Puzzle games challenge players to use logical thinking to succeed, ranging from traditional puzzles to more unique concepts that originated on mobile. Mechanics could include symbol matching, word finding, or spatial reasoning.',
#     'subgenres': [{'game_subgenre': 'Bubble Shooter',
#       'definition': 'Puzzle games where the player matches bubbles by shooting them from the bottom of the screen. Examples: Bubble Witch 3 Saga, LINE バブル2, Bubble Shooter - Panda Pop!'},
#      {'game_subgenre': 'Environmental',
#       'definition': "Puzzle games where players are presented with a series of challenges that require them to navigate the environment, and solve puzzles by exploring and manipulating objects in a given environment. Examples: Monument Valley, Five Nights at Freddy's, Puzzle Adventure: Mystery Tale"},
#      {'game_subgenre': 'Hidden Objects',
#       'definition': "Puzzle games that challenge the player to identify a list of items hiding in an environment. Examples: Seekers Notes: Hidden Objects, June's Journey: Hidden Objects, Mystery manor: Hidden Objects"},
#      {'game_subgenre': 'Jigsaw',
#       'definition': 'Puzzle games where players recreate an image by arranging and fitting together small, interlocking puzzle pieces. Examples: Jigsaw Puzzles for Adults HD, Magic Jigsaw Puzzles－Games HD, Puzzle Villa: Art Jigsaw games'},
#      {'game_subgenre': 'Match Blast',
#       'definition': 'Puzzle games where players "blasts" tiles by tapping on matching colors. Examples: Toon Blast, Lily’s Garden: Design & Match, Property Brothers Home Design'},
#      {'game_subgenre': 'Match Chain',
#       'definition': 'Puzzle games where players create chains of matching pieces to remove them from the board. Examples: LINE: Disney Tsum Tsum, Two Dots: Brain Puzzle Games, Collect Em All! Clear the Dots'},
#      {'game_subgenre': 'Match Merge 2',
#       'definition': 'Puzzle games where the main feature involves combining identical pairs of items to form stronger units or items. Examples: Merge Mansion, Gossip Harbor®: Merge & Story, Travel Town - Merge Adventure'},
#      {'game_subgenre': 'Match Merge 3',
#       'definition': "Puzzle games where the primary mechanic is matching and merging 3 identical items to create more powerful units or items. Examples: Merge Dragons!, EverMerge: Match 3 Puzzle Game, Alice's Dream ： Merge Games"},
#      {'game_subgenre': 'Match Pair',
#       'definition': 'Puzzle games where players tap groups of two or more identical pieces or tiles in order to remove them from the board. Examples: Triple Match 3D, Match 3D, Zen Match - Relaxing Puzzle'},
#      {'game_subgenre': 'Match Swap',
#       'definition': 'Puzzle games where players swap adjacent pieces to create a match of two or more identical pieces. Examples: Candy Crush Saga, Royal Match, Gardenscapes'},
#      {'game_subgenre': 'Other Puzzle',
#       'definition': 'Puzzle games that do not fit into other Puzzle sub-genres. Like Tic Tac Toe and Puzzle Hubs. Examples: World of Peppa Pig: Kids Games, Papers, Please, Bimi Boo & Friends: Kids Games'},
#      {'game_subgenre': 'Physics',
#       'definition': 'Puzzle games where players use the knowledge of physical concepts and manipulate objects such as rope, balls, blocks to solve puzzles. Examples: Angry Birds 2, Lemmings, Cut the Rope'},
#      {'game_subgenre': 'Trivia',
#       'definition': 'Games that allow the player to answer trivia questions without another distinct theme. Examples: Trivia Crack, Elevate - Brain Training'},
#      {'game_subgenre': 'Word',
#       'definition': 'Puzzle games where the player creates or finds words, combining puzzle strategy with dictionary knowledge. Examples: Wordle!, Words of Wonders, Wordscapes'}]},
#    {'game_genre': 'Simulation',
#     'definition': 'Simulation games typically feature real world activities, often based on scenarios that involve planning, training, or building. The realistic nature of these games allow users to have immersive experiences as various occupations or characters.',
#     'subgenres': [{'game_subgenre': 'Adventure',
#       'definition': "Simulation games that are single-player and narrative driven. The player's interactions with the game progress the storyline. Examples: Harry Potter: Hogwarts Mystery, Animal Crossing: Pocket Camp, Kim Kardashian: Hollywood"},
#      {'game_subgenre': 'Avatar Life',
#       'definition': 'Simulation games where the player interacts with a virtual community and socializes with other players or characters as their own avatar. Examples: Animal Crossing: Pocket Camp, The Sims™ FreePlay, PK XD: Fun, friends & games'},
#      {'game_subgenre': 'Breeding',
#       'definition': 'Simulation games where the player breeds animals or creatures to strategically produce better varieties. Examples: Dragon City Mobile, Monster Legends: Collect them!, My Singing Monsters'},
#      {'game_subgenre': 'Driving / Flight Simulator',
#       'definition': 'Simulation games where the player drives vehicles to perform realistic tasks. Examples: Infinite Flight Simulator, Truck Simulator : Ultimate, Car Parking Multiplayer'},
#      {'game_subgenre': 'Idler',
#       'definition': 'Simulation games with passive idle mechanics at the center of the core loop, where players gather resources to accumulate wealth. Examples: Clean It: Cleaning Games, Burger Please!, My Perfect Hotel'},
#      {'game_subgenre': 'Sandbox',
#       'definition': 'Games that allow the player to do anything they wish, usually resulting in any number of possible themes being applied. Examples: Roblox, Minecraft'},
#      {'game_subgenre': 'Simulator',
#       'definition': 'Simulation games where the player performs tasks similar to real-life. Examples: Farming Simulator 20, Mission Chief - Fire Fighter, Teacher Simulator: School Days'},
#      {'game_subgenre': 'Time Management',
#       'definition': 'Simulation games with time-restricted objectives, where the player must complete tasks quickly in order to succeed. Examples: Cooking Diary® Restaurant Game, Cooking Fever: Restaurant Game, SpongeBob: Krusty Cook-Off'},
#      {'game_subgenre': 'Tycoon / Crafting',
#       'definition': 'Simulation games that challenge the player to build a city, town, or farm with resource management mechanics. Examples: Township, Hay Day, Family Island'}]},
#    {'game_genre': 'Tabletop',
#     'definition': 'Tabletop games largely incorporate the use of dice, tiles, cards, dominoes and turn based gameplay in solo or multiplayer competitions. These games are often mobile ports or reimagined versions of tabletop classics which require a combination of skill and luck to achieve victory.',
#     'subgenres': [{'game_subgenre': 'Board',
#       'definition': 'Tabletop games that are mechanically similar to real-life board games. Can be original or licensed. Examples: Chess - Play & Learn, Ludo STAR, Dice Dreams™'},
#      {'game_subgenre': 'Drawing & Coloring',
#       'definition': 'Tabletop games where the player colors pre-drawn illustrations, sometimes through paint-by-number mechanics, or draws their own designs. Examples: Color by Number：Coloring Gamess, Disney Coloring World, Drawing for kids: doodle games'},
#      {'game_subgenre': 'Solitaire',
#       'definition': 'Tabletop games that replicate Solitaire. Examples: Fishdom Solitaire, Solitaire Grand Harvest'},
#      {'game_subgenre': 'Tabletop Cards',
#       'definition': 'Tabletop games that replicate real-life non-gambling card games. Can be a regular deck of cards or a special deck of cards like in UNO! Examples: Phase 10: World Tour, UNO!™, Belote.com - Belote & Coinche'}]}]},
#  {'game_class': 'Sports & Racing',
#   'definition': 'The Sports & Racing class is a collection of genres which have dedicated fans of various sports and racing themed games. Titles may include either arcade or realistic mechanics.',
#   'genres': [{'game_genre': 'Racing',
#     'definition': 'Racing games challenge the player to race against other players, an AI, or a clock in order to complete a course in the fastest time. Typically, players drive cars or other vehicles.',
#     'subgenres': [{'game_subgenre': 'Arcade Racing',
#       'definition': 'Racing games with unrealistic gameplay, vehicles, and physics. Examples: Need for Speed No Limits, Asphalt 9: Legends, CarX Drift Racing 2'},
#      {'game_subgenre': 'Drag Racing',
#       'definition': 'Racing games where the player is challenged to shift gears at the correct time. Examples: CSR 2 Drag Racing Car Games, No Limit Drag Racing 2, Pixel Car Racer'},
#      {'game_subgenre': 'Kart Racing',
#       'definition': 'Racing games with go-kart vehicles, power-ups, and combat mechanics. Examples: Mario Kart Tour, Hot Wheels Unlimited, KartRider Rush+'},
#      {'game_subgenre': 'Realistic Racing',
#       'definition': 'Racing games with realistic gameplay, designed to replicate real-life vehicle racing. Examples: Real Racing 3, F1 Mobile Racing, Trucks Off Road'}]},
#    {'game_genre': 'Sports',
#     'definition': 'Sports games adapt real-life sports (soccer, baseball, etc.) for a mobile audience.',
#     'subgenres': [{'game_subgenre': 'Arcade Sports',
#       'definition': 'Sports games based on real-life sports with unrealistic and simplified gameplay. Examples: Golf Clash, Tennis Clash：Sports Stars Game, True Skate'},
#      {'game_subgenre': 'Realistic Sports',
#       'definition': 'Sports games based on real-life sports with realistic gameplay. Examples: 8 Ball Pool™, FIFA Soccer, Madden NFL 22 Mobile Football'},
#      {'game_subgenre': 'Sports Manager',
#       'definition': 'Sports games where the player takes the role of the manager of a sports team. Examples: Retro Bowl, Top Eleven Be a Soccer Manager, F1 Clash - Car Racing Manager'}]}]}]

# %%
with open('data/output/sensor_tower_game_classification.json', 'w', encoding='utf-8') as file:
    json.dump(taxonomy_structure, file, ensure_ascii=False, indent=4)  # `ensure_ascii=False` keeps non-ASCII characters readable

# %%
list(
    filter(
        lambda x: x['game_id'] == '642ea283c084ff1c6afcc825',
        input_data_for_gpt_genre_cleaning
    )
)
# Out:
# [{'game_id': '642ea283c084ff1c6afcc825',
#   'game_name': 'Honkai Impact 3-VN',
#   'game_class': 'Action & Strategy',
#   'game_genre': 'Strategy',
#   'game_subgenre': 'MOBA',
#   'individual_app_info': [{'app_id': 6448864292,
#     'name': 'Honkai Impact 3-VN',
#     'short_description': None,
#     'description': 'Honkai Impact 3 là game hành động mạo hiểm mới của HoYoverse.\nGóc nhìn 3D tinh xảo, hệ thống hành động nối chiêu vô hạn, cảm giác sảng khoái mạnh mẽ... Tạo nên trò chơi hành động của thời đại!\nChuỗi câu chuyện Honkai rung động lòng người, cốt truyện sâu sắc, đội ngũ lồng tiếng hào hoa, sẽ đưa bạn chìm đắm vào câu chuyện, tận hưởng cảm giác chưa từng có.\nNguy cơ trên Trái Đất tạm thời đã chấm dứt, cuộc mạo hiểm mới trên Sao Hỏa đã bắt đầu.\nGặp gỡ những Valkyrie với tính cách khác nhau, cùng khám phá bí mật của nền văn minh Sao Hỏa.\n\nHệ thống chỉ huy Hyperion đã sẵn sàng, đang xử lý yêu cầu đăng nhập... Kiểm tra hoàn tất!\nToàn thể nghe lệnh, mở khóa chốt phòng hộ, động cơ tải bắt đầu vận chuyển năng lượng nồng độ cao, đếm ngược đăng nhập 10,9,8...\n\n"Captain on the bridge."\n\nTừ hôm nay bạn là Thuyền Trưởng của chúng tôi rồi.\nHãy cùng chúng tôi chiến đấu vì mọi điều tốt đẹp trên thế giới!\n\n------------\n\nDưới cái bóng của Honkai, nền văn minh đối mặt với nguy cơ trùng trùng; Các cô gái trẻ đã dũng cảm đứng lên, chiến đấu để bảo vệ thế giới. Nhưng "thế giới" này, còn rộng lớn hơn tưởng tượng rất nhiều...\n\n[Tương Tác Nhiều Hơn! Đồng Đội Cũ, Đồng Đội Mới Cùng Nhau Mạo Hiểm!]\nSau khi Kiana chìm vào giấc ngủ, những người bạn từ các hành tinh khác nhau, mang theo những mục tiêu riêng, đã tập hợp lại để khám phá bí mật của Sao Hỏa. Còn Vita, người cùng các cô gái "kề vai tác chiến", dường như cũng có mục đích khác...\n\n[Linh Hồn Hành Động! Kết Hợp Đội Linh Hoạt!]\nKết hợp đội ngũ phong phú hơn, tư duy chiến đấu đa dạng hơn, mang đến nhiều khả năng thao tác hơn. Hợp lực xuất kích, cùng chiến đấu vì những điều tốt đẹp!\n\n[Hôm Nay Nghỉ Ngơi~ Giảm Tải Công Việc Hàng Ngày, Nhẹ Nhàng Trải Nghiệm]\nRa mắt hệ thống Giảm Gánh Nặng hoàn toàn mới, hôm nay muốn nghỉ ngơi như Theresa sao? Dùng "Phiếu Nghỉ Phép Hoeru" nhanh chóng hoàn thành nhiệm vụ và nhận thưởng nhé! Còn có nhiều tính năng tối ưu hóa khác đã được cập nhật, mang đến cho Thuyền Trưởng trải nghiệm tốt hơn.\n\n[Khung Cảnh Mới, Trải Nghiệm Đắm Chìm Với Khung Cảnh Mới]\nKhông ngừng mài giũa các chi tiết như ánh sáng, chất liệu, mang đến vẻ đẹp sống động như phim ảnh; Khung cảnh mới sẽ lần lượt khai mở, tự do thám hiểm, cảm nhận cảm giác chìm đắm trong trải nghiệm cốt truyện, cảm nhận sức hấp dẫn của chất lượng hình ảnh thế hệ mới!',
#     'subtitle': '',
#     'promo_text': ''}]}]

# %% [markdown]
# # Task ID-061-296

# %%
# Lấy dữ liệu thể loại (class, genre, subgenre) của các game năm 2024

# %%
# Get the list of games in 2024

# %%
df_games_2024 = raw_game_data_df[
    raw_game_data_df['Date'] == '2024-01-01'
]

# %%
df_games_2024
# Out:
#                         Unified Name                Unified ID  \
# 0                      Kvíz do kapsy  5f067598d871ea764a819b24
# 1              Talking Tom Time Rush  635372ab32237d5b65415f8a
# 2                       Hidden Folks  58a469a80211a6cc1500058c
# 3     Pawnbarian: a Puzzle Roguelike  627b22f00e9c981d5769d229
# 4       WildCraft: Animal Sim Online  5a68f22709b90f36e22b4d40
# ...                              ...                       ...
# 9995                    Dinos Online  56e336fd454d740fec004304
# 9996                   Into the Dead  55c5090f02ac64f9c000220c
# 9997                         ▻Sudoku  55d3a1a002ac64350a000544
# 9998     Baby Panda’s Ice Cream Shop  575914e00211a679df0002ce
# 9999            Affairs of the Court  558e0e03fcc9bffa8d000438
#
#                             Unified Publisher Name      Unified Publisher ID  \
# 0                                   FORNEMI s.r.o.  666c9d88f399ed2390e3f106
# 1                                     Outfit7 金科文化  5d3aa5f49cc0f85f968d0731
# 2                                 Adriaan de Jongh  55f895878ac350426b0429ab
# 3                                             j4nw  627b22f00e9c981d5769d228
# 4                              Vladimir Duchenchuk  5604a4d78ac3501722022f81
# ...                                            ...                       ...
# 9995                                     oh minhoo  56048e0f8ac3501722005985
# 9996  Prodigy Design Limited T/A Sidhe Interactive  560c3f378ac3506439000d37
# 9997                                 AppLovin Corp  5b636e91197e97572b98422b
# 9998                                 BabyBus Group  5614c2823f07e25d29006806
# 9999                               Choice of Games  5614b4973f07e2077c0010b0
#
#            Date Platform   Category  Downloads (Absolute)  Downloads (Growth)  \
# 0    2024-01-01  Unified     Trivia                     0                   0
# 1    2024-01-01  Unified     Action               2087997              566501
# 2    2024-01-01  Unified      Games                     2                   2
# 3    2024-01-01  Unified      Games                 13655                1970
# 4    2024-01-01  Unified      Games                639911              238993
# ...         ...      ...        ...                   ...                 ...
# 9995 2024-01-01  Unified      Games                  3971               -1063
# 9996 2024-01-01  Unified     Action                  5892              -35610
# 9997 2024-01-01  Unified      Games                     0                   0
# 9998 2024-01-01  Unified  Education                138206             -141312
# 9999 2024-01-01  Unified      Games                     0                   0
#
#       Downloads (Growth %)  Revenue (Absolute, $)  Revenue (Growth, $)  \
# 0                      NaN                     40                  -37
# 1                        0                   1471                 1293
# 2                      NaN                   1454                  103
# 3                        0                   1454                  224
# 4                        1                   1457                 -613
# ...                    ...                    ...                  ...
# 9995                    -0                    185                   44
# 9996                    -1                    185                 -206
# 9997                   NaN                    185                 -119
# 9998                    -1                    185                   97
# 9999                   NaN                    185                  156
#
#       Revenue (Growth %)  Average DAU (Absolute)  Average DAU (Growth)  \
# 0                     -0                     NaN                   NaN
# 1                      7                  290037                172495
# 2                      0                     NaN                   NaN
# 3                      0                     213                    45
# 4                     -0                    6229                  2132
# ...                  ...                     ...                   ...
# 9995                   0                      25                    -9
# 9996                  -1                     151                  -409
# 9997                  -0                     NaN                   NaN
# 9998                   1                    2376                 -2540
# 9999                   5                     NaN                   NaN
#
#       Average DAU (Growth %)
# 0                        NaN
# 1                          1
# 2                        NaN
# 3                          0
# 4                          1
# ...                      ...
# 9995                      -0
# 9996                      -1
# 9997                     NaN
# 9998                      -1
# 9999                     NaN
#
# [10000 rows x 16 columns]

# %%
# Get the class, genre, subgenre data of these games

# %%
list(df_game_full_info.columns)
# Out:
# ['unified_app_id',
#  'canonical_app_id',
#  'name',
#  'cohort_id',
#  'itunes_apps',
#  'android_apps',
#  'unified_publisher_ids',
#  'itunes_publisher_ids',
#  'android_publisher_ids',
#  'game_class',
#  'game_genre',
#  'game_subgenre',
#  'game_art_style',
#  'game_camera_pov',
#  'game_setting',
#  'game_theme',
#  'game_product_model',
#  'game_ip_corporate_parent',
#  'game_ip_operator',
#  'game_ip_media_type',
#  'game_licensed_ip',
#  'game_earliest_release_date',
#  'game_release_date_ww',
#  'game_release_date_us',
#  'game_release_date_jp',
#  'game_release_date_cn']

# %%
df_games_2024_with_genre_info = pd.merge(
    df_games_2024,
    df_game_full_info,
    left_on = 'Unified ID',
    right_on = 'unified_app_id',
    how = 'left'
)[
    ['Date',
    'unified_app_id',
    'name',
    'game_class',
    'game_genre',
    'game_subgenre']
]

# %%
df_games_2024_with_genre_info
# Out:
#            Date            unified_app_id                            name  \
# 0    2024-01-01  5f067598d871ea764a819b24                   Kvíz do kapsy
# 1    2024-01-01  635372ab32237d5b65415f8a           Talking Tom Time Rush
# 2    2024-01-01  58a469a80211a6cc1500058c                    Hidden Folks
# 3    2024-01-01  627b22f00e9c981d5769d229  Pawnbarian: a Puzzle Roguelike
# 4    2024-01-01  5a68f22709b90f36e22b4d40    WildCraft: Animal Sim Online
# ...         ...                       ...                             ...
# 9995 2024-01-01  56e336fd454d740fec004304                    Dinos Online
# 9996 2024-01-01  55c5090f02ac64f9c000220c                   Into the Dead
# 9997 2024-01-01  55d3a1a002ac64350a000544                         ▻Sudoku
# 9998 2024-01-01  575914e00211a679df0002ce     Baby Panda’s Ice Cream Shop
# 9999 2024-01-01  558e0e03fcc9bffa8d000438            Affairs of the Court
#
#               game_class  game_genre        game_subgenre
# 0     Lifestyle & Puzzle      Puzzle               Trivia
# 1     Lifestyle & Puzzle      Arcade  Platformer / Runner
# 2     Lifestyle & Puzzle      Puzzle       Hidden Objects
# 3     Lifestyle & Puzzle      Arcade         Other Arcade
# 4     Lifestyle & Puzzle  Simulation            Simulator
# ...                  ...         ...                  ...
# 9995  Lifestyle & Puzzle  Simulation            Simulator
# 9996  Lifestyle & Puzzle      Arcade  Platformer / Runner
# 9997  Lifestyle & Puzzle      Puzzle              Numbers
# 9998  Lifestyle & Puzzle   Lifestyle        Customization
# 9999  Lifestyle & Puzzle   Lifestyle    Interactive Story
#
# [10000 rows x 6 columns]

# %% [markdown]
# # Task ID-000-002

# %%
# Consolidate the algorithm to get release date of games

# %%
# Get the list of games released in 2023 and 2024

# %%
games_release_year = []

for index, row in df_game_revenue_adjusted.iterrows():
    
    current_game_release_year = get_release_year(
        df_game_revenue_adjusted,
        index
    )
    
    games_release_year.append(
        {
            'unified_app_id': index,
            'release_year': current_game_release_year
        }
    )

# %%
games_released_in_2023_2024 = list(
    filter(
        lambda x: x['release_year'] in [2023, 2024],
        games_release_year
    )
)

# %%
len(games_released_in_2023_2024)
# Out:
# 4187

# %%
# Get the list of unified_app_ids of these games

# %%
list_unified_ids_released_in_2023_2024 = list(
    map(
        lambda x: x['unified_app_id'],
        games_released_in_2023_2024
    )
)

# %%
# Get the list of apps belonging to these games

# %%
df_app_info_released_in_2023_2024 = df_all_app_info_list[
    df_all_app_info_list['unified_app_id'].isin(list_unified_ids_released_in_2023_2024)
]

# %%
# Get the ios and android app ids of these apps

# %%
list_app_ids_released_in_2023_2024_ios = list(
    map(lambda x: str(x),
        list(
                df_app_info_released_in_2023_2024[
                    df_app_info_released_in_2023_2024['os'] == 'ios'
                ]['app_id']
            )
        )
    )

list_app_ids_released_in_2023_2024_android = list(
    map(lambda x: str(x),
        list(
                df_app_info_released_in_2023_2024[
                    df_app_info_released_in_2023_2024['os'] == 'android'
                ]['app_id']
            )
        )
    )

# %%
# Query the app performance data (performance piece - each in a period, for an app)

# %%
## query for ios apps

app_performance_data_ios = get_apps_performance(
    api_key, 
    base_url, 
    os = 'ios', 
    app_ids = list_app_ids_released_in_2023_2024_ios, 
    country_code = 'VN', 
    granularity = 'daily', 
    max_periods = 1000, 
    start_date = '2023-01-01', 
    end_date = '2024-11-27'
)
# Out:
# Date ranges: [('2023-01-01', '2024-11-27')]
# Requesting Data for Range: 2023-01-01 to 2024-11-27
# making call for chunk number 1
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 2
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 3
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 4
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 5
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 6
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 7
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 8
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 9
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 10
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 11
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 12
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 13
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 14
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 15
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 16
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 17
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 18
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 19
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 20
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 21
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 22
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 23
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 24
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 25
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 26
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 27
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 28
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 29
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 30
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 31
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 32
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 33
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 34
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 35
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 36
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 37
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 38
# Data retrieved for 2023-01-01 to 2024-11-27

# %%
## query for android apps

app_performance_data_android = get_apps_performance(
    api_key, 
    base_url, 
    os = 'android', 
    app_ids = list_app_ids_released_in_2023_2024_android, 
    country_code = 'VN', 
    granularity = 'daily', 
    max_periods = 1000, 
    start_date = '2023-01-01', 
    end_date = '2024-11-27'
)
# Out:
# Date ranges: [('2023-01-01', '2024-11-27')]
# Requesting Data for Range: 2023-01-01 to 2024-11-27
# making call for chunk number 1
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 2
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 3
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 4
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 5
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 6
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 7
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 8
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 9
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 10
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 11
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 12
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 13
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 14
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 15
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 16
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 17
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 18
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 19
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 20
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 21
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 22
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 23
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 24
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 25
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 26
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 27
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 28
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 29
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 30
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 31
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 32
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 33
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 34
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 35
# Data retrieved for 2023-01-01 to 2024-11-27
# making call for chunk number 36
# Data retrieved for 2023-01-01 to 2024-11-27

# %%
## join the 2 lists of performance data together

app_performance_data_released_in_2023_2024 = app_performance_data_ios + app_performance_data_android

# %%
### Save to JSON file
with open('data/output/app_performance_data_released_in_2023_2024.json', 'w', encoding='utf-8') as file:
    json.dump(app_performance_data_released_in_2023_2024, file, ensure_ascii=False, indent=4)  # `ensure_ascii=False` keeps non-ASCII characters readable

# %%
# Order the performance pieces into app performance data

# %%
app_performance_data_grouped_by_app_released_in_2023_2024_ios = []

total_count = len(list_app_ids_released_in_2023_2024_ios)
count = 1

for app_id in list_app_ids_released_in_2023_2024_ios:
    
    print("Iteration {}/{}".format(count, total_count))
    print("Processing app_id {}".format(app_id))
    
    app_performance_data_grouped_by_app_released_in_2023_2024_ios.append(
        {
            'app_id': app_id,
            'os': 'ios',
            'unified_app_id': list(
                df_all_app_info_list[
                    df_all_app_info_list['app_id'].astype(str) == str(app_id)
                ]['unified_app_id']
            )[0],
            'app_performance': sorted(
                list(
                    filter(
                        lambda x: str(x['aid']) == app_id,
                        app_performance_data_released_in_2023_2024
                    )
                ),
                key = lambda x: x['d']
            )
        }
    )
    
    print("Done!")
    
    count += 1
# Out:
# Iteration 
# Processing app_id 1589094825
# Done!
# Iteration 3307
# Processing app_id 1599223984
# Done!
# Iteration 3308
# Processing app_id 1627500041
# Done!
# Iteration 3309
# Processing app_id 1642715290
# Done!
# Iteration 3310
# Processing app_id 1670483177
# Done!
# Iteration 3311
# Processing app_id 1670597542
# Done!
# Iteration 3312
# Processing app_id 6443442131
# Done!
# Iteration 3313
# Processing app_id 6444211856
# Done!
# Iteration 3314
# Processing app_id 6444901924
# Done!
# Iteration 3315
# Processing app_id 6455983161
# Done!
# Iteration 3316
# Processing app_id 6508165149
# Done!
# Iteration 3317
# Processing app_id 6670597981
# Done!
# Iteration 3318
# Processing app_id 1547569443
# Done!
# Iteration 3319
# Processing app_id 1555725078

# %%
with open('data/output/app_performance_data_grouped_by_app_released_in_2023_2024_ios.json', 'w', encoding='utf-8') as file:
    json.dump(app_performance_data_grouped_by_app_released_in_2023_2024_ios, file, ensure_ascii=False, indent=4)  # `ensure_ascii=False` keeps non-ASCII characters readable

# %%
app_performance_data_grouped_by_app_released_in_2023_2024_android = []

total_count = len(list_app_ids_released_in_2023_2024_android)
count = 1

for app_id in list_app_ids_released_in_2023_2024_android:
    
    print("Iteration {}/{}".format(count, total_count))
    print("Processing app_id {}".format(app_id))
    
    app_performance_data_grouped_by_app_released_in_2023_2024_android.append(
        {
            'app_id': app_id,
            'os': 'android',
            'unified_app_id': list(
                df_all_app_info_list[
                    df_all_app_info_list['app_id'].astype(str) == str(app_id)
                ]['unified_app_id']
            )[0],
            'app_performance': sorted(
                list(
                    filter(
                        lambda x: str(x['aid']) == app_id,
                        app_performance_data_released_in_2023_2024
                    )
                ),
                key = lambda x: x['d']
            )
        }
    )
    
    print("Done!")
    
    count += 1
# Out:
# Iteration 1/3528
# Processing app_id coloring.book.games.kids.toddlers
# Done!
# Iteration 2/3528
# Processing app_id com.ETxghf.game
# Done!
# Iteration 3/3528
# Processing app_id com.claweden.arcade.toy
# Done!
# Iteration 4/3528
# Processing app_id com.deuscraft.gymmania
# Done!
# Iteration 5/3528
# Processing app_id com.dominigames.mor2
# Done!
# Iteration 6/3528
# Processing app_id com.dominigames.mor3serial1
# Done!
# Iteration 7/3528
# Processing app_id com.dominigames.mor3serial2
# Done!
# Iteration 8/3528
# Processing app_id com.dominigames.mor4
# Done!
# Iteration 9/3528
# Processing app_id com.higame.zombie.survival.dead
# Done!
# Iteration 10/3528
# Processing app_id com.ignm.puri
# Done!
# Iteration 11/3528
# Processing app_id com.logoquiz.triviagame
# Done!
# Iteration 12/3528
# Processing app_id com.minogames.dogs.android
# Done!
# Iteration 13/3528
# Processing app_id com.scu.earthdigger
# Done!
# Iteration 14/3528
# Processing app_id com.squareenix.oko
# Done!
# Iteration 15/3528
# Processing app_id com.sweatychair.tingus
# Done!
# Iteration 16/3528
# Processing app_id com.sydl.sgcxand
# Done!
# Iteration 17/3528
# Processing app_id com.turner.tooncup
# Done!
# Iteration 18/3528
# Processing app_id com.wanxi.mxwvn
# Done!
# Iteration 19/3528
# Processing app_id com.xd.SettlementSurvival.gp.global
# Done!
# Iteration 20/3528
# Processing app_id games.my.zombie.shooter
# Done!
# Iteration 21/3528
# Processing app_id com.animaccord.matbcooking
# Done!
# Iteration 22/3528
# Processing app_id com.danhbai.choibai.Vip777.Phom
# Done!
# Iteration 23/3528
# Processing app_id com.global.zljslg
# Done!
# Iteration 24/3528
# Processing app_id com.global.zljslgru
# Done!
# Iteration 25/3528
# Processing app_id com.herowars.afkheroes
# Done!
# Iteration 26/3528
# Processing app_id com.magic.strategy.war.games
# Done!
# Iteration 27/3528
# Processing app_id com.neocubegames.randi.g
# Done!
# Iteration 28/3528
# Processing app_id com.sinyee.babybus.kidsgames.safety.education.learning
# Done!
# Iteration 150/3528
# Processing app_id funvent.tilepark
# Done!
# Iteration 151/3528
# Processing app_id survival.rpg.idle.arcade.build
# Done!
# Iteration 152/3528
# Processing app_id and.lihuhu.woober
# Done!
# Iteration 153/3528
# Processing app_id com.doomsdayvanguard.survivor
# Done!
# Iteration 154/3528
# Processing app_id com.ndreamgames.wod
# Done!
# Iteration 155/3528
# Processing app_id com.pazugames.sushimaker
# Done!
# Iteration 156/3528
# Processing app_id com.peoplug.heroandflyingpan
# Done!
# Iteration 157/3528
# Processing app_id com.percent.aos.randomdicego
# Done!
# Iteration 158/3528
# Processing app_id com.starbattleroyale.play
# Done!
# Iteration 159/3528
# Processing app_id com.superbox.aos.jewelsjungle
# Done!
# Iteration 160/3528
# Processing app_id com.tripledot.petcafe
# Done!
# Iteration 161/3528
# Processing app_id io.playville
# Done!
# Iteration 162/3528
# Processing app_id org.cranst0n.gug
# Done!
# Iteration 163/3528
# Processing app_id vn.vplay.khoinguyen.t016a
# Done!
# Iteration 164/3528
# Processing app_id com.Lizardry.RefindSelf
# Done!
# Iteration 165/3528
# Processing app_id com.atomic.collegefootball
# Done!
# Iteration 166/3528
# Processing app_id com.bravestars.doll.dressup.princess.coloringgame
# Done!
# Iteration 167/3528
# Processing app_id com.candysoft.SBZombiesRe4
# Done!
# Iteration 168/3528
# Processing app_id com.dokkaebipow.shootingstar
# Done!
# Iteration 169/3528
# Processing app_id com.firedogstudio.astralsurvivor
# Done!
# Iteration 170/3528
# Processing app_id com.galileo.r3
# Done!
# Iteration 171/3528
# Processing app_id com.gamesofa.android.ongtrumpoker2
# Done!
# Iteration 172/3528
# Processing app_id com.pirate.potc.gp
# Done!
# Iteration 173/3528
# Processing app_id com.ryki.zombie.a
# Done!
# Iteration 174/3528
# Processing app_id com.sticksports.stickcricketclash
# Done!
# Iteration 175/3528
# Processing app_id com.tisu.yyjglobal
# Done!
# Iteration 176/3528
# Processing app_id com.unicostudio.wordpirates
# Done!
# Iteration 177/3528
# Processing app_id games.onebutton.badminton
# Done!
# Iteration 178/3528
# Processing app_id jp.co.goodroid.hyper.crushzombies
# Done!
# Iteration 179/3528
# Processing app_id com.Deload.LittleArmyManager
# Done!
# Iteration 180/3528
# Processing app_id com.LG.LuxuryMall
# Done!
# Iteration 181/3528
# Processing app_id com.baishemmo.gp
# Done!
# Iteration 182/3528
# Processing app_id com.bestwishes.ginrummy
# Done!
# Iteration 183/3528
# Processing app_id com.bgf.merge
# Done!
# Iteration 184/3528
# Processing app_id com.chess.kingdom
# Done!
# Iteration 185/3528
# Processing app_id com.dmg.sa.timbermanadventure
# Done!
# Iteration 186/3528
# Processing app_id com.dominigames.ca4
# Done!
# Iteration 187/3528
# Processing app_id com.heshu.northlegend
# Done!
# Iteration 188/3528
# Processing app_id com.hg.endling
# Done!
# Iteration 189/3528
# Processing app_id com.highbrow.games.swidle
# Done!
# Iteration 190/3528
# Processing app_id com.joymore.sniperofduty
# Done!
# Iteration 191/3528
# Processing app_id com.lrgame.goc.sea
# Done!
# Iteration 192/3528
# Processing app_id com.mgame.queensknightsgp
# Done!
# Iteration 193/3528
# Processing app_id com.mobirix.valkyrieidle
# Done!
# Iteration 194/3528
# Processing app_id com.noctuagames.android.littledragon
# Done!
# Iteration 195/3528
# Processing app_id com.npixel.knightsurvivors
# Done!
# Iteration 196/3528
# Processing app_id com.playhardlab.duckchicken
# Done!
# Iteration 197/3528
# Processing app_id com.trivia.knowledgeispower
# Done!
# Iteration 198/3528
# Processing app_id com.woned.daylong
# Done!
# Iteration 199/3528
# Processing app_id com.ylhy.mt.starshipvoyage
# Done!
# Iteration 200/3528
# Processing app_id net.gameduo.af2
# Done!
# Iteration 201/3528
# Processing app_id com.aesthetiqore.nhie
# Done!
# Iteration 202/3528
# Processing app_id com.codore.dressup.selena
# Done!
# Iteration 203/3528
# Processing app_id com.enblocksound.EscapeGameNamelessRoom
# Done!
# Iteration 204/3528
# Processing app_id com.esportshooting.fps.thekillbox.at
# Done!
# Iteration 205/3528
# Processing app_id com.esportshooting.fps.thekillbox.de
# Done!
# Iteration 206/3528
# Processing app_id com.esportshooting.fps.thekillbox.hk
# Done!
# Iteration 207/3528
# Processing app_id com.esportshooting.fps.thekillbox.mo
# Done!
# Iteration 208/3528
# Processing app_id com.esportshooting.fps.thekillbox.taiwan
# Done!
# Iteration 209/3528
# Processing app_id com.occess.battlestrike.ultimate.shooting.games
# Done!
# Iteration 210/3528
# Processing app_id com.puzzlecorp.daycare.idle.game
# Done!
# Iteration 211/3528
# Processing app_id com.shengjing.towerdefend
# Done!
# Iteration 212/3528
# Processing app_id com.socialllc.socialanimal
# Done!
# Iteration 213/3528
# Processing app_id com.ta2.darkgod.gp
# Done!
# Iteration 214/3528
# Processing app_id com.tapps.virtual.pet.hotel.games.world
# Done!
# Iteration 215/3528
# Processing app_id com.wireless.defenseland
# Done!
# Iteration 216/3528
# Processing app_id gas.station.idle
# Done!
# Iteration 217/3528
# Processing app_id net.addiktivegames.idleinvaders
# Done!
# Iteration 218/3528
# Processing app_id sk.inlogic.tennis.open
# Done!
# Iteration 219/3528
# Processing app_id com.Jiffycrew.LostPages
# Done!
# Iteration 220/3528
# Processing app_id com.devvisiongames.deadisland
# Done!
# Iteration 221/3528
# Processing app_id com.fivebn.lt3.f2p
# Done!
# Iteration 222/3528
# Processing app_id com.itogame.smqygp
# Done!
# Iteration 223/3528
# Processing app_id com.movga.crazyKnightage
# Done!
# Iteration 224/3528
# Processing app_id com.retrobot.sorcero
# Done!
# Iteration 225/3528
# Processing app_id com.tlplay.domino
# Done!
# Iteration 226/3528
# Processing app_id com.zps.cotyphu.af
# Done!
# Iteration 227/3528
# Processing app_id jp.co.beeworks.nameko.ganso
# Done!
# Iteration 228/3528
# Processing app_id com.LonelyTroops.HerooftheKingdomII
# Done!
# Iteration 229/3528
# Processing app_id com.cmgames.CoinCars
# Done!
# Iteration 230/3528
# Processing app_id com.elevenpuzzles.unboxing
# Done!
# Iteration 231/3528
# Processing app_id com.habupain.saikonosutokapaid
# Done!
# Done!
# Iteration 3492/3528
# Processing app_id vn.cmn.heromax
# Done!
# Iteration 3493/3528
# Processing app_id com.CatalystApps.PetCity2
# Done!
# Iteration 3494/3528
# Processing app_id com.HoYoverse.hkrpgoversea
# Done!
# Iteration 3495/3528
# Processing app_id com.HoYoverse.hkrpgvn
# Done!
# Iteration 3496/3528
# Processing app_id com.ahoygames.rummy
# Done!
# Iteration 3497/3528
# Processing app_id com.gamehollywood.ef3
# Done!
# Iteration 3498/3528
# Processing app_id com.jzysj.sea.google
# Done!
# Iteration 3499/3528
# Processing app_id com.logisk.matexo
# Done!
# Iteration 3500/3528
# Processing app_id com.storytaco.p26client
# Done!
# Iteration 3501/3528
# Processing app_id io.superbrick.minimartmaster
# Done!
# Iteration 3502/3528
# Processing app_id com.JindoBlu.OfflineGames
# Done!
# Iteration 3503/3528
# Processing app_id com.gamee.arc8.android.app
# Done!
# Iteration 3504/3528
# Processing app_id com.gg016.thuongco
# Done!
# Iteration 3505/3528
# Processing app_id com.gokids.supertransport
# Done!
# Iteration 3506/3528
# Processing app_id com.lingame.idlefashionmall
# Done!
# Iteration 3507/3528
# Processing app_id com.oceangames.combo.us.googleplay
# Done!
# Iteration 3508/3528
# Processing app_id com.snapbreak.lip
# Done!
# Iteration 3509/3528
# Processing app_id com.stickman.heroes.battle.of.warriors.stickmanwarriors
# Done!
# Iteration 3510/3528
# Processing app_id com.vtc.tapkich
# Done!
# Iteration 3511/3528
# Processing app_id diamond.cash.slots.casino
# Done!
# Iteration 3512/3528
# Processing app_id princess.life.daycare.games
# Done!
# Iteration 3513/3528
# Processing app_id vn.com.tygon.ichess
# Done!
# Iteration 3514/3528
# Processing app_id com.edujoy.mashabear.gamezone
# Done!
# Iteration 3515/3528
# Processing app_id com.elysium.monster.knight.warriors.fighter.platformer.action.rpg.mmo
# Done!
# Iteration 3516/3528
# Processing app_id com.fishing.game.banca
# Done!
# Iteration 3517/3528
# Processing app_id com.gamehouse.ccc2
# Done!
# Iteration 3518/3528
# Processing app_id com.headgame.ancientstars
# Done!
# Iteration 3519/3528
# Processing app_id com.higgs.tongitsstar
# Done!
# Iteration 3520/3528
# Processing app_id com.inkruby.forgotten
# Done!
# Iteration 3521/3528
# Processing app_id com.mgmasia.newa
# Done!
# Iteration 3522/3528
# Processing app_id com.niklas.fpsdefense
# Done!
# Iteration 3523/3528
# Processing app_id com.nlabsoft.idlegame.HeroDino
# Done!
# Iteration 3524/3528
# Processing app_id com.pazugames.petsalon
# Done!
# Iteration 3525/3528
# Processing app_id com.sonidorico.blushed
# Done!
# Iteration 3526/3528
# Processing app_id com.wemadeconnect.aos.paladin
# Done!
# Iteration 3527/3528
# Processing app_id net.amanita_design.pilgrims
# Done!
# Iteration 3528/3528
# Processing app_id vn.funtap.dauphamobile
# Done!

# %%
# Quick fix the problem of wrong os assignment

# app_performance_data_grouped_by_app_released_in_2023_2024_android_fixed = list(
#     map(
#         lambda x: {
#             'app_id': x['app_id'],
#             'os': 'android',
#             'unified_app_id': x['unified_app_id'],
#             'app_performance': x['app_performance']
#         },
#         app_performance_data_grouped_by_app_released_in_2023_2024_android
#     )
# )

# %%
# app_performance_data_grouped_by_app_released_in_2023_2024_android = app_performance_data_grouped_by_app_released_in_2023_2024_android_fixed

# %%
with open('data/output/app_performance_data_grouped_by_app_released_in_2023_2024_android.json', 'w', encoding='utf-8') as file:
    json.dump(app_performance_data_grouped_by_app_released_in_2023_2024_android, file, ensure_ascii=False, indent=4)  # `ensure_ascii=False` keeps non-ASCII characters readable

# %%
## Combine the 2 lists

app_performance_data_grouped_by_app_released_in_2023_2024 = app_performance_data_grouped_by_app_released_in_2023_2024_ios + app_performance_data_grouped_by_app_released_in_2023_2024_android

# %%
### Save to JSON file
with open('data/output/app_performance_data_grouped_by_app_released_in_2023_2024.json', 'w', encoding='utf-8') as file:
    json.dump(app_performance_data_grouped_by_app_released_in_2023_2024, file, ensure_ascii=False, indent=4)  # `ensure_ascii=False` keeps non-ASCII characters readable

# %%
# Order the app performance data into game performance data

game_performance_data_for_games_released_in_2023_2024 = []

total_count = len(list_unified_ids_released_in_2023_2024)
count = 1

for unified_app_id in list_unified_ids_released_in_2023_2024:

    print("Iteration {}/{}".format(count, total_count))
    print("Processing unified_id {}".format(unified_app_id))
    
    game_performance_data_for_games_released_in_2023_2024.append(
        {
            'unified_app_id': unified_app_id,
            'performance_streams': list(
                filter(
                    lambda x: x['unified_app_id'] == unified_app_id,
                    app_performance_data_grouped_by_app_released_in_2023_2024
                )
            )
        }
    )
    
    print("Done!")
    count += 1
# Out:
# Iteration 1/4187
# Processing unified_id 6539d116d2e5a9284e6a76e2
# Done!
# Iteration 2/4187
# Processing unified_id 64d262a510a3142a25912bd2
# Done!
# Iteration 3/4187
# Processing unified_id 633b886973f76b48784c36b9
# Done!
# Iteration 4/4187
# Processing unified_id 5da67c09a546ab1edeb6c50d
# Done!
# Iteration 5/4187
# Processing unified_id 63e5633fded9c9175b7fca1e
# Done!
# Iteration 6/4187
# Processing unified_id 64fb527ee935e16ab92c6938
# Done!
# Iteration 7/4187
# Processing unified_id 639ff55ec7f5ec0d1883c726
# Done!
# Iteration 8/4187
# Processing unified_id 62f32a5044136e0eba10c9ba
# Done!
# Iteration 9/4187
# Processing unified_id 666a7679850648f34fb41215
# Done!
# Iteration 10/4187
# Processing unified_id 64fb52e1649dfd28c72aa698
# Done!
# Iteration 11/4187
# Processing unified_id 5d84173e3ea9835b8b1d4081
# Done!
# Iteration 12/4187
# Processing unified_id 651504efd211a646d98e8b5a
# Done!
# Iteration 13/4187
# Processing unified_id 64a91142f08b1411f1c62ffc
# Done!
# Iteration 14/4187
# Processing unified_id 6641bd6ed6c68d326fdd8917
# Done!
# Iteration 15/4187
# Processing unified_id 63c277626f979e711c7d7886
# Done!
# Iteration 16/4187
# Processing unified_id 63ecece74760b21b6d8706b2
# Done!
# Iteration 17/4187
# Processing unified_id 65cc5eab69eefb4fad4c1376
# Done!
# Iteration 18/4187
# Processing unified_id 65a1e8cd950aa41941ff9752
# Done!
# Iteration 19/4187
# Processing unified_id 65fd06dba6a66211427de1cd
# Done!
# Iteration 20/4187
# Processing unified_id 64075e77537c41636a8e1c58
# Done!
# Iteration 21/4187
# Processing unified_id 661e16f2b279ba3aff370af0
# Done!
# Iteration 22/4187
# Processing unified_id 64e70b3f0872f07ed0df43da
# Done!
# Iteration 23/4187
# Processing unified_id 666267cee122ae413cbc931a
# Done!
# Iteration 24/4187
# Processing unified_id 663ffa0564df7d1ea5a06b10
# Done!
# Iteration 25/4187
# Processing unified_id 65407d5b4227cd64a6723c90
# Done!
# Iteration 26/4187
# Processing unified_id 654c53c5060f963522369293
# Done!
# Iteration 27/4187
# Processing unified_id 65c59246ef45c441d8c8886b
# Done!
# Iteration 28/4187
# Processing unified_id 6600ce3df7516f24e66be439
# Done!
# Iteration 29/4187
# Processing unified_id 6626a822a9cba85698402d6b
# Done!
# Iteration 30/4187
# Processing unified_id 6470444f124b5028b45d9743
# Done!
# Iteration 31/4187
# Processing unified_id 6669e2a8e04fc6fe82c53f5f
# Done!
# Iteration 32/4187
# Processing unified_id 6700f9a78547467da5c62a2b
# Done!
# Iteration 33/4187
# Processing unified_id 641b2e4392a9a7430889b512
# Done!
# Iteration 34/4187
# Processing unified_id 6410802d9aac52470e6eaea4
# Done!
# Processing unified_id 6560c5384a9aab309997203f
# Done!
# Iteration 4184/4187
# Processing unified_id 65613fdb90d35f013b308d7f
# Done!
# Iteration 4185/4187
# Processing unified_id 6577de01fe0b10310b71e29f
# Done!
# Iteration 4186/4187
# Processing unified_id 6580d67da558800d72ea1057
# Done!
# Iteration 4187/4187
# Processing unified_id 66061b83fbc0b138864b01f1
# Done!

# %%
### Save to JSON file
with open('data/output/game_performance_data_for_games_released_in_2023_2024.json', 'w', encoding='utf-8') as file:
    json.dump(game_performance_data_for_games_released_in_2023_2024, file, ensure_ascii=False, indent=4)  # `ensure_ascii=False` keeps non-ASCII characters readable

# %%
# Create the performance dataframe for each game

# %%
performance_df_for_games_released_in_2023_2024 = []

total_count = len(game_performance_data_for_games_released_in_2023_2024)
count = 1

for game in game_performance_data_for_games_released_in_2023_2024:

    print("Iteration {}/{}".format(count, total_count))
    print("Processing unified_id {}".format(game['unified_app_id']))
    
    performance_df_for_games_released_in_2023_2024.append(
        {
            'unified_app_id': game['unified_app_id'],
            'performance_df': generate_performance_streams_df(game['performance_streams'])
        }
    )

    print("Done!\n")
    count += 1
# Out:
# Iteration 1/4187
# Processing unified_id 6539d116d2e5a9284e6a76e2
# Done!
#
# Iteration 2/4187
# Processing unified_id 64d262a510a3142a25912bd2
# Done!
#
# Iteration 3/4187
# Processing unified_id 633b886973f76b48784c36b9
# Done!
#
# Iteration 4/4187
# Processing unified_id 5da67c09a546ab1edeb6c50d
# Done!
#
# Iteration 5/4187
# Processing unified_id 63e5633fded9c9175b7fca1e
# Done!
#
# Iteration 6/4187
# Processing unified_id 64fb527ee935e16ab92c6938
# Done!
#
# Iteration 7/4187
# Processing unified_id 639ff55ec7f5ec0d1883c726
# Done!
#
# Iteration 8/4187
# Processing unified_id 62f32a5044136e0eba10c9ba
# Done!
#
# Iteration 9/4187
# Processing unified_id 666a7679850648f34fb41215
# Done!
#
# Iteration 10/4187
# Processing unified_id 64fb52e1649dfd28c72aa698
# Done!
#
# Iteration 11/4187
# Processing unified_id 5d84173e3ea9835b8b1d4081
# Done!
#
# Iteration 12/4187
# Processing unified_id 651504efd211a646d98e8b5a
# Done!
#
# Iteration 13/4187
# Processing unified_id 64a91142f08b1411f1c62ffc
# Done!
#
# Iteration 14/4187
# Processing unified_id 6641bd6ed6c68d326fdd8917
# Done!
#
# Iteration 15/4187
# Processing unified_id 63c277626f979e711c7d7886
# Done!
#
# Iteration 16/4187
# Processing unified_id 63ecece74760b21b6d8706b2
# Done!
#
# Iteration 17/4187
# Processing unified_id 65cc5eab69eefb4fad4c1376
# Done!
#
# Iteration 18/4187
# Processing unified_id 65a1e8cd950aa41941ff9752
# Done!
#
# Iteration 19/4187
# Processing unified_id 65fd06dba6a66211427de1cd
# Done!
#
# Iteration 20/4187
# Processing unified_id 64075e77537c41636a8e1c58
# Done!
#
# Iteration 21/4187
# Processing unified_id 661e16f2b279ba3aff370af0
# Done!
#
# Iteration 22/4187
# Processing unified_id 64e70b3f0872f07ed0df43da
# Done!
#
# Iteration 23/4187
# Processing unified_id 666267cee122ae413cbc931a
# Done!
#
# Iteration 24/4187
# Processing unified_id 663ffa0564df7d1ea5a06b10
# Done!
#
# Iteration 25/4187
# Processing unified_id 65407d5b4227cd64a6723c90
# Done!
#
# Iteration 26/4187
# Processing unified_id 654c53c5060f963522369293
# Done!
#
# Iteration 27/4187
# Processing unified_id 65c59246ef45c441d8c8886b
# Done!
#
# Iteration 28/4187
# Processing unified_id 6600ce3df7516f24e66be439
# Done!
#
# Iteration 29/4187
# Processing unified_id 6626a822a9cba85698402d6b
# Done!
#
# Iteration 30/4187
# Processing unified_id 6470444f124b5028b45d9743
# Done!
#
# Iteration 31/4187
# Processing unified_id 6669e2a8e04fc6fe82c53f5f
# Done!
#
# Iteration 32/4187
# Processing unified_id 6700f9a78547467da5c62a2b
# Done!
#
# Iteration 33/4187
# Processing unified_id 641b2e4392a9a7430889b512
# Done!
#
# Iteration 34/4187
# Processing unified_id 6410802d9aac52470e6eaea4
# Done!
#
# Iteration 35/4187
# Processing unified_id 66c957353541e6dc062a9464
# Done!
#
# Iteration 36/4187
# Processing unified_id 6454cd2adab74e35c18f5e11
# Done!
#
# Iteration 37/4187
# Processing unified_id 66580d5ac55264a66c0ef1e5
# Done!
#
# Iteration 38/4187
# Processing unified_id 60f151ef6ffae745341f100f
# Done!
#
# Iteration 39/4187
# Processing unified_id 66d211d85ca5ed0dbdb92d59
# Done!
#
# Iteration 40/4187
# Processing unified_id 64d5f2f9229d840ac6025910
# Done!
#
# Iteration 41/4187
# Processing unified_id 654415160b276e73bf2c8613
# Done!
#
# Iteration 42/4187
# Processing unified_id 652da61c5b601405ec02892d
# Done!
#
# Iteration 43/4187
# Processing unified_id 62f638da3811e936454f2b0f
# Done!
#
# Iteration 44/4187
# Processing unified_id 64bde7c0beec1f7450127b2b
# Done!
#
# Iteration 45/4187
# Processing unified_id 66fb97dffb320cffcfb1e326
# Done!
#
# Iteration 46/4187
# Processing unified_id 65f11fa81107bb6df0b1f78f
# Done!
#
# Iteration 47/4187
# Processing unified_id 6483e3cd22863a6e05e81bb6
# Done!
#
# Iteration 48/4187
# Processing unified_id 6220bbe38b9e665095bc83e4
# Done!
#
# Iteration 49/4187
# Processing unified_id 664045116e12e024bf42865d
# Done!
#
# Iteration 50/4187
# Processing unified_id 646c3514990ee340597b4d76
# Done!
#
# Iteration 51/4187
# Processing unified_id 642656f2b3ae2774a49b30a5
# Done!
#
# Iteration 52/4187
# Processing unified_id 6670098947a500c078db041b
# Done!
#
# Iteration 53/4187
# Processing unified_id 65d63474dde1d1707d640651
# Done!
#
# Iteration 54/4187
# Processing unified_id 66527ed9290c7211874abe73
# Done!
#
# Iteration 55/4187
# Processing unified_id 6454a42a22a2d214408396bc
# Done!
#
# Iteration 56/4187
# Processing unified_id 66cc10059e7c3b0db92da359
# Done!
#
# Iteration 57/4187
# Processing unified_id 6638a848ad4adb4594498e36
# Done!
#
# Iteration 58/4187
# Processing unified_id 65d86b46b3ae27599313c4b8
# Done!
#
# Iteration 59/4187
# Processing unified_id 65ea86a3fcf09c1798042107
# Done!
#
# Iteration 60/4187
# Processing unified_id 66613fad992f6b2ae2d1fd76
# Done!
#
# Iteration 61/4187
# Processing unified_id 64fb35908efc75514b107a11
# Done!
#
# Iteration 62/4187
# Processing unified_id 6620de2d9db92b4ddddd2e2e
# Done!
#
# Iteration 63/4187
# Processing unified_id 6475198bd97d345134e9a059
# Done!
#
# Iteration 64/4187
# Processing unified_id 63afc769278f9e137947186c
# Done!
#
# Iteration 65/4187
# Processing unified_id 6522ce55fe6cd0517760607e
# Done!
#
# Iteration 66/4187
# Processing unified_id 64d1b7b51395ad06162da82f
# Done!
#
# Iteration 67/4187
# Processing unified_id 642ea283c084ff1c6afcc825
# Done!
#
# Iteration 68/4187
# Processing unified_id 6618cd4754e2531457fd8cb1
# Done!
#
# Iteration 69/4187
# Processing unified_id 6653fa538ed6b90f78a58a12
# Done!
#
# Iteration 70/4187
# Processing unified_id 66d28fe97bf35d0dbcf396a8
# Done!
#
# Iteration 71/4187
# Processing unified_id 65f3e2edd2d2f066b363542b
# Done!
#
# Iteration 72/4187
# Processing unified_id 655ec802058d7b5482ce1ac2
# Done!
#
# Iteration 73/4187
# Processing unified_id 671c9b792a534ff71cf88055
# Done!
#
# Iteration 74/4187
# Processing unified_id 664d70e9d5a7dd7a0a1526b9
# Done!
#
# Iteration 75/4187
# Processing unified_id 6583e25297a8976e501b05a8
# Done!
#
# Iteration 76/4187
# Processing unified_id 64c8c3698966bc32a9d8acde
# Done!
#
# Iteration 77/4187
# Processing unified_id 62be6a5fbab10c69c5a0a42a
# Done!
#
# Iteration 78/4187
# Processing unified_id 62a6c74618009737cff9f80b
# Done!
#
# Iteration 79/4187
# Processing unified_id 647601522d39db6603e86b66
# Done!
#
# Iteration 80/4187
# Processing unified_id 666a7679850648f34fb41214
# Done!
#
# Iteration 81/4187
# Processing unified_id 656e7b186fff126c9540d08c
# Done!
#
# Iteration 82/4187
# Processing unified_id 6671c114b2e31852277f76c2
# Done!
#
# Iteration 83/4187
# Processing unified_id 637b0dc7863b79516a758a69
# Done!
#
# Iteration 84/4187
# Processing unified_id 6687a2d5e7ade0b96ff87601
# Done!
#
# Iteration 85/4187
# Processing unified_id 666907a2d5a4c6c117b3bd01
# Done!
#
# Iteration 86/4187
# Processing unified_id 626d11b3b672a029fdbf45c0
# Done!
# Processing unified_id 63c4d18654b41c6945ddda18
# Done!
#
# Iteration 226/4187
# Processing unified_id 62b05a8c9daa41614e523fa1
# Done!
#
# Iteration 227/4187
# Processing unified_id 667e0fe6ea2d373df0444595
# Done!
#
# Iteration 228/4187
# Processing unified_id 660bbeb2ad4adb4d3f849641
# Done!
#
# Iteration 229/4187
# Processing unified_id 66973a56918f2990e8957249
# Done!
#
# Iteration 230/4187
# Processing unified_id 652e00e0950cd27748028cf6
# Done!
#
# Iteration 231/4187
# Processing unified_id 66581728e62f94191c273068
# Done!
#
# Iteration 232/4187
# Processing unified_id 64b18914115e7f58f200f225
# Done!
#
# Iteration 233/4187
# Processing unified_id 66fa465f87d48d0f665a4acf
# Done!
#
# Iteration 234/4187
# Processing unified_id 6572809c7c5fd0579dceb24f
# Done!
#
# Iteration 235/4187
# Processing unified_id 66bd20efa26c8332ff0dfd01
# Done!
#
# Iteration 236/4187
# Processing unified_id 65958d9715957b3e944f394d
# Done!
#
# Iteration 237/4187
# Processing unified_id 66877456eff239036696e3eb
# Done!
#
# Iteration 238/4187
# Processing unified_id 6596294b7074e873454e3820
# Done!
#
# Iteration 239/4187
# Processing unified_id 6322100abd16da6f1e6d7ec2
# Done!
#
# Iteration 240/4187
# Processing unified_id 63368d7b3f14b910172d070a
# Done!
#
# Iteration 241/4187
# Processing unified_id 627dbe261e0df81ebb851419
# Done!
#
# Iteration 242/4187
# Processing unified_id 66ad95400c767576f5a7ec0b
# Done!
#
# Iteration 243/4187
# Processing unified_id 66b9c4b0e5dfbf0e5fb63f71
# Done!
#
# Iteration 244/4187
# Processing unified_id 63490526117e02647456295a
# Done!
#
# Iteration 245/4187
# Processing unified_id 6633617e133987f049af8fa0
# Done!
#
# Iteration 246/4187
# Processing unified_id 627d771fd094ad7f9beb9d2c
# Done!
#
# Iteration 247/4187
# Processing unified_id 64a99d736943cd2328f2ec54
# Done!
#
# Iteration 248/4187
# Processing unified_id 65558799e0cdcd540df72ffe
# Done!
#
# Iteration 249/4187
# Processing unified_id 635fd6edad4adb542fb2a709
# Done!
#
# Iteration 250/4187
# Processing unified_id 655ee13234bcb563d7d66e17
# Done!
#
# Iteration 251/4187
# Processing unified_id 641c7b876a77fd016b7d4e3a
# Done!
#
# Iteration 252/4187
# Processing unified_id 66b98fdfaf0c1c0e6845cd13
# Done!
#
# Iteration 253/4187
# Processing unified_id 65491de8b3ae2728832369f8
# Done!
#
# Iteration 254/4187
# Processing unified_id 6379ba3f10c9211635260c8a
# Done!
#
# Iteration 255/4187
# Processing unified_id 66b6b5abc4bbd31d2645ef9a
# Done!
#
# Iteration 256/4187
# Processing unified_id 662c1c024891f40cacada25f
# Done!
#
# Iteration 257/4187
# Processing unified_id 64a95779c9c8441632c24e84
# Done!
#
# Iteration 258/4187
# Processing unified_id 657992bbac683833c4bccfd6
# Done!
#
# Iteration 259/4187
# Processing unified_id 636c4e26080e980fa381a2b9
# Done!
#
# Iteration 260/4187
# Processing unified_id 65826151ead12212042f977e
# Done!
#
# Iteration 261/4187
# Processing unified_id 5d72b0d7a5e7102a3ef175d8
# Done!
#
# Iteration 262/4187
# Processing unified_id 65dc8f9ab5757d2c8dcfafaf
# Done!
#
# Iteration 263/4187
# Processing unified_id 65d56f57dd4de13fbef0768b
# Done!
#
# Iteration 264/4187
# Processing unified_id 62eae837634d5f482ed3e796
# Done!
#
# Iteration 265/4187
# Processing unified_id 652f6e39a020f13af057ccec
# Done!
#
# Iteration
# Processing unified_id 638997fed1a3715c246bb0a3
# Done!
#
# Iteration 389/4187
# Processing unified_id 660b8fab5cce4b4f526e91a2
# Done!
#
# Iteration 390/4187
# Processing unified_id 670a1b920b518d244c6cbc93
# Done!
#
# Iteration 391/4187
# Processing unified_id 6503162837351a382970a14f
# Done!
#
# Iteration 392/4187
# Processing unified_id 613dbbbedcfd071388f2cbd3
# Done!
#
# Iteration 393/4187
# Processing unified_id 64fcb9cd87ed90536926982c
# Done!
#
# Iteration 394/4187
# Processing unified_id 66a6fd56b5a5ce0e2f86f289
# Done!
#
# Iteration 395/4187
# Processing unified_id 6308bd5998623b742c992f16
# Done!
#
# Iteration 396/4187
# Processing unified_id 6450f2b2d19deb49d874ca05
# Done!
#
# Iteration 397/4187
# Processing unified_id 644bd89284b3d569997380af
# Done!
#
# Iteration 398/4187
# Processing unified_id 64ef5ffc0483de1c0149b292
# Done!
#
# Iteration 399/4187
# Processing unified_id 65b9b145f41ad5326c29a93b
# Done!
#
# Iteration 400/4187
# Processing unified_id 638d432a8243fb7f2d3043ca
# Done!
#
# Iteration 401/4187
# Processing unified_id 646bbb914c907369933a71a9
# Done!
#
# Iteration 402/4187
# Processing unified_id 65d715a61d451677f6e808ef
# Done!
#
# Iteration 403/4187
# Processing unified_id 65d6dff2f204153773532b59
# Done!
#
# Iteration 404/4187
# Processing unified_id 64ee2f1ac672c360abe808d4
# Done!
#
# Iteration 405/4187
# Processing unified_id 63a3c13b74c07e596db42c3f
# Done!
#
# Iteration 406/4187
# Processing unified_id 65b2d74ec04a5a5b9d32e3ca
# Done!
#
# Iteration 407/4187
# Processing unified_id 636095f746b007464ab325ea
# Done!
#
# Iteration 408/4187
# Processing unified_id 6341fa5d45fcd55b7323da5b
# Done!
#
# Iteration 409/4187
# Processing unified_id 665682c028500ac00a5d0caa
# Done!
#
# Iteration 410/4187
# Processing unified_id 6448bce14d8fd574645cc2a8
# Done!
#
# Iteration 411/4187
# Processing unified_id 64796634d20ff2116f39a01d
# Done!
#
# Iteration 412/4187
# Processing unified_id 64dae21468fccf5b55b40def
# Done!
#
# Iteration 413/4187
# Processing unified_id 6451c9a7cbe44a2ea763041b
# Done!
#
# Iteration 414/4187
# Processing unified_id 649baa9762776938d01e3fa6
# Done!
#
# Iteration 415/4187
# Processing unified_id 657ba2948fbfb623da057b06
# Done!
#
# Iteration 416/4187
# Processing unified_id 6387231562dc5a3aa684d61f
# Done!
#
# Iteration 417/4187
# Processing unified_id 5fe29c6578cf3954077644c3
# Done!
#
# Iteration 418/4187
# Processing unified_id 65c10688a3c10e7e5fce4c64
# Done!
#
# Iteration 419/4187
# Processing unified_id 646add89faa7d1619bc2989b
# Done!
#
# Iteration 420/4187
# Processing unified_id 6274836f03986e7bdceb3117
# Done!
#
# Iteration 421/4187
# Processing unified_id 64a8ed37fd0a6a586e1e87a8
# Done!
#
# Iteration 422/4187
# Processing unified_id 64ead21615604f0ab0d81700
# Done!
#
# Iteration 423/4187
# Processing unified_id 6684ef8e31fab6f7c8d0584c
# Done!
#
# Iteration 424/4187
# Processing unified_id 6480b69f35dfa029027a745d
# Done!
#
# Iteration 425/4187
# Processing unified_id 65ceaf4e56461418241b1f1c
# Done!
#
# Iteration 426/4187
# Processing unified_id 638f0c511d5ce40c06447d79
# Done!
#
# Iteration 427/4187
# Processing unified_id 64bcadada4ce9b5d17b6d61f
# Done!
#
# Iteration 428/4187
# Processing unified_id 6221dfc317cccb659028e919
# Done!
#
# Iteration 429/4187
# Processing unified_id 65d5913fc22a81162efd50ca
# Done!
#
# Iteration 430/4187
# Processing unified_id 647979b8a6dfdb1d21d622a6
# Done!
#
# Iteration 431/4187
# Processing unified_id 661a74a9ad4adb613a0c175f
# Done!
#
# Iteration 432/4187
# Processing unified_id 6352245607956d6ff7019bba
# Done!
#
# Iteration 433/4187
# Processing unified_id 65fe3703fe76ce3657e52d8d
# Done!
#
# Iteration 434/4187
# Processing unified_id 647349df37938646851bad00
# Done!
#
# Iteration 435/4187
# Processing unified_id 6527f8df1cb82124b472f08f
# Done!
#
# Iteration 436/4187
# Processing unified_id 66f1a618eaad1f61c8855846
# Done!
#
# Iteration 437/4187
# Processing unified_id 6375e4cc38e89733e46f31d9
# Done!
#
# Iteration 438/4187
# Processing unified_id 6502c82473896301b8a8ac76
# Done!
#
# Iteration 439/4187
# Processing unified_id 641ee0d7a2d7741561235005
# Done!
#
# Iteration 440/4187
# Processing unified_id 6153b4a2f3e690163b93ec0b
# Done!
#
# Iteration 441/4187
# Processing unified_id 647db77c25186e7cb5c12245
# Done!
#
# Iteration 442/4187
# Processing unified_id 6648295744302b2d45d31670
# Done!
#
# Iteration 443/4187
# Processing unified_id 6478a99938db1301c3f31631
# Done!
#
# Iteration 444/4187
# Processing unified_id 636fbcbdacbf545165ced5ce
# Done!
#
# Iteration 445/4187
# Processing unified_id 657a4d4f40beda598b713a23
# Done!
#
# Iteration 446/4187
# Processing unified_id 64edce90ec70ba11dbdd3f4f
# Done!
#
# Iteration 447/4187
# Processing unified_id 666bcd67f399ed2af1464ce2
# Done!
#
# Iteration 448/4187
# Processing unified_id 65c0acd8b3ae274e14ba93e0
# Done!
#
# Iteration 449/4187
# Processing unified_id 65fd039da8c1f7059d5c7617
# Done!
#
# Iteration 450/4187
# Processing unified_id 62319382da86161e0b4d76e4
# Done!
#
# Iteration 451/4187
# Processing unified_id 652f48b630d67a2f3813217f
# Done!
#
# Iteration 452/4187
# Processing unified_id 6446c093046947073f0ef152
# Done!
#
# Iteration 453/4187
# Processing unified_id 65fc2ae175e0d7335461175b
# Done!
#
# Iteration 454/4187
# Processing unified_id 65b35896d78e025f0f7be8ba
# Done!
#
# Iteration 455/4187
# Processing unified_id 642e23f9ead13f2dfcb3781a
# Done!
#
# Iteration 456/4187
# Processing unified_id 64c7aef06caf79033f98f43a
# Done!
#
# Iteration 457/4187
# Processing unified_id 6526dfacad4adb61832d8e21
# Done!
#
# Iteration 458/4187
# Processing unified_id 635deafaa4251d157eb0deda
# Done!
#
# Iteration 459/4187
# Processing unified_id 61c4c1abdd870a1f2e873f3b
# Done!
#
# Iteration 460/4187
# Processing unified_id 64267180af8f2f221d2ac3bd
# Done!
#
# Iteration 461/4187
# Processing unified_id 65850490fffedd1ccee07ffc
# Done!
#
# Iteration 462/4187
# Processing unified_id 65c5833d190adc0cfe7d3ffc
# Done!
#
# Iteration 463/4187
# Processing unified_id 66cdd1bb961dfb2cb948f9ab
# Done!
#
# Iteration 464/4187
# Processing unified_id 661f5080be9d9b060e7f8317
# Done!
#
# Iteration 465/4187
# Processing unified_id 65601d4dc8169671d78a38ac
# Done!
#
# Iteration 466/4187
# Processing unified_id 5e1286cf92d07e6b1017a05d
# Done!
#
# Iteration 467/4187
# Processing unified_id 671097e58603da6e20d47f79
# Done!
#
# Iteration 468/4187
# Processing unified_id 639a7b563285e92c3df0da10
# Done!
#
# Iteration 469/4187
# Processing unified_id 64ca3aff087f667132d8edff
# Done!
#
# Iteration 470/4187
# Processing unified_id 643fa763595cd1433a803788
# Done!
#
# Iteration 471/4187
# Processing unified_id 63d8e0144d2a476e25537b8e
# Done!
#
# Iteration 472/4187
# Processing unified_id 65185e198c588b7d81f22c3b
# Done!
#
# Iteration 473/4187
# Processing unified_id 646ce2b1b3ae270d304a370f
# Done!
#
# Iteration 474/4187
# Processing unified_id 652e07247f32fb67ad33dbec
# Done!
#
# Iteration 475/4187
# Processing unified_id 64ec50529a9c5f31468faf50
# Done!
#
# Iteration 476/4187
# Processing unified_id 6529f51ededb8d7d0bba1d05
# Done!
#
# Iteration 477/4187
# Processing unified_id 660e605bad4adb788281cee4
# Done!
#
# Iteration 478/4187
# Processing unified_id 64a7cf1ce425a76375c946e3
# Done!
#
# Iteration 479/4187
# Processing unified_id 655822c7a0b4d9584616a91e
# Done!
#
# Iteration 480/4187
# Processing unified_id 644938fdd972db3cf73a1ecc
# Done!
#
# Iteration 481/4187
# Processing unified_id 65826358ad4adb7c8ae07871
# Done!
#
# Iteration 482/4187
# Processing unified_id 640f3f031cf9556277590210
# Done!
#
# Iteration 483/4187
# Processing unified_id 664c8b33af490eaf16588b4e
# Done!
#
# Iteration 484/4187
# Processing unified_id 660f528ff801af0928980e8a
# Done!
#
# Iteration 485/4187
# Processing unified_id 64a895d6c092060ea99cf110
# Done!
#
# Iteration 486/4187
# Processing unified_id 65f2a1400c89c52d61ef90fa
# Done!
#
# Iteration 487/4187
# Processing unified_id 66f305acbff88b2279074f9c
# Done!
#
# Iteration 488/4187
# Processing unified_id 640f3f51cf58564010c78232
# Done!
#
# Iteration 489/4187
# Processing unified_id 666aa6f0276183d683a7dd86
# Done!
#
# Iteration 490/4187
# Processing unified_id 63842eadf31d4c1633de8b28
# Done!
#
# Iteration 491/4187
# Processing unified_id 672c42b0e7ade022e2d5571d
# Done!
#
# Iteration 492/4187
# Processing unified_id 6656adfae397ceb3207d6a35
# Done!
#
# Iteration 493/4187
# Processing unified_id 65523ab8b3ae2717177e6748
# Done!
#
# Iteration 494/4187
# Processing unified_id 55de062902ac6453fd07c7f2
# Done!
#
# Iteration 495/4187
# Processing unified_id 63039bf2ad4adb6d5ccc7a76
# Done!
#
# Iteration 496/4187
# Processing unified_id 644a1eb4762ace147c8c605f
# Done!
#
# Iteration 497/4187
# Processing unified_id 65fa3360cd8c521c43cd36b2
# Done!
#
# Iteration 498/4187
# Processing unified_id 6481a456de2518330c01dd93
# Done!
#
# Iteration 499/4187
# Processing unified_id 63c2142da0d4b50fbe1cea5b
# Done!
#
# Iteration 500/4187
# Processing unified_id 64f2c388b3ae2750e9e5f747
# Done!
#
# Iteration 501/4187
# Processing unified_id 646ed7408071684c34aa911c
# Done!
#
# Iteration 502/4187
# Processing unified_id 60429535eafbc62debc8cd85
# Done!
#
# Iteration 503/4187
# Processing unified_id 6381cf7a40da537c7e3d0a3e
# Done!
#
# Iteration 504/4187
# Processing unified_id 63fef7eeed19026bdd544891
# Done!
#
# Iteration 505/4187
# Processing unified_id 671ce39138958c0b75ff9ab6
# Done!
#
# Iteration 506/4187
# Processing unified_id 660374ed73f5ad450931545d
# Done!
#
# Iteration 507/4187
# Processing unified_id 66da5dee87ef820dda2622fa
# Done!
#
# Iteration 508/4187
# Processing unified_id 63cad0db5a64db36b429e19f
# Done!
#
# Iteration 509/4187
# Processing unified_id 62b16a386c940f14a0cd6f9f
# Done!
#
# Iteration 510/4187
# Processing unified_id 650c64487980ca43e077784c
# Done!
#
# Iteration 511/4187
# Processing unified_id 66987d637186ad64235f58b9
# Done!
#
# Iteration 512/4187
# Processing unified_id 653209a59d8c460138c3e203
# Done!
#
# Iteration 513/4187
# Processing unified_id 6669b18d2404298575b1e58f
# Done!
#
# Iteration 514/4187
# Processing unified_id 65aa7377294313129e731d32
# Done!
#
# Iteration 515/4187
# Processing unified_id 66303c18b2fa244acc4749aa
# Done!
#
# Iteration 516/4187
# Processing unified_id 615e803bd160407598a7aabe
# Done!
#
# Iteration 517/4187
# Processing unified_id 641484dd02fbee78c17c735e
# Done!
#
# Iteration 518/4187
# Processing unified_id 669ddae9af6282f1e1ae4b8c
# Done!
#
# Iteration 519/4187
# Processing unified_id 65d4e2ad6d22b63ca727bfd1
# Done!
#
# Iteration 520/4187
# Processing unified_id 6042dbba42da0868045db265
# Done!
#
# Iteration 521/4187
# Processing unified_id 6312b10e5a461346ab5b0ad2
# Done!
#
# Iteration 522/4187
# Processing unified_id 63693379eb094668b3ebf908
# Done!
#
# Iteration 523/4187
# Processing unified_id 613c00d2e5e3621368331bb4
# Done!
#
# Iteration 524/4187
# Processing unified_id 6514e8a8f8d48a5468337952
# Done!
#
# Iteration 525/4187
# Processing unified_id 64d4a0100c884818f2029330
# Done!
#
# Iteration 526/4187
# Processing unified_id 63e3da9bad4adb156af213b3
# Done!
#
# Iteration 527/4187
# Processing unified_id 65b86080807168542fb100a9
# Done!
#
# Iteration 528/4187
# Processing unified_id 65cec9df9faa1918f7609588
# Done!
#
# Iteration 529/4187
# Processing unified_id 665e5f316638481b8df5791e
# Done!
#
# Iteration 530/4187
# Processing unified_id 63ba51df302258631abc3891
# Done!
#
# Iteration 531/4187
# Processing unified_id 659fd495955f612f53e019d7
# Done!
#
# Iteration 532/4187
# Processing unified_id 6238627571689a670c6b8c4e
# Done!
#
# Iteration 533/4187
# Processing unified_id 6524cfcbead122732c9699fa
# Done!
#
# Iteration 534/4187
# Processing unified_id 6417ff09a8c1f7081eaa0418
# Done!
#
# Iteration 535/4187
# Processing unified_id 64aeaa0ff7baf07cffdd738a
# Done!
#
# Iteration 536/4187
# Processing unified_id 6711c8a804c993fa9f546b30
# Done!
# Processing unified_id 64fb5254c397d213263bbe2f
# Done!
#
# Iteration 575/4187
# Processing unified_id 60c4477af7fc78748201a8cf
# Done!
#
# Iteration 576/4187
# Processing unified_id 66687cb621caef11b31fc787
# Done!
#
# Iteration 577/4187
# Processing unified_id 629aaf65d4f4751064b4aa2c
# Done!
#
# Iteration 578/4187
# Processing unified_id 65e8881b7803d36781b07ce4
# Done!
#
# Iteration 579/4187
# Processing unified_id 671bd0ccf7d714e9052d9ea5
# Done!
#
# Iteration 580/4187
# Processing unified_id 64f1724082cad0688ed2d545
# Done!
#
# Iteration 581/4187
# Processing unified_id 64c2bac0a791d16644735ed4
# Done!
#
# Iteration 582/4187
# Processing unified_id 659b4247f4576f717dd50ec6
# Done!
#
# Iteration 583/4187
# Processing unified_id 650d0186d327dc5dae280a90
# Done!
#
# Iteration 584/4187
# Processing unified_id 62453a4d950aa43054cffd26
# Done!
#
# Iteration 585/4187
# Processing unified_id 6556eda8d4baa95a1807141a
# Done!
#
# Iteration 586/4187
# Processing unified_id 628b1cb7ffa0451cd76317e1
# Done!
#
# Iteration 587/4187
# Processing unified_id 6466fe86c1623e6d08bae08c
# Done!
#
# Iteration 588/4187
# Processing unified_id 64912d5f96526e177a52bc33
# Done!
#
# Iteration 589/4187
# Processing unified_id 5f493530b3f4a2190b676f1d
# Done!
#
# Iteration 590/4187
# Processing unified_id 639cabb1ad4adb627a79e6bd
# Done!
#
# Iteration 591/4187
# Processing unified_id 66050958ec3c1117710970b9
# Done!
#
# Iteration 592/4187
# Processing unified_id 60776d444060ef352c67db8a
# Done!
#
# Iteration 593/4187
# Processing unified_id 660387f273f5ad3356707a27
# Done!
#
# Iteration 594/4187
# Processing unified_id 653cd3e8594b7b39e9ec42f9
# Done!
#
# Iteration 595/4187
# Processing unified_id 662dcb4dac6b59370913e8c8
# Done!
#
# Iteration 596/4187
# Processing unified_id 65543d12379f6d256ee21b99
# Done!
#
# Iteration 597/4187
# Processing unified_id 6677b7c1d8316b0d3d1bd903
# Done!
#
# Iteration 598/4187
# Processing unified_id 660df4e016140f22016895cc
# Done!
#
# Iteration 599/4187
# Processing unified_id 64ce95d0697eff2798068618
# Done!
#
# Iteration 600/4187
# Processing unified_id 66cfc00c70c8c6f34f7c5f6d
# Done!
#
# Iteration 601/4187
# Processing unified_id 65c49850e18dac29e93d25a2
# Done!
#
# Iteration 602/4187
# Processing unified_id 60a71ab403e99e432644143c
# Done!
#
# Iteration 603/4187
# Processing unified_id 6053333dbbbfa401a4d768a3
# Done!
#
# Iteration 604/4187
# Processing unified_id 65e8006aab9d2c46f6bf7b2c
# Done!
#
# Iteration 605/4187
# Processing unified_id 6372f7c3e06cfb39bb4c052d
# Done!
#
# Iteration 606/4187
# Processing unified_id 647b3613358b4702598fedff
# Done!
#
# Iteration 607/4187
# Processing unified_id 64d26e651e6f743eae05ac5b
# Done!
#
# Iteration 608/4187
# Processing unified_id 65346de2a9022f48cf9fea91
# Done!
#
# Iteration 609/4187
# Processing unified_id 66698f4fb3ae27fc1429e36b
# Done!
#
# Iteration 610/4187
# Processing unified_id 64bde4c83097596d8e327dae
# Done!
#
# Iteration 611/4187
# Processing unified_id 658e120d59f83d59bfeee27d
# Done!
#
# Iteration 612/4187
# Processing unified_id 6325f122b3ae2746db49b1eb
# Done!
#
# Iteration 613/4187
# Processing unified_id 63f58d02da86162676d4b289
# Done!
#
# Iteration 614/4187
# Processing unified_id 64190da078ba2b37961da01e
# Done!
#
# Iteration 615/4187
# Processing unified_id 652547ca05f57b5ed221a57c
# Done!
#
# Iteration 616/4187
# Processing unified_id 64cb2f250cf4835a45bda71b
# Done!
#
# Iteration 617/4187
# Processing unified_id 66a1066a8211f5674f76781c
# Done!
#
# Iteration 618/4187
# Processing unified_id 66055189a910a719c6af5716
# Done!
#
# Iteration 619/4187
# Processing unified_id 6582f0b39208b038459934a1
# Done!
#
# Iteration 620/4187
# Processing unified_id 641a563a84af6c562029e792
# Done!
#
# Iteration 621/4187
# Processing unified_id 61c2af64d4661561c0ce1230
# Done!
#
# Iteration 622/4187
# Processing unified_id 63da4008ece838580dd6e12d
# Done!
#
# Iteration 623/4187
# Processing unified_id 65f91a92b783a42f3bd57215
# Done!
#
# Iteration 624/4187
# Processing unified_id 609a32e0e70a2019461588f6
# Done!
#
# Iteration 625/4187
# Processing unified_id 616a4cfcd679e802fa050b27
# Done!
#
# Iteration 626/4187
# Processing unified_id 637653d27323b3172a7d05ad
# Done!
#
# Iteration 627/4187
# Processing unified_id 6598ae2e0e7ac8716dae3caf
# Done!
#
# Iteration 628/4187
# Processing unified_id 66a2ad1ea86ec4b77da07c19
# Done!
#
# Iteration 629/4187
# Processing unified_id 65544d2aad4adb23da617e8d
# Done!
#
# Iteration 630/4187
# Processing unified_id 65f2c7134d4ff929dc77b561
# Done!
#
# Iteration 631/4187
# Processing unified_id 61298fb033c4d633f9258426
# Done!
#
# Iteration 632/4187
# Processing unified_id 654074cdfad3be5221585537
# Done!
#
# Iteration 633/4187
# Processing unified_id 645092d6bd259e0bb6f17f08
# Done!
#
# Iteration 634/4187
# Processing unified_id 648a04c4698f8d5ccc3ca88d
# Done!
#
# Iteration 635/4187
# Processing unified_id 63e479dd03e99e1d4fcbb07f
# Done!
#
# Iteration 636/4187
# Processing unified_id 6024c0f2b21dc836bafc2f77
# Done!
#
# Iteration 637/4187
# Processing unified_id 664c29ebad4adb81b92b17dd
# Done!
#
# Iteration 638/4187
# Processing unified_id 6378866be6bd53715b31a27b
# Done!
#
# Iteration 639/4187
# Processing unified_id 63dbbb40ded9c93fec4118f7
# Done!
#
# Iteration 640/4187
# Processing unified_id 6567ef26f5eeb978c462c0cb
# Done!
#
# Iteration 641/4187
# Processing unified_id 64352a4705557331118a3cc7
# Done!
#
# Iteration 642/4187
# Processing unified_id 6593d119ba2c860e52c4bdaf
# Done!
#
# Iteration 643/4187
# Processing unified_id 650d2160ba2c8658d4f44da4
# Done!
#
# Iteration 644/4187
# Processing unified_id 655cb14bbd3ebd5da9f0516f
# Done!
#
# Iteration 645/4187
# Processing unified_id 658f8f982b5e681459a816d3
# Done!
#
# Iteration 646/4187
# Processing unified_id 669dc9d8e04f78d8e9c99c18
# Done!
#
# Iteration 647/4187
# Processing unified_id 64677124c51eae4b686a16ef
# Done!
#
# Iteration 648/4187
# Processing unified_id 6526b69f0d061a7b0aa62f7c
# Done!
#
# Iteration 649/4187
# Processing unified_id 654714f6aa75d856601d4390
# Done!
#
# Iteration 650/4187
# Processing unified_id 664e983e97ac3b5f79d2bb4a
# Done!
#
# Iteration 651/4187
# Processing unified_id 63c70d57b3ae271a0c9eea11
# Done!
#
# Iteration 652/4187
# Processing unified_id 665d255075a2380eaf1ef3dc
# Done!
#
# Iteration 653/4187
# Processing unified_id 66a48512e3e8bb583ced30ad
# Done!
#
# Iteration 654/4187
# Processing unified_id 652c585b3c6e2e513cdac939
# Done!
#
# Iteration 655/4187
# Processing unified_id 64fc084cb3ae2719e22147c4
# Done!
#
# Iteration 656/4187
# Processing unified_id 661bf4ea8b7d4a21404c49a7
# Done!
#
# Iteration 657/4187
# Processing unified_id 64fb6895594b7b4362c56626
# Done!
#
# Iteration 658/4187
# Processing unified_id 64afb93dad4adb43c49e2c01
# Done!
#
# Iteration 659/4187
# Processing unified_id 5faf88bf4de76e3ce428a02d
# Done!
#
# ...
# Done!
#
# Iteration 3972/4187
# Processing unified_id 640e8a291de3c656568ad936
# Done!
#
# Iteration 3973/4187
# Processing unified_id 640ea0ceb7c50e54e5c15c28
# Done!
#
# Iteration 3974/4187
# Processing unified_id 640ef00d7678a4273dc878de
# Done!
#
# Iteration 3975/4187
# Processing unified_id 6410789e6b20ff63186ddb7c
# Done!
#
# Iteration 3976/4187
# Processing unified_id 6410f5b65993e747e491ab08
# Done!
#
# Iteration 3977/4187
# Processing unified_id 64116dceb6f0803023eff61f
# Done!
#
# Iteration 3978/4187
# Processing unified_id 6412f07b94fd9e79a7ee121b
# Done!
#
# Iteration 3979/4187
# Processing unified_id 641336685157005cb1f7a608
# Done!
#
# Iteration 3980/4187
# Processing unified_id 64156975e77c6f300c54ec80
# Done!
#
# Iteration 3981/4187
# Processing unified_id 641617a1627735287f72ace7
# Done!
#
# Iteration 3982/4187
# Processing unified_id 641682c06fe233539cfa2d7c
# Done!
#
# Iteration 3983/4187
# Processing unified_id 6416f51f8c57377bf1b46e77
# Done!
#
# Iteration 3984/4187
# Processing unified_id 6417b32dbe5e7f50eb73927a
# Done!
#
# Iteration 3985/4187
# Processing unified_id 6417e1f4660c3455962bd70e
# Done!
#
# Iteration 3986/4187
# Processing unified_id 64180f9731046966a451dfb4
# Done!
#
# Iteration 3987/4187
# Processing unified_id 64181bb74ccb80415e15d3b8
# Done!
#
# Iteration 3988/4187
# Processing unified_id 64188af79c962130e4e1a4cb
# Done!
#
# Iteration 3989/4187
# Processing unified_id 641943a128ecec5301cf0978
# Done!
#
# Iteration 3990/4187
# Processing unified_id 6419be717796b43c7f54e8aa
# Done!
#
# Iteration 3991/4187
# Processing unified_id 641a5267ba1de95512f67c69
# Done!
#
# Iteration 3992/4187
# Processing unified_id 641b5ac8d994c335c96e13ae
# Done!
#
# Iteration 3993/4187
# Processing unified_id 641b672fb3e27307468b0fd1
# Done!
#
# Iteration 3994/4187
# Processing unified_id 641c1313c21b4c5644352dbe
# Done!
#
# Iteration 3995/4187
# Processing unified_id 641d233ee2f1eb790c3c72e9
# Done!
#
# Iteration 3996/4187
# Processing unified_id 641d911e067dc631621e4ab8
# Done!
#
# Iteration 3997/4187
# Processing unified_id 641ddef30443837fdb90c578
# Done!
#
# Iteration 3998/4187
# Processing unified_id 6420fcd9812e4f028d2e5330
# Done!
#
# Iteration 3999/4187
# Processing unified_id 646735f67b9c1b1f4b7e429a
# Done!
#
# Iteration 4071/4187
# Processing unified_id 6467a4994fd86a4fe3fc0a06
# Done!
#
# Iteration 4072/4187
# Processing unified_id 646886026f979e59e09b3a60
# Done!
#
# Iteration 4073/4187
# Processing unified_id 646a548e548d6a26578d7747
# Done!
#
# Iteration 4074/4187
# Processing unified_id 646a9c4afc53c8266f92f59e
# Done!
#
# Iteration 4075/4187
# Processing unified_id 646b01a2c01f9126603efe4e
# Done!
#
# Iteration 4076/4187
# Processing unified_id 646d32ca6fff1224d5b79372
# Done!
#
# Iteration 4077/4187
# Processing unified_id 646dde09106d0b07f474aec0
# Done!
#
# Iteration 4078/4187
# Processing unified_id 646df1ed480e646ee66a6e95
# Done!
#
# Iteration 4079/4187
# Processing unified_id 646ed7973eb54b766ce13b33
# Done!
#
# Iteration 4080/4187
# Processing unified_id 647355186237396a23b47aa7
# Done!
#
# Iteration 4081/4187
# Processing unified_id 6474883b30bb45625b250fea
# Done!
#
# Iteration 4082/4187
# Processing unified_id 6475618e077601792f69a762
# Done!
#
# Iteration 4083/4187
# Processing unified_id 64763199d8f702599f19bac0
# Done!
#
# Iteration 4084/4187
# Processing unified_id 6476b67cb3ae272195af6dd5
# Done!
#
# Iteration 4085/4187
# Processing unified_id 6479ef45c01f91622c1eadc2
# Done!
#
# Iteration 4086/4187
# Processing unified_id 647be9ef4de76e7bd5c2a84e
# Done!
#
# Iteration 4087/4187
# Processing unified_id 647eef9234394c2ac136b042
# Done!
#
# Iteration 4088/4187
# Processing unified_id 647f469c9492f62016dc2d73
# Done!
#
# Iteration 4089/4187
# Processing unified_id 64802578045fce0617fd7dd9
# Done!
#
# Iteration 4090/4187
# Processing unified_id 64809aea4ce44e75fe37a76e
# Done!
#
# Iteration 4091/4187
# Processing unified_id 6480ea6a22863a0b94309586
# Done!
#
# Iteration 4092/4187
# Processing unified_id 6481967fdde1d10c4cd81f6d
# Done!
#
# Iteration 4093/4187
# Processing unified_id 648203e8aaeb8362aac0590f
# Done!
#
# Iteration 4094/4187
# Processing unified_id 648289dd6022c53d5b7e8bb8
# Done!
#
# Iteration 4095/4187
# Processing unified_id 6482903e8d50eb061f808a30
# Done!
#
# Iteration 4096/4187
# Processing unified_id 64837ee75de85852af64c2bb
# Done!
#
# Iteration 4097/4187
# Processing unified_id 648ac99430d67a6eff3c02e1
# Done!
#
# Iteration 4098/4187
# Processing unified_id 648de81073ee985b3d94cab0
# Done!
#
# Iteration 4099/4187
# Processing unified_id 648e7c668b7d4a33bc0c664e
# Done!
#
# Iteration 4100/4187
# Processing unified_id 6493e0c74fb5ee66b10278d9
# Done!
#
# Iteration 4101/4187
# Processing unified_id 64943f2a83a8c92e0d5ef4dd
# Done!
#
# Iteration 4102/4187
# Processing unified_id 649451db895ce7407d23f58b
# Done!
#
# Iteration 4103/4187
# Processing unified_id 649470540bdc62034427bafb
# Done!
#
# Iteration 4104/4187
# Processing unified_id 649531a482193531450a5c4b
# Done!
#
# Iteration 4105/4187
# Processing unified_id 6495d76615361250769270d8
# Iteration 4175/4187
# Processing unified_id 654156d6bfc5dc5f40d8a92f
# Done!
#
# Iteration 4176/4187
# Processing unified_id 65443dd03e9fd32de7337ad5
# Done!
#
# Iteration 4177/4187
# Processing unified_id 6544725233c4d62a3ffd551e
# Done!
#
# Iteration 4178/4187
# Processing unified_id 654d78f787b2754c24cf45ba
# Done!
#
# Iteration 4179/4187
# Processing unified_id 654edf4c58f59b6d1d3cb27b
# Done!
#
# Iteration 4180/4187
# Processing unified_id 6553620e93f17f5bdb2e120e
# Done!
#
# Iteration 4181/4187
# Processing unified_id 6555b0f6ebfdf7513efae446
# Done!
#
# Iteration 4182/4187
# Processing unified_id 65567c4cfe0329481ef230ff
# Done!
#
# Iteration 4183/4187
# Processing unified_id 6560c5384a9aab309997203f
# Done!
#
# Iteration 4184/4187
# Processing unified_id 65613fdb90d35f013b308d7f
# Done!
#
# Iteration 4185/4187
# Processing unified_id 6577de01fe0b10310b71e29f
# Done!
#
# Iteration 4186/4187
# Processing unified_id 6580d67da558800d72ea1057
# Done!
#
# Iteration 4187/4187
# Processing unified_id 66061b83fbc0b138864b01f1
# Done!

# %%
# Calculate the full adjusted revenue of each game (daily)

# %%
daily_sum_performance_df_for_games_released_in_2023_2024 = []

total_count = len(performance_df_for_games_released_in_2023_2024)
count = 1

for game in performance_df_for_games_released_in_2023_2024:
    
    print("Iteration {}/{}".format(count, total_count))
    print("Processing unified_id {}".format(game['unified_app_id']))
    
    daily_sum_performance_df_for_games_released_in_2023_2024.append(
        {
            'unified_app_id': game['unified_app_id'],
            'daily_adjusted_revenue_series': get_adjusted_daily_revenue(
                game['performance_df'], 
                df_all_app_info_list
            )
        }
    )
    
    print("Done!\n")
    count += 1
# Out:
# Iteration 1/4187
# Processing unified_id 6539d116d2e5a9284e6a76e2
# Done!
#
# Iteration 2/4187
# Processing unified_id 64d262a510a3142a25912bd2
# Done!
#
# Iteration 3/4187
# Processing unified_id 633b886973f76b48784c36b9
# Done!
#
# Iteration 4/4187
# Processing unified_id 5da67c09a546ab1edeb6c50d
# Done!
#
# Iteration 5/4187
# Processing unified_id 63e5633fded9c9175b7fca1e
# Done!
#
# Iteration 6/4187
# Processing unified_id 64fb527ee935e16ab92c6938
# Done!
#
# Iteration 7/4187
# Processing unified_id 639ff55ec7f5ec0d1883c726
# Done!
#
# Iteration 8/4187
# Processing unified_id 62f32a5044136e0eba10c9ba
# Done!
#
# Iteration 9/4187
# Processing unified_id 666a7679850648f34fb41215
# Done!
#
# Iteration 10/4187
# Processing unified_id 64fb52e1649dfd28c72aa698
# Done!
#
# Iteration 11/4187
# Processing unified_id 5d84173e3ea9835b8b1d4081
# Done!
#
# Iteration 12/4187
# Processing unified_id 651504efd211a646d98e8b5a
# Done!
#
# Iteration 13/4187
# Processing unified_id 64a91142f08b1411f1c62ffc
# Done!
#
# Iteration 14/4187
# Processing unified_id 6641bd6ed6c68d326fdd8917
# Done!
#
# Iteration 15/4187
# Processing unified_id 63c277626f979e711c7d7886
# Done!
#
# Iteration 16/4187
# Processing unified_id 63ecece74760b21b6d8706b2
# Done!
#
# Iteration 17/4187
# Processing unified_id 65cc5eab69eefb4fad4c1376
# Done!
#
# Iteration 18/4187
# Processing unified_id 65a1e8cd950aa41941ff9752
# Done!
#
# Iteration 19/4187
# Processing unified_id 65fd06dba6a66211427de1cd
# Done!
#
# Iteration 20/4187
# Processing unified_id 64075e77537c41636a8e1c58
# Done!
#
# Iteration 21/4187
# Processing unified_id 661e16f2b279ba3aff370af0
# Done!
#
# Iteration 22/4187
# Processing unified_id 64e70b3f0872f07ed0df43da
# Done!
#
# Iteration 23/4187
# Processing unified_id 666267cee122ae413cbc931a
# Done!
#
# Iteration 24/4187
# Processing unified_id 663ffa0564df7d1ea5a06b10
# Done!
#
# Iteration 25/4187
# Processing unified_id 65407d5b4227cd64a6723c90
# Done!
#
# Iteration 26/4187
# Processing unified_id 654c53c5060f963522369293
# Done!
#
# Iteration 27/4187
# Processing unified_id 65c59246ef45c441d8c8886b
# Done!
#
# Iteration 28/4187
# Processing unified_id 6600ce3df7516f24e66be439
# Done!
#
# Iteration 29/4187
# Processing unified_id 6626a822a9cba85698402d6b
# Done!
# Processing unified_id 658e788c69e18719360c0c2d
# Done!
#
# Iteration 214/4187
# Processing unified_id 637ec3b082685a1efcbc35ac
# Done!
#
# Iteration 215/4187
# Processing unified_id 6270da5e478582182c2d9c7a
# Done!
#
# Iteration 216/4187
# Processing unified_id 668240e2172ea60d9e30adb0
# Done!
#
# Iteration 217/4187
# Processing unified_id 64972068f83bff2a9d8a086e
# Done!
#
# Iteration 218/4187
# Processing unified_id 6549cba84251ad48400e50bf
# Done!
#
# Iteration 219/4187
# Processing unified_id 672353aca4c9da292e391435
# Done!
#
# Iteration 220/4187
# Processing unified_id 66c82d07410ff0a97e039ed3
# Done!
#
# Iteration 221/4187
# Processing unified_id 65765f06cb54b62bf7af6a85
# Done!
#
# Iteration 222/4187
# Processing unified_id 6545db024227cd177700a064
# Done!
#
# Iteration 223/4187
# Processing unified_id 5f75bd556ec51b7e4e13fa8f
# Done!
#
# Iteration 224/4187
# Processing unified_id 666a7683850648f34fb41216
# Done!
#
# Iteration 225/4187
# Processing unified_id 63c4d18654b41c6945ddda18
# Done!
#
# Iteration 226/4187
# Processing unified_id 62b05a8c9daa41614e523fa1
# Done!
#
# Iteration 227/4187
# Processing unified_id 667e0fe6ea2d373df0444595
# Done!
#
# Iteration 228/4187
# Processing unified_id 660bbeb2ad4adb4d3f849641
# Done!
#
# Iteration 229/4187
# Processing unified_id 66973a56918f2990e8957249
# Done!
#
# Iteration 230/4187
# Processing unified_id 652e00e0950cd27748028cf6
# Done!
#
# Iteration 231/4187
# Processing unified_id 66581728e62f94191c273068
# Done!
#
# Iteration 232/4187
# Processing unified_id 64b18914115e7f58f200f225
# Done!
#
# Iteration 233/4187
# Processing unified_id 66fa465f87d48d0f665a4acf
# Done!
#
# Iteration 234/4187
# Processing unified_id 6572809c7c5fd0579dceb24f
# Done!
#
# Iteration 235/4187
# Processing unified_id 66bd20efa26c8332ff0dfd01
# Done!
#
# Iteration 236/4187
# Processing unified_id 65958d9715957b3e944f394d
# Done!
#
# Iteration 237/4187
# Processing unified_id 66877456eff239036696e3eb
# Done!
#
# Iteration 238/4187
# Processing unified_id 6596294b7074e873454e3820
# Done!
#
# Iteration 239/4187
# Processing unified_id 6322100abd16da6f1e6d7ec2
# Done!
#
# Iteration 240/4187
# Processing unified_id 63368d7b3f14b910172d070a
# Done!
#
# Iteration 241/4187
# Processing unified_id 627dbe261e0df81ebb851419
# Done!
#
# Iteration 242/4187
# Processing unified_id 66ad95400c767576f5a7ec0b
# Done!
#
# Iteration 243/4187
# Processing unified_id 66b9c4b0e5dfbf0e5fb63f71
# Done!
#
# Iteration 244/4187
# Processing unified_id 63490526117e02647456295a
# Done!
#
# Iteration 245/4187
# Processing unified_id 6633617e133987f049af8fa0
# Done!
#
# Iteration 246/4187
# Processing unified_id 627d771fd094ad7f9beb9d2c
# Done!
#
# Iteration 247/4187
# Processing unified_id 64a99d736943cd2328f2ec54
# Done!
#
# Iteration 248/4187
# Processing unified_id 65558799e0cdcd540df72ffe
# Done!
#
# Iteration 249/4187
# Processing unified_id 635fd6edad4adb542fb2a709
# Done!
#
# Iteration 250/4187
# Processing unified_id 655ee13234bcb563d7d66e17
# Done!
#
# Iteration 251/4187
# Processing unified_id 641c7b876a77fd016b7d4e3a
# Done!
#
# Iteration 252/4187
# Processing unified_id 66b98fdfaf0c1c0e6845cd13
# Done!
#
# Iteration 253/4187
# Processing unified_id 65491de8b3ae2728832369f8
# Done!
#
# Iteration 254/4187
# Processing unified_id 6379ba3f10c9211635260c8a
# Done!
#
# Iteration 255/4187
# Processing unified_id 66b6b5abc4bbd31d2645ef9a
# Processing unified_id 65c10688a3c10e7e5fce4c64
# Done!
#
# Iteration 419/4187
# Processing unified_id 646add89faa7d1619bc2989b
# Done!
#
# Iteration 420/4187
# Processing unified_id 6274836f03986e7bdceb3117
# Done!
#
# Iteration 421/4187
# Processing unified_id 64a8ed37fd0a6a586e1e87a8
# Done!
#
# Iteration 422/4187
# Processing unified_id 64ead21615604f0ab0d81700
# Done!
#
# Iteration 423/4187
# Processing unified_id 6684ef8e31fab6f7c8d0584c
# Done!
#
# Iteration 424/4187
# Processing unified_id 6480b69f35dfa029027a745d
# Done!
#
# Iteration 425/4187
# Processing unified_id 65ceaf4e56461418241b1f1c
# Done!
#
# Iteration 426/4187
# Processing unified_id 638f0c511d5ce40c06447d79
# Done!
#
# Iteration 427/4187
# Processing unified_id 64bcadada4ce9b5d17b6d61f
# Done!
#
# Iteration 428/4187
# Processing unified_id 6221dfc317cccb659028e919
# Done!
#
# Iteration 429/4187
# Processing unified_id 65d5913fc22a81162efd50ca
# Done!
#
# Iteration 430/4187
# Processing unified_id 647979b8a6dfdb1d21d622a6
# Done!
#
# Iteration 431/4187
# Processing unified_id 661a74a9ad4adb613a0c175f
# Done!
#
# Iteration 432/4187
# Processing unified_id 6352245607956d6ff7019bba
# Done!
#
# Iteration 433/4187
# Processing unified_id 65fe3703fe76ce3657e52d8d
# Done!
#
# Iteration 434/4187
# Processing unified_id 647349df37938646851bad00
# Done!
#
# Iteration 435/4187
# Processing unified_id 6527f8df1cb82124b472f08f
# Done!
#
# Iteration 436/4187
# Processing unified_id 66f1a618eaad1f61c8855846
# Done!
#
# Iteration 437/4187
# Processing unified_id 6375e4cc38e89733e46f31d9
# Done!
#
# Iteration 438/4187
# Processing unified_id 6502c82473896301b8a8ac76
# Done!
#
# Iteration 439/4187
# Processing unified_id 641ee0d7a2d7741561235005
# Done!
#
# Iteration 440/4187
# Processing unified_id 6153b4a2f3e690163b93ec0b
# Done!
#
# Iteration 441/4187
# Processing unified_id 647db77c25186e7cb5c12245
# Done!
#
# Iteration 442/4187
# Processing unified_id 6648295744302b2d45d31670
# Done!
#
# Iteration 443/4187
# Processing unified_id 6478a99938db1301c3f31631
# Done!
#
# Iteration 444/4187
# Processing unified_id 636fbcbdacbf545165ced5ce
# Done!
#
# Iteration 445/4187
# Processing unified_id 657a4d4f40beda598b713a23
# Done!
#
# Iteration 446/4187
# Processing unified_id 64edce90ec70ba11dbdd3f4f
# Done!
#
# Iteration 447/4187
# Processing unified_id 666bcd67f399ed2af1464ce2
# Done!
#
# Iteration 448/4187
# Processing unified_id 65c0acd8b3ae274e14ba93e0
# Done!
#
# Iteration 449/4187
# Processing unified_id 65fd039da8c1f7059d5c7617
# Done!
#
# Iteration 450/4187
# Processing unified_id 62319382da86161e0b4d76e4
# Done!
#
# Iteration 451/4187
# Processing unified_id 652f48b630d67a2f3813217f
# Done!
#
# Iteration 452/4187
# Processing unified_id 6446c093046947073f0ef152
# Done!
#
# Iteration 453/4187
# Processing unified_id 65fc2ae175e0d7335461175b
# Done!
#
# Iteration 454/4187
# Processing unified_id 65b35896d78e025f0f7be8ba
# Done!
#
# Iteration 455/4187
# Processing unified_id 642e23f9ead13f2dfcb3781a
# Done!
#
# Iteration 456/4187
# Processing unified_id 64c7aef06caf79033f98f43a
# Done!
#
# Iteration 457/4187
# Processing unified_id 6526dfacad4adb61832d8e21
# Done!
#
# Iteration 458/4187
# Processing unified_id 635deafaa4251d157eb0deda
# Done!
#
# Iteration 459/4187
# Processing unified_id 61c4c1abdd870a1f2e873f3b
# Done!
#
# Iteration 460/4187
# Processing unified_id 64267180af8f2f221d2ac3bd
# Done!
#
# Iteration 461/4187
# Processing unified_id 65850490fffedd1ccee07ffc
# Done!
#
# Iteration 462/4187
# Processing unified_id 65c5833d190adc0cfe7d3ffc
# Done!
#
# Iteration 463/4187
# Processing unified_id 66cdd1bb961dfb2cb948f9ab
# Done!
#
# Iteration 464/4187
# Processing unified_id 661f5080be9d9b060e7f8317
# Done!
#
# Iteration 465/4187
# Processing unified_id 65601d4dc8169671d78a38ac
# Done!
#
# Iteration 466/4187
# Processing unified_id 5e1286cf92d07e6b1017a05d
# Done!
#
# Iteration 467/4187
# Processing unified_id 671097e58603da6e20d47f79
# Done!
#
# Iteration 468/4187
# Processing unified_id 639a7b563285e92c3df0da10
# Done!
#
# Iteration 469/4187
# Processing unified_id 64ca3aff087f667132d8edff
# Done!
#
# Iteration 470/4187
# Processing unified_id 643fa763595cd1433a803788
# Done!
#
# Iteration 471/4187
# Processing unified_id 63d8e0144d2a476e25537b8e
# Done!
#
# Iteration 472/4187
# Processing unified_id 65185e198c588b7d81f22c3b
# Done!
#
# Iteration 473/4187
# Processing unified_id 646ce2b1b3ae270d304a370f
# Done!
#
# Iteration 474/4187
# Processing unified_id 652e07247f32fb67ad33dbec
# Done!
#
# Iteration 475/4187
# Processing unified_id 64ec50529a9c5f31468faf50
# Done!
#
# Iteration 476/4187
# Processing unified_id 6529f51ededb8d7d0bba1d05
# Done!
#
# Iteration 477/4187
# Processing unified_id 660e605bad4adb788281cee4
# Done!
#
# Iteration 478/4187
# Processing unified_id 64a7cf1ce425a76375c946e3
# Done!
#
# Iteration 479/4187
# Processing unified_id 655822c7a0b4d9584616a91e
# Done!
#
# Iteration 480/4187
# Processing unified_id 644938fdd972db3cf73a1ecc
# Done!
#
# Iteration 481/4187
# Processing unified_id 65826358ad4adb7c8ae07871
# Done!
#
# Iteration 482/4187
# Processing unified_id 640f3f031cf9556277590210
# Done!
#
# Iteration 483/4187
# Processing unified_id 664c8b33af490eaf16588b4e
# Done!
#
# Iteration 484/4187
# Processing unified_id 660f528ff801af0928980e8a
# Done!
#
# Iteration 485/4187
# Processing unified_id 64a895d6c092060ea99cf110
# Done!
#
# Iteration 486/4187
# Processing unified_id 65f2a1400c89c52d61ef90fa
# Done!
#
# Iteration 487/4187
# Processing unified_id 66f305acbff88b2279074f9c
# Done!
#
# Iteration 488/4187
# Processing unified_id 640f3f51cf58564010c78232
# Done!
#
# Iteration 489/4187
# Processing unified_id 666aa6f0276183d683a7dd86
# Done!
#
# Iteration 490/4187
# Processing unified_id 63842eadf31d4c1633de8b28
# Done!
#
# Iteration 491/4187
# Processing unified_id 672c42b0e7ade022e2d5571d
# Done!
#
# Iteration 492/4187
# Processing unified_id 6656adfae397ceb3207d6a35
# Done!
#
# Iteration 493/4187
# Processing unified_id 65523ab8b3ae2717177e6748
# Done!
#
# Iteration 494/4187
# Processing unified_id 55de062902ac6453fd07c7f2
# Done!
#
# Iteration 495/4187
# Processing unified_id 63039bf2ad4adb6d5ccc7a76
# Done!
#
# Iteration 496/4187
# Processing unified_id 644a1eb4762ace147c8c605f
# Done!
#
# Iteration 497/4187
# Processing unified_id 65fa3360cd8c521c43cd36b2
# Done!
#
# Iteration 498/4187
# Processing unified_id 6481a456de2518330c01dd93
# Done!
#
# Iteration 499/4187
# Processing unified_id 63c2142da0d4b50fbe1cea5b
# Done!
#
# Iteration 500/4187
# Processing unified_id 64f2c388b3ae2750e9e5f747
# Done!
#
# Iteration 501/4187
# Processing unified_id 646ed7408071684c34aa911c
# Done!
#
# Iteration 502/4187
# Processing unified_id 60429535eafbc62debc8cd85
# Done!
#
# Iteration 503/4187
# Processing unified_id 6381cf7a40da537c7e3d0a3e
# Done!
#
# Iteration 504/4187
# Processing unified_id 63fef7eeed19026bdd544891
# Done!
#
# Iteration 505/4187
# Processing unified_id 671ce39138958c0b75ff9ab6
# Done!
#
# Iteration 506/4187
# Processing unified_id 660374ed73f5ad450931545d
# Done!
#
# Iteration 507/4187
# Processing unified_id 66da5dee87ef820dda2622fa
# Done!
#
# Iteration 508/4187
# Processing unified_id 63cad0db5a64db36b429e19f
# Done!
#
# Iteration 509/4187
# Processing unified_id 62b16a386c940f14a0cd6f9f
# Done!
#
# Iteration 510/4187
# Processing unified_id 650c64487980ca43e077784c
# Done!
#
# Iteration 511/4187
# Processing unified_id 66987d637186ad64235f58b9
# Done!
#
# Iteration 512/4187
# Processing unified_id 653209a59d8c460138c3e203
# Done!
#
# Iteration 513/4187
# Processing unified_id 6669b18d2404298575b1e58f
# Done!
#
# Iteration 514/4187
# Processing unified_id 65aa7377294313129e731d32
# Done!
#
# Iteration 515/4187
# Processing unified_id 66303c18b2fa244acc4749aa
# Done!
#
# Iteration 516/4187
# Processing unified_id 615e803bd160407598a7aabe
# Done!
#
# Iteration 517/4187
# Processing unified_id 641484dd02fbee78c17c735e
# Done!
#
# Iteration 518/4187
# Processing unified_id 669ddae9af6282f1e1ae4b8c
# Done!
#
# Iteration 519/4187
# Processing unified_id 65d4e2ad6d22b63ca727bfd1
# Done!
#
# Iteration 520/4187
# Processing unified_id 6042dbba42da0868045db265
# Done!
#
# Iteration 521/4187
# Processing unified_id 6312b10e5a461346ab5b0ad2
# Done!
#
# Iteration 522/4187
# Processing unified_id 63693379eb094668b3ebf908
# Done!
#
# Iteration 523/4187
# Processing unified_id 613c00d2e5e3621368331bb4
# Done!
#
# Iteration 524/4187
# Processing unified_id 6514e8a8f8d48a5468337952
# Done!
#
# Iteration 525/4187
# Processing unified_id 64d4a0100c884818f2029330
# Done!
#
# Iteration 526/4187
# Processing unified_id 63e3da9bad4adb156af213b3
# Done!
#
# Iteration 527/4187
# Processing unified_id 65b86080807168542fb100a9
# Done!
#
# Iteration 528/4187
# Processing unified_id 65cec9df9faa1918f7609588
# Done!
#
# Iteration 529/4187
# Processing unified_id 665e5f316638481b8df5791e
# Done!
#
# Iteration 530/4187
# Processing unified_id 63ba51df302258631abc3891
# Done!
#
# Iteration 531/4187
# Processing unified_id 659fd495955f612f53e019d7
# Done!
#
# Iteration 532/4187
# Processing unified_id 6238627571689a670c6b8c4e
# Done!
#
# Iteration 533/4187
# Processing unified_id 6524cfcbead122732c9699fa
# Done!
#
# Iteration 534/4187
# Processing unified_id 6417ff09a8c1f7081eaa0418
# Done!
#
# Iteration 535/4187
# Processing unified_id 64aeaa0ff7baf07cffdd738a
# Done!
#
# Iteration 536/4187
# Processing unified_id 6711c8a804c993fa9f546b30
# Done!
# Processing unified_id 66d99ac029fdcad663bbe043
# Done!
#
# Iteration 572/4187
# Processing unified_id 6498f9f3c7f8f47151436049
# Done!
#
# Iteration 573/4187
# Processing unified_id 63ecdf04e35855063e4b594b
# Done!
#
# Iteration 574/4187
# Processing unified_id 64fb5254c397d213263bbe2f
# Done!
#
# Iteration 575/4187
# Processing unified_id 60c4477af7fc78748201a8cf
# Done!
#
# Iteration 576/4187
# Processing unified_id 66687cb621caef11b31fc787
# Done!
#
# Iteration 577/4187
# Processing unified_id 629aaf65d4f4751064b4aa2c
# Done!
#
# Iteration 578/4187
# Processing unified_id 65e8881b7803d36781b07ce4
# Done!
#
# Iteration 579/4187
# Processing unified_id 671bd0ccf7d714e9052d9ea5
# Done!
#
# Iteration 580/4187
# Processing unified_id 64f1724082cad0688ed2d545
# Done!
#
# Iteration 581/4187
# Processing unified_id 64c2bac0a791d16644735ed4
# Done!
#
# Iteration 582/4187
# Processing unified_id 659b4247f4576f717dd50ec6
# Done!
#
# Iteration 583/4187
# Processing unified_id 650d0186d327dc5dae280a90
# Done!
#
# Iteration 584/4187
# Processing unified_id 62453a4d950aa43054cffd26
# Done!
#
# Iteration 585/4187
# Processing unified_id 6556eda8d4baa95a1807141a
# Done!
#
# Iteration 586/4187
# Processing unified_id 628b1cb7ffa0451cd76317e1
# Done!
#
# Iteration 587/4187
# Processing unified_id 6466fe86c1623e6d08bae08c
# Done!
#
# Iteration 588/4187
# Processing unified_id 64912d5f96526e177a52bc33
# Done!
#
# Iteration 589/4187
# Processing unified_id 5f493530b3f4a2190b676f1d
# Done!
#
# Iteration 590/4187
# Processing unified_id 639cabb1ad4adb627a79e6bd
# Done!
#
# Iteration 591/4187
# Processing unified_id 66050958ec3c1117710970b9
# Done!
#
# Iteration 592/4187
# Processing unified_id 60776d444060ef352c67db8a
# Done!
#
# Iteration 593/4187
# Processing unified_id 660387f273f5ad3356707a27
# Done!
#
# Iteration 594/4187
# Processing unified_id 653cd3e8594b7b39e9ec42f9
# Done!
#
# Iteration 595/4187
# Processing unified_id 662dcb4dac6b59370913e8c8
# Done!
#
# Iteration 596/4187
# Processing unified_id 65543d12379f6d256ee21b99
# Done!
#
# Iteration 597/4187
# Processing unified_id 6677b7c1d8316b0d3d1bd903
# Done!
#
# Iteration 598/4187
# Processing unified_id 660df4e016140f22016895cc
# Done!
#
# Iteration 599/4187
# Processing unified_id 64ce95d0697eff2798068618
# Done!
#
# Iteration 600/4187
# Processing unified_id 66cfc00c70c8c6f34f7c5f6d
# Done!
#
# Iteration 601/4187
# Processing unified_id 65c49850e18dac29e93d25a2
# Done!
#
# Iteration 602/4187
# Processing unified_id 60a71ab403e99e432644143c
# Done!
#
# Iteration 603/4187
# Processing unified_id 6053333dbbbfa401a4d768a3
# Done!
#
# Iteration 604/4187
# Processing unified_id 65e8006aab9d2c46f6bf7b2c
# Done!
#
# Iteration 605/4187
# Processing unified_id 6372f7c3e06cfb39bb4c052d
# Done!
#
# Iteration 606/4187
# Processing unified_id 647b3613358b4702598fedff
# Done!
#
# Iteration 607/4187
# Processing unified_id 64d26e651e6f743eae05ac5b
# Done!
#
# Iteration 608/4187
# Processing unified_id 65346de2a9022f48cf9fea91
# Done!
#
# Iteration 609/4187
# Processing unified_id 66698f4fb3ae27fc1429e36b
# Done!
#
# Iteration 610/4187
# Processing unified_id 64bde4c83097596d8e327dae
# Done!
#
# Iteration 611/4187
# Processing unified_id 658e120d59f83d59bfeee27d
# Done!
#
# Iteration 612/4187
# Processing unified_id 6325f122b3ae2746db49b1eb
# Done!
#
# Iteration 613/4187
# Processing unified_id 63f58d02da86162676d4b289
# Done!
#
# Iteration 614/4187
# Processing unified_id 64190da078ba2b37961da01e
# Done!
#
# Iteration 615/4187
# Processing unified_id 652547ca05f57b5ed221a57c
# Done!
#
# Iteration 616/4187
# Processing unified_id 64cb2f250cf4835a45bda71b
# Done!
#
# Iteration 617/4187
# Processing unified_id 66a1066a8211f5674f76781c
# Done!
#
# Iteration 618/4187
# Processing unified_id 66055189a910a719c6af5716
# Done!
#
# Iteration 619/4187
# Processing unified_id 6582f0b39208b038459934a1
# Done!
#
# Iteration 620/4187
# Processing unified_id 641a563a84af6c562029e792
# Done!
#
# Iteration 621/4187
# Processing unified_id 61c2af64d4661561c0ce1230
# Done!
#
# Iteration 622/4187
# Processing unified_id 63da4008ece838580dd6e12d
# Done!
#
# Iteration 623/4187
# Processing unified_id 65f91a92b783a42f3bd57215
# Done!
#
# Iteration 624/4187
# Processing unified_id 609a32e0e70a2019461588f6
# Done!
#
# Iteration 625/4187
# Processing unified_id 616a4cfcd679e802fa050b27
# Done!
#
# Iteration 626/4187
# Processing unified_id 637653d27323b3172a7d05ad
# Done!
#
# Iteration 627/4187
# Processing unified_id 6598ae2e0e7ac8716dae3caf
# Done!
#
# Iteration 628/4187
# Processing unified_id 66a2ad1ea86ec4b77da07c19
# Done!
#
# Iteration 629/4187
# Processing unified_id 65544d2aad4adb23da617e8d
# Done!
#
# Iteration 630/4187
# Processing unified_id 65f2c7134d4ff929dc77b561
# Done!
#
# Iteration 631/4187
# Processing unified_id 61298fb033c4d633f9258426
# Done!
#
# Iteration 632/4187
# Processing unified_id 654074cdfad3be5221585537
# Done!
#
# Iteration 633/4187
# Processing unified_id 645092d6bd259e0bb6f17f08
# Done!
#
# Iteration 634/4187
# Processing unified_id 648a04c4698f8d5ccc3ca88d
# Done!
#
# Iteration 635/4187
# Processing unified_id 63e479dd03e99e1d4fcbb07f
# Done!
#
# Iteration 636/4187
# Processing unified_id 6024c0f2b21dc836bafc2f77
# Done!
#
# Iteration 637/4187
# Processing unified_id 664c29ebad4adb81b92b17dd
# Done!
#
# Iteration 638/4187
# Processing unified_id 6378866be6bd53715b31a27b
# Done!
#
# Iteration 639/4187
# Processing unified_id 63dbbb40ded9c93fec4118f7
# Done!
#
# Iteration 640/4187
# Processing unified_id 6567ef26f5eeb978c462c0cb
# Done!
#
# Iteration 641/4187
# Processing unified_id 64352a4705557331118a3cc7
# Done!
#
# Iteration 642/4187
# Processing unified_id 6593d119ba2c860e52c4bdaf
# Done!
#
# Iteration 643/4187
# Processing unified_id 650d2160ba2c8658d4f44da4
# Done!
#
# Iteration 644/4187
# Processing unified_id 655cb14bbd3ebd5da9f0516f
# Done!
#
# Iteration 645/4187
# Processing unified_id 658f8f982b5e681459a816d3
# Done!
#
# Iteration 646/4187
# Processing unified_id 669dc9d8e04f78d8e9c99c18
# Done!
#
# Iteration 647/4187
# Processing unified_id 64677124c51eae4b686a16ef
# Done!
#
# Iteration 648/4187
# Processing unified_id 6526b69f0d061a7b0aa62f7c
# Done!
#
# Iteration 649/4187
# Processing unified_id 654714f6aa75d856601d4390
# Done!
#
# Iteration 650/4187
# Processing unified_id 664e983e97ac3b5f79d2bb4a
# Done!
#
# Iteration 651/4187
# Processing unified_id 63c70d57b3ae271a0c9eea11
# Done!
#
# Iteration 652/4187
# Processing unified_id 665d255075a2380eaf1ef3dc
# Done!
#
# Iteration 653/4187
# Processing unified_id 66a48512e3e8bb583ced30ad
# Done!
#
# Iteration 654/4187
# Processing unified_id 652c585b3c6e2e513cdac939
# Done!
#
# Iteration 655/4187
# Processing unified_id 64fc084cb3ae2719e22147c4
# Done!
#
# Iteration 656/4187
# Processing unified_id 661bf4ea8b7d4a21404c49a7
# Done!
#
# Iteration 657/4187
# Processing unified_id 64fb6895594b7b4362c56626
# Done!
#
# Iteration 658/4187
# Processing unified_id 64afb93dad4adb43c49e2c01
# Done!
#
# Iteration 659/4187
# Processing unified_id 5faf88bf4de76e3ce428a02d
# Done!
#
# ...
# Done!
#
# Iteration 3972/4187
# Processing unified_id 640e8a291de3c656568ad936
# Done!
#
# Iteration 3973/4187
# Processing unified_id 640ea0ceb7c50e54e5c15c28
# Done!
#
# Iteration 3974/4187
# Processing unified_id 640ef00d7678a4273dc878de
# Done!
#
# Iteration 3975/4187
# Processing unified_id 6410789e6b20ff63186ddb7c
# Done!
#
# Iteration 3976/4187
# Processing unified_id 6410f5b65993e747e491ab08
# Done!
#
# Iteration 3977/4187
# Processing unified_id 64116dceb6f0803023eff61f
# Done!
#
# Iteration 3978/4187
# Processing unified_id 6412f07b94fd9e79a7ee121b
# Done!
#
# Iteration 3979/4187
# Processing unified_id 641336685157005cb1f7a608
# Done!
#
# Iteration 3980/4187
# Processing unified_id 64156975e77c6f300c54ec80
# Done!
#
# Iteration 3981/4187
# Processing unified_id 641617a1627735287f72ace7
# Done!
#
# Iteration 3982/4187
# Processing unified_id 641682c06fe233539cfa2d7c
# Done!
#
# Iteration 3983/4187
# Processing unified_id 6416f51f8c57377bf1b46e77
# Done!
#
# Iteration 3984/4187
# Processing unified_id 6417b32dbe5e7f50eb73927a
# Done!
#
# Iteration 3985/4187
# Processing unified_id 6417e1f4660c3455962bd70e
# Done!
#
# Iteration 3986/4187
# Processing unified_id 64180f9731046966a451dfb4
# Done!
#
# Iteration 3987/4187
# Processing unified_id 64181bb74ccb80415e15d3b8
# Done!
#
# Iteration 3988/4187
# Processing unified_id 64188af79c962130e4e1a4cb
# Done!
#
# Iteration 3989/4187
# Processing unified_id 641943a128ecec5301cf0978
# Done!
#
# Iteration 3990/4187
# Processing unified_id 6419be717796b43c7f54e8aa
# Done!
#
# Iteration 3991/4187
# Done!
#
# Iteration 4063/4187
# Processing unified_id 645f04ffeaed7272179926d3
# Done!
#
# Iteration 4064/4187
# Processing unified_id 6461dd3e7bde8f75717916b2
# Done!
#
# Iteration 4065/4187
# Processing unified_id 646250950e82ff332099fd81
# Done!
#
# Iteration 4066/4187
# Processing unified_id 646326e6ad4adb717d35c036
# Done!
#
# Iteration 4067/4187
# Processing unified_id 64647506775e462b0c4bf9ba
# Done!
#
# Iteration 4068/4187
# Processing unified_id 6465917aad4adb71e3e5e03c
# Done!
#
# Iteration 4069/4187
# Processing unified_id 646718372a360435efcd0991
# Done!
#
# Iteration 4070/4187
# Processing unified_id 646735f67b9c1b1f4b7e429a
# Done!
#
# Iteration 4071/4187
# Processing unified_id 6467a4994fd86a4fe3fc0a06
# Done!
#
# Iteration 4072/4187
# Processing unified_id 646886026f979e59e09b3a60
# Done!
#
# Iteration 4073/4187
# Processing unified_id 646a548e548d6a26578d7747
# Done!
#
# Iteration 4074/4187
# Processing unified_id 646a9c4afc53c8266f92f59e
# Done!
#
# Iteration 4075/4187
# Processing unified_id 646b01a2c01f9126603efe4e
# Done!
#
# Iteration 4076/4187
# Processing unified_id 646d32ca6fff1224d5b79372
# Done!
#
# Iteration 4077/4187
# Processing unified_id 646dde09106d0b07f474aec0
# Done!
#
# Iteration 4078/4187
# Processing unified_id 646df1ed480e646ee66a6e95
# Done!
#
# Iteration 4079/4187
# Processing unified_id 646ed7973eb54b766ce13b33
# Done!
#
# Iteration 4080/4187
# Processing unified_id 647355186237396a23b47aa7
# Done!
#
# Iteration 4081/4187
# Processing unified_id 6474883b30bb45625b250fea
# Done!
#
# Iteration 4082/4187
# Processing unified_id 6475618e077601792f69a762
# Done!
#
# Iteration 4083/4187
# Processing unified_id 64763199d8f702599f19bac0
# Done!
#
# Iteration 4084/4187
# Processing unified_id 6476b67cb3ae272195af6dd5
# Done!
#
# Iteration 4085/4187
# Processing unified_id 6479ef45c01f91622c1eadc2
# Done!
#
# Iteration 4086/4187
# Processing unified_id 647be9ef4de76e7bd5c2a84e
# Done!
#
# Iteration 4087/4187
# Processing unified_id 647eef9234394c2ac136b042
# Done!
#
# Iteration 4088/4187
# Processing unified_id 647f469c9492f62016dc2d73
# Done!
#
# Iteration 4089/4187
# Processing unified_id 64802578045fce0617fd7dd9
# Done!
#
# Iteration 4090/4187
# Processing unified_id 64809aea4ce44e75fe37a76e
# Done!
#
# Iteration 4091/4187
# Processing unified_id 6480ea6a22863a0b94309586
# Done!
#
# Iteration 4092/4187
# Processing unified_id 6481967fdde1d10c4cd81f6d
# Done!
#
# Iteration 4093/4187
# Processing unified_id 648203e8aaeb8362aac0590f
# Done!
#
# Iteration 4094/4187
# Processing unified_id 648289dd6022c53d5b7e8bb8
# Done!
#
# Iteration 4095/4187
# Processing unified_id 6482903e8d50eb061f808a30
# Done!
#
# Iteration 4096/4187
# Processing unified_id 64837ee75de85852af64c2bb
# Done!
#
# Iteration 4097/4187
# Processing unified_id 648ac99430d67a6eff3c02e1
# Processing unified_id 65223bfdfdcd83580759e8f0
# Done!
#
# Iteration 4168/4187
# Processing unified_id 652cd618885187783ceaa79f
# Done!
#
# Iteration 4169/4187
# Processing unified_id 652dd64f4d59be7141b9b98c
# Done!
#
# Iteration 4170/4187
# Processing unified_id 652f9112ae430c3d2de9336d
# Done!
#
# Iteration 4171/4187
# Processing unified_id 6535dfd78636176c51d89db4
# Done!
#
# Iteration 4172/4187
# Processing unified_id 653a05fdf960096b90665399
# Done!
#
# Iteration 4173/4187
# Processing unified_id 653a94fe1b96f16c7c3de937
# Done!
#
# Iteration 4174/4187
# Processing unified_id 653b30f39c7c3e380cc0b71c
# Done!
#
# Iteration 4175/4187
# Processing unified_id 654156d6bfc5dc5f40d8a92f
# Done!
#
# Iteration 4176/4187
# Processing unified_id 65443dd03e9fd32de7337ad5
# Done!
#
# Iteration 4177/4187
# Processing unified_id 6544725233c4d62a3ffd551e
# Done!
#
# Iteration 4178/4187
# Processing unified_id 654d78f787b2754c24cf45ba
# Done!
#
# Iteration 4179/4187
# Processing unified_id 654edf4c58f59b6d1d3cb27b
# Done!
#
# Iteration 4180/4187
# Processing unified_id 6553620e93f17f5bdb2e120e
# Done!
#
# Iteration 4181/4187
# Processing unified_id 6555b0f6ebfdf7513efae446
# Done!
#
# Iteration 4182/4187
# Processing unified_id 65567c4cfe0329481ef230ff
# Done!
#
# Iteration 4183/4187
# Processing unified_id 6560c5384a9aab309997203f
# Done!
#
# Iteration 4184/4187
# Processing unified_id 65613fdb90d35f013b308d7f
# Done!
#
# Iteration 4185/4187
# Processing unified_id 6577de01fe0b10310b71e29f
# Done!
#
# Iteration 4186/4187
# Processing unified_id 6580d67da558800d72ea1057
# Done!
#
# Iteration 4187/4187
# Processing unified_id 66061b83fbc0b138864b01f1
# Done!

# %%
# Testing get release date function

# %%
get_release_date_from_daily_game_performance_table(
    daily_sum_performance_df_for_games_released_in_2023_2024,
    '62fe31a07dbc4336ed0d0892'
)
# Out:
# datetime.date(2023, 1, 25)

# %%
daily_sum_performance_df_for_games_released_in_2023_2024
# Out:
# [{'unified_app_id': '6539d116d2e5a9284e6a76e2',
#   'daily_adjusted_revenue_series': 2024-03-07    5286
#   2024-03-08   33763
#   2024-03-09   36565
#   2024-03-10   42813
#   2024-03-11   42784
#                 ...
#   2024-11-23    7652
#   2024-11-24    5693
#   2024-11-25    4688
#   2024-11-26    6661
#   2024-11-27    6649
#   Length: 266, dtype: float64},
#  {'unified_app_id': '64d262a510a3142a25912bd2',
#   'daily_adjusted_revenue_series': 2024-02-25       2
#   2024-02-26     302
#   2024-02-27     542
#   2024-02-28    6564
#   2024-02-29   25077
#                 ...
#   2024-11-23    5371
#   2024-11-24    5647
#   2024-11-25    6391
#   2024-11-26    6239
#   2024-11-27    6020
#   Length: 277, dtype: float64},
#  {'unified_app_id': '633b886973f76b48784c36b9',
#   'daily_adjusted_revenue_series': 2023-01-30       0
#   2023-01-31       0
#   2023-02-01       0
#   2023-02-02      38
#   2023-02-03     481
#                 ...
#   2024-11-26    0
#   2024-11-27    0
#   Length: 270, dtype: float64},
#  {'unified_app_id': '64f09ff0b3ae2770c6ac4c83',
#   'daily_adjusted_revenue_series': 2023-12-13   4
#   2023-12-14   4
#   2023-12-15   6
#   2023-12-16   9
#   2023-12-17   8
#                ..
#   2024-11-23   4
#   2024-11-24   4
#   2024-11-25   3
#   2024-11-26   3
#   2024-11-27   2
#   Length: 351, dtype: float64},
#  {'unified_app_id': '65281f6ecf149450ff3bc680',
#   'daily_adjusted_revenue_series': 2023-10-12     0
#   2023-10-13   120
#   2023-10-14    15
#   2023-10-15    68
#   2023-10-16     9
#                 ..
#   2024-11-23     0
#   2024-11-24     0
#   2024-11-25     0
#   2024-11-26     0
#   2024-11-27     0
#   Length: 413, dtype: float64},
#  {'unified_app_id': '6632cc06d49de620d41d6fae',
#   'daily_adjusted_revenue_series': 2024-05-02   0
#   2024-05-03   0
#   2024-05-07   0
#   2024-05-08   0
#   2024-05-09   0
#                ..
#   2024-11-23   9
#   2024-11-24   6
#   2024-11-25   8
#   2024-11-26   6
#   2024-11-27   4
#   Length: 201, dtype: float64},
#  {'unified_app_id': '65eae1baf008086d4d119281',
#   'daily_adjusted_revenue_series': 2024-03-04   1
#   2024-03-05   1
#   2024-03-06   1
#   2024-03-07   1
#   2024-03-08   1
#                ..
#   2024-11-23   1
#   2024-11-24   1
#   2024-11-25   1
#   2024-11-26   1
#   2024-11-27   1
#   Length: 267, dtype: float64},
#  {'unified_app_id': '6620046afcf09c318f786626',
#   'daily_adjusted_revenue_series': 2024-04-18   15
#   2024-04-19   16
#   2024-04-20   21
#   2024-04-21   22
#   2024-04-22    3
#                ..
#   2024-11-23    7
#   2024-11-24    8
#   2024-11-25    9
#   2024-11-26   12
#   2024-11-27    3
#   Length: 224, dtype: float64},
#  {'unified_app_id': '64d22def54624675a7cb5781',
#   'daily_adjusted_revenue_series': 2024-01-20   0
#   2024-01-21   1
#   2024-01-22   1
#   2024-01-23   1
#   2024-01-24   1
#                ..
#   2024-11-19   2
#   2024-11-20   2
#   2024-11-21   3
#   2024-11-26   0
#   2024-11-27   1
#   Length: 194, dtype: float64},
#  ...]

# %% [markdown]
# # Task ID-091-105: Calculate total rev of 2023 & 2024

# %%
# 2023 Total Rev

# %%
df_game_revenue_adjusted[2023].sum()
# Out:
# 620771189.25

# %%
# 2024 Total Rev

# %%
df_game_revenue_adjusted[2024].sum()
# Out:
# 645255035.0913253

# %% [markdown]
# # Task ID-101-626: Write function to calculate D7, D30 and D90 revenues

# %%
# Testing the function

# %%
test_game = daily_sum_performance_df_for_games_released_in_2023_2024[0]

# %%
test_game['unified_app_id']
# Out:
# '6539d116d2e5a9284e6a76e2'

# %%
calculate_first_n_day_revenue(
    daily_sum_performance_df_for_games_released_in_2023_2024,
    test_game['unified_app_id'],
    90
)
# Out:
# 3855864.39

# %% [markdown]
# # Task ID-081-480: Run the function to get the first 7-day, 30-day and 90-day revenue of games released in 2024

# %%
# Get the unified IDs of games released in 2024

# %%
games_released_in_2024 = list(
    filter(
        lambda x: x['release_year'] in [2024,],
        games_release_year
    )
)

# %%
list_unified_ids_released_in_2024 = list(
    map(
        lambda x: x['unified_app_id'],
        games_released_in_2024
    )
)

# %%
# Calculate D7, D30, D90 table for these games

# %%
new_games_performance_2024 = calculate_performance_for_new_games(
    daily_sum_performance_df_for_games_released_in_2023_2024,
    list_unified_ids_released_in_2024
)
# Out:
# Game 6700f9a78547467da5c62a2b does not have enough data points for 90-day revenue.
# Game 66c957353541e6dc062a9464 does not have enough data points for 90-day revenue.
# Game 66580d5ac55264a66c0ef1e5 does not have enough data points for 90-day revenue.
# Game 66fb97dffb320cffcfb1e326 does not have enough data points for 90-day revenue.
# Game 6670098947a500c078db041b does not have enough data points for 90-day revenue.
# Game 66cc10059e7c3b0db92da359 does not have enough data points for 90-day revenue.
# Game 66d28fe97bf35d0dbcf396a8 does not have enough data points for 90-day revenue.
# Game 671c9b792a534ff71cf88055 does not have enough data points for 30-day revenue.
# Game 671c9b792a534ff71cf88055 does not have enough data points for 90-day revenue.
# Game 666c314e108dacfa113ea464 does not have enough data points for 90-day revenue.
# Game 66cfe921110e857d09c8d395 does not have enough data points for 90-day revenue.
# Game 6573c39d5c3b423d5d04560f does not have enough data points for 90-day revenue.
# Game 647641acad220f0a40f82980 does not have enough data points for 90-day revenue.
# Game 66ea9e13cb4c1386e36bda83 does not have enough data points for 90-day revenue.
# Game 66c44213f87b4709ea1accc8 does not have enough data points for 90-day revenue.
# Game 667ee33a7d30ae1b930fb01d does not have enough data points for 90-day revenue.
# Game 66e593373e1f11bf5dc323cc does not have enough data points for 90-day revenue.
# Game 66cf467f4a925979c56cd84c does not have enough data points for 30-day revenue.
# Game 66cf467f4a925979c56cd84c does not have enough data points for 90-day revenue.
# Game 672353aca4c9da292e391435 does not have enough data points for 30-day revenue.
# Game 672353aca4c9da292e391435 does not have enough data points for 90-day revenue.
# Game 66581728e62f94191c273068 does not have enough data points for 90-day revenue.
# Game 66fa465f87d48d0f665a4acf does not have enough data points for 90-day revenue.
# Game 66bd20efa26c8332ff0dfd01 does not have enough data points for 90-day revenue.
# Game 6322100abd16da6f1e6d7ec2 does not have enough data points for 90-day revenue.
# Game 66b9c4b0e5dfbf0e5fb63f71 does not have enough data points for 90-day revenue.
# Game 66b6b5abc4bbd31d2645ef9a does not have enough data points for 90-day revenue.
# Game 67238b35f77092870c06c03d does not have enough data points for 30-day revenue.
# Game 67238b35f77092870c06c03d does not have enough data points for 90-day revenue.
# Game 65c67f67f51b52076cbdd6c9 does not have enough data points for 90-day revenue.
# Game 6674cc15a9d4319b95eb1ee6 does not have enough data points for 90-day revenue.
# Game 6712a9a4036618f0032576fa does not have enough data points for 30-day revenue.
# Game 6712a9a4036618f0032576fa does not have enough data points for 90-day revenue.
# Game 67085602d02dd71b4eb24acd does not have enough data points for 30-day revenue.
# Game 67085602d02dd71b4eb24acd does not have enough data points for 90-day revenue.
# Game 66c76b2cd940502783cd3f92 does not have enough data points for 90-day revenue.
# Game 617b48a80706ff094ef8b205 does not have enough data points for 30-day revenue.
# Game 617b48a80706ff094ef8b205 does not have enough data points for 90-day revenue.
# Game 597748480211a673830001c0 does not have enough data points for 30-day revenue.
# Game 597748480211a673830001c0 does not have enough data points for 90-day revenue.
# Game 65ac90b43511a21115e5ad40 does not have enough data points for 30-day revenue.
# Game 65ac90b43511a21115e5ad40 does not have enough data points for 90-day revenue.
# Game 629dad910ff289229dfc058e does not have enough data points for 30-day revenue.
# Game 629dad910ff289229dfc058e does not have enough data points for 90-day revenue.
# Game 6716517403a34f139e3c7e64 does not have enough data points for 7-day revenue.
# Game 6716517403a34f139e3c7e64 does not have enough data points for 30-day revenue.
# Game 6716517403a34f139e3c7e64 does not have enough data points for 90-day revenue.
# Game 639416cd4dc429249136cc51 does not have enough data points for 90-day revenue.
# Game 65863db3190adc43f4add3da does not have enough data points for 90-day revenue.
# Game 5b399af64cddf925e0c2a94d does not have enough data points for 30-day revenue.
# Game 5b399af64cddf925e0c2a94d does not have enough data points for 90-day revenue.
# Game 6583b1a1821935166dd6c769 does not have enough data points for 30-day revenue.
# Game 6583b1a1821935166dd6c769 does not have enough data points for 90-day revenue.
# Game 65d3010b656baa43a78914cf does not have enough data points for 30-day revenue.
# Game 65d3010b656baa43a78914cf does not have enough data points for 90-day revenue.
# Game 5d27e30b188d2e4eda773d99 does not have enough data points for 7-day revenue.
# Game 5d27e30b188d2e4eda773d99 does not have enough data points for 30-day revenue.
# Game 5d27e30b188d2e4eda773d99 does not have enough data points for 90-day revenue.
# Game 65681134f6275d0fe45db1eb does not have enough data points for 90-day revenue.
# Game 643707a8f7bab726f6c40c7d does not have enough data points for 30-day revenue.
# Game 643707a8f7bab726f6c40c7d does not have enough data points for 90-day revenue.

# %%
df_new_games_performance_2024 = pd.DataFrame(new_games_performance_2024)

# %%
df_new_games_performance_2024.to_csv('data/output/df_new_games_performance_2024.csv', index=False)

# %% [markdown]
# # Task ID-100-476: Get the list of games released during 2023

# %%
# Get the unified IDs of games released in 2024

# %%
games_released_in_2023 = list(
    filter(
        lambda x: x['release_year'] in [2023,],
        games_release_year
    )
)

# %%
list_unified_ids_released_in_2023 = list(
    map(
        lambda x: x['unified_app_id'],
        games_released_in_2023
    )
)

# %%
# Calculate D7, D30, D90 table for these games

# %%
new_games_performance_2023 = calculate_performance_for_new_games(
    daily_sum_performance_df_for_games_released_in_2023_2024,
    list_unified_ids_released_in_2023
)
# Out:
# Game 657a4f1e4124950cf802455e does not have enough data points for 90-day revenue.
# Game 65728067cc4c517f40cda163 does not have enough data points for 90-day revenue.
# Game 616640472cfa1f4fad686728 does not have enough data points for 90-day revenue.
# Game 63884b1162373922c0be61b9 does not have enough data points for 90-day revenue.
# Game 64fff8a21675515708ae8668 does not have enough data points for 90-day revenue.
# Game 63359b9bb3ae2779ad193bf1 does not have enough data points for 90-day revenue.
# Game 64b8ff7d8d4b232e43e52e50 does not have enough data points for 90-day revenue.
# Game 6535dfd78636176c51d89db4 does not have enough data points for 90-day revenue.
# Game 653a05fdf960096b90665399 does not have enough data points for 90-day revenue.
# Game 653a94fe1b96f16c7c3de937 does not have enough data points for 30-day revenue.
# Game 653a94fe1b96f16c7c3de937 does not have enough data points for 90-day revenue.
# Game 654156d6bfc5dc5f40d8a92f does not have enough data points for 30-day revenue.
# Game 654156d6bfc5dc5f40d8a92f does not have enough data points for 90-day revenue.
# Game 65443dd03e9fd32de7337ad5 does not have enough data points for 30-day revenue.
# Game 65443dd03e9fd32de7337ad5 does not have enough data points for 90-day revenue.
# Game 6544725233c4d62a3ffd551e does not have enough data points for 90-day revenue.
# Game 654d78f787b2754c24cf45ba does not have enough data points for 90-day revenue.
# Game 654edf4c58f59b6d1d3cb27b does not have enough data points for 30-day revenue.
# Game 654edf4c58f59b6d1d3cb27b does not have enough data points for 90-day revenue.
# Game 6553620e93f17f5bdb2e120e does not have enough data points for 30-day revenue.
# Game 6553620e93f17f5bdb2e120e does not have enough data points for 90-day revenue.
# Game 6555b0f6ebfdf7513efae446 does not have enough data points for 30-day revenue.
# Game 6555b0f6ebfdf7513efae446 does not have enough data points for 90-day revenue.
# Game 65567c4cfe0329481ef230ff does not have enough data points for 30-day revenue.
# Game 65567c4cfe0329481ef230ff does not have enough data points for 90-day revenue.
# Game 6560c5384a9aab309997203f does not have enough data points for 90-day revenue.
# Game 65613fdb90d35f013b308d7f does not have enough data points for 90-day revenue.
# Game 6577de01fe0b10310b71e29f does not have enough data points for 90-day revenue.
# Game 6580d67da558800d72ea1057 does not have enough data points for 30-day revenue.
# Game 6580d67da558800d72ea1057 does not have enough data points for 90-day revenue.

# %%
df_new_games_performance_2023 = pd.DataFrame(new_games_performance_2023)

# %%
df_new_games_performance_2023.to_csv('data/output/df_new_games_performance_2023.csv', index=False)

# %% [markdown]
# # Task ID-095-734: Calculate CAGR for every genre 2014 - 2024

# %%
# Import cleaned genre data to game full info DataFrame

# %%
df_genre_validation_gpt_output_manually_corrected = pd.read_csv(
    'data/input/genre_validation_gpt_output_manually_corrected.csv'
)

# %%
df_genre_validation_gpt_output_manually_corrected = df_genre_validation_gpt_output_manually_corrected.drop(
    columns = ['Unnamed: 0']
)

# %%
df_game_full_info_with_corrected_genres = update_game_classification(
    df_game_full_info, 
    df_genre_validation_gpt_output_manually_corrected
)

# %%
# Additional cleaning for 2 games that do not have classfication data

# %%
additional_genre_cleaning_data = [
    {
        'game_id': '57a00886fcc9bf22dc000061',
        'finalized_game_class': 'Lifestyle & Puzzle',
        'finalized_game_genre': 'Tabletop',
        'finalized_game_subgenre': 'Board'
    },
    {
        'game_id': '6093457f165c24138d3573e4',
        'finalized_game_class': 'Lifestyle & Puzzle',
        'finalized_game_genre': 'Simulation',
        'finalized_game_subgenre': 'Simulator'
    }
]

# %%
df_game_full_info_with_corrected_genres = update_game_classification(
    df_game_full_info_with_corrected_genres,
    pd.DataFrame(additional_genre_cleaning_data)
)

# %%
df_game_full_info_with_corrected_genres.to_csv('data/output/df_game_full_info_with_corrected_genres.csv', index = False)

# %%
# Join genere information to df_game_revenue_adjusted

# %%
df_game_revenue_adjusted_with_genre_info = join_game_genres_to_revenue(
    df_game_revenue_adjusted, 
    df_game_full_info_with_corrected_genres
)

# %%
# Additional cleaning (classification assignment) for 4 games 
# that exist in df_game_revenue_adjusted (also in raw_game_data_df 
# and in ST manually downloaded game performance data
# But these games cannot be searched in ST search bar
# and do not show up in API-querying game info (unified game data/canonical app data)

# %%
additional_genre_cleaning_data_2 = [
    {
        'game_id': '6325e999594b7b7d941a8b4f',
        'finalized_game_class': 'Lifestyle & Puzzle',
        'finalized_game_genre': 'Simulation',
        'finalized_game_subgenre': 'Simulator'
    },
    {
        'game_id': '630f1cd8dc8e05696cfa66a6',
        'finalized_game_class': 'Lifestyle & Puzzle',
        'finalized_game_genre': 'Simulation',
        'finalized_game_subgenre': 'Avatar Life'
    },
    {
        'game_id': '60fe57ac5de8586d10af26e5',
        'finalized_game_class': 'Lifestyle & Puzzle',
        'finalized_game_genre': 'Simulation',
        'finalized_game_subgenre': 'Simulator'
    },
    {
        'game_id': '57c62c560a94ac4a6e00215b',
        'finalized_game_class': 'Action & Strategy',
        'finalized_game_genre': 'RPG',
        'finalized_game_subgenre': 'MMORPG'
    }
]

# %%
df_game_revenue_adjusted_with_genre_info = update_game_classification_for_revenue_df(
    df_game_revenue_adjusted_with_genre_info,
    additional_genre_cleaning_data_2
)

# %%
# Save file

# %%
df_game_revenue_adjusted_with_genre_info.to_csv(
    'data/output/df_game_revenue_adjusted_with_genre_info.csv'
)

# %%
# Calculate CAGR for every class

# %%
def calculate_revenue_and_growth_by_classification(df_revenue_with_genres, classification):
    """
    Calculate total revenue, YoY growth, and CAGR for revenue grouped by 'game_class'.

    Args:
        df_revenue_with_genres (pd.DataFrame): Revenue data with 'game_class', 'game_genre', 'game_subgenre'.
        classification (str): Classification to group by ('class', 'genre', 'subgenre').

    Returns:
        tuple: Two DataFrames:
            - Total revenue by game class.
            - Growth and CAGR by game class.
    """

    classifications = ['class', 'genre', 'subgenre']
    if classification not in classifications:
        raise Exception('Invalid classification. Must be in the list {}'.format(classifications))

    full_classification_list = ['game_' + cls for cls in classifications]

    if classification == 'class':
        to_drop_list = ['game_genre', 'game_subgenre']
        groupby_list = ['game_class']
    elif classification == 'genre':
        to_drop_list = ['game_subgenre']
        groupby_list = ['game_class', 'game_genre']
    else:
        to_drop_list = []
        groupby_list = full_classification_list

    # Group by classification and sum revenue
    total_revenue = df_revenue_with_genres.drop(
        to_drop_list, axis=1
    ).groupby(groupby_list).sum()

    # Calculate YoY growth (proportions, not percentages)
    yoy_growth = total_revenue.pct_change(axis=1) * 100

    # Calculate CAGR with dynamic start year
    cagr_results = {}
    for game_class, revenue_row in total_revenue.iterrows():
        # Drop NaN values
        revenue_row = revenue_row.dropna()

        # Dynamically determine the first year with non-zero revenue
        for year in revenue_row.index:
            if revenue_row[year] > 0:
                actual_start_year = year
                break
        else:
            # If no non-zero revenue found, skip this group
            cagr_results[game_class] = None
            continue

        # Determine the end year
        actual_end_year = revenue_row.index.max()
        revenue_start = revenue_row[actual_start_year]
        revenue_end = revenue_row[actual_end_year]

        if actual_start_year == actual_end_year or revenue_start == 0 or revenue_end == 0:
            # Cannot calculate CAGR for only one year or if revenue is zero
            cagr_results[game_class] = None
        else:
            num_years = int(actual_end_year) - int(actual_start_year)
            cagr_results[game_class] = ((revenue_end / revenue_start) ** (1 / num_years) - 1) * 100

    # Create a DataFrame for CAGR
    cagr_df = pd.DataFrame.from_dict(cagr_results, orient='index', columns=['CAGR'])

    # Combine results into one DataFrame with only YoY growth and CAGR
    growth_and_cagr = pd.concat([yoy_growth.add_suffix('_YoY'), cagr_df], axis=1)

    return total_revenue, growth_and_cagr

# %%
df_class_revenue_adjusted, df_class_revenue_growth_adjusted = calculate_revenue_and_growth_by_classification(
    df_game_revenue_adjusted_with_genre_info,
    'class'
)

# %%
df_genre_revenue_adjusted, df_genre_revenue_growth_adjusted = calculate_revenue_and_growth_by_classification(
    df_game_revenue_adjusted_with_genre_info,
    'genre'
)

# %%
df_subgenre_revenue_adjusted, df_subgenre_revenue_growth_adjusted = calculate_revenue_and_growth_by_classification(
    df_game_revenue_adjusted_with_genre_info,
    'subgenre'
)

# %%
df_subgenre_revenue_adjusted.to_csv('data/output/df_subgenre_revenue_adjusted.csv')

# %%
df_subgenre_revenue_growth_adjusted.to_csv('data/output/df_subgenre_revenue_growth_adjusted.csv')

# %% [markdown]
# # Task ID-077-281: Calculate Release Date of Games released in 2024

# %%
# The list of unified ids of games released in 2024

# %%
# Create a table of unified_ids - released dates for 2024 new games

# %%
release_dates_of_games_released_in_2023_2024 = list(
    map(
        lambda x: {
            'unified_app_id': x['unified_app_id'],
            'release_year': x['release_year'],
            'release_date': get_release_date_from_daily_game_performance_table(
                daily_sum_performance_df_for_games_released_in_2023_2024,
                x['unified_app_id']
            )
        },
        games_released_in_2023_2024
    )
)
# Out:
# Processing unified app id: 6539d116d2e5a9284e6a76e2
# Processing unified app id: 64d262a510a3142a25912bd2
# Processing unified app id: 633b886973f76b48784c36b9
# Processing unified app id: 5da67c09a546ab1edeb6c50d
# Processing unified app id: 63e5633fded9c9175b7fca1e
# Processing unified app id: 64fb527ee935e16ab92c6938
# Processing unified app id: 639ff55ec7f5ec0d1883c726
# Processing unified app id: 62f32a5044136e0eba10c9ba
# Processing unified app id: 666a7679850648f34fb41215
# Processing unified app id: 64fb52e1649dfd28c72aa698
# Processing unified app id: 5d84173e3ea9835b8b1d4081
# Processing unified app id: 651504efd211a646d98e8b5a
# Processing unified app id: 64a91142f08b1411f1c62ffc
# Processing unified app id: 6641bd6ed6c68d326fdd8917
# Processing unified app id: 63c277626f979e711c7d7886
# Processing unified app id: 63ecece74760b21b6d8706b2
# Processing unified app id: 65cc5eab69eefb4fad4c1376
# Processing unified app id: 65a1e8cd950aa41941ff9752
# Processing unified app id: 65fd06dba6a66211427de1cd
# Processing unified app id: 64075e77537c41636a8e1c58
# Processing unified app id: 661e16f2b279ba3aff370af0
# Processing unified app id: 64f1c458fd69866ae393bcfc
# Processing unified app id: 64f1e67fdd26d5691375da8c
# Processing unified app id: 64f56ac2b83e6660d1632bcc
# Processing unified app id: 64f9c4fff2930b59f4907f20
# Processing unified app id: 650165beadc18f3d1ea75699
# Processing unified app id: 650908cdda6776191e77c1a1
# Processing unified app id: 6509375496c652552961fad1
# Processing unified app id: 650a59b31de3c6423483da8f
# Processing unified app id: 65167ed8008d7472705865ca
# Processing unified app id: 6516d43c06696d6bd0076b64
# Processing unified app id: 65203557b7a83c2bd55fa1fc
# Processing unified app id: 65223bfdfdcd83580759e8f0
# Processing unified app id: 652cd618885187783ceaa79f
# Processing unified app id: 652dd64f4d59be7141b9b98c
# Processing unified app id: 652f9112ae430c3d2de9336d
# Processing unified app id: 6535dfd78636176c51d89db4
# Processing unified app id: 653a05fdf960096b90665399
# Processing unified app id: 653a94fe1b96f16c7c3de937
# Processing unified app id: 653b30f39c7c3e380cc0b71c
# Processing unified app id: 654156d6bfc5dc5f40d8a92f
# Processing unified app id: 65443dd03e9fd32de7337ad5
# Processing unified app id: 6544725233c4d62a3ffd551e
# Processing unified app id: 654d78f787b2754c24cf45ba
# Processing unified app id: 654edf4c58f59b6d1d3cb27b
# Processing unified app id: 6553620e93f17f5bdb2e120e
# Processing unified app id: 6555b0f6ebfdf7513efae446
# Processing unified app id: 65567c4cfe0329481ef230ff
# Processing unified app id: 6560c5384a9aab309997203f
# Processing unified app id: 65613fdb90d35f013b308d7f
# Processing unified app id: 6577de01fe0b10310b71e29f
# Processing unified app id: 6580d67da558800d72ea1057
# Processing unified app id: 66061b83fbc0b138864b01f1

# %%
df_release_dates_of_games_released_in_2023_2024 = pd.DataFrame(
    release_dates_of_games_released_in_2023_2024
)

# %%
df_release_dates_of_games_released_in_2023_2024.to_csv('data/output/df_release_dates_of_games_released_in_2023_2024.csv', index=False)

# %% [markdown]
# # Task ID-102-525: Calculate average monthly revenue for all games released in 2023 & 2024

# %%
games_released_in_2023_2024
# Out:
# [{'unified_app_id': '6539d116d2e5a9284e6a76e2', 'release_year': 2024},
#  {'unified_app_id': '64d262a510a3142a25912bd2', 'release_year': 2024},
#  {'unified_app_id': '633b886973f76b48784c36b9', 'release_year': 2023},
#  {'unified_app_id': '5da67c09a546ab1edeb6c50d', 'release_year': 2023},
#  {'unified_app_id': '63e5633fded9c9175b7fca1e', 'release_year': 2023},
#  {'unified_app_id': '64fb527ee935e16ab92c6938', 'release_year': 2023},
#  {'unified_app_id': '639ff55ec7f5ec0d1883c726', 'release_year': 2023},
#  {'unified_app_id': '62f32a5044136e0eba10c9ba', 'release_year': 2023},
#  {'unified_app_id': '666a7679850648f34fb41215', 'release_year': 2024},
#  {'unified_app_id': '64fb52e1649dfd28c72aa698', 'release_year': 2023},
#  {'unified_app_id': '5d84173e3ea9835b8b1d4081', 'release_year': 2023},
#  {'unified_app_id': '651504efd211a646d98e8b5a', 'release_year': 2023},
#  {'unified_app_id': '64a91142f08b1411f1c62ffc', 'release_year': 2023},
#  {'unified_app_id': '66904a855882c30a12dc9544', 'release_year': 2024},
#  {'unified_app_id': '64f1767232fe4242418968c3', 'release_year': 2024},
#  {'unified_app_id': '660230937b8e41633d6ff1b9', 'release_year': 2024},
#  {'unified_app_id': '64e6bc41e19d8369562c2f48', 'release_year': 2023},
#  {'unified_app_id': '664eca6a35c8599ccb6efd5e', 'release_year': 2024},
#  {'unified_app_id': '64103c25e5f1a773b37f8abf', 'release_year': 2023},
#  {'unified_app_id': '63a3d0e9b1b0a10a69f48b4c', 'release_year': 2024},
#  {'unified_app_id': '62ccfc956015ac4089418041', 'release_year': 2023},
#  {'unified_app_id': '64c0b3188c85a0522c08a46e', 'release_year': 2023},
#  {'unified_app_id': '66081c294b864f75f127eeb7', 'release_year': 2024},
#  {'unified_app_id': '66dbf79840dfb7d4a9b1dce9', 'release_year': 2024},
#  {'unified_app_id': '66be0dd2356d7ec3b1e597dc', 'release_year': 2024},
#  {'unified_app_id': '66f78742ea3daf9ce5afd4cb', 'release_year': 2024},
#  {'unified_app_id': '626c9e943c0c6b1c656af25c', 'release_year': 2024},
#  {'unified_app_id': '66362d8ead4adb24eb569c95', 'release_year': 2024},
#  {'unified_app_id': '6706e83974075026fda87f3d', 'release_year': 2024},
#  {'unified_app_id': '62c19a55928f7e02003e935e', 'release_year': 2023},
#  {'unified_app_id': '65c0981dad4adb70336fb53e', 'release_year': 2024},
#  {'unified_app_id': '64f09ff0b3ae2770c6ac4c83', 'release_year': 2023},
#  {'unified_app_id': '65281f6ecf149450ff3bc680', 'release_year': 2023},
#  {'unified_app_id': '6632cc06d49de620d41d6fae', 'release_year': 2024},
#  {'unified_app_id': '65eae1baf008086d4d119281', 'release_year': 2024},
#  {'unified_app_id': '6620046afcf09c318f786626', 'release_year': 2024},
#  {'unified_app_id': '64d22def54624675a7cb5781', 'release_year': 2024},
#  ...]

# %%
avg_monthly_revenue_of_games_released_in_2023_2024 = list(
    map(
        lambda x: {
            'unified_app_id': x['unified_app_id'],
            'release_year': x['release_year'],
            'average_monthly_revenue': calculate_average_30_day_revenue(
                daily_sum_performance_df_for_games_released_in_2023_2024,
                x['unified_app_id']
            )['average_30_day_revenue']
        },
        games_released_in_2023_2024
    )
)

# %%
avg_monthly_revenue_of_games_released_in_2023_2024
# Out:
# [{'unified_app_id': '6539d116d2e5a9284e6a76e2',
#   'release_year': 2024,
#   'average_monthly_revenue': 776540.5815789474},
#  {'unified_app_id': '64d262a510a3142a25912bd2',
#   'release_year': 2024,
#   'average_monthly_revenue': 707415.4667870037},
#  {'unified_app_id': '633b886973f76b48784c36b9',
#   'release_year': 2023,
#   'average_monthly_revenue': 332610.9884730539},
#  {'unified_app_id': '5da67c09a546ab1edeb6c50d',
#   'release_year': 2023,
#   'average_monthly_revenue': 1789078.152546917},
#  {'unified_app_id': '63e5633fded9c9175b7fca1e',
#   'release_year': 2023,
#   'average_monthly_revenue': 191566.78615384613},
#  {'unified_app_id': '64fb527ee935e16ab92c6938',
#   'release_year': 2023,
#   'average_monthly_revenue': 107638.13817330211},
#  {'unified_app_id': '639ff55ec7f5ec0d1883c726',
#   'release_year': 2023,
#   'average_monthly_revenue': 389364.2444763271},
#  {'unified_app_id': '62f32a5044136e0eba10c9ba',
#   'release_year': 2023,
#   'average_monthly_revenue': 435177.84904458607},
#  {'unified_app_id': '666a7679850648f34fb41215',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64fb52e1649dfd28c72aa698',
#   'release_year': 2023,
#   'average_monthly_revenue': 140252.63188405798},
#  {'unified_app_id': '5d84173e3ea9835b8b1d4081',
#   'release_year': 2023,
#   'average_monthly_revenue': 402863.1004322767},
#  {'unified_app_id': '651504efd211a646d98e8b5a',
#   'release_year': 2023,
#   'average_monthly_revenue': 337522.1061124694},
#  {'unified_app_id': '64a91142f08b1411f1c62ffc',
#   'release_year': 2023,
#   'average_monthly_revenue': 315332.2290766209},
#  {'unified_app_id': '6641bd6ed6c68d326fdd8917',
#   'release_year': 2024,
#   'average_monthly_revenue': 129423.9882352941},
#  {'unified_app_id': '63c277626f979e711c7d7886',
#   'release_year': 2023,
#   'average_monthly_revenue': 82935.88392036753},
#  {'unified_app_id': '63ecece74760b21b6d8706b2',
#   'release_year': 2023,
#   'average_monthly_revenue': 993631.2526766596},
#  {'unified_app_id': '65cc5eab69eefb4fad4c1376',
#   'release_year': 2024,
#   'average_monthly_revenue': 181667.54774436087},
#  {'unified_app_id': '65a1e8cd950aa41941ff9752',
#   'release_year': 2024,
#   'average_monthly_revenue': 70700.38591549295},
#  {'unified_app_id': '65fd06dba6a66211427de1cd',
#   'release_year': 2024,
#   'average_monthly_revenue': 183275.46951219512},
#  {'unified_app_id': '64075e77537c41636a8e1c58',
#   'release_year': 2023,
#   'average_monthly_revenue': 40614.775},
#  {'unified_app_id': '661e16f2b279ba3aff370af0',
#   'release_year': 2024,
#   'average_monthly_revenue': 739198.44},
#  {'unified_app_id': '64e70b3f0872f07ed0df43da',
#   'release_year': 2023,
#   'average_monthly_revenue': 66985.00245535714},
#  {'unified_app_id': '666267cee122ae413cbc931a',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '663ffa0564df7d1ea5a06b10',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65407d5b4227cd64a6723c90',
#   'release_year': 2023,
#   'average_monthly_revenue': 38417.14596774193},
#  {'unified_app_id': '654c53c5060f963522369293',
#   'release_year': 2023,
#   'average_monthly_revenue': 49752.93184357542},
#  {'unified_app_id': '65c59246ef45c441d8c8886b',
#   'release_year': 2024,
#   'average_monthly_revenue': 122171.92978723402},
#  {'unified_app_id': '6600ce3df7516f24e66be439',
#   'release_year': 2024,
#   'average_monthly_revenue': 48292.21351351351},
#  {'unified_app_id': '6626a822a9cba85698402d6b',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6470444f124b5028b45d9743',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6669e2a8e04fc6fe82c53f5f',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6700f9a78547467da5c62a2b',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '641b2e4392a9a7430889b512',
#   'release_year': 2024,
#   'average_monthly_revenue': 37871.78816793893},
#  {'unified_app_id': '6410802d9aac52470e6eaea4',
#   'release_year': 2023,
#   'average_monthly_revenue': 315716.10719999997},
#  {'unified_app_id': '66c957353541e6dc062a9464',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6454cd2adab74e35c18f5e11',
#   'release_year': 2024,
#   'average_monthly_revenue': 30847.083774834435},
#  {'unified_app_id': '66580d5ac55264a66c0ef1e5',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '60f151ef6ffae745341f100f',
#   'release_year': 2023,
#   'average_monthly_revenue': 77545.48337349397},
#  {'unified_app_id': '66d211d85ca5ed0dbdb92d59',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64d5f2f9229d840ac6025910',
#   'release_year': 2023,
#   'average_monthly_revenue': 158490.8486352357},
#  {'unified_app_id': '654415160b276e73bf2c8613',
#   'release_year': 2023,
#   'average_monthly_revenue': 26052.65871313673},
#  {'unified_app_id': '652da61c5b601405ec02892d',
#   'release_year': 2023,
#   'average_monthly_revenue': 384431.421875},
#  {'unified_app_id': '62f638da3811e936454f2b0f',
#   'release_year': 2023,
#   'average_monthly_revenue': 121974.59487666033},
#  {'unified_app_id': '64bde7c0beec1f7450127b2b',
#   'release_year': 2023,
#   'average_monthly_revenue': 38534.955555555556},
#  {'unified_app_id': '66fb97dffb320cffcfb1e326',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65f11fa81107bb6df0b1f78f',
#   'release_year': 2024,
#   'average_monthly_revenue': 336991.8237885462},
#  {'unified_app_id': '6483e3cd22863a6e05e81bb6',
#   'release_year': 2023,
#   'average_monthly_revenue': 83120.71400778211},
#  {'unified_app_id': '6220bbe38b9e665095bc83e4',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '664045116e12e024bf42865d',
#   'release_year': 2024,
#   'average_monthly_revenue': 37559.86153846153},
#  {'unified_app_id': '646c3514990ee340597b4d76',
#   'release_year': 2023,
#   'average_monthly_revenue': 129187.75557586837},
#  {'unified_app_id': '642656f2b3ae2774a49b30a5',
#   'release_year': 2023,
#   'average_monthly_revenue': 132500.27076023392},
#  {'unified_app_id': '6670098947a500c078db041b',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65d63474dde1d1707d640651',
#   'release_year': 2024,
#   'average_monthly_revenue': 23548.22618181818},
#  {'unified_app_id': '66527ed9290c7211874abe73',
#   'release_year': 2024,
#   'average_monthly_revenue': 105554.59672131146},
#  {'unified_app_id': '6454a42a22a2d214408396bc',
#   'release_year': 2023,
#   'average_monthly_revenue': 13154.998932384342},
#  {'unified_app_id': '66cc10059e7c3b0db92da359',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6638a848ad4adb4594498e36',
#   'release_year': 2024,
#   'average_monthly_revenue': 91833.83201970442},
#  {'unified_app_id': '65d86b46b3ae27599313c4b8',
#   'release_year': 2024,
#   'average_monthly_revenue': 21639.435766423358},
#  {'unified_app_id': '65ea86a3fcf09c1798042107',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '66613fad992f6b2ae2d1fd76',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64fb35908efc75514b107a11',
#   'release_year': 2024,
#   'average_monthly_revenue': 18015.065506329112},
#  {'unified_app_id': '6620de2d9db92b4ddddd2e2e',
#   'release_year': 2024,
#   'average_monthly_revenue': 88366.33125},
#  {'unified_app_id': '6475198bd97d345134e9a059',
#   'release_year': 2023,
#   'average_monthly_revenue': 70707.46990099011},
#  {'unified_app_id': '63afc769278f9e137947186c',
#   'release_year': 2023,
#   'average_monthly_revenue': 413230.08292682923},
#  {'unified_app_id': '6522ce55fe6cd0517760607e',
#   'release_year': 2023,
#   'average_monthly_revenue': 57858.4305},
#  {'unified_app_id': '64d1b7b51395ad06162da82f',
#   'release_year': 2023,
#   'average_monthly_revenue': 31443.62857142857},
#  {'unified_app_id': '642ea283c084ff1c6afcc825',
#   'release_year': 2023,
#   'average_monthly_revenue': 67772.09500831946},
#  {'unified_app_id': '6618cd4754e2531457fd8cb1',
#   'release_year': 2024,
#   'average_monthly_revenue': 237192.29596412554},
#  {'unified_app_id': '6653fa538ed6b90f78a58a12',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '66d28fe97bf35d0dbcf396a8',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65f3e2edd2d2f066b363542b',
#   'release_year': 2024,
#   'average_monthly_revenue': 63550.46582278482},
#  {'unified_app_id': '655ec802058d7b5482ce1ac2',
#   'release_year': 2024,
#   'average_monthly_revenue': 17354.328421052633},
#  {'unified_app_id': '671c9b792a534ff71cf88055',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '664d70e9d5a7dd7a0a1526b9',
#   'release_year': 2024,
#   'average_monthly_revenue': 25596.216315789476},
#  {'unified_app_id': '6583e25297a8976e501b05a8',
#   'release_year': 2024,
#   'average_monthly_revenue': 14781.105230769226},
#  {'unified_app_id': '64c8c3698966bc32a9d8acde',
#   'release_year': 2023,
#   'average_monthly_revenue': 78921.8387628866},
#  {'unified_app_id': '62be6a5fbab10c69c5a0a42a',
#   'release_year': 2023,
#   'average_monthly_revenue': 16666.766834170856},
#  {'unified_app_id': '62a6c74618009737cff9f80b',
#   'release_year': 2023,
#   'average_monthly_revenue': 21019.407547169812},
#  {'unified_app_id': '647601522d39db6603e86b66',
#   'release_year': 2023,
#   'average_monthly_revenue': 30778.04838709677},
#  {'unified_app_id': '666a7679850648f34fb41214',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '656e7b186fff126c9540d08c',
#   'release_year': 2024,
#   'average_monthly_revenue': 18388.612831858405},
#  {'unified_app_id': '6671c114b2e31852277f76c2',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '637b0dc7863b79516a758a69',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6687a2d5e7ade0b96ff87601',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '666907a2d5a4c6c117b3bd01',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '626d11b3b672a029fdbf45c0',
#   'release_year': 2023,
#   'average_monthly_revenue': 56442.72676056338},
#  {'unified_app_id': '66029b32649dfd33fdf3656e',
#   'release_year': 2024,
#   'average_monthly_revenue': 51033.83663793104},
#  {'unified_app_id': '64356046b1ed80042094cf02',
#   'release_year': 2023,
#   'average_monthly_revenue': 17121.56025},
#  {'unified_app_id': '62a17c64d4cf060ee448fb7f',
#   'release_year': 2023,
#   'average_monthly_revenue': 43017.86150442478},
#  {'unified_app_id': '66428480f651ec16ec266c57',
#   'release_year': 2024,
#   'average_monthly_revenue': 199441.546875},
#  {'unified_app_id': '62d92bdc43ec765f5d8e8436',
#   'release_year': 2023,
#   'average_monthly_revenue': 15239.506618705036},
#  {'unified_app_id': '6358f0f562fd874db61de079',
#   'release_year': 2023,
#   'average_monthly_revenue': 6099.74560117302},
#  {'unified_app_id': '6505716743c5fb4cfa603ca9',
#   'release_year': 2023,
#   'average_monthly_revenue': 10183.580249999999},
#  {'unified_app_id': '666c314e108dacfa113ea464',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6649dddb43c10c0f7eb290d1',
#   'release_year': 2024,
#   'average_monthly_revenue': 58706.17258064516},
#  {'unified_app_id': '654adebc42e7a158c7cdee68',
#   'release_year': 2024,
#   'average_monthly_revenue': 12399.906338028171},
#  {'unified_app_id': '639adbe243827d039d096627',
#   'release_year': 2023,
#   'average_monthly_revenue': 21696.924017467245},
#  {'unified_app_id': '64b27fa627460e0efd9908ee',
#   'release_year': 2024,
#   'average_monthly_revenue': 11579.245033112582},
#  {'unified_app_id': '64eeb50c0ad52111f17605cd',
#   'release_year': 2023,
#   'average_monthly_revenue': 107314.1064665127},
#  {'unified_app_id': '63d6584bc6086b28bf3830c7',
#   'release_year': 2023,
#   'average_monthly_revenue': 5969.922776911076},
#  {'unified_app_id': '66509a05c6bb0e548b65dc4a',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '644bb0bdc5b9042c3e1e0c3a',
#   'release_year': 2023,
#   'average_monthly_revenue': 53221.95642857143},
#  {'unified_app_id': '642fc30df704e06d9a260a76',
#   'release_year': 2023,
#   'average_monthly_revenue': 14911.14580645161},
#  {'unified_app_id': '64c688dc09dac163562055d2',
#   'release_year': 2023,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '641ce1cf3169d82cab237c53',
#   'release_year': 2023,
#   'average_monthly_revenue': 29658.165306122453},
#  {'unified_app_id': '6640945b0a025f1a7a130e27',
#   'release_year': 2024,
#   'average_monthly_revenue': 49243.21846153846},
#  {'unified_app_id': '64dc7ff401a93e0ff44f86db',
#   'release_year': 2023,
#   'average_monthly_revenue': 44079.20322580645},
#  {'unified_app_id': '63bdd6b32d63ee0ecbfc3636',
#   'release_year': 2023,
#   'average_monthly_revenue': 505716.6288209607},
#  {'unified_app_id': '65372d7ff8cfcd2d61def651',
#   'release_year': 2023,
#   'average_monthly_revenue': 11847.212096774192},
#  {'unified_app_id': '669df767059af1f0653d9d65',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '66cfe921110e857d09c8d395',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6518e90143ee8718b7e23fec',
#   'release_year': 2023,
#   'average_monthly_revenue': 27967.022009569377},
#  {'unified_app_id': '657d0cf4c14b4712c96aecb3',
#   'release_year': 2024,
#   'average_monthly_revenue': 9463.220322580644},
#  {'unified_app_id': '66277ad02535561238b4b68d',
#   'release_year': 2024,
#   'average_monthly_revenue': 29720.801834862385},
#  {'unified_app_id': '6219e63b0c6ad83301492f26',
#   'release_year': 2023,
#   'average_monthly_revenue': 6046.8819364161845},
#  {'unified_app_id': '615689dfbdb047784e567718',
#   'release_year': 2023,
#   'average_monthly_revenue': 65694.5909774436},
#  {'unified_app_id': '65b99c37a944a17f721e229b',
#   'release_year': 2024,
#   'average_monthly_revenue': 9793.985106382977},
#  {'unified_app_id': '63882256bfa0280535094a22',
#   'release_year': 2023,
#   'average_monthly_revenue': 282173.6484375},
#  {'unified_app_id': '6573c39d5c3b423d5d04560f',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '63e00c87ad4adb5fc4af67d5',
#   'release_year': 2023,
#   'average_monthly_revenue': 10309.263819875778},
#  {'unified_app_id': '5e7cd8f4413bb61acc959a44',
#   'release_year': 2023,
#   'average_monthly_revenue': 9201.986524822694},
#  {'unified_app_id': '647641acad220f0a40f82980',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '639bfd31d8753806a5d3b9e6',
#   'release_year': 2023,
#   'average_monthly_revenue': 23314.39170305677},
#  {'unified_app_id': '63be498c22d978122038c4a5',
#   'release_year': 2023,
#   'average_monthly_revenue': 44134.306349206345},
#  {'unified_app_id': '656c0d8edbcdf60b54718ffa',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64b0d0e9b71acf296fd2a3e9',
#   'release_year': 2023,
#   'average_monthly_revenue': 26171.781872509957},
#  {'unified_app_id': '65b26f0897da691492537bb6',
#   'release_year': 2024,
#   'average_monthly_revenue': 8406.511074918566},
#  {'unified_app_id': '65b4886afc772143e83c80e9',
#   'release_year': 2024,
#   'average_monthly_revenue': 28820.639776951673},
#  {'unified_app_id': '63baf02f9ed53e6b14532411',
#   'release_year': 2023,
#   'average_monthly_revenue': 5241.445486725664},
#  {'unified_app_id': '662dce766b8761692457fdc1',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65a8ee63896fa0197e2de4f1',
#   'release_year': 2024,
#   'average_monthly_revenue': 9081.753736654806},
#  {'unified_app_id': '63bcd1a4b4bac82834c85cba',
#   'release_year': 2023,
#   'average_monthly_revenue': 8621.653231939164},
#  {'unified_app_id': '641b0858f934b57c9b3c7549',
#   'release_year': 2023,
#   'average_monthly_revenue': 6430.7259109311735},
#  {'unified_app_id': '63a153348066e10644ae2342',
#   'release_year': 2023,
#   'average_monthly_revenue': 6271.0402985074625},
#  {'unified_app_id': '669116dd9b5b60e5668100d6',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '66ac33d0aa7fb99d2bb5fd46',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6582c284108f505df6239c87',
#   'release_year': 2024,
#   'average_monthly_revenue': 9718.293902439025},
#  {'unified_app_id': '66ea9e13cb4c1386e36bda83',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6635c621f748cdf578efb571',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '66051229301a126d56bac263',
#   'release_year': 2024,
#   'average_monthly_revenue': 10546.566666666666},
#  {'unified_app_id': '6439381ea0f47f0e94b71f6f',
#   'release_year': 2023,
#   'average_monthly_revenue': 74781.96222596963},
#  {'unified_app_id': '645f3bf5fbea7c637ecc3636',
#   'release_year': 2023,
#   'average_monthly_revenue': 35583.26101083033},
#  {'unified_app_id': '6509474dabf35e12a4a89db3',
#   'release_year': 2023,
#   'average_monthly_revenue': 23426.797241379314},
#  {'unified_app_id': '6485263131a16d10d6a1456d',
#   'release_year': 2023,
#   'average_monthly_revenue': 5551.3176},
#  {'unified_app_id': '65fc7cd3b3ae276f898cf5d9',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '624221e4aaeb833d98f8b149',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6683635d2897da2ed9daad0b',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6419ebccdc4a985f4260b157',
#   'release_year': 2023,
#   'average_monthly_revenue': 9130.007352941175},
#  {'unified_app_id': '61cbd43323c9d253fd36eee8',
#   'release_year': 2023,
#   'average_monthly_revenue': 4151.767567567567},
#  {'unified_app_id': '6206571f2c82040b2559bd07',
#   'release_year': 2023,
#   'average_monthly_revenue': 23200.523633440513},
#  {'unified_app_id': '6463f752d0cc851cfc23b635',
#   'release_year': 2023,
#   'average_monthly_revenue': 6865.904096385541},
#  {'unified_app_id': '6424429a64179871a82f09db',
#   'release_year': 2023,
#   'average_monthly_revenue': 5914.975675675675},
#  {'unified_app_id': '6650dbe7b3ae2736333a1e51',
#   'release_year': 2024,
#   'average_monthly_revenue': 30553.101639344262},
#  {'unified_app_id': '65fa75d7fbea7c523c3ab106',
#   'release_year': 2024,
#   'average_monthly_revenue': 24073.46103896104},
#  {'unified_app_id': '6679b0ea56287121469ffe1a',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '66c44213f87b4709ea1accc8',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '5fb347007ae5ba145dcc4025',
#   'release_year': 2023,
#   'average_monthly_revenue': 29540.58216216216},
#  {'unified_app_id': '61e1037e854378623d0db61d',
#   'release_year': 2023,
#   'average_monthly_revenue': 3631.534090909091},
#  {'unified_app_id': '63e1f070a4076914275702ae',
#   'release_year': 2023,
#   'average_monthly_revenue': 4336.0040625},
#  {'unified_app_id': '66bc15b8654b1a7dd291abd2',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6442297e6287e55419d54cbd',
#   'release_year': 2023,
#   'average_monthly_revenue': 7018.053513513513},
#  {'unified_app_id': '653746ae5cb60a679a7e0433',
#   'release_year': 2023,
#   'average_monthly_revenue': 6395.761563517915},
#  {'unified_app_id': '652547de05f57b5ed221a585',
#   'release_year': 2023,
#   'average_monthly_revenue': 8495.124742268039},
#  {'unified_app_id': '66ae27a7bb7ff7d8b74d55a0',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '664c0cd11efadcbf5a1070c3',
#   'release_year': 2024,
#   'average_monthly_revenue': 8962.161497326204},
#  {'unified_app_id': '6488c7679eb02564ab95ca9f',
#   'release_year': 2023,
#   'average_monthly_revenue': 7530.083146067414},
#  {'unified_app_id': '66c50b19fd00e3defecc832e',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64ca96928a678b4349c0bbbb',
#   'release_year': 2023,
#   'average_monthly_revenue': 26052.68491735537},
#  {'unified_app_id': '64e954de1816cd779f4a0feb',
#   'release_year': 2024,
#   'average_monthly_revenue': 7783.392753623188},
#  {'unified_app_id': '6480c3e55b6ccd7d9c1330d6',
#   'release_year': 2023,
#   'average_monthly_revenue': 30250.784332688585},
#  {'unified_app_id': '6646b58355b6d7105b6b6553',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '63251588bd16da1b1372ca0a',
#   'release_year': 2023,
#   'average_monthly_revenue': 4537.265733113674},
#  {'unified_app_id': '662a74de78ba2b46960b38cf',
#   'release_year': 2024,
#   'average_monthly_revenue': 8170.234554973821},
#  {'unified_app_id': '65a6117967197e4e41abafe1',
#   'release_year': 2024,
#   'average_monthly_revenue': 6788.329565217392},
#  {'unified_app_id': '65e97fe3ad4adb3f5481b6fb',
#   'release_year': 2024,
#   'average_monthly_revenue': 7004.653636363636},
#  {'unified_app_id': '650e6b4ea9fe9065eceb9a93',
#   'release_year': 2023,
#   'average_monthly_revenue': 23164.2375},
#  {'unified_app_id': '63b3c94f4c451a7e6c2a25ba',
#   'release_year': 2023,
#   'average_monthly_revenue': 16309.393258426968},
#  {'unified_app_id': '667ee33a7d30ae1b930fb01d',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65a9e095b59cd828b6b223e4',
#   'release_year': 2024,
#   'average_monthly_revenue': 6876.712676056339},
#  {'unified_app_id': '64405fc98f8f2413f98524c7',
#   'release_year': 2023,
#   'average_monthly_revenue': 33867.6393939394},
#  {'unified_app_id': '6639aebe33c80842d30efff1',
#   'release_year': 2024,
#   'average_monthly_revenue': 7287.160606060606},
#  {'unified_app_id': '6659e428226b831d7faf84cc',
#   'release_year': 2024,
#   'average_monthly_revenue': 23289.931491712705},
#  {'unified_app_id': '64c401a8fd0a1f23ecad93ba',
#   'release_year': 2023,
#   'average_monthly_revenue': 6612.46945945946},
#  {'unified_app_id': '6290ce5e1800971cd3a04884',
#   'release_year': 2023,
#   'average_monthly_revenue': 5181.154352030948},
#  {'unified_app_id': '659778cfa33983212809c751',
#   'release_year': 2024,
#   'average_monthly_revenue': 14634.213829787235},
#  {'unified_app_id': '6669c5864b5ce4f9f2239488',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '655d9b1101a70b167356cba0',
#   'release_year': 2023,
#   'average_monthly_revenue': 4995.274504249291},
#  {'unified_app_id': '6409517c18abe602d0d47896',
#   'release_year': 2023,
#   'average_monthly_revenue': 10507.649206349206},
#  {'unified_app_id': '656ea54ed25aa570be79a74d',
#   'release_year': 2023,
#   'average_monthly_revenue': 5698.17242339833},
#  {'unified_app_id': '65ba8bb1b3ae273d1237cb55',
#   'release_year': 2024,
#   'average_monthly_revenue': 4594.332978723403},
#  {'unified_app_id': '668621c4a46e849e79fb1bd6',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '607cebfac5853c115c5b0c35',
#   'release_year': 2023,
#   'average_monthly_revenue': 5145.103543913713},
#  {'unified_app_id': '665007045156925fddb2ea79',
#   'release_year': 2024,
#   'average_monthly_revenue': 6418.078723404256},
#  {'unified_app_id': '65348a9500d391512bb49468',
#   'release_year': 2023,
#   'average_monthly_revenue': 4455.0985835694055},
#  {'unified_app_id': '63b7af54e1752a247e2814e6',
#   'release_year': 2023,
#   'average_monthly_revenue': 25957.81317715959},
#  {'unified_app_id': '66a366065ec77c1b773d0a52',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '66e593373e1f11bf5dc323cc',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65c580d0f3af822f19c74036',
#   'release_year': 2024,
#   'average_monthly_revenue': 5597.354066985646},
#  {'unified_app_id': '5ea24b229115fc08b79a7e6f',
#   'release_year': 2023,
#   'average_monthly_revenue': 4313.859770114943},
#  {'unified_app_id': '6433861625e4142227a40236',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64ccf4fe895ce705f552799f',
#   'release_year': 2023,
#   'average_monthly_revenue': 7486.613114754097},
#  {'unified_app_id': '66306b48a596c73d59dfc888',
#   'release_year': 2024,
#   'average_monthly_revenue': 15712.06285714286},
#  {'unified_app_id': '6437d7afd994c304426f28c5',
#   'release_year': 2023,
#   'average_monthly_revenue': 7922.105978260869},
#  {'unified_app_id': '61c2bf670d74bc57cf9b8843',
#   'release_year': 2023,
#   'average_monthly_revenue': 3250.540431266846},
#  {'unified_app_id': '626ce45fed68d5132b481f25',
#   'release_year': 2023,
#   'average_monthly_revenue': 3583.858598726115},
#  {'unified_app_id': '65eeb44aad4adb49f75b389f',
#   'release_year': 2024,
#   'average_monthly_revenue': 5117.072857142856},
#  {'unified_app_id': '62ea03abd875382b78c4d8b8',
#   'release_year': 2023,
#   'average_monthly_revenue': 1875.2302725968436},
#  {'unified_app_id': '66cf467f4a925979c56cd84c',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '646e3805106d0b36d6643e8e',
#   'release_year': 2023,
#   'average_monthly_revenue': 3468.3771428571426},
#  {'unified_app_id': '6537adfcb3ae275470fdbb7c',
#   'release_year': 2023,
#   'average_monthly_revenue': 2828.23984375},
#  {'unified_app_id': '652f279195c76076172d19a9',
#   'release_year': 2023,
#   'average_monthly_revenue': 3050.3456824512537},
#  {'unified_app_id': '605461d15be6d405f8d4253d',
#   'release_year': 2023,
#   'average_monthly_revenue': 8675.558333333334},
#  {'unified_app_id': '658e788c69e18719360c0c2d',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '637ec3b082685a1efcbc35ac',
#   'release_year': 2023,
#   'average_monthly_revenue': 4717.77968503937},
#  {'unified_app_id': '6270da5e478582182c2d9c7a',
#   'release_year': 2023,
#   'average_monthly_revenue': 3443.387185929648},
#  {'unified_app_id': '668240e2172ea60d9e30adb0',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64972068f83bff2a9d8a086e',
#   'release_year': 2023,
#   'average_monthly_revenue': 3129.84},
#  {'unified_app_id': '6549cba84251ad48400e50bf',
#   'release_year': 2023,
#   'average_monthly_revenue': 11495.426288659793},
#  {'unified_app_id': '672353aca4c9da292e391435',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '66c82d07410ff0a97e039ed3',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65765f06cb54b62bf7af6a85',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6545db024227cd177700a064',
#   'release_year': 2023,
#   'average_monthly_revenue': 9822.111825192802},
#  {'unified_app_id': '5f75bd556ec51b7e4e13fa8f',
#   'release_year': 2024,
#   'average_monthly_revenue': 4474.473113207546},
#  {'unified_app_id': '666a7683850648f34fb41216',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '63c4d18654b41c6945ddda18',
#   'release_year': 2023,
#   'average_monthly_revenue': 24542.922026431723},
#  {'unified_app_id': '62b05a8c9daa41614e523fa1',
#   'release_year': 2023,
#   'average_monthly_revenue': 1395.29375},
#  {'unified_app_id': '667e0fe6ea2d373df0444595',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '660bbeb2ad4adb4d3f849641',
#   'release_year': 2024,
#   'average_monthly_revenue': 4799.427272727273},
#  {'unified_app_id': '66973a56918f2990e8957249',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '652e00e0950cd27748028cf6',
#   'release_year': 2023,
#   'average_monthly_revenue': 2446.855919395466},
#  {'unified_app_id': '66581728e62f94191c273068',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64b18914115e7f58f200f225',
#   'release_year': 2024,
#   'average_monthly_revenue': 2491.0855932203394},
#  {'unified_app_id': '66fa465f87d48d0f665a4acf',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6572809c7c5fd0579dceb24f',
#   'release_year': 2023,
#   'average_monthly_revenue': 2553.264606741573},
#  {'unified_app_id': '66bd20efa26c8332ff0dfd01',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65958d9715957b3e944f394d',
#   'release_year': 2024,
#   'average_monthly_revenue': 2595.6936363636364},
#  {'unified_app_id': '66877456eff239036696e3eb',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6596294b7074e873454e3820',
#   'release_year': 2024,
#   'average_monthly_revenue': 2563.947720364741},
#  {'unified_app_id': '6322100abd16da6f1e6d7ec2',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '63368d7b3f14b910172d070a',
#   'release_year': 2023,
#   'average_monthly_revenue': 1588.2733695652173},
#  {'unified_app_id': '627dbe261e0df81ebb851419',
#   'release_year': 2024,
#   'average_monthly_revenue': 4181.816080402011},
#  {'unified_app_id': '66ad95400c767576f5a7ec0b',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '66b9c4b0e5dfbf0e5fb63f71',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '63490526117e02647456295a',
#   'release_year': 2023,
#   'average_monthly_revenue': 1898.1246835443037},
#  {'unified_app_id': '6633617e133987f049af8fa0',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '627d771fd094ad7f9beb9d2c',
#   'release_year': 2023,
#   'average_monthly_revenue': 4246.381395348838},
#  {'unified_app_id': '64a99d736943cd2328f2ec54',
#   'release_year': 2023,
#   'average_monthly_revenue': 2793.220432220039},
#  {'unified_app_id': '65558799e0cdcd540df72ffe',
#   'release_year': 2024,
#   'average_monthly_revenue': 2665.8030303030305},
#  {'unified_app_id': '635fd6edad4adb542fb2a709',
#   'release_year': 2023,
#   'average_monthly_revenue': 1900.4994983277593},
#  {'unified_app_id': '655ee13234bcb563d7d66e17',
#   'release_year': 2024,
#   'average_monthly_revenue': 2786.920774647888},
#  {'unified_app_id': '641c7b876a77fd016b7d4e3a',
#   'release_year': 2023,
#   'average_monthly_revenue': 4313.680213903744},
#  {'unified_app_id': '66b98fdfaf0c1c0e6845cd13',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65491de8b3ae2728832369f8',
#   'release_year': 2024,
#   'average_monthly_revenue': 2554.80304054054},
#  {'unified_app_id': '6379ba3f10c9211635260c8a',
#   'release_year': 2023,
#   'average_monthly_revenue': 2555.9775862068964},
#  {'unified_app_id': '66b6b5abc4bbd31d2645ef9a',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '662c1c024891f40cacada25f',
#   'release_year': 2024,
#   'average_monthly_revenue': 10403.594786729858},
#  {'unified_app_id': '64a95779c9c8441632c24e84',
#   'release_year': 2023,
#   'average_monthly_revenue': 2617.6975113122166},
#  {'unified_app_id': '657992bbac683833c4bccfd6',
#   'release_year': 2024,
#   'average_monthly_revenue': 2395.186092715232},
#  {'unified_app_id': '636c4e26080e980fa381a2b9',
#   'release_year': 2023,
#   'average_monthly_revenue': 1172.6273542600898},
#  {'unified_app_id': '65826151ead12212042f977e',
#   'release_year': 2024,
#   'average_monthly_revenue': 6975.926298701298},
#  {'unified_app_id': '5d72b0d7a5e7102a3ef175d8',
#   'release_year': 2023,
#   'average_monthly_revenue': 2322.5142857142855},
#  {'unified_app_id': '65dc8f9ab5757d2c8dcfafaf',
#   'release_year': 2024,
#   'average_monthly_revenue': 8083.857735849057},
#  {'unified_app_id': '65d56f57dd4de13fbef0768b',
#   'release_year': 2024,
#   'average_monthly_revenue': 7847.549999999999},
#  {'unified_app_id': '62eae837634d5f482ed3e796',
#   'release_year': 2023,
#   'average_monthly_revenue': 2730.927615062761},
#  {'unified_app_id': '652f6e39a020f13af057ccec',
#   'release_year': 2023,
#   'average_monthly_revenue': 7212.425000000001},
#  {'unified_app_id': '64253bbeacbf5412b98bd4cf',
#   'release_year': 2023,
#   'average_monthly_revenue': 2448.7090395480227},
#  {'unified_app_id': '658f9f16623739111651e8a0',
#   'release_year': 2024,
#   'average_monthly_revenue': 8297.883529411763},
#  {'unified_app_id': '64c9fa0d28bb8778789ef1b5',
#   'release_year': 2023,
#   'average_monthly_revenue': 5462.657427937916},
#  {'unified_app_id': '61eb711a06e65f54590e5ae7',
#   'release_year': 2023,
#   'average_monthly_revenue': 2322.1546153846157},
#  {'unified_app_id': '64ede5412d63ee580d609fb9',
#   'release_year': 2023,
#   'average_monthly_revenue': 32948.650657894745},
#  {'unified_app_id': '664b764d8430adac59525fa6',
#   'release_year': 2024,
#   'average_monthly_revenue': 11667.200000000003},
#  {'unified_app_id': '6603aa389cc7a7189ba7b66d',
#   'release_year': 2024,
#   'average_monthly_revenue': 8464.774390243903},
#  {'unified_app_id': '6535dbb0ae80ae506d64fe07',
#   'release_year': 2023,
#   'average_monthly_revenue': 2395.5116279069766},
#  {'unified_app_id': '63751090ea883738a992ab6b',
#   'release_year': 2023,
#   'average_monthly_revenue': 8634.469604863223},
#  {'unified_app_id': '63d2d64273a92265b8f120f5',
#   'release_year': 2023,
#   'average_monthly_revenue': 1853.980880121396},
#  {'unified_app_id': '67238b35f77092870c06c03d',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65c67f67f51b52076cbdd6c9',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6674cc15a9d4319b95eb1ee6',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '640f87d4950aa46f256cb3f8',
#   'release_year': 2023,
#   'average_monthly_revenue': 1884.5473770491806},
#  {'unified_app_id': '637ea0012ade4a0aeafad27b',
#   'release_year': 2023,
#   'average_monthly_revenue': 1093.7711111111112},
#  {'unified_app_id': '65226106b3ae272630968d62',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '5fe791243d456d1f394fe280',
#   'release_year': 2024,
#   'average_monthly_revenue': 2115.5761589403974},
#  {'unified_app_id': '649c44dd52d89a315b65eeab',
#   'release_year': 2023,
#   'average_monthly_revenue': 7691.79980544747},
#  {'unified_app_id': '6410099407ef2e17463e0304',
#   'release_year': 2023,
#   'average_monthly_revenue': 3245.0642016806723},
#  {'unified_app_id': '6588aefbad4adb77c3d68e1a',
#   'release_year': 2024,
#   'average_monthly_revenue': 3064.7685},
#  {'unified_app_id': '66932d63c787b90e25781175',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64f2f8edd77f4d5e3a382a7a',
#   'release_year': 2023,
#   'average_monthly_revenue': 1499.4641330166273},
#  {'unified_app_id': '6196fc2d955f6110a85ad3ea',
#   'release_year': 2023,
#   'average_monthly_revenue': 1772.6985804416404},
#  {'unified_app_id': '61b177e87a8e43536bc6736b',
#   'release_year': 2024,
#   'average_monthly_revenue': 3027.8751219512196},
#  {'unified_app_id': '6616ab102f41160e027868b6',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64ec2a042eabaa4dbdb84421',
#   'release_year': 2024,
#   'average_monthly_revenue': 2824.7082191780823},
#  {'unified_app_id': '65c43f1eef45c458d5fd1073',
#   'release_year': 2024,
#   'average_monthly_revenue': 2774.228959276018},
#  {'unified_app_id': '640add16358b47279424355f',
#   'release_year': 2023,
#   'average_monthly_revenue': 2964.9195378151258},
#  {'unified_app_id': '664e520a8430ad7b672dd2c2',
#   'release_year': 2024,
#   'average_monthly_revenue': 9717.27157894737},
#  {'unified_app_id': '64d5b9edff1e1b45929f3dfe',
#   'release_year': 2024,
#   'average_monthly_revenue': 3033.885221674877},
#  {'unified_app_id': '66a9f962bbe8c80fefe4935d',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6409e14e2535561b3c74b8e9',
#   'release_year': 2023,
#   'average_monthly_revenue': 4338.070749542962},
#  {'unified_app_id': '6582608575c8970d9fe7b5c2',
#   'release_year': 2024,
#   'average_monthly_revenue': 5829.050322580646},
#  {'unified_app_id': '6559757f8747bd5c52ff84c1',
#   'release_year': 2023,
#   'average_monthly_revenue': 3707.2206642066417},
#  {'unified_app_id': '66193b9ead4adb2170e90f91',
#   'release_year': 2024,
#   'average_monthly_revenue': 3026.668020304569},
#  {'unified_app_id': '666a79b96b79e13f1241593f',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '63c8966b3ce60c0372c47acf',
#   'release_year': 2023,
#   'average_monthly_revenue': 1601.0610044313148},
#  {'unified_app_id': '641b11cc68dfa76471530e34',
#   'release_year': 2023,
#   'average_monthly_revenue': 3099.948813559322},
#  {'unified_app_id': '65032b7ab4b2520f8e95fd9e',
#   'release_year': 2024,
#   'average_monthly_revenue': 3946.9425287356325},
#  {'unified_app_id': '6712a9a4036618f0032576fa',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64619ad72e146b39c0fa0a6a',
#   'release_year': 2023,
#   'average_monthly_revenue': 25292.914754098358},
#  {'unified_app_id': '641d124238d2a27d90f5dae8',
#   'release_year': 2023,
#   'average_monthly_revenue': 1505.2981751824818},
#  {'unified_app_id': '64f73631830d145f0f9cd474',
#   'release_year': 2024,
#   'average_monthly_revenue': 2523.052401746725},
#  {'unified_app_id': '65e3c6b03b29876b2760ca17',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6495c627cbae9739e17bae4c',
#   'release_year': 2023,
#   'average_monthly_revenue': 30730.18240469208},
#  {'unified_app_id': '65fdadbcb3ae2712f9074eca',
#   'release_year': 2024,
#   'average_monthly_revenue': 2313.5692622950814},
#  {'unified_app_id': '66051155d25aa53a5cb75bbe',
#   'release_year': 2024,
#   'average_monthly_revenue': 5654.240816326531},
#  {'unified_app_id': '67085602d02dd71b4eb24acd',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '63be63bfad4adb2ef034cd8d',
#   'release_year': 2023,
#   'average_monthly_revenue': 1340.9788288288287},
#  {'unified_app_id': '6633249d9351a92192ffb03e',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '657a855474d0e66f4f2e1aad',
#   'release_year': 2024,
#   'average_monthly_revenue': 1687.6844720496895},
#  {'unified_app_id': '6355f8b188dc6b1e854a4e89',
#   'release_year': 2023,
#   'average_monthly_revenue': 2710.984447674419},
#  {'unified_app_id': '64b978fd594b7b5207e89384',
#   'release_year': 2023,
#   'average_monthly_revenue': 1538.573607748184},
#  {'unified_app_id': '647575425af896693b862c7d',
#   'release_year': 2023,
#   'average_monthly_revenue': 3874.2251461988303},
#  {'unified_app_id': '64f8940987b27513be84d10f',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '635cbafc61f4f92db6c56e0d',
#   'release_year': 2023,
#   'average_monthly_revenue': 4447.147450110864},
#  {'unified_app_id': '60a2fd0fab3bcb0b25f1c0b2',
#   'release_year': 2023,
#   'average_monthly_revenue': 6952.482272727274},
#  {'unified_app_id': '66418b750a025f67791fcbea',
#   'release_year': 2024,
#   'average_monthly_revenue': 2768.0952127659575},
#  {'unified_app_id': '669a8cc0e19c0a72837acc1a',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6549ac29887138106dbe03b4',
#   'release_year': 2023,
#   'average_monthly_revenue': 1727.2872881355934},
#  {'unified_app_id': '66c76b2cd940502783cd3f92',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '62d9f711bbb9705a68181669',
#   'release_year': 2023,
#   'average_monthly_revenue': 1763.4030534351145},
#  {'unified_app_id': '64edd65bbcae522fce56fcf1',
#   'release_year': 2023,
#   'average_monthly_revenue': 1529.3281318681315},
#  {'unified_app_id': '668c4c7133e902ad62d64fb9',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '632e6c3fb03a9e6950b40fa4',
#   'release_year': 2023,
#   'average_monthly_revenue': 2460.45563583815},
#  {'unified_app_id': '659029eae850a10f952b4b02',
#   'release_year': 2023,
#   'average_monthly_revenue': 1531.3859281437126},
#  {'unified_app_id': '65c1d1ec7b852717fc7a34d1',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '5adf7833dec8331fa74b63dc',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64a3aee70692e87fcc51c2c3',
#   'release_year': 2023,
#   'average_monthly_revenue': 3498.3150627615064},
#  {'unified_app_id': '65eab451ba1de90187c4c651',
#   'release_year': 2024,
#   'average_monthly_revenue': 1901.2666666666667},
#  {'unified_app_id': '66de8fb77625711859619afa',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6667ed3863e96ed8611233f0',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '667a0edcd6ee48951827c832',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '63622c15ac0f8f141792e179',
#   'release_year': 2023,
#   'average_monthly_revenue': 989.6053084648493},
#  {'unified_app_id': '66ad0195ed58add63f343fe0',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65c661f12395f436a0990ffc',
#   'release_year': 2024,
#   'average_monthly_revenue': 1715.2942446043164},
#  {'unified_app_id': '644764d364e2cd7370727b07',
#   'release_year': 2023,
#   'average_monthly_revenue': 992.5384615384614},
#  {'unified_app_id': '670f31a5d78bad921ff05197',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6698a10f43283a89fe7f8645',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65dd5ba3a0662666f0762566',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6604e48dbd40f74962b103b2',
#   'release_year': 2024,
#   'average_monthly_revenue': 5674.584146341464},
#  {'unified_app_id': '66b59e4e66ed2afad9349444',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '665e8f9d8abb1241b09700fc',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64d48047449508728dc5d2bc',
#   'release_year': 2023,
#   'average_monthly_revenue': 1316.1964864864865},
#  {'unified_app_id': '656a8a8bfe8ffb69fccadeea',
#   'release_year': 2023,
#   'average_monthly_revenue': 1468.1361878453038},
#  {'unified_app_id': '64a795a198d14227007ab249',
#   'release_year': 2023,
#   'average_monthly_revenue': 1192.2642436149313},
#  {'unified_app_id': '6695e953ff0c1af70c83442a',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6478af54865e1572efd598b1',
#   'release_year': 2024,
#   'average_monthly_revenue': 1201.0271052631579},
#  {'unified_app_id': '66b438c34c3370c8ac58c9ec',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '638cbdc2e83df215e43c9123',
#   'release_year': 2023,
#   'average_monthly_revenue': 977.8591185410335},
#  {'unified_app_id': '640019fee7f7c12f5149c7c7',
#   'release_year': 2023,
#   'average_monthly_revenue': 4348.909957627119},
#  {'unified_app_id': '63f41f73f3594e55d90f03d1',
#   'release_year': 2023,
#   'average_monthly_revenue': 1200.0557275541794},
#  {'unified_app_id': '6723f7d4a8592a3ecc5fc35d',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6434f36d74f648189c0a1f86',
#   'release_year': 2023,
#   'average_monthly_revenue': 6621.105852842808},
#  {'unified_app_id': '649bd1d75e226451d07069da',
#   'release_year': 2023,
#   'average_monthly_revenue': 1127.1446028513237},
#  {'unified_app_id': '65ab6980555b556d899b6015',
#   'release_year': 2024,
#   'average_monthly_revenue': 1451.9478688524591},
#  {'unified_app_id': '66628ed2aaba82c7827f23e1',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '652f73396ac36003532e47dd',
#   'release_year': 2023,
#   'average_monthly_revenue': 1182.4945945945947},
#  {'unified_app_id': '658ccb16e87569306ac36439',
#   'release_year': 2023,
#   'average_monthly_revenue': 3920.5285714285715},
#  {'unified_app_id': '657b720c40509c711d90a891',
#   'release_year': 2023,
#   'average_monthly_revenue': 1356.346418338109},
#  {'unified_app_id': '657926706277693b751c0cb4',
#   'release_year': 2023,
#   'average_monthly_revenue': 12543.137142857142},
#  {'unified_app_id': '64ee5f07ca97153451fffc21',
#   'release_year': 2023,
#   'average_monthly_revenue': 1184.147027027027},
#  {'unified_app_id': '6658060e331ab7cee6e1cced',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '636a68331cd39c45671d6b69',
#   'release_year': 2023,
#   'average_monthly_revenue': 1249.3721664275467},
#  {'unified_app_id': '6720d728fc576b7e60e14c9a',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '63c8966fe752785969720d90',
#   'release_year': 2023,
#   'average_monthly_revenue': 1794.762029459902},
#  {'unified_app_id': '6582614bb759a80dbc1cbcc4',
#   'release_year': 2024,
#   'average_monthly_revenue': 1359.4606451612904},
#  {'unified_app_id': '640b3157b25c6163f5feed3f',
#   'release_year': 2023,
#   'average_monthly_revenue': 1145.587741935484},
#  {'unified_app_id': '6186216abef05d0acaef7b1f',
#   'release_year': 2023,
#   'average_monthly_revenue': 748.4258823529411},
#  {'unified_app_id': '64f146d54126280d6f6ade90',
#   'release_year': 2023,
#   'average_monthly_revenue': 1018.0225446428573},
#  {'unified_app_id': '666a92bd09823549d82212e0',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '632bb6d1b31b0e701003180c',
#   'release_year': 2023,
#   'average_monthly_revenue': 1324.615484804631},
#  {'unified_app_id': '64253e0ef8a9dd5acbe09176',
#   'release_year': 2024,
#   'average_monthly_revenue': 1362.0926910299004},
#  {'unified_app_id': '66c83d383515f5d21d046d8c',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64b513f2c5ff011c96c12bb5',
#   'release_year': 2024,
#   'average_monthly_revenue': 1439.899293286219},
#  {'unified_app_id': '65991c8ac39fd85f57d47507',
#   'release_year': 2024,
#   'average_monthly_revenue': 1363.2541806020067},
#  {'unified_app_id': '62dc1094950aa45ff9e85ddb',
#   'release_year': 2024,
#   'average_monthly_revenue': 1812.5437499999998},
#  {'unified_app_id': '63a3e07527145907961bfcbf',
#   'release_year': 2023,
#   'average_monthly_revenue': 1330.863209076175},
#  {'unified_app_id': '5e8aa634dc8e05221963ec38',
#   'release_year': 2023,
#   'average_monthly_revenue': 1689.9709489051095},
#  {'unified_app_id': '64ec165478581f4ea2d3d1b7',
#   'release_year': 2023,
#   'average_monthly_revenue': 1628.4304347826085},
#  {'unified_app_id': '65d4c962b3ae271289298ead',
#   'release_year': 2024,
#   'average_monthly_revenue': 1567.0401544401545},
#  {'unified_app_id': '6379be799fb75c0d67353df1',
#   'release_year': 2023,
#   'average_monthly_revenue': 873.6299424184261},
#  {'unified_app_id': '638997fed1a3715c246bb0a3',
#   'release_year': 2023,
#   'average_monthly_revenue': 13245.846428571429},
#  {'unified_app_id': '660b8fab5cce4b4f526e91a2',
#   'release_year': 2024,
#   'average_monthly_revenue': 1696.0663865546214},
#  {'unified_app_id': '670a1b920b518d244c6cbc93',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6503162837351a382970a14f',
#   'release_year': 2023,
#   'average_monthly_revenue': 1963.187951807229},
#  {'unified_app_id': '613dbbbedcfd071388f2cbd3',
#   'release_year': 2023,
#   'average_monthly_revenue': 1403.489219330855},
#  {'unified_app_id': '64fcb9cd87ed90536926982c',
#   'release_year': 2023,
#   'average_monthly_revenue': 1057.5352517985611},
#  {'unified_app_id': '66a6fd56b5a5ce0e2f86f289',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6308bd5998623b742c992f16',
#   'release_year': 2023,
#   'average_monthly_revenue': 1304.9324005891017},
#  {'unified_app_id': '6450f2b2d19deb49d874ca05',
#   'release_year': 2023,
#   'average_monthly_revenue': 2167.7662921348315},
#  {'unified_app_id': '644bd89284b3d569997380af',
#   'release_year': 2023,
#   'average_monthly_revenue': 1339.729295154185},
#  {'unified_app_id': '64ef5ffc0483de1c0149b292',
#   'release_year': 2023,
#   'average_monthly_revenue': 3105.9396887159533},
#  {'unified_app_id': '65b9b145f41ad5326c29a93b',
#   'release_year': 2024,
#   'average_monthly_revenue': 1892.9634146341464},
#  {'unified_app_id': '638d432a8243fb7f2d3043ca',
#   'release_year': 2023,
#   'average_monthly_revenue': 1014.260832137733},
#  {'unified_app_id': '646bbb914c907369933a71a9',
#   'release_year': 2023,
#   'average_monthly_revenue': 1158.381923076923},
#  {'unified_app_id': '65d715a61d451677f6e808ef',
#   'release_year': 2024,
#   'average_monthly_revenue': 1371.7305755395685},
#  {'unified_app_id': '65d6dff2f204153773532b59',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64ee2f1ac672c360abe808d4',
#   'release_year': 2023,
#   'average_monthly_revenue': 16762.97142857143},
#  {'unified_app_id': '63a3c13b74c07e596db42c3f',
#   'release_year': 2023,
#   'average_monthly_revenue': 992.3992805755395},
#  {'unified_app_id': '65b2d74ec04a5a5b9d32e3ca',
#   'release_year': 2024,
#   'average_monthly_revenue': 1555.8899999999999},
#  {'unified_app_id': '636095f746b007464ab325ea',
#   'release_year': 2023,
#   'average_monthly_revenue': 1200.3197802197801},
#  {'unified_app_id': '6341fa5d45fcd55b7323da5b',
#   'release_year': 2023,
#   'average_monthly_revenue': 1055.1630841121494},
# ...
#   'average_monthly_revenue': 219.07032418952622},
#  {'unified_app_id': '627b1db26ab37d5090457467',
#   'release_year': 2024,
#   'average_monthly_revenue': 437.1366666666667},
#  {'unified_app_id': '631a90c13428057a0eaca1de',
#   'release_year': 2023,
#   'average_monthly_revenue': 207.51908177905307},
#  {'unified_app_id': '63e32a7ba4c1c03a12c2d182',
#   'release_year': 2023,
#   'average_monthly_revenue': 3694.2123456790123},
#  {'unified_app_id': '64e6dfaf514391162a986f91',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6531c9330d294864bec1bc31',
#   'release_year': 2024,
#   'average_monthly_revenue': 337.11244635193134},
#  {'unified_app_id': '64b810fd2f52b04a7a79d0b4',
#   'release_year': 2023,
#   'average_monthly_revenue': 206.22765957446808},
#  {'unified_app_id': '639b821ab3ae277aeb6b4a17',
#   'release_year': 2023,
#   'average_monthly_revenue': 150.75705024311182},
#  {'unified_app_id': '6737071118fbd0e9b9fff6c6',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6291896433208866f322e654',
#   'release_year': 2023,
#   'average_monthly_revenue': 300.12297297297295},
#  {'unified_app_id': '6583fcabf7164e020c42e9be',
#   'release_year': 2024,
#   'average_monthly_revenue': 261.21283783783787},
#  {'unified_app_id': '64f8d4289f22db417f0c6250',
#   'release_year': 2024,
#   'average_monthly_revenue': 215.53036211699163},
#  {'unified_app_id': '672bc4949ef000b580ec04d0',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '667388e8a4c9daa1717fdd10',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6384083ff8c4ed6eb68c33ed',
#   'release_year': 2023,
#   'average_monthly_revenue': 286.7455429497569},
#  {'unified_app_id': '64a7a491e18dac6ee1115d9d',
#   'release_year': 2024,
#   'average_monthly_revenue': 197.28497409326425},
#  {'unified_app_id': '640065b6b3ae275062ed1597',
#   'release_year': 2023,
#   'average_monthly_revenue': 449.1733624454148},
#  {'unified_app_id': '647fe1a1fefdb67002f71198',
#   'release_year': 2023,
#   'average_monthly_revenue': 253.07730061349693},
#  {'unified_app_id': '6482d9faf6a67b111bc6ec82',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64dd79801cc57716c717e492',
#   'release_year': 2024,
#   'average_monthly_revenue': 204.9590296495957},
#  {'unified_app_id': '65cd788036733a28b1efade8',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65e7dda49e2b732e18b4a7ab',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '66862648be6131922a7501f9',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '641a6ba5975b6205c9a256c2',
#   'release_year': 2024,
#   'average_monthly_revenue': 409.327868852459},
#  {'unified_app_id': '6369e8ce241f821ac9d4eb2d',
#   'release_year': 2024,
#   'average_monthly_revenue': 156.80715789473686},
#  {'unified_app_id': '5f64dd85ec1eca189ead0d67',
#   'release_year': 2023,
#   'average_monthly_revenue': 337.3314199395771},
#  {'unified_app_id': '65a05ddbab8d8c4997abb549',
#   'release_year': 2024,
#   'average_monthly_revenue': 256.25567010309277},
#  {'unified_app_id': '657087a7a066265b20c0008f',
#   'release_year': 2024,
#   'average_monthly_revenue': 286.4596153846154},
#  {'unified_app_id': '61e65fa2638de4401a78a036',
#   'release_year': 2023,
#   'average_monthly_revenue': 292.85579119086464},
#  {'unified_app_id': '641b21b5e99a15542c6b3cf2',
#   'release_year': 2024,
#   'average_monthly_revenue': 328.804},
#  {'unified_app_id': '564d94a602ac640405000054',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '63101198a2bbae482502bf2e',
#   'release_year': 2023,
#   'average_monthly_revenue': 233.7848948374761},
#  {'unified_app_id': '66e91463ce404a077ad0f526',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '645dd1205ef6e169a8d874e2',
#   'release_year': 2023,
#   'average_monthly_revenue': 287.7133086876155},
#  {'unified_app_id': '651ef01778f6022a95dc4cb2',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6642de9f950aa4882c269de6',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '645b11661db947239576b927',
#   'release_year': 2023,
#   'average_monthly_revenue': 342.5423487544484},
#  {'unified_app_id': '6539b2be33d10d4dfb0d897c',
#   'release_year': 2023,
#   'average_monthly_revenue': 228.3083333333333},
#  {'unified_app_id': '645e41e78de91a405ec4aa02',
#   'release_year': 2023,
#   'average_monthly_revenue': 191.99836363636362},
#  {'unified_app_id': '65a741dbad4adb09cfec6bac',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '663d8caa8118f84ddb231bb8',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65af33ba3511a267e0c52fec',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64443697c5bd9c26aa6e9b67',
#   'release_year': 2023,
#   'average_monthly_revenue': 347.75199999999995},
#  {'unified_app_id': '662a1648f01ac011dc2b3cde',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6720621588970436e1cdd7ef',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '66f14a7127e2c1ad87fb4146',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '644b39cc046947629f8ef79d',
#   'release_year': 2023,
#   'average_monthly_revenue': 1682.1741794310722},
#  {'unified_app_id': '5f50b7e6ec1eca780bcc9371',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6677abafc82cd40f5db2b13a',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '648fa62bedca1004020c6d92',
#   'release_year': 2023,
#   'average_monthly_revenue': 323.0946428571429},
#  {'unified_app_id': '66c7f7527f02f2a9085cca42',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6413dad9008f435663aae119',
#   'release_year': 2023,
#   'average_monthly_revenue': 1397.0607296137339},
#  {'unified_app_id': '6737392e18fbd0e9b90bf750',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6364337af977603983ee9ab0',
#   'release_year': 2023,
#   'average_monthly_revenue': 5463.479999999999},
#  {'unified_app_id': '6562d8e63daf9961681ade39',
#   'release_year': 2024,
#   'average_monthly_revenue': 210.66818181818184},
#  {'unified_app_id': '65f0f7251eadb62982c35050',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65291770da67765d98b7b17f',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6191ececbb22155689823e2f',
#   'release_year': 2023,
#   'average_monthly_revenue': 371.79365482233504},
#  {'unified_app_id': '55d93cab02ac645ad20b2444',
#   'release_year': 2023,
#   'average_monthly_revenue': 294.8101167315175},
#  {'unified_app_id': '647fb45fbca8724ac8b7593c',
#   'release_year': 2023,
#   'average_monthly_revenue': 166.90613207547167},
#  {'unified_app_id': '64fea0605be6d473d859be77',
#   'release_year': 2023,
#   'average_monthly_revenue': 693.6484988452656},
#  {'unified_app_id': '6614059f663cca013ea05b90',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65600bb78bab030f8dbff0d7',
#   'release_year': 2024,
#   'average_monthly_revenue': 200.72368421052633},
#  {'unified_app_id': '650fdaa2d40e7c1f02caadb7',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '666a2ae67406415e0a81c006',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '66e5176f5b72e1c63d21dd73',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '641278a7a9f5e463053575c5',
#   'release_year': 2023,
#   'average_monthly_revenue': 555.1014598540146},
#  {'unified_app_id': '671495e88f435f0f9869a9b0',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '62ad24138079e37104bd61a6',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '658ba6c4f0f0d01a17896ecd',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '62625a20dff18334c32afb79',
#   'release_year': 2023,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '655fed5ac04a5a0ac5926ea9',
#   'release_year': 2024,
#   'average_monthly_revenue': 204.35272727272726},
#  {'unified_app_id': '66727f8cf9d20312d0566206',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65b87bc6bde65b1b42a5338d',
#   'release_year': 2024,
#   'average_monthly_revenue': 228.16952054794524},
#  {'unified_app_id': '6417b523b1b45c4e9e1a8362',
#   'release_year': 2023,
#   'average_monthly_revenue': 151.3001953125},
#  {'unified_app_id': '640b68eac22a811d1172e4e1',
#   'release_year': 2024,
#   'average_monthly_revenue': 186.20308988764043},
#  {'unified_app_id': '61c3ee333d93e913932f862c',
#   'release_year': 2023,
#   'average_monthly_revenue': 229.75128712871285},
#  {'unified_app_id': '64dae220ef20773252afe191',
#   'release_year': 2023,
#   'average_monthly_revenue': 162.35251798561148},
#  {'unified_app_id': '661424efe90da212cd2e1451',
#   'release_year': 2024,
#   'average_monthly_revenue': 307.93177570093457},
#  {'unified_app_id': '65a845b74d5c602fb221c28e',
#   'release_year': 2024,
#   'average_monthly_revenue': 301.3772093023256},
#  {'unified_app_id': '647920777963e25375151bd1',
#   'release_year': 2023,
#   'average_monthly_revenue': 353.12164948453614},
#  {'unified_app_id': '665528cb223bb995962b8ec6',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '63ec7c38b3ae271e72a6118c',
#   'release_year': 2023,
#   'average_monthly_revenue': 302.2705150976909},
#  {'unified_app_id': '61ecef72e6a0745b03f894ad',
#   'release_year': 2024,
#   'average_monthly_revenue': 299.1013824884793},
#  {'unified_app_id': '6539b4d445535c6394eeb6a4',
#   'release_year': 2024,
#   'average_monthly_revenue': 162.85314861460955},
#  {'unified_app_id': '640631d8ad4adb1450b12312',
#   'release_year': 2024,
#   'average_monthly_revenue': 346.8208556149733},
#  {'unified_app_id': '6629573d68e29d39aa1e9729',
#   'release_year': 2024,
#   'average_monthly_revenue': 307.96857142857135},
#  {'unified_app_id': '6465ac123889995998191ac1',
#   'release_year': 2023,
#   'average_monthly_revenue': 477.7852564102564},
#  {'unified_app_id': '6527825dda48c00992b0d4fc',
#   'release_year': 2023,
#   'average_monthly_revenue': 196.36198347107438},
#  {'unified_app_id': '6541e03a1b6a8933ae45efc0',
#   'release_year': 2024,
#   'average_monthly_revenue': 208.77857142857144},
#  {'unified_app_id': '634a30413e802152934b651e',
#   'release_year': 2023,
#   'average_monthly_revenue': 267.73601147776185},
#  {'unified_app_id': '66f510abc01724f2d6323401',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '66abf3e9bf2c79156a2f0a79',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '62fdeb714ddd2760716e4c11',
#   'release_year': 2023,
#   'average_monthly_revenue': 172.67264150943396},
#  {'unified_app_id': '65fd2e3ead4adb70067fda22',
#   'release_year': 2024,
#   'average_monthly_revenue': 347.2901639344263},
#  {'unified_app_id': '641ae7da0555732208b70723',
#   'release_year': 2023,
#   'average_monthly_revenue': 266.8811980033278},
#  {'unified_app_id': '60f8ca6ba000f12cfc83cc8d',
#   'release_year': 2023,
#   'average_monthly_revenue': 412.8317829457364},
#  {'unified_app_id': '63dc7b8f32370b7503fefb08',
#   'release_year': 2023,
#   'average_monthly_revenue': 122.82126537785587},
#  {'unified_app_id': '64b6ca8e4436c02bd4786e13',
#   'release_year': 2023,
#   'average_monthly_revenue': 396.066765578635},
#  {'unified_app_id': '658fad9049a1a9125632fd2a',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '647f8a1e9d70776873955195',
#   'release_year': 2023,
#   'average_monthly_revenue': 206.01222222222222},
#  {'unified_app_id': '63a267eddaef9849c729e9d9',
#   'release_year': 2023,
#   'average_monthly_revenue': 197.14965986394557},
#  {'unified_app_id': '628c41758403c92ca6681a45',
#   'release_year': 2023,
#   'average_monthly_revenue': 3092.640886699507},
#  {'unified_app_id': '6544318d4b273e6406b5a7fb',
#   'release_year': 2023,
#   'average_monthly_revenue': 1789.73595505618},
#  {'unified_app_id': '67129bf90ca8d5f4b26d99d9',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6340d4590b276e2e84ff2572',
#   'release_year': 2023,
#   'average_monthly_revenue': 101.88076311605725},
#  {'unified_app_id': '666aa4c45c52967cdc80bbf5',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '62fe5bb4c084ff069dab06eb',
#   'release_year': 2023,
#   'average_monthly_revenue': 142.35667144906742},
#  {'unified_app_id': '665dadebb3ae2733b9dc6b4e',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '60c2801cecda0577704aed6f',
#   'release_year': 2023,
#   'average_monthly_revenue': 237.01094224924014},
#  {'unified_app_id': '5a93b7dcc563e6773f8c8c25',
#   'release_year': 2023,
#   'average_monthly_revenue': 212.4953271028037},
#  {'unified_app_id': '6516455d30ddf610fd1b36f5',
#   'release_year': 2023,
#   'average_monthly_revenue': 187.24929577464792},
#  {'unified_app_id': '667136ff9d5e3bcf8d464345',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '65655222fd7e7b700a87a268',
#   'release_year': 2024,
#   'average_monthly_revenue': 206.0808724832215},
#  {'unified_app_id': '66904a855882c30a12dc9544',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64f1767232fe4242418968c3',
#   'release_year': 2024,
#   'average_monthly_revenue': 159.59453125},
#  {'unified_app_id': '660230937b8e41633d6ff1b9',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64e6bc41e19d8369562c2f48',
#   'release_year': 2023,
#   'average_monthly_revenue': 276.29519230769233},
#  {'unified_app_id': '664eca6a35c8599ccb6efd5e',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '64103c25e5f1a773b37f8abf',
#   'release_year': 2023,
#   'average_monthly_revenue': 322.9738144329897},
#  {'unified_app_id': '63a3d0e9b1b0a10a69f48b4c',
#   'release_year': 2024,
#   'average_monthly_revenue': 193.75},
#  {'unified_app_id': '62ccfc956015ac4089418041',
#   'release_year': 2023,
#   'average_monthly_revenue': 294.09672897196265},
#  {'unified_app_id': '64c0b3188c85a0522c08a46e',
#   'release_year': 2023,
#   'average_monthly_revenue': 57891.52645914398},
#  {'unified_app_id': '66081c294b864f75f127eeb7',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '66dbf79840dfb7d4a9b1dce9',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '66be0dd2356d7ec3b1e597dc',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '66f78742ea3daf9ce5afd4cb',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '626c9e943c0c6b1c656af25c',
#   'release_year': 2024,
#   'average_monthly_revenue': 108.75844370860928},
#  {'unified_app_id': '66362d8ead4adb24eb569c95',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '6706e83974075026fda87f3d',
#   'release_year': 2024,
#   'average_monthly_revenue': None},
#  {'unified_app_id': '62c19a55928f7e02003e935e',
#   'release_year': 2023,
#   'average_monthly_revenue': 116.73333333333335},
#  {'unified_app_id': '65c0981dad4adb70336fb53e',
#   'release_year': 2024,
#   'average_monthly_revenue': 220.89444444444445},
#  {'unified_app_id': '64f09ff0b3ae2770c6ac4c83',
#   'release_year': 2023,
#   'average_monthly_revenue': 174.54017094017095},
#  {'unified_app_id': '65281f6ecf149450ff3bc680',
#   'release_year': 2023,
#   'average_monthly_revenue': 279.2484261501211},
#  {'unified_app_id': '6632cc06d49de620d41d6fae',
#   'release_year': 2024,
#   'average_monthly_revenue': 294.85671641791043},
#  {'unified_app_id': '65eae1baf008086d4d119281',
#   'release_year': 2024,
#   'average_monthly_revenue': 221.92584269662922},
#  {'unified_app_id': '6620046afcf09c318f786626',
#   'release_year': 2024,
#   'average_monthly_revenue': 264.7727678571429},
#  {'unified_app_id': '64d22def54624675a7cb5781',
#   'release_year': 2024,
#   'average_monthly_revenue': 304.4180412371134},
#  ...]

# %%
df_avg_monthly_revenue_of_games_released_in_2023_2024 = pd.DataFrame(
    avg_monthly_revenue_of_games_released_in_2023_2024
)

# %%
df_avg_monthly_revenue_of_games_released_in_2023_2024.to_csv('data/output/df_avg_monthly_revenue_of_games_released_in_2023_2024.csv',index=False)

# %% [markdown]
# # Task ID-000-004: Create slide on top new games by publisher

# %%
# Find list of games released during 2020 - 2024 period

# %%
games_released_from_2020_to_2024 = list(
    filter(
        lambda x: x['release_year'] in [2020, 2021, 2022, 2023, 2024],
        games_release_year
    )
)

# %%
# Get the list of unified_app_ids of these games

# %%
list_unified_ids_released_from_2020_to_2024 = list(
    map(
        lambda x: x['unified_app_id'],
        games_released_from_2020_to_2024
    )
)

# %%
# Get the list of apps belonging to these games (released from 2020 to 2024)

# %%
df_app_info_released_from_2020_to_2024 = df_all_app_info_list[
    df_all_app_info_list['unified_app_id'].isin(list_unified_ids_released_from_2020_to_2024)
]

# %%
df_app_info_released_from_2020_to_2024[
    df_app_info_released_from_2020_to_2024['unified_app_id'] == '5f3ca1373901921b75c92afe'
]
# Out:
#                  app_id canonical_country                            name  \
# 7076         1521771561                US  SoulLand:Đấu La Đại Lục-Funtap
# 34818  com.vn.sl.google                US  Soul Land: Đấu La Đại Lục-Funt
#
#                                publisher_name publisher_id  \
# 7076   WISENESS GAME ONLINE INTERNATIONAL LTD   1091188713
# 34818                              Hong Ha VN   Hong+Ha+VN
#
#                        humanized_name  \
# 7076   SoulLand:Đấu La Đại Lục-Funtap
# 34818  Soul Land: Đấu La Đại Lục-Funt
#
#                                                 icon_url       os  active  \
# 7076   https://is1-ssl.mzstatic.com/image/thumb/Purpl...      ios    True
# 34818  https://play-lh.googleusercontent.com/hFpSdJxH...  android   False
#
#                                                      url  ...  \
# 7076     https://apps.apple.com/US/app/id1521771561?l=en  ...
# 34818  https://play.google.com/store/apps/details?hl=...  ...
#
#                                          screenshot_urls  \
# 7076   ['https://is1-ssl.mzstatic.com/image/thumb/Pur...
# 34818  ['https://play-lh.googleusercontent.com/bhya0n...
#
#                                   tablet_screenshot_urls  \
# 7076   ['https://is1-ssl.mzstatic.com/image/thumb/Pur...
# 34818                                                 []
#
#                                              description subtitle promo_text  \
# 7076   ——GT Game——\nCải biên từ tiểu thuyết bán chạy ...      NaN        NaN
# 34818  SoulLand: Đấu La Đại Lục sẽ chính thức mở serv...      NaN        NaN
#
#                                              permissions  \
# 7076                                                 NaN
# 34818  {'Storage': ['read the contents of your USB st...
#
#             supported_languages country_release_date  cleaned_publisher_name  \
# 7076   ['en', 'zh', 'th', 'vi']                  NaN                  Funtap
# 34818                        []                  NaN                  Funtap
#
#        revenue_multiplier
# 7076                    3
# 34818                   3
#
# [2 rows x 53 columns]

# %%
# Filter the apps that belong to VNese publishers

# %%
df_app_info_released_from_2020_to_2024_from_vn_publisher = df_app_info_released_from_2020_to_2024[
    df_app_info_released_from_2020_to_2024['revenue_multiplier'] > 1
]

# %%
list_unified_ids_released_from_2020_to_2024_from_vn_publisher = list(set(list(
    df_app_info_released_from_2020_to_2024_from_vn_publisher['unified_app_id']
)))

# %%
# Side-check: check the list of publisher_ids per unified_app_id

# %%
cleaned_publisher_names_per_unified_id_released_from_2020_to_2024_from_vn_publisher = list(
    map(
        lambda x: {
            'unified_app_id': x,
            'cleaned_publisher_names': list(
                set(
                    df_app_info_released_from_2020_to_2024_from_vn_publisher[
                        df_app_info_released_from_2020_to_2024_from_vn_publisher['unified_app_id'] == x
                    ]['cleaned_publisher_name']
                )
            )
        },
        list_unified_ids_released_from_2020_to_2024_from_vn_publisher
    )
)

# %%
cleaned_publisher_names_per_unified_id_released_from_2020_to_2024_from_vn_publisher
# Out:
# [{'unified_app_id': '6518e90143ee8718b7e23fec',
#   'cleaned_publisher_names': ['Gamota']},
#  {'unified_app_id': '64ce95d0697eff2798068618',
#   'cleaned_publisher_names': ['SohaGame']},
#  {'unified_app_id': '5d0355893ea9832c13e157d2',
#   'cleaned_publisher_names': ['Garena', 'VNG']},
#  {'unified_app_id': '6300aa37d42f2333652844f0',
#   'cleaned_publisher_names': ['VNG']},
#  {'unified_app_id': '6650dbe7b3ae2736333a1e51',
#   'cleaned_publisher_names': ['Gamota']},
#  {'unified_app_id': '
#  {'unified_app_id': '5ee9e41a60b07c7b7c27170d',
#   'cleaned_publisher_names': ['VGP']},
#  {'unified_app_id': '62872474cc9ba5317df026c7',
#   'cleaned_publisher_names': ['VNG']},
#  {'unified_app_id': '66050958ec3c1117710970b9',
#   'cleaned_publisher_names': ['Gamota']}]

# %%
# Check games having multiple VN publishers

list(
    filter(
        lambda x: len(x['cleaned_publisher_names']) > 1,
        cleaned_publisher_names_per_unified_id_released_from_2020_to_2024_from_vn_publisher
    )    
)
# Out:
# [{'unified_app_id': '5d0355893ea9832c13e157d2',
#   'cleaned_publisher_names': ['Garena', 'VNG']},
#  {'unified_app_id': '6522ce55fe6cd0517760607e',
#   'cleaned_publisher_names': ['Funtap', 'HHGAME LTD']},
#  {'unified_app_id': '6178da8bfb94934d110250cb',
#   'cleaned_publisher_names': ['Funtap', 'HHGAME LTD']},
#  {'unified_app_id': '64dc7ff401a93e0ff44f86db',
#   'cleaned_publisher_names': ['Funtap', 'HHGAME LTD']},
#  {'unified_app_id': '63578bb99d838447746c5887',
#   'cleaned_publisher_names': ['Funtap', 'HHGAME LTD']},
#  {'unified_app_id': '64619ad72e146b39c0fa0a6a',
#   'cleaned_publisher_names': ['Funtap', 'HHGAME LTD']},
#  {'unified_app_id': '66fb97dffb320cffcfb1e326',
#   'cleaned_publisher_names': ['Funtap', 'HHGAME LTD']},
#  {'unified_app_id': '5fa254dc7a8e43733d2b1c03',
#   'cleaned_publisher_names': ['Funtap', 'HHGAME LTD']}]

# %%
# Manually fix some mapping (unified id --> cleaned_publisher_names)

for row in cleaned_publisher_names_per_unified_id_released_from_2020_to_2024_from_vn_publisher:
    if row['unified_app_id'] == '5d0355893ea9832c13e157d2':
        row['cleaned_publisher_names'] = ['VNG']
    
    if row['unified_app_id'] == '6522ce55fe6cd0517760607e':
        row['cleaned_publisher_names'] = ['HHGAME LTD']

    if row['unified_app_id'] == '6178da8bfb94934d110250cb':
        row['cleaned_publisher_names'] = ['HHGAME LTD']

    if row['unified_app_id'] == '64dc7ff401a93e0ff44f86db':
        row['cleaned_publisher_names'] = ['HHGAME LTD']

    if row['unified_app_id'] == '63578bb99d838447746c5887':
        row['cleaned_publisher_names'] = ['HHGAME LTD']

    if row['unified_app_id'] == '64619ad72e146b39c0fa0a6a':
        row['cleaned_publisher_names'] = ['HHGAME LTD']

    if row['unified_app_id'] == '66fb97dffb320cffcfb1e326':
        row['cleaned_publisher_names'] = ['HHGAME LTD']
        
    if row['unified_app_id'] == '5fa254dc7a8e43733d2b1c03':
        row['cleaned_publisher_names'] = ['HHGAME LTD']

# %%
# Get the ios and android app ids of these apps

# %%
list_app_ids_released_from_2020_to_2024_from_vn_publisher_ios = list(
    map(lambda x: str(x),
        list(
                df_app_info_released_from_2020_to_2024_from_vn_publisher[
                    df_app_info_released_from_2020_to_2024_from_vn_publisher['os'] == 'ios'
                ]['app_id']
            )
        )
    )

list_app_ids_released_from_2020_to_2024_from_vn_publisher_android = list(
    map(lambda x: str(x),
        list(
                df_app_info_released_from_2020_to_2024_from_vn_publisher[
                    df_app_info_released_from_2020_to_2024_from_vn_publisher['os'] == 'android'
                ]['app_id']
            )
        )
    )

# %%
# Query the app performance data (performance piece - each in a period, for an app)

# %%
## query for ios apps

app_performance_data_ios = get_apps_performance(
    api_key, 
    base_url, 
    os = 'ios', 
    app_ids = list_app_ids_released_from_2020_to_2024_from_vn_publisher_ios, 
    country_code = 'VN', 
    granularity = 'daily', 
    max_periods = 10000, 
    start_date = '2020-01-01', 
    end_date = '2024-11-27'
)
# Out:
# Date ranges: [('2020-01-01', '2024-11-27')]
# Requesting Data for Range: 2020-01-01 to 2024-11-27
# making call for chunk number 1
# Data retrieved for 2020-01-01 to 2024-11-27
# making call for chunk number 2
# Data retrieved for 2020-01-01 to 2024-11-27
# making call for chunk number 3
# Data retrieved for 2020-01-01 to 2024-11-27

# %%
## query for android apps

app_performance_data_android = get_apps_performance(
    api_key, 
    base_url, 
    os = 'android', 
    app_ids = list_app_ids_released_from_2020_to_2024_from_vn_publisher_android, 
    country_code = 'VN', 
    granularity = 'daily', 
    max_periods = 10000, 
    start_date = '2020-01-01', 
    end_date = '2024-11-27'
)
# Out:
# Date ranges: [('2020-01-01', '2024-11-27')]
# Requesting Data for Range: 2020-01-01 to 2024-11-27
# making call for chunk number 1
# Data retrieved for 2020-01-01 to 2024-11-27
# making call for chunk number 2
# Data retrieved for 2020-01-01 to 2024-11-27
# making call for chunk number 3
# Data retrieved for 2020-01-01 to 2024-11-27

# %%
## join the 2 lists of performance data together

app_performance_data_released_from_2020_to_2024_from_vn_publisher = app_performance_data_ios + app_performance_data_android

# %%
### Save to JSON file
with open('data/output/app_performance_data_released_from_2020_to_2024_from_vn_publisher.json', 'w', encoding='utf-8') as file:
    json.dump(app_performance_data_released_from_2020_to_2024_from_vn_publisher, file, ensure_ascii=False, indent=4)  # `ensure_ascii=False` keeps non-ASCII characters readable

# %%
# Order the performance pieces into app performance data

# %%
app_performance_data_grouped_by_app_released_from_2020_to_2024_from_vn_publisher_ios = []

total_count = len(list_app_ids_released_from_2020_to_2024_from_vn_publisher_ios)
count = 1

for app_id in list_app_ids_released_from_2020_to_2024_from_vn_publisher_ios:
    
    print("Iteration {}/{}".format(count, total_count))
    print("Processing app_id {}".format(app_id))
    
    app_performance_data_grouped_by_app_released_from_2020_to_2024_from_vn_publisher_ios.append(
        {
            'app_id': app_id,
            'os': 'ios',
            'unified_app_id': list(
                df_all_app_info_list[
                    df_all_app_info_list['app_id'].astype(str) == str(app_id)
                ]['unified_app_id']
            )[0],
            'app_performance': sorted(
                list(
                    filter(
                        lambda x: str(x['aid']) == app_id,
                        app_performance_data_released_from_2020_to_2024_from_vn_publisher
                    )
                ),
                key = lambda x: x['d']
            )
        }
    )
    
    print("Done!")
    
    count += 1
# Out:
# Iteration 1
# Processing app_id com.shg.sg425
# Done!
# Iteration 282/290
# Processing app_id vng.games.thienlong.kiemhiep3d.mobile
# Done!
# Iteration 283/290
# Processing app_id com.HoYoverse.NapVn
# Done!
# Iteration 284/290
# Processing app_id com.archosaur.vn.dr.gp
# Done!
# Iteration 285/290
# Processing app_id com.pg1.tghmm
# Done!
# Iteration 286/290
# Processing app_id com.vng.onepunchman
# Done!
# Iteration 287/290
# Processing app_id com.vtc.tapkich
# Done!
# Iteration 288/290
# Processing app_id adventure.rpg.anime.game.vng.ys6
# Done!
# Iteration 289/290
# Processing app_id com.redriver.shjjc
# Done!
# Iteration 290/290
# Processing app_id vn.funtap.dauphamobile
# Done!

# %%
## Combine the 2 lists

app_performance_data_grouped_by_app_released_from_2020_to_2024_from_vn_publisher = app_performance_data_grouped_by_app_released_from_2020_to_2024_from_vn_publisher_ios + app_performance_data_grouped_by_app_released_from_2020_to_2024_from_vn_publisher_android

# %%
### Save to JSON file
with open('data/output/app_performance_data_grouped_by_app_released_from_2020_to_2024_from_vn_publisher.json', 'w', encoding='utf-8') as file:
    json.dump(app_performance_data_grouped_by_app_released_from_2020_to_2024_from_vn_publisher, file, ensure_ascii=False, indent=4)  # `ensure_ascii=False` keeps non-ASCII characters readable

# %%
# Order the app performance data into game performance data

game_performance_data_for_games_released_from_2020_to_2024_from_vn_publisher = []

total_count = len(list_unified_ids_released_from_2020_to_2024_from_vn_publisher)
count = 1

for unified_app_id in list_unified_ids_released_from_2020_to_2024_from_vn_publisher:

    print("Iteration {}/{}".format(count, total_count))
    print("Processing unified_id {}".format(unified_app_id))
    
    game_performance_data_for_games_released_from_2020_to_2024_from_vn_publisher.append(
        {
            'unified_app_id': unified_app_id,
            'performance_streams': list(
                filter(
                    lambda x: x['unified_app_id'] == unified_app_id,
                    app_performance_data_grouped_by_app_released_from_2020_to_2024_from_vn_publisher
                )
            )
        }
    )
    
    print("Done!")
    count += 1
# Out:
# Iteration 1/323
# Processing unified_id 6518e90143ee8718b7e23fec
# Done!
# Iteration 2/323
# Processing unified_id 64ce95d0697eff2798068618
# Done!
# Iteration 3/323
# Processing unified_id 5d0355893ea9832c13e157d2
# Done!
# Iteration 4/323
# Processing unified_id 6300aa37d42f2333652844f0
# Done!
# Iteration 5/323
# Processing unified_id 6650dbe7b3ae2736333a1e51
# Done!
# Iteration 6/323
# Processing unified_id 6620de2d9db92b4ddddd2e2e
# Done!
# Iteration 7/323
# Processing unified_id 66029b32649dfd33fdf3656e
# Done!
# Iteration 8/323
# Processing unified_id 6522ce55fe6cd0517760607e
# Done!
# Iteration 9/323
# Processing unified_id 5d9fd7ea5ea49e7325c44553
# Done!
# Iteration 10/323
# Processing unified_id 5f09e992d871ea7bfa1d261b
# Done!
# Iteration 11/323
# Processing unified_id 615689dfbdb047784e567718
# Done!
# Iteration 12/323
# Processing unified_id 5fee6d73b66dd8498d61a935
# Done!
# Iteration 13/323
# Processing unified_id 6656475dac116c46d932c207
# Done!
# Iteration 14/323
# Processing unified_id 611cd44e76e4121f94f8b29f
# Done!
# Iteration 15/323
# Processing unified_id 6447cf45b7accc6e0b137aec
# Done!
# Iteration 16/323
# Processing unified_id 6626a822a9cba85698402d6b
# Done!
# Iteration 17/323
# Processing unified_id 6178da8bfb94934d110250cb
# Done!
# Iteration 18/323
# Processing unified_id 6129532d2d9d223923db3b2d
# Done!
# Iteration 19/323
# Processing unified_id 5fbdadc45ad4e402529d483e
# Done!
# Iteration 20/323
# Processing unified_id 62a17c64d4cf060ee448fb7f
# Done!
# Iteration 21/323
# Processing unified_id 63b7af54e1752a247e2814e6
# Done!
# Iteration 22/323
# Processing unified_id 5d91778c29053f773fdc2346
# Done!
# Iteration 23/323
# Processing unified_id 6100f08b1bfb8b36e50a7f66
# Done!
# Iteration 24/323
# Processing unified_id 5eab99d1d7688302f041bc39
# Done!
# Iteration 25/323
# Processing unified_id 66cf467f4a925979c56cd84c
# Done!
# Iteration 26/323
# Processing unified_id 65032b7ab4b2520f8e95fd9e
# Done!
# Iteration 27/323
# Processing unified_id 6481a456de2518330c01dd93
# Done!
# Iteration 28/323
# Processing unified_id 5f493530b3f4a2190b676f1d
# Done!
# Iteration 29/323
# Processing unified_id 66d99ac029fdcad663bbe043
# Done!
# Iteration 30/323
# Processing unified_id 6319c4a774d0e67d8de647b2
# Done!
# Iteration 31/323
# Processing unified_id 636a0b47ba94be6966721f6b
# Done!
# Iteration 32/323
# Processing unified_id 66e5176f5b72e1c63d21dd73
# Done!
# Iteration 33/323
# Processing unified_id 601608ff005b1610e85f2ec4
# Done!
# Iteration 34/323
# Processing unified_id 64dc7ff401a93e0ff44f86db
# Done!
# Iteration 35/323
# Processing unified_id 6180f793f5de045560ea9725
# Done!
# Iteration 36/323
# Processing unified_id 64405fc98f8f2413f98524c7
# Done!
# Iteration 37/323
# Processing unified_id 64c8c3698966bc32a9d8acde
# Done!
# Iteration 38/323
# Processing unified_id 64bde4c83097596d8e327dae
# Done!
# Iteration 39/323
# Processing unified_id 65826151ead12212042f977e
# Done!
# Iteration 40/323
# Processing unified_id 64a91142f08b1411f1c62ffc
# Done!
# Iteration 41/323
# Processing unified_id 66bd20efa26c8332ff0dfd01
# Done!
# Iteration 42/323
# Processing unified_id 6509474dabf35e12a4a89db3
# Done!
# Iteration 43/323
# Processing unified_id 65f11fa81107bb6df0b1f78f
# Done!
# Iteration 44/323
# Processing unified_id 635cbafc61f4f92db6c56e0d
# Done!
# Iteration 45/323
# Processing unified_id 659778cfa33983212809c751
# Done!
# Iteration 46/323
# Processing unified_id 5f073173eafbc65b5d321cf7
# Done!
# Iteration 47/323
# Processing unified_id 5e6f1195a6800a19ab8866ac
# Done!
323
# Processing unified_id 663ffa0564df7d1ea5a06b10
# Done!
# Iteration 318/323
# Processing unified_id 6603aa389cc7a7189ba7b66d
# Done!
# Iteration 319/323
# Processing unified_id 6649dddb43c10c0f7eb290d1
# Done!
# Iteration 320/323
# Processing unified_id 60f64dbd404f3717c8adacaa
# Done!
# Iteration 321/323
# Processing unified_id 5ee9e41a60b07c7b7c27170d
# Done!
# Iteration 322/323
# Processing unified_id 62872474cc9ba5317df026c7
# Done!
# Iteration 323/323
# Processing unified_id 66050958ec3c1117710970b9
# Done!

# %%
# Create the performance dataframe for each game

performance_df_for_games_released_from_2020_to_2024_from_vn_publisher = []

total_count = len(game_performance_data_for_games_released_from_2020_to_2024_from_vn_publisher)
count = 1

for game in game_performance_data_for_games_released_from_2020_to_2024_from_vn_publisher:

    print("Iteration {}/{}".format(count, total_count))
    print("Processing unified_id {}".format(game['unified_app_id']))
    
    performance_df_for_games_released_from_2020_to_2024_from_vn_publisher.append(
        {
            'unified_app_id': game['unified_app_id'],
            'performance_df': generate_performance_streams_df(game['performance_streams'])
        }
    )

    print("Done!\n")
    count += 1
# Out:
# Iteration 1/323
# Processing unified_id 6518e90143ee8718b7e23fec
# Done!
#
# Iteration 2/323
# Processing unified_id 64ce95d0697eff2798068618
# Done!
#
# Iteration 3/323
# Processing unified_id 5d0355893ea9832c13e157d2
# Done!
#
# Iteration 4/323
# Processing unified_id 6300aa37d42f2333652844f0
# Done!
#
# Iteration 5/323
# Processing unified_id 6650dbe7b3ae2736333a1e51
# Done!
#
# Iteration 6/323
# Processing unified_id 6620de2d9db92b4ddddd2e2e
# Done!
#
# Iteration 7/323
# Processing unified_id 66029b32649dfd33fdf3656e
# Done!
#
# Iteration 8/323
# Processing unified_id 6522ce55fe6cd0517760607e
# Done!
#
# Iteration 9/323
# Processing unified_id 5d9fd7ea5ea49e7325c44553
# Done!
#
# Iteration 10/323
# Processing unified_id 5f09e992d871ea7bfa1d261b
# Done!
#
# Iteration 11/323
# Processing unified_id 615689dfbdb047784e567718
# Done!
#
# Iteration 12/323
# Processing unified_id 5fee6d73b66dd8498d61a935
# Done!
#
# Iteration 13/323
# Processing unified_id 6656475dac116c46d932c207
# Done!
#
# Iteration 14/323
# Processing unified_id 611cd44e76e4121f94f8b29f
# Done!
#
# Iteration 15/323
# Processing unified_id 6447cf45b7accc6e0b137aec
# Done!
#
# Iteration 16/323
# Processing unified_id 6626a822a9cba85698402d6b
# Done!
#
# Iteration 17/323
# Processing unified_id 6178da8bfb94934d110250cb
# Done!
#
# Iteration 18/323
# Processing unified_id 6129532d2d9d223923db3b2d
# Done!
#
# Iteration 19/323
# Processing unified_id 5fbdadc45ad4e402529d483e
# Done!
#
# Iteration 20/323
# Processing unified_id 62a17c64d4cf060ee448fb7f
# Done!
#
# Iteration 21/323
# Processing unified_id 63b7af54e1752a247e2814e6
# Done!
#
# Iteration 22/323
# Processing unified_id 5d91778c29053f773fdc2346
# Done!
#
# Iteration 23/323
# Processing unified_id 6100f08b1bfb8b36e50a7f66
# Done!
#
# Iteration 24/323
# Processing unified_id 5eab99d1d7688302f041bc39
# Done!
#
# Iteration 25/323
# Processing unified_id 66cf467f4a925979c56cd84c
# Done!
#
# Iteration 26/323
# Processing unified_id 65032b7ab4b2520f8e95fd9e
# Done!
#
# Iteration 27/323
# Processing unified_id 6481a456de2518330c01dd93
# Done!
#
# Iteration 28/323
# Processing unified_id 5f493530b3f4a2190b676f1d
# Done!
#
# Iteration 29/323
# Processing unified_id 66d99ac029fdcad663bbe043
# Done!
#
# Iteration 30/323
# Processing unified_id 6319c4a774d0e67d8de647b2
# Done!
#
# Iteration 31/323
# Processing unified_id 636a0b47ba94be6966721f6b
# Done!
#
# Iteration 32/323
# Processing unified_id 66e5176f5b72e1c63d21dd73
# Done!
#
# Iteration 33/323
# Processing unified_id 601608ff005b1610e85f2ec4
# Done!
#
# Iteration 34/323
# Processing unified_id 64dc7ff401a93e0ff44f86db
# Done!
#
# Iteration 35/323
# Processing unified_id 6180f793f5de045560ea9725
# Done!
#
# Iteration 36/323
# Processing unified_id 64405fc98f8f2413f98524c7
# Done!
#
# Iteration 37/323
# Processing unified_id 64c8c3698966bc32a9d8acde
# Done!
#
# Iteration 38/323
# Processing unified_id 64bde4c83097596d8e327dae
# Done!
#
# Iteration 39/323
# Processing unified_id 65826151ead12212042f977e
# Done!
#
# Iteration 40/323
# Processing unified_id 64a91142f08b1411f1c62ffc
# Done!
#
# Iteration 41/323
# Processing unified_id 66bd20efa26c8332ff0dfd01
# Done!
#
# Iteration 42/323
# Processing unified_id 6509474dabf35e12a4a89db3
# Done!
#
# Iteration 43/323
# Processing unified_id 65f11fa81107bb6df0b1f78f
# Done!
#
# Iteration 44/323
# Processing unified_id 635cbafc61f4f92db6c56e0d
# Done!
#
# Iteration 45/323
# Processing unified_id 659778cfa33983212809c751
# Done!
#
# Iteration 46/323
# Processing unified_id 5f073173eafbc65b5d321cf7
# Done!
#
# Iteration 47/323
# Processing unified_id 5e6f1195a6800a19ab8866ac
# Done!
#
# Iteration 48/323
# Processing unified_id 63578bb99d838447746c5887
# Done!
#
# Iteration 49/323
# Processing unified_id 622877933c0c6b14b6bc14ba
# Done!
#
# Iteration 50/323
# Processing unified_id 5e0ae513b9ab9472634970d8
# Done!
#
# Iteration 51/323
# Processing unified_id 666a7683850648f34fb41216
# Done!
#
# Iteration 52/323
# Processing unified_id 63882256bfa0280535094a22
# Done!
#
# Iteration 53/323
# Processing unified_id 64399222b1bc2032d36f13d2
# Done!
#
# Iteration 54/323
# Processing unified_id 6582608575c8970d9fe7b5c2
# Done!
#
# Iteration 55/323
# Processing unified_id 64ccf5f86d841b5ecdc14652
# Done!
#
# Iteration 56/323
# Processing unified_id 6646b58355b6d7105b6b6553
# Done!
#
# Iteration 57/323
# Processing unified_id 61c193558b65541c675aa8c0
# Done!
#
# Iteration 58/323
# Processing unified_id 5e5df9dab9f68d5607e8b614
# Done!
#
# Iteration 59/323
# Processing unified_id 6531fe3cf934b541dfacf3fa
# Done!
#
# Iteration 60/323
# Processing unified_id 650e6b4ea9fe9065eceb9a93
# Done!
#
# Iteration 61/323
# Processing unified_id 651504efd211a646d98e8b5a
# Done!
#
# Iteration 62/323
# Processing unified_id 610454e3c3e5327151b87343
# Done!
#
# Iteration 63/323
# Processing unified_id 666a7679850648f34fb41214
# Done!
#
# Iteration 64/323
# Processing unified_id 661e16f2b279ba3aff370af0
# Done!
#
# Iteration 65/323
# Processing unified_id 625f6726cebc4a14876fc773
# Done!
#
# Iteration 66/323
# Processing unified_id 64999aa4c0eb7a6b20020998
# Done!
#
# Iteration 67/323
# Processing unified_id 5f65b6981212ce6aaffcd17e
# Done!
#
# Iteration 68/323
# Processing unified_id 601cde08ef43f0785537be37
# Done!
#
# Iteration 69/323
# Processing unified_id 64afce0fe18dac563e5cabb7
# Done!
#
# Iteration 70/323
# Processing unified_id 65b4886afc772143e83c80e9
# Done!
#
# Iteration 71/323
# Processing unified_id 6204f587308b704dbab9a1b1
# Done!
#
# Iteration 72/323
# Processing unified_id 600a69ef830d143079c670d3
# Done!
#
# Iteration 73/323
# Processing unified_id 658ccb16e87569306ac36439
# Done!
#
# Iteration 74/323
# Processing unified_id 5fe0662ae795d82242c6e6d2
# Done!
#
# Iteration 75/323
# Processing unified_id 5eaa3bb083de486c48766499
# Done!
#
# Iteration 76/323
# Processing unified_id 62f6203c190adc642328708c
# Done!
#
# Iteration 77/323
# Processing unified_id 60940a23c4ef1c33e2222f99
# Done!
#
# Iteration 78/323
# Processing unified_id 5f3ca1373901921b75c92afe
# Done!
#
# Iteration 79/323
# Processing unified_id 5df8ef0cb9ab94547c68c177
# Done!
#
# Iteration 80/323
# Processing unified_id 5e6729514d03db3aeb2d65f8
# Done!
#
# Iteration 81/323
# Processing unified_id 66527ed9290c7211874abe73
# Done!
#
# Iteration 82/323
# Processing unified_id 63bdd6b32d63ee0ecbfc3636
# Done!
#
# Iteration 83/323
# Processing unified_id 6638a848ad4adb4594498e36
# Done!
#
# Iteration 84/323
# Processing unified_id 60d4c0248b5a71256cd28a33
# Done!
#
# Iteration 85/323
# Processing unified_id 66306b48a596c73d59dfc888
# Done!
#
# Iteration 86/323
# Processing unified_id 657926706277693b751c0cb4
# Done!
#
# Iteration 87/323
# Processing unified_id 6640945b0a025f1a7a130e27
# Done!
#
# Iteration 88/323
# Processing unified_id 64c7aef06caf79033f98f43a
# Done!
#
# Iteration 89/323
# Processing unified_id 5f403686eb829d6d59785db9
# Done!
#
# Iteration 90/323
# Processing unified_id 6349abc10e277b274584b54b
# Done!
#
# Iteration 91/323
# Processing unified_id 633b886973f76b48784c36b9
# Done!
#
# Iteration 92/323
# Processing unified_id 645f3bf5fbea7c637ecc3636
# Done!
#
# Iteration 93/323
# Processing unified_id 66277ad02535561238b4b68d
# Done!
#
# Iteration 94/323
# Processing unified_id 637b0dc7863b79516a758a69
# Done!
#
# Iteration 95/323
# Processing unified_id 62f4cd09367be93fea19fa8a
# Done!
#
# Iteration 96/323
# Processing unified_id 6115323b7a2fb545e009cfcb
# Done!
#
# Iteration 97/323
# Processing unified_id 6495c627cbae9739e17bae4c
# Done!
#
# Iteration 98/323
# Processing unified_id 618221c9bdb0471bbdded487
# Done!
#
# Iteration 99/323
# Processing unified_id 5f4dde3ea223317356e00eb9
# Done!
#
# Iteration 100/323
# Processing unified_id 624221e4aaeb833d98f8b149
# Done!
#
# Iteration 101/323
# Processing unified_id 5e97db66e425a74cab3ef06d
# Done!
#
# Iteration 102/323
# Processing unified_id 6389d4782dc2ea240b06a982
# Done!
#
# Iteration 103/323
# Processing unified_id 6320fb30ad4adb161582e209
# Done!
#
# Iteration 104/323
# Processing unified_id 609d636a95b5d1366e3c9b7e
# Done!
#
# Iteration 105/323
# Processing unified_id 61b1f7b96ffae75bc24b4d78
# Done!
#
# Iteration 106/323
# Processing unified_id 632c0091412495143e4ba92f
# Done!
#
# Iteration 107/323
# Processing unified_id 60618dba71bcbf53dc936e86
# Done!
#
# Iteration 108/323
# Processing unified_id 5fb89ea2056f101d12123469
# Done!
#
# Iteration 109/323
# Processing unified_id 65523ab8b3ae2717177e6748
# Done!
#
# Iteration 110/323
# Processing unified_id 60aa13a370319f6e2508a4dd
# Done!
#
# Iteration 111/323
# Processing unified_id 6030d93db2df116837eb62c1
# Done!
#
# Iteration 112/323
# Processing unified_id 65d56f57dd4de13fbef0768b
# Done!
#
# Iteration 113/323
# Processing unified_id 634fb6d5915ae947b9c8185a
# Done!
#
# Iteration 114/323
# Processing unified_id 66428480f651ec16ec266c57
# Done!
#
# Iteration 115/323
# Processing unified_id 60d04ac6b3ae270609fe554b
# Done!
#
# Iteration 116/323
# Processing unified_id 5e8d8cbef228a334d5f1beb6
# Done!
#
# Iteration 117/323
# Processing unified_id 666a7679850648f34fb41215
# Done!
#
# Iteration 118/323
# Processing unified_id 5db250835a46f07d1cc9702e
# Done!
#
# Iteration 119/323
# Processing unified_id 5ec7ec8ceafbc61deec3b7d9
# Done!
#
# Iteration 120/323
# Processing unified_id 62d5e0a2beb7957a0b786490
# Done!
#
# Iteration 121/323
# Processing unified_id 60645f1554f2382aab21e32d
# Done!
#
# Iteration 122/323
# Processing unified_id 65e5da34d29202576bdea65a
# Done!
#
# Iteration 123/323
# Processing unified_id 5f2beb6eec1eca1d614abc89
# Done!
#
# Iteration 124/323
# Processing unified_id 5eddcd2be7e6b81e5ef0f068
# Done!
#
# Iteration 125/323
# Processing unified_id 65823471fc3fe50f8e2b14d9
# Done!
#
# Iteration 126/323
# Processing unified_id 664b764d8430adac59525fa6
# Done!
#
# Iteration 127/323
# Processing unified_id 64e5dee58bab0362967d66b0
# Done!
#
# Iteration 128/323
# Processing unified_id 61d414d961a2397948b61f01
# Done!
#
# Iteration 129/323
# Processing unified_id 62ad8df00105e66c1355d59b
# Done!
#
# Iteration 130/323
# Processing unified_id 62b18ff2991fd92dd394d299
# Done!
#
# Iteration 131/323
# Processing unified_id 65cc5eab69eefb4fad4c1376
# Done!
#
# Iteration
323
# Processing unified_id 5c6e53e450795405f48b88cf
# Done!
#
# Iteration 194/323
# Processing unified_id 6711c8a804c993fa9f546b30
# Done!
#
# Iteration 195/323
# Processing unified_id 6478a8ca4800d7095fb186d3
# Done!
#
# Iteration 196/323
# Processing unified_id 5d2d6caa3ea983183934bc12
# Done!
#
# Iteration 197/323
# Processing unified_id 64ca96928a678b4349c0bbbb
# Done!
#
# Iteration 198/323
# Processing unified_id 5fac66403e5ce4073a088ced
# Done!
#
# Iteration 199/323
# Processing unified_id 65765f06cb54b62bf7af6a85
# Done!
#
# Iteration 200/323
# Processing unified_id 658f9f16623739111651e8a0
# Done!
#
# Iteration 201/323
# Processing unified_id 65fe3703fe76ce3657e52d8d
# Done!
#
# Iteration 202/323
# Processing unified_id 64796634d20ff2116f39a01d
# Done!
#
# Iteration 203/323
# Processing unified_id 669df767059af1f0653d9d65
# Done!
#
# Iteration 204/323
# Processing unified_id 637c5fffe3e3c3040b84f159
# Done!
#
# Iteration 205/323
# Processing unified_id 6246cef8381d8f5db9ffa82f
# Done!
#
# Iteration 206/323
# Processing unified_id 6547962a994f9650c753bb29
# Done!
#
# Iteration 207/323
# Processing unified_id 6214c8b68c588b3c9acd19c7
# Done!
#
# Iteration 208/323
# Processing unified_id 652da61c5b601405ec02892d
# Done!
#
# Iteration 209/323
# Processing unified_id 602676ea8761c6130584636e
# Done!
#
# Iteration 210/323
# Processing unified_id 6545db024227cd177700a064
# Done!
#
# Iteration 211/323
# Processing unified_id 5d09e4b03ea9836770c1cf5a
# Done!
#
# Iteration 212/323
# Processing unified_id 617a5c64f6275d2d93560471
# Done!
#
# Iteration 213/323
# Processing unified_id 64ede5412d63ee580d609fb9
# Done!
#
# Iteration 214/323
# Processing unified_id 652f6e39a020f13af057ccec
# Done!
#
# Iteration 215/323
# Processing unified_id 6360cbf2c705ab01d03c9a25
# Done!
#
# Iteration 216/323
# Processing unified_id 6659e428226b831d7faf84cc
# Done!
#
# Iteration 217/323
# Processing unified_id 6220bbe38b9e665095bc83e4
# Done!
#
# Iteration 218/323
# Processing unified_id 66ae27a7bb7ff7d8b74d55a0
# Done!
#
# Iteration 219/323
# Processing unified_id 66fb97dffb320cffcfb1e326
# Done!
#
# Iteration 220/323
# Processing unified_id 64e08f3297c8184aa66a7886
# Done!
#
# Iteration 221/323
# Processing unified_id 6695e953ff0c1af70c83442a
# Done!
#
# Iteration 222/323
# Processing unified_id 665e8f9d8abb1241b09700fc
# Done!
#
# Iteration 223/323
# Processing unified_id 6364ea2f68948619f25880c9
# Done!
#
# Iteration 224/323
# Processing unified_id 5dae7186998dea362fffc8d3
# Done!
#
# Iteration 225/323
# Processing unified_id 62678e2024a36301dc7044ea
# Done!
#
# Iteration 226/323
# Processing unified_id 6737392e18fbd0e9b90bf750
# Done!
#
# Iteration 227/323
# Processing unified_id 60b9cea9e459e26eb13c2468
# Done!
#
# Iteration 228/323
# Processing unified_id 610376042cfa1f0edaec093a
# Done!
#
# Iteration 229/323
# Processing unified_id 61c4303963339964b7852420
# Done!
#
# Iteration 230/323
# Processing unified_id 66c82d07410ff0a97e039ed3
# Done!
#
# Iteration 231/323
# Processing unified_id 5f3b76921392d052ebf0d0ca
# Done!
#
# Iteration 232/323
# Processing unified_id 62f638da3811e936454f2b0f
# Done!
#
# Iteration 233/323
# Processing unified_id 66a48512e3e8bb583ced30ad
# Done!
#
# Iteration 234/323
# Processing unified_id 5fbb699458aaf04004a26d90
# Done!
#
# Iteration 235/323
# Processing unified_id 5d560fc327474347a137e0f3
# Done!
#
# Iteration 236/323
# Processing unified_id 66f305acbff88b2279074f9c
# Done!
#
# Iteration 237/323
# Processing unified_id 60afcafcd691a12d95e60ba0
# Done!
#
# Iteration 238/323
# Processing unified_id 656ea3db367b4633e6567f8e
# Done!
#
# Iteration 239/323
# Processing unified_id 604355ffec1eca4ecdcb5f91
# Done!
#
# Iteration 240/323
# Processing unified_id 5d37fa8e2cd5aa39b8f13c57
# Done!
#
# Iteration 241/323
# Processing unified_id 66a9f962bbe8c80fefe4935d
# Done!
#
# Iteration 242/323
# Processing unified_id 633f2758594b7b63d09751fc
# Done!
#
# Iteration 243/323
# Processing unified_id 5fa254dc7a8e43733d2b1c03
# Done!
#
# Iteration 244/323
# Processing unified_id 6204aa439cc0f863cb03a1f2
# Done!
#
# Iteration 245/323
# Processing unified_id 62ed7f32b3f4a244d482d6c7
# Done!
#
# Iteration 246/323
# Processing unified_id 62b407bb60b07c1a92d7c847
# Done!
#
# Iteration 247/323
# Processing unified_id 6141c4fd8bb2076d56699e94
# Done!
#
# Iteration 248/323
# Processing unified_id 5e055822e98ec10b74e9180d
# Done!
#
# Iteration 249/323
# Processing unified_id 62e4c2dcaac2e50a05df221a
# Done!
#
# Iteration 250/323
# Processing unified_id 64c0b3188c85a0522c08a46e
# Done!
#
# Iteration 251/323
# Processing unified_id 66932d63c787b90e25781175
# Done!
#
# Iteration 252/323
# Processing unified_id 62f23800666b0f348c89d1e0
# Done!
#
# Iteration 253/323
# Processing unified_id 644cd690584b2707b7036be0
# Done!
#
# Iteration 254/323
# Processing unified_id 6635c621f748cdf578efb571
# Done!
#
# Iteration 255/323
# Processing unified_id 62764aac9252ed0a82145d18
# Done!
#
# Iteration 256/323
# Processing unified_id 664e520a8430ad7b672dd2c2
# Done!
#
# Iteration 257/323
# Processing unified_id 65e7dda49e2b732e18b4a7ab
# Done!
#
# Iteration 258/323
# Processing unified_id 65f3e2edd2d2f066b363542b
# Done!
#
# Iteration 259/323
# Processing unified_id 6305b7cde8b1a2695d89cb12
# Done!
#
# Iteration 260/323
# Processing unified_id 614d60492ade4a314bb87a34
# Done!
#
# Iteration 261/323
# Processing unified_id 63a0fbe3ad4adb6b3ba39504
# Done!
#
# Iteration 262/323
# Processing unified_id 665e5f316638481b8df5791e
# Done!
#
# Iteration 263/323
# Processing unified_id 673880ef1f7c4000ba1ef924
# Done!
#
# Iteration 264/323
# Processing unified_id 5fc7392b941f963c99485d0f
# Done!
#
# Iteration 265/323
# Processing unified_id 669dc9d8e04f78d8e9c99c18
# Done!
#
# Iteration 266/323
# Processing unified_id 5f378fe871feeb730dbbc0fb
# Done!
#
# Iteration 267/323
# Processing unified_id 66029cfcbd40f76228abacd0
# Done!
#
# Iteration 268/323
# Processing unified_id 64fb5254c397d213263bbe2f
# Done!
#
# Iteration 269/323
# Processing unified_id 6439381ea0f47f0e94b71f6f
# Done!
#
# Iteration 270/323
# Processing unified_id 5f32f216c00d3a66ea0ced98
# Done!
#
# Iteration 271/323
# Processing unified_id 627a4d23fbd17a6ab4f0b1ac
# Done!
#
# Iteration 272/323
# Processing unified_id 6083a7885934a82d73701a07
# Done!
#
# Iteration 273/323
# Processing unified_id 6670098947a500c078db041b
# Done!
#
# Iteration 274/323
# Processing unified_id 61711804d325802f015b38f3
# Done!
#
# Iteration 275/323
# Processing unified_id 66de8fb77625711859619afa
# Done!
#
# Iteration 276/323
# Processing unified_id 5f8fc387a8c16d131d6ade64
# Done!
#
# Iteration 277/323
# Processing unified_id 60699652c46ae667f2187b41
# Done!
#
# Iteration 278/323
# Processing unified_id 62625a20dff18334c32afb79
# Done!
#
# Iteration 279/323
# Processing unified_id 666a79b96b79e13f1241593f
# Done!
#
# Iteration 280/323
# Processing unified_id 5e8fd1732707ba584b92b2ad
# Done!
#
# Iteration 281/323
# Processing unified_id 60b8e4051107bb390293a4bf
# Done!
#
# Iteration 282/323
# Processing unified_id 5fd097d591e67b7b27422fb0
# Done!
#
# Iteration 283/323
# Processing unified_id 6684ef8e31fab6f7c8d0584c
# Done!
#
# Iteration 284/323
# Processing unified_id 66cc10059e7c3b0db92da359
# Done!
#
# Iteration 285/323
# Processing unified_id 64d5f2f9229d840ac6025910
# Done!
#
# Iteration 286/323
# Processing unified_id 6440e6b08ce2c13709535dc3
# Done!
#
# Iteration 287/323
# Processing unified_id 626d11b3b672a029fdbf45c0
# Done!
#
# Iteration 288/323
# Processing unified_id 651487070b2bad724578b041
# Done!
#
# Iteration 289/323
# Processing unified_id 62f680b10e277b1e1595a7de
# Done!
#
# Iteration 290/323
# Processing unified_id 615ea824e5b3b35c1c9e612c
# Done!
#
# Iteration 291/323
# Processing unified_id 5f852df6a08c4e194dbd707e
# Done!
#
# Iteration 292/323
# Processing unified_id 639ff55ec7f5ec0d1883c726
# Done!
#
# Iteration 293/323
# Processing unified_id 60f151ef6ffae745341f100f
# Done!
#
# Iteration 294/323
# Processing unified_id 5fa8bd39ff1e1b28d892937d
# Done!
#
# Iteration 295/323
# Processing unified_id 6549cba84251ad48400e50bf
# Done!
#
# Iteration 296/323
# Processing unified_id 66db66c817f69ae1b1559809
# Done!
#
# Iteration 297/323
# Processing unified_id 636886ea24cb101fb00ce22e
# Done!
#
# Iteration 298/323
# Processing unified_id 633679f395b5d1083638c77a
# Done!
#
# Iteration 299/323
# Processing unified_id 63be498c22d978122038c4a5
# Done!
#
# Iteration 300/323
# Processing unified_id 6223305711885471e9b9c0ea
# Done!
#
# Iteration 301/323
# Processing unified_id 641ce1cf3169d82cab237c53
# Done!
#
# Iteration 302/323
# Processing unified_id 5da67c09a546ab1edeb6c50d
# Done!
#
# Iteration 303/323
# Processing unified_id 6679b0ea56287121469ffe1a
# Done!
#
# Iteration 304/323
# Processing unified_id 6618cd4754e2531457fd8cb1
# Done!
#
# Iteration 305/323
# Processing unified_id 669a8cc0e19c0a72837acc1a
# Done!
#
# Iteration 306/323
# Processing unified_id 6478a99938db1301c3f31631
# Done!
#
# Iteration 307/323
# Processing unified_id 641031dea3e9543d579181af
# Done!
#
# Iteration 308/323
# Processing unified_id 644bb0bdc5b9042c3e1e0c3a
# Done!
#
# Iteration 309/323
# Processing unified_id 625e0c55315ff51e5f75b358
# Done!
#
# Iteration 310/323
# Processing unified_id 66c50b19fd00e3defecc832e
# Done!
#
# Iteration 311/323
# Processing unified_id 642ea283c084ff1c6afcc825
# Done!
#
# Iteration 312/323
# Processing unified_id 62d8ad489454482d4d746322
# Done!
#
# Iteration 313/323
# Processing unified_id 638997fed1a3715c246bb0a3
# Done!
#
# Iteration 314/323
# Processing unified_id 6539d116d2e5a9284e6a76e2
# Done!
#
# Iteration 315/323
# Processing unified_id 5e841b5bdf90524c5ea661f3
# Done!
#
# Iteration 316/323
# Processing unified_id 632fe9375b974b3f5f59bfb0
# Done!
#
# Iteration 317/323
# Processing unified_id 663ffa0564df7d1ea5a06b10
# Done!
#
# Iteration 318/323
# Processing unified_id 6603aa389cc7a7189ba7b66d
# Done!
#
# Iteration 319/323
# Processing unified_id 6649dddb43c10c0f7eb290d1
# Done!
#
# Iteration 320/323
# Processing unified_id 60f64dbd404f3717c8adacaa
# Done!
#
# Iteration 321/323
# Processing unified_id 5ee9e41a60b07c7b7c27170d
# Done!
#
# Iteration 322/323
# Processing unified_id 62872474cc9ba5317df026c7
# Done!
#
# Iteration 323/323
# Processing unified_id 66050958ec3c1117710970b9
# Done!

# %%
# Calculate the full adjusted revenue of each game (daily)

daily_sum_performance_df_for_games_released_from_2020_to_2024_from_vn_publisher = []

total_count = len(performance_df_for_games_released_from_2020_to_2024_from_vn_publisher)
count = 1

for game in performance_df_for_games_released_from_2020_to_2024_from_vn_publisher:
    
    print("Iteration {}/{}".format(count, total_count))
    print("Processing unified_id {}".format(game['unified_app_id']))
    
    daily_sum_performance_df_for_games_released_from_2020_to_2024_from_vn_publisher.append(
        {
            'unified_app_id': game['unified_app_id'],
            'daily_adjusted_revenue_series': get_adjusted_daily_revenue(
                game['performance_df'], 
                df_all_app_info_list
            )
        }
    )
    
    print("Done!\n")
    count += 1
# Out:
# Iteration 1/323
# Processing unified_id 6518e90143ee8718b7e23fec
# Done!
#
# Iteration 2/323
# Processing unified_id 64ce95d0697eff2798068618
# Done!
#
# Iteration 3/323
# Processing unified_id 5d0355893ea9832c13e157d2
# Done!
#
# Iteration 4/323
# Processing unified_id 6300aa37d42f2333652844f0
# Done!
#
# Iteration 5/323
# Processing unified_id 6650dbe7b3ae2736333a1e51
# Done!
#
# Iteration 6/323
# Processing unified_id 6620de2d9db92b4ddddd2e2e
# Done!
#
# Iteration 7/323
# Processing unified_id 66029b32649dfd33fdf3656e
# Done!
#
# Iteration 8/323
# Processing unified_id 6522ce55fe6cd0517760607e
# Done!
#
# Iteration 9/323
# Processing unified_id 5d9fd7ea5ea49e7325c44553
# Done!
#
# Iteration 10/323
# Processing unified_id 5f09e992d871ea7bfa1d261b
# Done!
#
# Iteration 11/323
# Processing unified_id 615689dfbdb047784e567718
# Done!
#
# Iteration 12/323
# Processing unified_id 5fee6d73b66dd8498d61a935
# Done!
#
# Iteration 13/323
# Processing unified_id 6656475dac116c46d932c207
# Done!
#
# Iteration 14/323
# Processing unified_id 611cd44e76e4121f94f8b29f
# Done!
#
# Iteration 15/323
# Processing unified_id 6447cf45b7accc6e0b137aec
# Done!
#
# Iteration 16/323
# Processing unified_id 6626a822a9cba85698402d6b
# Done!
#
# Iteration 17/323
# Processing unified_id 6178da8bfb94934d110250cb
# Done!
#
# Iteration 18/323
# Processing unified_id 6129532d2d9d223923db3b2d
# Done!
#
# Iteration 19/323
# Processing unified_id 5fbdadc45ad4e402529d483e
# Done!
#
# Iteration 20/323
# Processing unified_id 62a17c64d4cf060ee448fb7f
# Done!
#
# Iteration 21/323
# Processing unified_id 63b7af54e1752a247e2814e6
# Done!
#
# Iteration 22/323
# Processing unified_id 5d91778c29053f773fdc2346
# Done!
#
# Iteration 23/323
# Processing unified_id 6100f08b1bfb8b36e50a7f66
# Done!
#
# Iteration 24/323
# Processing unified_id 5eab99d1d7688302f041bc39
# Done!
#
# Iteration 25/323
# Processing unified_id 66cf467f4a925979c56cd84c
# Done!
#
# Iteration 26/323
# Processing unified_id 65032b7ab4b2520f8e95fd9e
# Done!
#
# Iteration 27/323
# Processing unified_id 6481a456de2518330c01dd93
# Done!
#
# Iteration 28/323
# Processing unified_id 5f493530b3f4a2190b676f1d
# Done!
#
# Iteration 29/323
# Processing unified_id 66d99ac029fdcad663bbe043
# Done!
#
# Iteration 30/323
# Processing unified_id 6319c4a774d0e67d8de647b2
# Done!
#
# Iteration 31/323
# Processing unified_id 636a0b47ba94be6966721f6b
# Done!
#
# Iteration 32/323
# Processing unified_id 66e5176f5b72e1c63d21dd73
# Done!
#
# Iteration 33/323
# Processing unified_id 601608ff005b1610e85f2ec4
# Done!
#
# Iteration 34/323
# Processing unified_id 64dc7ff401a93e0ff44f86db
# Done!
#
# Iteration 35/323
# Processing unified_id 6180f793f5de045560ea9725
# Done!
#
# Iteration 36/323
# Processing unified_id 64405fc98f8f2413f98524c7
# Done!
#
# Iteration 37/323
# Processing unified_id 64c8c3698966bc32a9d8acde
# Done!
#
# Iteration 38/323
# Processing unified_id 64bde4c83097596d8e327dae
# Done!
#
# Iteration 39/323
# Processing unified_id 65826151ead12212042f977e
# Done!
#
# Iteration 40/323
# Processing unified_id 64a91142f08b1411f1c62ffc
# Done!
#
# Iteration 41/323
# Processing unified_id 66bd20efa26c8332ff0dfd01
# Done!
#
# Iteration 42/323
# Processing unified_id 6509474dabf35e12a4a89db3
# Done!
#
# Iteration 43/323
# Processing unified_id 65f11fa81107bb6df0b1f78f
# Done!
#
# Iteration 44/323
# Processing unified_id 635cbafc61f4f92db6c56e0d
# Done!
#
# Iteration 45/323
# Processing unified_id 659778cfa33983212809c751
# Done!
#
# Iteration 46/323
# Processing unified_id 5f073173eafbc65b5d321cf7
# Done!
#
# Iteration 47/323
# Processing unified_id 5e6f1195a6800a19ab8866ac
# Done!
#
# Iteration 48/323
# Processing unified_id 63578bb99d838447746c5887
# Done!
#
# Iteration 49/323
# Processing unified_id 622877933c0c6b14b6bc14ba
# Done!
#
# Iteration 50/323
# Processing unified_id 5e0ae513b9ab9472634970d8
# Done!
#
# Iteration 51/323
# Processing unified_id 666a7683850648f34fb41216
# Done!
#
# Iteration 52/323
# Processing unified_id 63882256bfa0280535094a22
# Done!
#
# Iteration 53/323
# Processing unified_id 64399222b1bc2032d36f13d2
# Done!
#
# Iteration 54/323
# Processing unified_id 6582608575c8970d9fe7b5c2
# Done!
#
# Iteration 55/323
# Processing unified_id 64ccf5f86d841b5ecdc14652
# Done!
#
# Iteration 56/323
# Processing unified_id 6646b58355b6d7105b6b6553
# Done!
#
# Iteration 57/323
# Processing unified_id 61c193558b65541c675aa8c0
# Done!
#
# Iteration 58/323
# Processing unified_id 5e5df9dab9f68d5607e8b614
# Done!
#
# Iteration 59/323
# Processing unified_id 6531fe3cf934b541dfacf3fa
# Done!
#
# Iteration 60/323
# Processing unified_id 650e6b4ea9fe9065eceb9a93
# Done!
#
# Iteration 61/323
# Processing unified_id 651504efd211a646d98e8b5a
# Done!
#
# Iteration 62/323
# Processing unified_id 610454e3c3e5327151b87343
# Done!
#
# Iteration 63/323
# Processing unified_id 666a7679850648f34fb41214
# Done!
#
# Iteration 64/323
# Processing unified_id 661e16f2b279ba3aff370af0
# Done!
#
# Iteration 65/323
# Processing unified_id 625f6726cebc4a14876fc773
# Done!
#
# Iteration 66/323
# Processing unified_id 64999aa4c0eb7a6b20020998
# Done!
#
# Iteration 67/323
# Processing unified_id 5f65b6981212ce6aaffcd17e
# Done!
#
# Iteration 68/323
# Processing unified_id 601cde08ef43f0785537be37
# Done!
#
# Iteration 69/323
# Processing unified_id 64afce0fe18dac563e5cabb7
# Done!
#
# Iteration 70/323
# Processing unified_id 65b4886afc772143e83c80e9
# Done!
#
# Iteration 71/323
# Processing unified_id 6204f587308b704dbab9a1b1
# Done!
#
# Iteration 72/323
# Processing unified_id 600a69ef830d143079c670d3
# Done!
#
# Iteration 73/323
# Processing unified_id 658ccb16e87569306ac36439
# Done!
#
# Iteration 74/323
# Processing unified_id 5fe0662ae795d82242c6e6d2
# Done!
#
# Iteration 75/323
# Processing unified_id 5eaa3bb083de486c48766499
# Done!
#
# Iteration 76/323
# Processing unified_id 62f6203c190adc642328708c
# Done!
#
# Iteration 77/323
# Processing unified_id 60940a23c4ef1c33e2222f99
# Done!
#
# Iteration 78/323
# Processing unified_id 5f3ca1373901921b75c92afe
# Done!
#
# Iteration 79/323
# Processing unified_id 5df8ef0cb9ab94547c68c177
# Done!
#
# Iteration 80/323
# Processing unified_id 5e6729514d03db3aeb2d65f8
# Done!
#
# Iteration 81/323
# Processing unified_id 66527ed9290c7211874abe73
# Done!
#
# Iteration 82/323
# Processing unified_id 63bdd6b32d63ee0ecbfc3636
# Done!
#
# Iteration 83/323
# Processing unified_id 6638a848ad4adb4594498e36
# Done!
#
# Iteration 84/323
# Processing unified_id 60d4c0248b5a71256cd28a33
# Done!
#
# Iteration 85/323
# Processing unified_id 66306b48a596c73d59dfc888
# Done!
#
# Iteration 86/323
# Processing unified_id 657926706277693b751c0cb4
# Done!
#
# Iteration 87/323
# Processing unified_id 6640945b0a025f1a7a130e27
# Done!
#
# Iteration 88/323
# Processing unified_id 64c7aef06caf79033f98f43a
# Done!
#
# Iteration 89/323
# Processing unified_id 5f403686eb829d6d59785db9
# Done!
#
# Iteration 90/323
# Processing unified_id 6349abc10e277b274584b54b
# Done!
#
# Iteration 91/323
# Processing unified_id 633b886973f76b48784c36b9
# Done!
#
# Iteration 92/323
# Processing unified_id 645f3bf5fbea7c637ecc3636
# Done!
#
# Iteration 93/323
# Processing unified_id 66277ad02535561238b4b68d
# Done!
#
# Iteration 94/323
# Processing unified_id 637b0dc7863b79516a758a69
# Done!
#
# Iteration 95/323
# Processing unified_id 62f4cd09367be93fea19fa8a
# Done!
#
# Iteration 96/323
# Processing unified_id 6115323b7a2fb545e009cfcb
# Done!
#
# Iteration 97/323
# Processing unified_id 6495c627cbae9739e17bae4c
# Done!
#
# Iteration 98/323
# Processing unified_id 618221c9bdb0471bbdded487
# Done!
#
# Iteration 99/323
# Processing unified_id 5f4dde3ea223317356e00eb9
# Done!
#
# Iteration 100/323
# Processing unified_id 624221e4aaeb833d98f8b149
# Done!
#
# Iteration 101/323
# Processing unified_id 5e97db66e425a74cab3ef06d
# Done!
#
# Iteration 102/323
# Processing unified_id 6389d4782dc2ea240b06a982
# Done!
#
# Iteration 103/323
# Processing unified_id 6320fb30ad4adb161582e209
# Done!
#
# Iteration 104/323
# Processing unified_id 609d636a95b5d1366e3c9b7e
# Done!
#
# Iteration 105/323
# Processing unified_id 61b1f7b96ffae75bc24b4d78
# Done!
#
# Iteration 106/323
# Processing unified_id 632c0091412495143e4ba92f
# Done!
#
# Iteration 107/323
# Processing unified_id 60618dba71bcbf53dc936e86
# Done!
#
# Iteration 108/323
# Processing unified_id 5fb89ea2056f101d12123469
# Done!
#
# Iteration 109/323
# Processing unified_id 65523ab8b3ae2717177e6748
# Done!
#
# Iteration 110/323
# Processing unified_id 60aa13a370319f6e2508a4dd
# Done!
#
# Iteration 111/323
# Processing unified_id 6030d93db2df116837eb62c1
# Done!
#
# Iteration 112/323
# Processing unified_id 65d56f57dd4de13fbef0768b
# Done!
#
# Iteration 113/323
# Processing unified_id 634fb6d5915ae947b9c8185a
# Done!
#
# Iteration 114/323
# Processing unified_id 66428480f651ec16ec266c57
# Done!
#
# Iteration 115/323
# Processing unified_id 60d04ac6b3ae270609fe554b
# Done!
#
# Iteration 116/323
# Processing unified_id 5e8d8cbef228a334d5f1beb6
# Done!
#
# Iteration 117/323
# Processing unified_id 666a7679850648f34fb41215
# Done!
#
# Iteration 118/323
# Processing unified_id 5db250835a46f07d1cc9702e
# Done!
#
# Iteration 119/323
# Processing unified_id 5ec7ec8ceafbc61deec3b7d9
# Done!
#
# Iteration 120/323
# Processing unified_id 62d5e0a2beb7957a0b786490
# Done!
#
# Iteration 121/323
# Processing unified_id 60645f1554f2382aab21e32d
# Done!
#
# Iteration 122/323
# Processing unified_id 65e5da34d29202576bdea65a
# Done!
#
# Iteration 123/323
# Processing unified_id 5f2beb6eec1eca1d614abc89
# Done!
#
# Iteration 124/323
# Processing unified_id 5eddcd2be7e6b81e5ef0f068
# Done!
#
# Iteration 125/323
# Processing unified_id 65823471fc3fe50f8e2b14d9
# Done!
#
# Iteration 126/323
# Processing unified_id 664b764d8430adac59525fa6
# Done!
#
# Iteration 127/323
# Processing unified_id 64e5dee58bab0362967d66b0
# Done!
#
# Iteration 128/323
# Processing unified_id 61d414d961a2397948b61f01
# Done!
#
# Iteration 129/323
# Processing unified_id 62ad8df00105e66c1355d59b
# Done!
#
# Iteration 130/323
# Processing unified_id 62b18ff2991fd92dd394d299
# Done!
#
# Iteration 131/323
# Processing unified_id 65cc5eab69eefb4fad4c1376
# Done!
#
# Iteration 132/323
# Processing unified_id 65d5913fc22a81162efd50ca
# Done!
#
# Iteration 133/323
# Processing unified_id 60f2091f2ccf555d2bc38ba6
# Done!
#
# Iteration 134/323
# Processing unified_id 62fc3f7f4fb5ee56485ba131
# Done!
#
# Iteration 135/323
# Processing unified_id 60a0312911c542326e602fd3
# Done!
#
# Iteration 136/323
# Processing unified_id 654708bd33c4d6468c54b26d
# Done!
#
# Iteration 137/323
# Processing unified_id 65fd06dba6a66211427de1cd
# Done!
323
# Processing unified_id 6547962a994f9650c753bb29
# Done!
#
# Iteration 207/323
# Processing unified_id 6214c8b68c588b3c9acd19c7
# Done!
#
# Iteration 208/323
# Processing unified_id 652da61c5b601405ec02892d
# Done!
#
# Iteration 209/323
# Processing unified_id 602676ea8761c6130584636e
# Done!
#
# Iteration 210/323
# Processing unified_id 6545db024227cd177700a064
# Done!
#
# Iteration 211/323
# Processing unified_id 5d09e4b03ea9836770c1cf5a
# Done!
#
# Iteration 212/323
# Processing unified_id 617a5c64f6275d2d93560471
# Done!
#
# Iteration 213/323
# Processing unified_id 64ede5412d63ee580d609fb9
# Done!
#
# Iteration 214/323
# Processing unified_id 652f6e39a020f13af057ccec
# Done!
#
# Iteration 215/323
# Processing unified_id 6360cbf2c705ab01d03c9a25
# Done!
#
# Iteration 216/323
# Processing unified_id 6659e428226b831d7faf84cc
# Done!
#
# Iteration 217/323
# Processing unified_id 6220bbe38b9e665095bc83e4
# Done!
#
# Iteration 218/323
# Processing unified_id 66ae27a7bb7ff7d8b74d55a0
# Done!
#
# Iteration 219/323
# Processing unified_id 66fb97dffb320cffcfb1e326
# Done!
#
# Iteration 220/323
# Processing unified_id 64e08f3297c8184aa66a7886
# Done!
#
# Iteration 221/323
# Processing unified_id 6695e953ff0c1af70c83442a
# Done!
#
# Iteration 222/323
# Processing unified_id 665e8f9d8abb1241b09700fc
# Done!
#
# Iteration 223/323
# Processing unified_id 6364ea2f68948619f25880c9
# Done!
#
# Iteration 224/323
# Processing unified_id 5dae7186998dea362fffc8d3
# Done!
#
# Iteration 225/323
# Processing unified_id 62678e2024a36301dc7044ea
# Done!
#
# Iteration 226/323
# Processing unified_id 6737392e18fbd0e9b90bf750
# Done!
#
# Iteration 227/323
# Processing unified_id 60b9cea9e459e26eb13c2468
# Done!
#
# Iteration 228/323
# Processing unified_id 610376042cfa1f0edaec093a
# Done!
#
# Iteration 229/323
# Processing unified_id 61c4303963339964b7852420
# Done!
#
# Iteration 230/323
# Processing unified_id 66c82d07410ff0a97e039ed3
# Done!
#
# Iteration 231/323
# Processing unified_id 5f3b76921392d052ebf0d0ca
# Done!
#
# Iteration 232/323
# Processing unified_id 62f638da3811e936454f2b0f
# Done!
#
# Iteration 233/323
# Processing unified_id 66a48512e3e8bb583ced30ad
# Done!
#
# Iteration 234/323
# Processing unified_id 5fbb699458aaf04004a26d90
# Done!
#
# Iteration 235/323
# Processing unified_id 5d560fc327474347a137e0f3
# Done!
#
# Iteration 236/323
# Processing unified_id 66f305acbff88b2279074f9c
# Done!
#
# Iteration 237/323
# Processing unified_id 60afcafcd691a12d95e60ba0
# Done!
#
# Iteration 238/323
# Processing unified_id 656ea3db367b4633e6567f8e
# Done!
#
# Iteration 239/323
# Processing unified_id 604355ffec1eca4ecdcb5f91
# Done!
#
# Iteration 240/323
# Processing unified_id 5d37fa8e2cd5aa39b8f13c57
# Done!
#
# Iteration 241/323
# Processing unified_id 66a9f962bbe8c80fefe4935d
# Done!
#
# Iteration 242/323
# Processing unified_id 633f2758594b7b63d09751fc
# Done!
#
# Iteration 243/323
# Processing unified_id 5fa254dc7a8e43733d2b1c03
# Done!
#
# Iteration 244/323
# Processing unified_id 6204aa439cc0f863cb03a1f2
# Done!
#
# Iteration 245/323
# Processing unified_id 62ed7f32b3f4a244d482d6c7
# Done!
#
# Iteration 246/323
# Processing unified_id 62b407bb60b07c1a92d7c847
# Done!
#
# Iteration 247/323
# Processing unified_id 6141c4fd8bb2076d56699e94
# Done!
#
# Iteration 248/323
# Processing unified_id 5e055822e98ec10b74e9180d
# Done!
#
# Iteration 249/323
# Processing unified_id 62e4c2dcaac2e50a05df221a
# Done!
#
# Iteration 250/323
# Processing unified_id 64c0b3188c85a0522c08a46e
# Done!
#
# Iteration 251/323
# Processing unified_id 66932d63c787b90e25781175
# Done!
#
# Iteration 252/323
# Processing unified_id 62f23800666b0f348c89d1e0
# Done!
#
# Iteration 253/323
# Processing unified_id 644cd690584b2707b7036be0
# Done!
#
# Iteration 254/323
# Processing unified_id 6635c621f748cdf578efb571
# Done!
#
# Iteration 255/323
# Processing unified_id 62764aac9252ed0a82145d18
# Done!
#
# Iteration 256/323
# Processing unified_id 664e520a8430ad7b672dd2c2
# Done!
#
# Iteration 257/323
# Processing unified_id 65e7dda49e2b732e18b4a7ab
# Done!
#
# Iteration 258/323
# Processing unified_id 65f3e2edd2d2f066b363542b
# Done!
#
# Iteration 259/323
# Processing unified_id 6305b7cde8b1a2695d89cb12
# Done!
#
# Iteration 260/323
# Processing unified_id 614d60492ade4a314bb87a34
# Done!
#
# Iteration 261/323
# Processing unified_id 63a0fbe3ad4adb6b3ba39504
# Done!
#
# Iteration 262/323
# Processing unified_id 665e5f316638481b8df5791e
# Done!
#
# Iteration 263/323
# Processing unified_id 673880ef1f7c4000ba1ef924
# Done!
#
# Iteration 264/323
# Processing unified_id 5fc7392b941f963c99485d0f
# Done!
#
# Iteration 265/323
# Processing unified_id 669dc9d8e04f78d8e9c99c18
# Done!
#
# Iteration 266/323
# Processing unified_id 5f378fe871feeb730dbbc0fb
# Done!
#
# Iteration 267/323
# Processing unified_id 66029cfcbd40f76228abacd0
# Done!
#
# Iteration 268/323
# Processing unified_id 64fb5254c397d213263bbe2f
# Done!
#
# Iteration 269/323
# Processing unified_id 6439381ea0f47f0e94b71f6f
# Done!
#
# Iteration 270/323
# Processing unified_id 5f32f216c00d3a66ea0ced98
# Done!
#
# Iteration 271/323
# Processing unified_id 627a4d23fbd17a6ab4f0b1ac
# Done!
#
# Iteration 272/323
# Processing unified_id 6083a7885934a82d73701a07
# Done!
#
# Iteration 273/323
# Processing unified_id 6670098947a500c078db041b
# Done!
#
# Iteration 274/323
# Processing unified_id 61711804d325802f015b38f3
# Done!
#
# Iteration 275/323
# Processing unified_id 66de8fb77625711859619afa
# Done!
#
# Iteration 276/323
# Processing unified_id 5f8fc387a8c16d131d6ade64
# Done!
#
# Iteration 277/323
# Processing unified_id 60699652c46ae667f2187b41
# Done!
#
# Iteration 278/323
# Processing unified_id 62625a20dff18334c32afb79
# Done!
#
# Iteration 279/323
# Processing unified_id 666a79b96b79e13f1241593f
# Done!
#
# Iteration 280/323
# Processing unified_id 5e8fd1732707ba584b92b2ad
# Done!
#
# Iteration 281/323
# Processing unified_id 60b8e4051107bb390293a4bf
# Done!
#
# Iteration 282/323
# Processing unified_id 5fd097d591e67b7b27422fb0
# Done!
#
# Iteration 283/323
# Processing unified_id 6684ef8e31fab6f7c8d0584c
# Done!
#
# Iteration 284/323
# Processing unified_id 66cc10059e7c3b0db92da359
# Done!
#
# Iteration 285/323
# Processing unified_id 64d5f2f9229d840ac6025910
# Done!
#
# Iteration 286/323
# Processing unified_id 6440e6b08ce2c13709535dc3
# Done!
#
# Iteration 287/323
# Processing unified_id 626d11b3b672a029fdbf45c0
# Done!
#
# Iteration 288/323
# Processing unified_id 651487070b2bad724578b041
# Done!
#
# Iteration 289/323
# Processing unified_id 62f680b10e277b1e1595a7de
# Done!
#
# Iteration 290/323
# Processing unified_id 615ea824e5b3b35c1c9e612c
# Done!
#
# Iteration 291/323
# Processing unified_id 5f852df6a08c4e194dbd707e
# Done!
#
# Iteration 292/323
# Processing unified_id 639ff55ec7f5ec0d1883c726
# Done!
#
# Iteration 293/323
# Processing unified_id 60f151ef6ffae745341f100f
# Done!
#
# Iteration 294/323
# Processing unified_id 5fa8bd39ff1e1b28d892937d
# Done!
#
# Iteration 295/323
# Processing unified_id 6549cba84251ad48400e50bf
# Done!
#
# Iteration 296/323
# Processing unified_id 66db66c817f69ae1b1559809
# Done!
#
# Iteration 297/323
# Processing unified_id 636886ea24cb101fb00ce22e
# Done!
#
# Iteration 298/323
# Processing unified_id 633679f395b5d1083638c77a
# Done!
#
# Iteration 299/323
# Processing unified_id 63be498c22d978122038c4a5
# Done!
#
# Iteration 300/323
# Processing unified_id 6223305711885471e9b9c0ea
# Done!
#
# Iteration 301/323
# Processing unified_id 641ce1cf3169d82cab237c53
# Done!
#
# Iteration 302/323
# Processing unified_id 5da67c09a546ab1edeb6c50d
# Done!
#
# Iteration 303/323
# Processing unified_id 6679b0ea56287121469ffe1a
# Done!
#
# Iteration 304/323
# Processing unified_id 6618cd4754e2531457fd8cb1
# Done!
#
# Iteration 305/323
# Processing unified_id 669a8cc0e19c0a72837acc1a
# Done!
#
# Iteration 306/323
# Processing unified_id 6478a99938db1301c3f31631
# Done!
#
# Iteration 307/323
# Processing unified_id 641031dea3e9543d579181af
# Done!
#
# Iteration 308/323
# Processing unified_id 644bb0bdc5b9042c3e1e0c3a
# Done!
#
# Iteration 309/323
# Processing unified_id 625e0c55315ff51e5f75b358
# Done!
#
# Iteration 310/323
# Processing unified_id 66c50b19fd00e3defecc832e
# Done!
#
# Iteration 311/323
# Processing unified_id 642ea283c084ff1c6afcc825
# Done!
#
# Iteration 312/323
# Processing unified_id 62d8ad489454482d4d746322
# Done!
#
# Iteration 313/323
# Processing unified_id 638997fed1a3715c246bb0a3
# Done!
#
# Iteration 314/323
# Processing unified_id 6539d116d2e5a9284e6a76e2
# Done!
#
# Iteration 315/323
# Processing unified_id 5e841b5bdf90524c5ea661f3
# Done!
#
# Iteration 316/323
# Processing unified_id 632fe9375b974b3f5f59bfb0
# Done!
#
# Iteration 317/323
# Processing unified_id 663ffa0564df7d1ea5a06b10
# Done!
#
# Iteration 318/323
# Processing unified_id 6603aa389cc7a7189ba7b66d
# Done!
#
# Iteration 319/323
# Processing unified_id 6649dddb43c10c0f7eb290d1
# Done!
#
# Iteration 320/323
# Processing unified_id 60f64dbd404f3717c8adacaa
# Done!
#
# Iteration 321/323
# Processing unified_id 5ee9e41a60b07c7b7c27170d
# Done!
#
# Iteration 322/323
# Processing unified_id 62872474cc9ba5317df026c7
# Done!
#
# Iteration 323/323
# Processing unified_id 66050958ec3c1117710970b9
# Done!

# %%
# Calculate first 365D revenue for each game above

daily_sum_performance_df_for_games_released_from_2020_to_2024_from_vn_publisher_with_d365_revenue = copy.deepcopy(
    daily_sum_performance_df_for_games_released_from_2020_to_2024_from_vn_publisher
)

for row in daily_sum_performance_df_for_games_released_from_2020_to_2024_from_vn_publisher_with_d365_revenue:
    row['first 365-day revenue'] = calculate_first_n_day_revenue(
        daily_sum_performance_df_for_games_released_from_2020_to_2024_from_vn_publisher,
        row['unified_app_id'],
        365
    )
    row['total revenue'] = row['daily_adjusted_revenue_series'].sum()
# Out:
# Processing for unified app id 6518e90143ee8718b7e23fec
# Processing for unified app id 64ce95d0697eff2798068618
# Processing for unified app id 5d0355893ea9832c13e157d2
# Processing for unified app id 6300aa37d42f2333652844f0
# Processing for unified app id 6650dbe7b3ae2736333a1e51
# Game 6650dbe7b3ae2736333a1e51 does not have a date range spanning 365 days.
# Processing for unified app id 60f2091f2ccf555d2bc38ba6
# Processing for unified app id 62fc3f7f4fb5ee56485ba131
# Processing for unified app id 60a0312911c542326e602fd3
# Processing for unified app id 654708bd33c4d6468c54b26d
# Processing for unified app id 65fd06dba6a66211427de1cd
# Game 65fd06dba6a66211427de1cd does not have a date range spanning 365 days.
# Processing for unified app id 6250ee684174343a71581727
# Processing for unified app id 66e5061613e8671e47ff09f0
# Game 66e5061613e8671e47ff09f0 does not have a date range spanning 365 days.
# Processing for unified app id 64b81e61b573e433c717cbdd
# Processing for unified app id 669116dd9b5b60e5668100d6
# Game 669116dd9b5b60e5668100d6 does not have a date range spanning 365 days.
# Processing for unified app id 5e9a8aa5dcc8d944ef74b78f
# Processing for unified app id 5dccab2ade63003f9d41834b
# Processing for unified app id 6667ed3863e96ed8611233f0
# Game 6667ed3863e96ed8611233f0 does not have a date range spanning 365 days.
# Processing for unified app id 5d84173e3ea9835b8b1d4081
# Processing for unified app id 6669c5864b5ce4f9f2239488
# Game 6669c5864b5ce4f9f2239488 does not have a date range spanning 365 days.
# Processing for unified app id 6394f81f005b161af2e96457
# Processing for unified app id 5eb5b4682bb96d1170ec346b
# Processing for unified app id 5fd7263b1109cd5975dfd66e
# Processing for unified app id 66b9c4b0e5dfbf0e5fb63f71
# Game 66b9c4b0e5dfbf0e5fb63f71 does not have a date range spanning 365 days.
# Processing for unified app id 5f64385428bb87713255c25e
# Processing for unified app id 65dc8f9ab5757d2c8dcfafaf
# Game 65dc8f9ab5757d2c8dcfafaf does not have a date range spanning 365 days.
# Processing for unified app id 62fb1587f448b334742c5f77
# Processing for unified app id 60965f24c7466a6fcd573d8a
# Processing for unified app id 5d8d51c03ea9832cb48b7090
# Processing for unified app id 64d262a510a3142a25912bd2
# Game 64d262a510a3142a25912bd2 does not have a date range spanning 365 days.
# Processing for unified app id 620247596b08607cc41e882a
# Processing for unified app id 65aa7377294313129e731d32
# Game 65aa7377294313129e731d32 does not have a date range spanning 365 days.
# Processing for unified app id 65a52459ad4adb12d6d2debf
# Game 65a52459ad4adb12d6d2debf does not have a date range spanning 365 days.
# Processing for unified app id 65601d4dc8169671d78a38ac
# Processing for unified app id 6604e48dbd40f74962b103b2
# Game 6604e48dbd40f74962b103b2 does not have a date range spanning 365 days.
# Processing for unified app id 646939b209db972560a6a24a
# Processing for unified app id 5fca66d4eafbc62d524fd94e
# Processing for unified app id 63ecece74760b21b6d8706b2
# Processing for unified app id 662c1c024891f40cacada25f
# Game 662c1c024891f40cacada25f does not have a date range spanning 365 days.
# Processing for unified app id 6201c48dd857b72c1aa096e1
# Processing for unified app id 66ac33d0aa7fb99d2bb5fd46
# Game 66ac33d0aa7fb99d2bb5fd46 does not have a date range spanning 365 days.
# Processing for unified app id 64eeb50c0ad52111f17605cd
# Processing for unified app id 60ed1360b3ae27015927896b
# Processing for unified app id 5fb347007ae5ba145dcc4025
# Processing for unified app id 61c97a1e467c426c65b2b7b9
# Processing for unified app id 66ad0195ed58add63f343fe0
# Game 66ad0195ed58add63f343fe0 does not have a date range spanning 365 days.
# Processing for unified app id 63be498c22d978122038c4a5
# Processing for unified app id 6223305711885471e9b9c0ea
# Processing for unified app id 641ce1cf3169d82cab237c53
# Processing for unified app id 5da67c09a546ab1edeb6c50d
# Processing for unified app id 6679b0ea56287121469ffe1a
# Game 6679b0ea56287121469ffe1a does not have a date range spanning 365 days.
# Processing for unified app id 6618cd4754e2531457fd8cb1
# Game 6618cd4754e2531457fd8cb1 does not have a date range spanning 365 days.
# Processing for unified app id 669a8cc0e19c0a72837acc1a
# Game 669a8cc0e19c0a72837acc1a does not have a date range spanning 365 days.
# Processing for unified app id 6478a99938db1301c3f31631
# Processing for unified app id 641031dea3e9543d579181af
# Processing for unified app id 644bb0bdc5b9042c3e1e0c3a
# Processing for unified app id 625e0c55315ff51e5f75b358
# Processing for unified app id 66c50b19fd00e3defecc832e
# Game 66c50b19fd00e3defecc832e does not have a date range spanning 365 days.
# Processing for unified app id 642ea283c084ff1c6afcc825
# Processing for unified app id 62d8ad489454482d4d746322
# Processing for unified app id 638997fed1a3715c246bb0a3
# Processing for unified app id 6539d116d2e5a9284e6a76e2
# Game 6539d116d2e5a9284e6a76e2 does not have a date range spanning 365 days.
# Processing for unified app id 5e841b5bdf90524c5ea661f3
# Processing for unified app id 632fe9375b974b3f5f59bfb0
# Processing for unified app id 663ffa0564df7d1ea5a06b10
# Game 663ffa0564df7d1ea5a06b10 does not have a date range spanning 365 days.
# Processing for unified app id 6603aa389cc7a7189ba7b66d
# Game 6603aa389cc7a7189ba7b66d does not have a date range spanning 365 days.
# Processing for unified app id 6649dddb43c10c0f7eb290d1
# Game 6649dddb43c10c0f7eb290d1 does not have a date range spanning 365 days.
# Processing for unified app id 60f64dbd404f3717c8adacaa
# Processing for unified app id 5ee9e41a60b07c7b7c27170d
# Processing for unified app id 62872474cc9ba5317df026c7
# Processing for unified app id 66050958ec3c1117710970b9
# Game 66050958ec3c1117710970b9 does not have a date range spanning 365 days.

# %%
# Add release date and cleaned publisher name info

# %%
daily_sum_performance_df_for_games_released_from_2020_to_2024_from_vn_publisher_with_d365_revenue_release_date_and_cleaned_publisher_name = copy.deepcopy(
    daily_sum_performance_df_for_games_released_from_2020_to_2024_from_vn_publisher_with_d365_revenue
)

for row in daily_sum_performance_df_for_games_released_from_2020_to_2024_from_vn_publisher_with_d365_revenue_release_date_and_cleaned_publisher_name:
    row['release_date'] = get_release_date_from_daily_game_performance_table(
        daily_sum_performance_df_for_games_released_from_2020_to_2024_from_vn_publisher,
        row['unified_app_id']
    )
    row['cleaned_publisher_name'] = list(
        filter(
            lambda x: x['unified_app_id'] == row['unified_app_id'],
            cleaned_publisher_names_per_unified_id_released_from_2020_to_2024_from_vn_publisher
        )
    )[0]['cleaned_publisher_names'][0]
# Out:
# Processing unified app id: 6518e90143ee8718b7e23fec
# Processing unified app id: 64ce95d0697eff2798068618
# Processing unified app id: 5d0355893ea9832c13e157d2
# Processing unified app id: 6300aa37d42f2333652844f0
# Processing unified app id: 6650dbe7b3ae2736333a1e51
# Processing unified app id: 6620de2d9db92b4ddddd2e2e
# Processing unified app id: 66029b32649dfd33fdf3656e
# Processing unified app id: 6522ce55fe6cd0517760607e
# Processing unified app id: 5d9fd7ea5ea49e7325c44553
# Processing unified app id: 5f09e992d871ea7bfa1d261b
# Processing unified app id: 615689dfbdb047784e567718
# Processing unified app id: 5fee6d73b66dd8498d61a935
# Processing unified app id: 6656475dac116c46d932c207
# Processing unified app id: 6478a99938db1301c3f31631
# Processing unified app id: 641031dea3e9543d579181af
# Processing unified app id: 644bb0bdc5b9042c3e1e0c3a
# Processing unified app id: 625e0c55315ff51e5f75b358
# Processing unified app id: 66c50b19fd00e3defecc832e
# Processing unified app id: 642ea283c084ff1c6afcc825
# Processing unified app id: 62d8ad489454482d4d746322
# Processing unified app id: 638997fed1a3715c246bb0a3
# Processing unified app id: 6539d116d2e5a9284e6a76e2
# Processing unified app id: 5e841b5bdf90524c5ea661f3
# Processing unified app id: 632fe9375b974b3f5f59bfb0
# Processing unified app id: 663ffa0564df7d1ea5a06b10
# Processing unified app id: 6603aa389cc7a7189ba7b66d
# Processing unified app id: 6649dddb43c10c0f7eb290d1
# Processing unified app id: 60f64dbd404f3717c8adacaa
# Processing unified app id: 5ee9e41a60b07c7b7c27170d
# Processing unified app id: 62872474cc9ba5317df026c7
# Processing unified app id: 66050958ec3c1117710970b9

# %%
# Leave out the revenue series row and turn the rest of columns into dataframe

# Keys to include in the DataFrame
selected_keys = [
    'unified_app_id', 
    'release_date',
    'cleaned_publisher_name',
    'first 365-day revenue',
    'total revenue'
]

# Filter the dictionaries to include only the selected keys
d365_revenue_of_games_released_from_2020_to_2024_from_vn_publisher_with_release_date_and_cleaned_publisher_name = [
    {key: d[key] for key in selected_keys if key in d} for d in daily_sum_performance_df_for_games_released_from_2020_to_2024_from_vn_publisher_with_d365_revenue_release_date_and_cleaned_publisher_name
]

# %%
# Turn into dataframe

# %%
df_d365_revenue_of_games_released_from_2020_to_2024_from_vn_publisher = pd.DataFrame(
    d365_revenue_of_games_released_from_2020_to_2024_from_vn_publisher_with_release_date_and_cleaned_publisher_name
)

# %%
df_d365_revenue_of_games_released_from_2020_to_2024_from_vn_publisher
# Out:
#                unified_app_id release_date cleaned_publisher_name  \
# 0    6518e90143ee8718b7e23fec   2023-10-07                 Gamota
# 1    64ce95d0697eff2798068618   2023-08-10               SohaGame
# 2    5d0355893ea9832c13e157d2   2020-04-18                    VNG
# 3    6300aa37d42f2333652844f0   2022-09-21                    VNG
# 4    6650dbe7b3ae2736333a1e51   2024-05-29                 Gamota
# ..                        ...          ...                    ...
# 318  6649dddb43c10c0f7eb290d1   2024-05-26                    VTC
# 319  60f64dbd404f3717c8adacaa   2022-01-17                 Gamota
# 320  5ee9e41a60b07c7b7c27170d   2020-06-29                    VGP
# 321  62872474cc9ba5317df026c7   2022-05-25                    VNG
# 322  66050958ec3c1117710970b9   2024-04-14                 Gamota
#
#      first 365-day revenue  total revenue
# 0                   354356         389674
# 1                    63299          63299
# 2                  9006078       25117306
# 3                  1689532        1984505
# 4                      NaN         186372
# ..                     ...            ...
# 318                    NaN         363887
# 319                 148302         175444
# 320                 224355         458708
# 321                 800752        1076044
# 322                    NaN          17367
#
# [323 rows x 5 columns]

# %%
# Checking

df_d365_revenue_of_games_released_from_2020_to_2024_from_vn_publisher[
 df_d365_revenue_of_games_released_from_2020_to_2024_from_vn_publisher['unified_app_id'] == '64d262a510a3142a25912bd2'   
]
# Out:
#                unified_app_id release_date cleaned_publisher_name  \
# 155  64d262a510a3142a25912bd2   2024-02-25                 Funtap
#
#      first 365-day revenue  total revenue
# 155                    NaN        6531562

# %%
# Export to csv
df_d365_revenue_of_games_released_from_2020_to_2024_from_vn_publisher.to_csv('data/output/df_d365_revenue_of_games_released_from_2020_to_2024_from_vn_publisher.csv', index=False)

# %% [markdown]
# # Task: Get 1-year installs

# %%
# Note
{
  "sales_report_estimates_key": {
    "ios": {
      "aid": "App ID",
      "cc": "Country Code",
      "d": "Date",
      "iu": "iPhone Downloads",
      "ir": "iPhone Revenue",
      "au": "iPad Downloads",
      "ar": "iPad Revenue"
    },
    "android": {
      "aid": "App ID",
      "c": "Country Code",
      "d": "Date",
      "u": "Android Downloads",
      "r": "Android Revenue"
    },
    "unified": {
      "app_id": "App ID",
      "country": "Country Code",
      "date": "Date",
      "android_units": "Android Downloads",
      "android_revenue": "Android Revenue",
      "ipad_units": "iPad Downloads",
      "ipad_revenue": "iPad Revenue",
      "iphone_units": "iPhone Downloads",
      "iphone_revenue": "iPhone Revenue"
    }
  }
}
# Out:
# {'sales_report_estimates_key': {'ios': {'aid': 'App ID',
#    'cc': 'Country Code',
#    'd': 'Date',
#    'iu': 'iPhone Downloads',
#    'ir': 'iPhone Revenue',
#    'au': 'iPad Downloads',
#    'ar': 'iPad Revenue'},
#   'android': {'aid': 'App ID',
#    'c': 'Country Code',
#    'd': 'Date',
#    'u': 'Android Downloads',
#    'r': 'Android Revenue'},
#   'unified': {'app_id': 'App ID',
#    'country': 'Country Code',
#    'date': 'Date',
#    'android_units': 'Android Downloads',
#    'android_revenue': 'Android Revenue',
#    'ipad_units': 'iPad Downloads',
#    'ipad_revenue': 'iPad Revenue',
#    'iphone_units': 'iPhone Downloads',
#    'iphone_revenue': 'iPhone Revenue'}}}

# %%
df_game_revenue_adjusted = pd.read_csv('data/output/df_game_revenue_adjusted.csv', index_col = 'Unified ID')

# %%
games_release_year = []

for index, row in df_game_revenue_adjusted.iterrows():
    
    current_game_release_year = get_release_year(
        df_game_revenue_adjusted,
        index
    )
    
    games_release_year.append(
        {
            'unified_app_id': index,
            'release_year': current_game_release_year
        }
    )

# %%
games_released_from_2020_to_2024 = list(
    filter(
        lambda x: x['release_year'] in [2020, 2021, 2022, 2023, 2024],
        games_release_year
    )
)

# %%
# Get the list of unified_app_ids of these games

list_unified_ids_released_from_2020_to_2024 = list(
    map(
        lambda x: x['unified_app_id'],
        games_released_from_2020_to_2024
    )
)

# %%
df_all_app_info_list = pd.read_csv('data/output/df_all_app_info_list.csv')
# Out:
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\467353629.py:1: DtypeWarning: Columns (0,4,25,26,27,34,35,36,39,40,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_all_app_info_list = pd.read_csv('data/output/df_all_app_info_list.csv')

# %%
df_app_info_released_from_2020_to_2024 = df_all_app_info_list[
    df_all_app_info_list['unified_app_id'].isin(list_unified_ids_released_from_2020_to_2024)
]

# %%
# Filter the apps that belong to VNese publishers

df_app_info_released_from_2020_to_2024_from_vn_publisher = df_app_info_released_from_2020_to_2024[
    df_app_info_released_from_2020_to_2024['revenue_multiplier'] > 1
]

# %%
list_unified_ids_released_from_2020_to_2024_from_vn_publisher = list(set(list(
    df_app_info_released_from_2020_to_2024_from_vn_publisher['unified_app_id']
)))

# %%
# Manually fix some mapping (unified id --> cleaned_publisher_names)

for row in cleaned_publisher_names_per_unified_id_released_from_2020_to_2024_from_vn_publisher:
    if row['unified_app_id'] == '5d0355893ea9832c13e157d2':
        row['cleaned_publisher_names'] = ['VNG']
    
    if row['unified_app_id'] == '6522ce55fe6cd0517760607e':
        row['cleaned_publisher_names'] = ['HHGAME LTD']

    if row['unified_app_id'] == '6178da8bfb94934d110250cb':
        row['cleaned_publisher_names'] = ['HHGAME LTD']

    if row['unified_app_id'] == '64dc7ff401a93e0ff44f86db':
        row['cleaned_publisher_names'] = ['HHGAME LTD']

    if row['unified_app_id'] == '63578bb99d838447746c5887':
        row['cleaned_publisher_names'] = ['HHGAME LTD']

    if row['unified_app_id'] == '64619ad72e146b39c0fa0a6a':
        row['cleaned_publisher_names'] = ['HHGAME LTD']

    if row['unified_app_id'] == '66fb97dffb320cffcfb1e326':
        row['cleaned_publisher_names'] = ['HHGAME LTD']
        
    if row['unified_app_id'] == '5fa254dc7a8e43733d2b1c03':
        row['cleaned_publisher_names'] = ['HHGAME LTD']

# %%
# Get the ios and android app ids of these apps

list_app_ids_released_from_2020_to_2024_from_vn_publisher_ios = list(
    map(lambda x: str(x),
        list(
                df_app_info_released_from_2020_to_2024_from_vn_publisher[
                    df_app_info_released_from_2020_to_2024_from_vn_publisher['os'] == 'ios'
                ]['app_id']
            )
        )
    )

list_app_ids_released_from_2020_to_2024_from_vn_publisher_android = list(
    map(lambda x: str(x),
        list(
                df_app_info_released_from_2020_to_2024_from_vn_publisher[
                    df_app_info_released_from_2020_to_2024_from_vn_publisher['os'] == 'android'
                ]['app_id']
            )
        )
    )

# %%
# Query the app performance data (performance piece - each in a period, for an app)

# %%
## query for ios apps

app_performance_data_ios = get_apps_performance(
    api_key, 
    base_url, 
    os = 'ios', 
    app_ids = list_app_ids_released_from_2020_to_2024_from_vn_publisher_ios, 
    country_code = 'VN', 
    granularity = 'daily', 
    max_periods = 10000, 
    start_date = '2020-01-01', 
    end_date = '2024-11-27'
)
# Out:
# Date ranges: [('2020-01-01', '2024-11-27')]
# Requesting Data for Range: 2020-01-01 to 2024-11-27
# making call for chunk number 1
# Data retrieved for 2020-01-01 to 2024-11-27
# making call for chunk number 2
# Data retrieved for 2020-01-01 to 2024-11-27
# making call for chunk number 3
# Data retrieved for 2020-01-01 to 2024-11-27

# %%
## query for android apps

app_performance_data_android = get_apps_performance(
    api_key, 
    base_url, 
    os = 'android', 
    app_ids = list_app_ids_released_from_2020_to_2024_from_vn_publisher_android, 
    country_code = 'VN', 
    granularity = 'daily', 
    max_periods = 10000, 
    start_date = '2020-01-01', 
    end_date = '2024-11-27'
)
# Out:
# Date ranges: [('2020-01-01', '2024-11-27')]
# Requesting Data for Range: 2020-01-01 to 2024-11-27
# making call for chunk number 1
# Data retrieved for 2020-01-01 to 2024-11-27
# making call for chunk number 2
# Data retrieved for 2020-01-01 to 2024-11-27
# making call for chunk number 3
# Data retrieved for 2020-01-01 to 2024-11-27

# %%
## join the 2 lists of performance data together

app_performance_data_released_from_2020_to_2024_from_vn_publisher = app_performance_data_ios + app_performance_data_android

# %%
### Save to JSON file
with open('data/output/app_performance_data_released_from_2020_to_2024_from_vn_publisher.json', 'w', encoding='utf-8') as file:
    json.dump(app_performance_data_released_from_2020_to_2024_from_vn_publisher, file, ensure_ascii=False, indent=4)  # `ensure_ascii=False` keeps non-ASCII characters readable

# %%
# Order the performance pieces into app performance data - iOS

app_performance_data_grouped_by_app_released_from_2020_to_2024_from_vn_publisher_ios = []

total_count = len(list_app_ids_released_from_2020_to_2024_from_vn_publisher_ios)
count = 1

for app_id in list_app_ids_released_from_2020_to_2024_from_vn_publisher_ios:
    
    print("Iteration {}/{}".format(count, total_count))
    print("Processing app_id {}".format(app_id))
    
    app_performance_data_grouped_by_app_released_from_2020_to_2024_from_vn_publisher_ios.append(
        {
            'app_id': app_id,
            'os': 'ios',
            'unified_app_id': list(
                df_all_app_info_list[
                    df_all_app_info_list['app_id'].astype(str) == str(app_id)
                ]['unified_app_id']
            )[0],
            'app_performance': sorted(
                list(
                    filter(
                        lambda x: str(x['aid']) == app_id,
                        app_performance_data_released_from_2020_to_2024_from_vn_publisher
                    )
                ),
                key = lambda x: x['d']
            )
        }
    )
    
    print("Done!")
    
    count += 1
# Out:
# Iteration 1/241
# Processing app_id 6449520792
# Done!
# Iteration 2/241
# Processing app_id 6467180067
# Done!
# Iteration 3/241
# Processing app_id 6478189835
# Done!
# Iteration 4/241
# Processing app_id 6478138913
# Done!
# Iteration 5/241
# Processing app_id 1537216540
# Done!
# Iteration 6/241
# Processing app_id 1557595935
# Done!
# Iteration 7/241
# Processing app_id 1598881852
# Done!
# Iteration 8/241
# Processing app_id 1633394133
# Done!
# Iteration 9/241
# Processing app_id 6466396468
# Done!
# Iteration 10/241
# Processing app_id 6502498607
# Done!
# Iteration 11/241
# Processing app_id 1638660628
# Done!
# Iteration 12/241
# Processing app_id 6479636678
# Done!
# Iteration 13/241
# Processing app_id 6544794058
# Done!
# Iteration 14/241
# Processing app_id 1634718661
# Done!
# Iteration 15/241
# Processing app_id 1616997659
# Done!
# Iteration 16/241
# Processing app_id 6450526727
# Done!
# Iteration 17/241
# Processing app_id 6447750572
# Done!
# Iteration 18/241
# Processing app_id 6468433525
# Done!
# Iteration 19/241
# Processing app_id 6446660906
# Done!
# Iteration 20/241
# Processing app_id 1638876595
_performance_data_grouped_by_app_released_from_2020_to_2024_from_vn_publisher_android = []

total_count = len(list_app_ids_released_from_2020_to_2024_from_vn_publisher_android)
count = 1

for app_id in list_app_ids_released_from_2020_to_2024_from_vn_publisher_android:
    
    print("Iteration {}/{}".format(count, total_count))
    print("Processing app_id {}".format(app_id))
    
    app_performance_data_grouped_by_app_released_from_2020_to_2024_from_vn_publisher_android.append(
        {
            'app_id': app_id,
            'os': 'android',
            'unified_app_id': list(
                df_all_app_info_list[
                    df_all_app_info_list['app_id'].astype(str) == str(app_id)
                ]['unified_app_id']
            )[0],
            'app_performance': sorted(
                list(
                    filter(
                        lambda x: str(x['aid']) == app_id,
                        app_performance_data_released_from_2020_to_2024_from_vn_publisher
                    )
                ),
                key = lambda x: x['d']
            )
        }
    )
    
    print("Done!")
    
    count += 1
# Out:
# Iteration 1/292
# Processing app_id com.and.riseofthekingsvn
# Done!
# Iteration 2/292
# Processing app_id com.wanxi.mxwvn
# Done!
# Iteration 3/292
# Processing app_id com.metroville.global
# Done!
# Iteration 4/292
# Processing app_id vn.funtap.kiemvu.hanhca
# Done!
# Iteration 5/292
# Processing app_id vn.funtap.thucsonthienhachien
# Done!
# Iteration 6/292
# Processing app_id com.gp.we
# Done!
# Iteration 7/292
# Processing app_id com.centurygames.idlecourier
# Done!
# Iteration 8/292
# Processing app_id com.shg.sg416
# Done!
# Iteration 9/292
# Processing app_id com.vtcmobile.ghbp
# Done!
# Iteration 10/292
# Processing app_id com.hermes.mk.asia
# Done!
# Iteration 11/292
# Processing app_id com.mrtgd.sea
# Done!
# Iteration 12/292
# Processing app_id com.onemt.and.kc.vn
# Done!
# Iteration 13/292
# Processing app_id com.pjsekai.kr
# Done!
# Iteration 14/292
# Processing app_id dev.ky.nguyen.genz
# Done!
# Iteration 15/292
# Processing app_id com.and.vn.daqin
# Done!
# Iteration 16/292
# Processing app_id vn.vplay.khoinguyen.t016a
# Done!
# Iteration 17/292
# Processing app_id com.mm.shan
# Done!
# Iteration 18/292
# Processing app_id com.vm3.global
# Done!
# Iteration 19/292
# Processing app_id vn.gosu.nhatdaithienton
# Done!
# Iteration 20/292
# Processing app_id com.vng.thiennhaiminhnguyetdaovng
# Done!
# Iteration 21/292
# Processing app_id com.tg.ysr.vn
# Done!
# Iteration 22/292
# Processing app_id com.vng.mf.liteuamo
# Done!
# Iteration 23/292
# Processing app_id vn.funtap.litebemeo
# Done!
# Iteration 24/292
# Processing app_id vng.games.my.cafe.hello.coffee
# Done!
# Iteration 25/292
# Processing app_id vnggames.chienthan.afk.huyenthoai.panilla.idle.rpg
# Done!
# Iteration 26/292
# Processing app_id dev.ngulong.kiem3d
# Done!
# Iteration 27/292
# Processing app_id com.global.dqvn
# Done!
# Iteration 28/292
# Processing app_id com.ddup.zombiewaves.zw
# Done!
# Iteration 29/292
# Processing app_id phil.luckynine
# Done!
# Iteration 30/292
# Processing app_id vng.games.revelation.mobile
# Done!
# Iteration 31/292
# Processing app_id vng.game.gunny.mobi.classic.original
# Done!
# Iteration 32/292
# Processing app_id com.archosaur.vn.sgzgc.gp
# Done!
# Iteration 33/292
# Processing app_id com.vng.tanomg3q
# Done!
# Iteration 34/292
# Processing app_id com.vtcmobile.thk
# Done!
# Iteration 35/292
# Processing app_id vng.games.boom.together
# Done!
# Iteration 36/292
# Processing app_id com.zps.caro
# Done!
# Iteration 37/292
for_games_released_from_2020_to_2024_from_vn_publisher = []

total_count = len(game_performance_data_for_games_released_from_2020_to_2024_from_vn_publisher)
count = 1

for game in game_performance_data_for_games_released_from_2020_to_2024_from_vn_publisher:

    print("Iteration {}/{}".format(count, total_count))
    print("Processing unified_id {}".format(game['unified_app_id']))
    
    download_df_for_games_released_from_2020_to_2024_from_vn_publisher.append(
        {
            'unified_app_id': game['unified_app_id'],
            'performance_df': generate_download_streams_df(game['performance_streams'])
        }
    )

    print("Done!\n")
    count += 1
# Out:
# Iteration 1/323
# Processing unified_id 60afcafcd691a12d95e60ba0
# Done!
#
# Iteration 2/323
# Processing unified_id 62625a20dff18334c32afb79
# Done!
#
# Iteration 3/323
# Processing unified_id 5ee9e41a60b07c7b7c27170d
# Done!
#
# Iteration 4/323
# Processing unified_id 646939b209db972560a6a24a
# Done!
#
# Iteration 5/323
# Processing unified_id 604355ffec1eca4ecdcb5f91
# Done!
#
# Iteration 6/323
# Processing unified_id 64a91142f08b1411f1c62ffc
# Done!
#
# Iteration 7/323
# Processing unified_id 5fac66403e5ce4073a088ced
# Done!
#
# Iteration 8/323
# Processing unified_id 6539d116d2e5a9284e6a76e2
# Done!
#
# Iteration 9/323
# Processing unified_id 6659e428226b831d7faf84cc
# Done!
#
# Iteration 10/323
# Processing unified_id 63c4d18654b41c6945ddda18
# Done!
#
# Iteration 11/323
# Processing unified_id 609d636a95b5d1366e3c9b7e
# Done!
#
# Iteration 12/323
# Processing unified_id 5c6e53e450795405f48b88cf
# Done!
#
# Iteration 13/323
# Processing unified_id 66a9f962bbe8c80fefe4935d
# Done!
#
# Iteration 14/323
# Processing unified_id 6545db024227cd177700a064
# Done!
#
# Iteration 15/323
# Processing unified_id 62678e2024a36301dc7044ea
# Done!
#
# Iteration 16/323
# Processing unified_id 673880ef1f7c4000ba1ef924
# Done!
#
# Iteration 17/323
# Processing unified_id 5f3b76921392d052ebf0d0ca
# Done!
#
# Iteration 18/323
# Processing unified_id 66277ad02535561238b4b68d
# Done!
#
# Iteration 19/323
# Processing unified_id 66ae27a7bb7ff7d8b74d55a0
# Done!
#
# Iteration 20/323
# Processing unified_id 65f11fa81107bb6df0b1f78f
# Done!
#
# Iteration 21/323
# Processing unified_id 6434f36d74f648189c0a1f86
# Done!
#
# Iteration 22/323
# Processing unified_id 657926706277693b751c0cb4
# Done!
#
# Iteration 23/323
# Processing unified_id 5fbb699458aaf04004a26d90
# Done!
#
# Iteration 24/323
# Processing unified_id 5f8fc387a8c16d131d6ade64
# Done!
#
# Iteration 25/323
# Processing unified_id 66c50b19fd00e3defecc832e
# Done!
#
# Iteration 26/323
# Processing unified_id 5eddcd2be7e6b81e5ef0f068
# Done!
#
# Iteration 27/323
# Processing unified_id 64399222b1bc2032d36f13d2
# Done!
#
# Iteration 28/323
# Processing unified_id 637b0dc7863b79516a758a69
# Done!
#
# Iteration 29/323
# Processing unified_id 6478a8ca4800d7095fb186d3
# Done!
#
# Iteration 30/323
# Processing unified_id 641ce1cf3169d82cab237c53
# Done!
#
# Iteration 31/323
# Processing unified_id 5d91778c29053f773fdc2346
# Done!
#
# Iteration 32/323
# Processing unified_id 60d04ac6b3ae270609fe554b
# Done!
#
# Iteration 33/323
# Processing unified_id 5e6729514d03db3aeb2d65f8
# Done!
#
# Iteration 34/323
# Processing unified_id 658f9f16623739111651e8a0
# Done!
#
# Iteration 35/323
# Processing unified_id 5da67c09a546ab1edeb6c50d
# Done!
#
# Iteration 36/323
# Processing unified_id 63be498c22d978122038c4a5
# Done!
#
# Iteration 37/323
# Processing unified_id 6640945b0a025f1a7a130e27
# Done!
#
# Iteration 38/323
# Processing unified_id 61c193558b65541c675aa8c0
# Done!
#
# Iteration 39/323
# Processing unified_id 65765f06cb54b62bf7af6a85
# Done!
#
# Iteration 40/323
# Processing unified_id 6214c8b68c588b3c9acd19c7
# Done!
#
# Iteration 41/323
# Processing unified_id 5f493530b3f4a2190b676f1d
# Done!
#
# Iteration 42/323
# Processing unified_id 65cc5eab69eefb4fad4c1376
# Done!
#
# Iteration 43/323
# Processing unified_id 60645f1554f2382aab21e32d
# Done!
#
# Iteration 44/323
# Processing unified_id 6129532d2d9d223923db3b2d
# Done!
#
# Iteration 45/323
# Processing unified_id 5f852df6a08c4e194dbd707e
# Done!
#
# Iteration 46/323
# Processing unified_id 64bde4c83097596d8e327dae
# Done!
#
# Iteration 47/323
# Processing unified_id 6547962a994f9650c753bb29
# Done!
#
# Iteration 48/323
# Processing unified_id 6603aa389cc7a7189ba7b66d
# Done!
#
# Iteration 49/323
# Processing unified_id 60a0312911c542326e602fd3
# Done!
#
# Iteration 50/323
# Processing unified_id 659778cfa33983212809c751
# Done!
#
# Iteration 51/323
# Processing unified_id 5d560fc327474347a137e0f3
# Done!
#
# Iteration 52/323
# Processing unified_id 5e0ae513b9ab9472634970d8
# Done!
#
# Iteration 53/323
# Processing unified_id 6495c627cbae9739e17bae4c
# Done!
#
# Iteration 54/323
# Processing unified_id 5d2d6caa3ea983183934bc12
# Done!
#
# Iteration 55/323
# Processing unified_id 6439381ea0f47f0e94b71f6f
# Done!
#
# Iteration 56/323
# Processing unified_id 6531fe3cf934b541dfacf3fa
# Done!
#
# Iteration 57/323
# Processing unified_id 5e8fd1732707ba584b92b2ad
# Done!
#
# Iteration 58/323
# Processing unified_id 627a4d23fbd17a6ab4f0b1ac
# Done!
#
# Iteration 59/323
# Processing unified_id 615689dfbdb047784e567718
# Done!
#
# Iteration 60/323
# Processing unified_id 60aa13a370319f6e2508a4dd
# Done!
#
# Iteration 61/323
# Processing unified_id 656ea3db367b4633e6567f8e
# Done!
#
# Iteration 62/323
# Processing unified_id 65b4886afc772143e83c80e9
# Done!
#
# Iteration 63/323
# Processing unified_id 669a8cc0e19c0a72837acc1a
# Done!
#
# Iteration 64/323
# Processing unified_id 6319c4a774d0e67d8de647b2
# Done!
#
# Iteration 65/323
# Processing unified_id 6250ee684174343a71581727
# Done!
#
# Iteration 66/323
# Processing unified_id 5fb89ea2056f101d12123469
# Done!
#
# Iteration 67/323
# Processing unified_id 5d8d51c03ea9832cb48b7090
# Done!
#
# Iteration 68/323
# Processing unified_id 6618cd4754e2531457fd8cb1
# Done!
#
# Iteration 69/323
# Processing unified_id 62f23800666b0f348c89d1e0
# Done!
#
# Iteration 70/323
# Processing unified_id 6679b0ea56287121469ffe1a
# Done!
#
# Iteration 71/323
# Processing unified_id 66a48512e3e8bb583ced30ad
# Done!
#
# Iteration 72/323
# Processing unified_id 60699652c46ae667f2187b41
# Done!
#
# Iteration 73/323
# Processing unified_id 5f378fe871feeb730dbbc0fb
# Done!
#
# Iteration 74/323
# Processing unified_id 614d60492ade4a314bb87a34
# Done!
#
# Iteration 75/323
# Processing unified_id 636886ea24cb101fb00ce22e
# Done!
#
# Iteration 76/323
# Processing unified_id 66ac33d0aa7fb99d2bb5fd46
# Done!
#
# Iteration 77/323
# Processing unified_id 6522ce55fe6cd0517760607e
# Done!
#
# Iteration 78/323
# Processing unified_id 632c0091412495143e4ba92f
# Done!
#
# Iteration 79/323
# Processing unified_id 62ad8df00105e66c1355d59b
# Done!
#
# Iteration 80/323
# Processing unified_id 642ea283c084ff1c6afcc825
# Done!
#
# Iteration 81/323
# Processing unified_id 633b886973f76b48784c36b9
# Done!
#
# Iteration 82/323
# Processing unified_id 666a79b96b79e13f1241593f
# Done!
#
# Iteration 83/323
# Processing unified_id 5db250835a46f07d1cc9702e
# Done!
#
# Iteration 84/323
# Processing unified_id 62f32a5044136e0eba10c9ba
# Done!
#
# Iteration 85/323
# Processing unified_id 5ff6c6de8839f743f46867a1
# Done!
#
# Iteration 86/323
# Processing unified_id 64619ad72e146b39c0fa0a6a
# Done!
#
# Iteration 87/323
# Processing unified_id 5e97db66e425a74cab3ef06d
# Done!
#
# Iteration 88/323
# Processing unified_id 625f6726cebc4a14876fc773
# Done!
#
# Iteration 89/323
# Processing unified_id 6638a848ad4adb4594498e36
# Done!
#
# Iteration 90/323
# Processing unified_id 6220bbe38b9e665095bc83e4
# Done!
#
# Iteration 91/323
# Processing unified_id 66050958ec3c1117710970b9
# Done!
#
# Iteration 92/323
# Processing unified_id 6141c4fd8bb2076d56699e94
# Done!
#
# Iteration 93/323
# Processing unified_id 65523ab8b3ae2717177e6748
# Done!
#
# Iteration 94/323
# Processing unified_id 5eb5b4682bb96d1170ec346b
# Done!
#
# Iteration 95/323
# Processing unified_id 61d414d961a2397948b61f01
# Done!
#
# Iteration 96/323
# Processing unified_id 5fe0662ae795d82242c6e6d2
# Done!
#
# Iteration 97/323
# Processing unified_id 658ccb16e87569306ac36439
# Done!
#
# Iteration 98/323
# Processing unified_id 64dc7ff401a93e0ff44f86db
# Done!
#
# Iteration 99/323
# Processing unified_id 64e5dee58bab0362967d66b0
# Done!
#
# Iteration 100/323
# Processing unified_id 6223305711885471e9b9c0ea
# Done!
#
# Iteration 101/323
# Processing unified_id 610376042cfa1f0edaec093a
# Done!
#
# Iteration 102/323
# Processing unified_id 6440e6b08ce2c13709535dc3
# Done!
#
# Iteration 103/323
# Processing unified_id 651487070b2bad724578b041
# Done!
#
# Iteration 104/323
# Processing unified_id 64c8c3698966bc32a9d8acde
# Done!
#
# Iteration 105/323
# Processing unified_id 634fb6d5915ae947b9c8185a
# Done!
#
# Iteration 106/323
# Processing unified_id 63ecece74760b21b6d8706b2
# Done!
#
# Iteration 107/323
# Processing unified_id 5f08b56697a04220f5899db6
# Done!
#
# Iteration 108/323
# Processing unified_id 5fc7392b941f963c99485d0f
# Done!
#
# Iteration 109/323
# Processing unified_id 64ca96928a678b4349c0bbbb
# Done!
#
# Iteration 110/323
# Processing unified_id 5df8ef0cb9ab94547c68c177
# Done!
#
# Iteration 111/323
# Processing unified_id 63578bb99d838447746c5887
# Done!
#
# Iteration 112/323
# Processing unified_id 60618dba71bcbf53dc936e86
# Done!
#
# Iteration 113/323
# Processing unified_id 66932d63c787b90e25781175
# Done!
#
# Iteration 114/323
# Processing unified_id 6180f793f5de045560ea9725
# Done!
#
# Iteration 115/323
# Processing unified_id 62e4c2dcaac2e50a05df221a
# Done!
#
# Iteration 116/323
# Processing unified_id 65823471fc3fe50f8e2b14d9
# Done!
#
# Iteration 117/323
# Processing unified_id 66e5061613e8671e47ff09f0
# Done!
#
# Iteration 118/323
# Processing unified_id 66ad0195ed58add63f343fe0
# Done!
#
# Iteration 119/323
# Processing unified_id 66029b32649dfd33fdf3656e
# Done!
#
# Iteration 120/323
# Processing unified_id 64796634d20ff2116f39a01d
# Done!
#
# Iteration 121/323
# Processing unified_id 669116dd9b5b60e5668100d6
# Done!
#
# Iteration 122/323
# Processing unified_id 651504efd211a646d98e8b5a
# Done!
#
# Iteration 123/323
# Processing unified_id 66bd20efa26c8332ff0dfd01
# Done!
#
# Iteration 124/323
# Processing unified_id 623953d01c638a1f05ac590e
# Done!
#
# Iteration 125/323
# Processing unified_id 64ede5412d63ee580d609fb9
# Done!
#
# Iteration 126/323
# Processing unified_id 65fe3703fe76ce3657e52d8d
# Done!
#
# Iteration 127/323
# Processing unified_id 5f09e992d871ea7bfa1d261b
# Done!
#
# Iteration 128/323
# Processing unified_id 644bb0bdc5b9042c3e1e0c3a
# Done!
#
# Iteration 129/323
# Processing unified_id 6620de2d9db92b4ddddd2e2e
# Done!
#
# Iteration 130/323
# Processing unified_id 650e6b4ea9fe9065eceb9a93
# Done!
#
# Iteration 131/323
# Processing unified_id 625e0c55315ff51e5f75b358
# Done!
#
# Iteration 132/323
# Processing unified_id 645f3bf5fbea7c637ecc3636
# Done!
#
# Iteration 133/323
# Processing unified_id 6300aa37d42f2333652844f0
# Done!
#
# Iteration 134/323
# Processing unified_id 6246cef8381d8f5db9ffa82f
# Done!
#
# Iteration 135/323
# Processing unified_id 6083a7885934a82d73701a07
# Done!
#
# Iteration 136/323
# Processing unified_id 617a5c64f6275d2d93560471
# Done!
#
# Iteration 137/323
# Processing unified_id 65c59246ef45c441d8c8886b
# Done!
#
# Iteration 138/323
# Processing unified_id 62b407bb60b07c1a92d7c847
# Done!
#
# Iteration 139/323
# Processing unified_id 6582608575c8970d9fe7b5c2
# Done!
#
# Iteration 140/323
# Processing unified_id 6544318d4b273e6406b5a7fb
# Done!
#
# Iteration 141/323
# Processing unified_id 6684ef8e31fab6f7c8d0584c
# Done!
#
# Iteration 142/323
# Processing unified_id 6201c48dd857b72c1aa096e1
# Done!
#
# Iteration 143/323
# Processing unified_id 639ff55ec7f5ec0d1883c726
# Done!
#
# Iteration 144/323
# Processing unified_id 5f073173eafbc65b5d321cf7
# Done!
#
# Iteration 145/323
# Processing unified_id 62fc3f7f4fb5ee56485ba131
# Done!
#
# Iteration 146/323
# Processing unified_id 64405fc98f8f2413f98524c7
# Done!
#
# Iteration 147/323
# Processing unified_id 5f4dde3ea223317356e00eb9
# Done!
#
# Iteration 148/323
# Processing unified_id 6646b58355b6d7105b6b6553
# Done!
#
# Iteration 149/323
# Processing unified_id 601cde08ef43f0785537be37
# Done!
#
# Iteration 150/323
# Processing unified_id 63a0fbe3ad4adb6b3ba39504
# Done!
#
# Iteration 151/323
# Processing unified_id 66e5176f5b72e1c63d21dd73
# Done!
#
# Iteration 152/323
# Processing unified_id 62764aac9252ed0a82145d18
# Done!
#
# Iteration 153/323
# Processing unified_id 64d262a510a3142a25912bd2
# Done!
#
# Iteration 154/323
# Processing unified_id 5e8d8cbef228a334d5f1beb6
# Done!
#
# Iteration 155/323
# Processing unified_id 6364ea2f68948619f25880c9
# Done!
#
# Iteration 156/323
# Processing unified_id 6030d93db2df116837eb62c1
# Done!
#
# Iteration 157/323
# Processing unified_id 65d56f57dd4de13fbef0768b
# Done!
#
# Iteration 158/323
# Processing unified_id 5e5df9dab9f68d5607e8b614
# Done!
#
# Iteration 159/323
# Processing unified_id 65a52459ad4adb12d6d2debf
# Done!
#
# Iteration 160/323
# Processing unified_id 65601d4dc8169671d78a38ac
# Done!
#
# Iteration 161/323
# Processing unified_id 64afce0fe18dac563e5cabb7
# Done!
#
# Iteration 162/323
# Processing unified_id 602676ea8761c6130584636e
# Done!
#
# Iteration 163/323
# Processing unified_id 63b7af54e1752a247e2814e6
# Done!
#
# Iteration 164/323
# Processing unified_id 66d99ac029fdcad663bbe043
# Done!
#
# Iteration 165/323
# Processing unified_id 6204aa439cc0f863cb03a1f2
# Done!
#
# Iteration 166/323
# Processing unified_id 66306b48a596c73d59dfc888
# Done!
#
# Iteration 167/323
# Processing unified_id 666a7679850648f34fb41214
# Done!
#
# Iteration 168/323
# Processing unified_id 5f65b6981212ce6aaffcd17e
# Done!
#
# Iteration 169/323
# Processing unified_id 666a7679850648f34fb41215
# Done!
#
# Iteration 170/323
# Processing unified_id 5fa8bd39ff1e1b28d892937d
# Done!
#
# Iteration 171/323
# Processing unified_id 6478a99938db1301c3f31631
# Done!
#
# Iteration 172/323
# Processing unified_id 6604e48dbd40f74962b103b2
# Done!
#
# Iteration 173/323
# Processing unified_id 637c5fffe3e3c3040b84f159
# Done!
#
# Iteration 174/323
# Processing unified_id 65f3e2edd2d2f066b363542b
# Done!
#
# Iteration 175/323
# Processing unified_id 5dae7186998dea362fffc8d3
# Done!
#
# Iteration 176/323
# Processing unified_id 6509474dabf35e12a4a89db3
# Done!
#
# Iteration 177/323
# Processing unified_id 5fee6d73b66dd8498d61a935
# Done!
#
# Iteration 178/323
# Processing unified_id 5e9a8aa5dcc8d944ef74b78f
# Done!
#
# Iteration 179/323
# Processing unified_id 66527ed9290c7211874abe73
# Done!
#
# Iteration 180/323
# Processing unified_id 62f638da3811e936454f2b0f
# Done!
#
# Iteration 181/323
# Processing unified_id 61b1f7b96ffae75bc24b4d78
# Done!
#
# Iteration 182/323
# Processing unified_id 5f32f216c00d3a66ea0ced98
# Done!
#
# Iteration 183/323
# Processing unified_id 66f305acbff88b2279074f9c
# Done!
#
# Iteration 184/323
# Processing unified_id 665e5f316638481b8df5791e
# Done!
#
# Iteration 185/323
# Processing unified_id 64999aa4c0eb7a6b20020998
# Done!
#
# Iteration 186/323
# Processing unified_id 622877933c0c6b14b6bc14ba
# Done!
#
# Iteration 187/323
# Processing unified_id 66cc10059e7c3b0db92da359
# Done!
#
# Iteration 188/323
# Processing unified_id 60d4c0248b5a71256cd28a33
# Done!
#
# Iteration 189/323
# Processing unified_id 6447cf45b7accc6e0b137aec
# Done!
#
# Iteration 190/323
# Processing unified_id 5d84173e3ea9835b8b1d4081
# Done!
#
# Iteration 191/323
# Processing unified_id 62d8ad489454482d4d746322
# Done!
#
# Iteration 192/323
# Processing unified_id 6737392e18fbd0e9b90bf750
# Done!
#
# Iteration 193/323
# Processing unified_id 5d37fa8e2cd5aa39b8f13c57
# Done!
#
# Iteration 194/323
# Processing unified_id 626d11b3b672a029fdbf45c0
# Done!
#
# Iteration 195/323
# Processing unified_id 644cd690584b2707b7036be0
# Done!
#
# Iteration 196/323
# Processing unified_id 661e16f2b279ba3aff370af0
# Done!
#
# Iteration 197/323
# Processing unified_id 62a17c64d4cf060ee448fb7f
# Done!
#
# Iteration 198/323
# Processing unified_id 64b81e61b573e433c717cbdd
# Done!
#
# Iteration 199/323
# Processing unified_id 611cd44e76e4121f94f8b29f
# Done!
#
# Iteration 200/323
# Processing unified_id 6394f81f005b161af2e96457
# Done!
#
# Iteration 201/323
# Processing unified_id 6670098947a500c078db041b
# Done!
#
# Iteration 202/323
# Processing unified_id 62f6203c190adc642328708c
# Done!
#
# Iteration 203/323
# Processing unified_id 615ea824e5b3b35c1c9e612c
# Done!
#
# Iteration 204/323
# Processing unified_id 6667ed3863e96ed8611233f0
# Done!
#
# Iteration 205/323
# Processing unified_id 5fb347007ae5ba145dcc4025
# Done!
#
# Iteration 206/323
# Processing unified_id 652da61c5b601405ec02892d
# Done!
#
# Iteration 207/323
# Processing unified_id 62b18ff2991fd92dd394d299
# Done!
#
# Iteration 208/323
# Processing unified_id 65fd06dba6a66211427de1cd
# Done!
#
# Iteration 209/323
# Processing unified_id 5ec7ec8ceafbc61deec3b7d9
# Done!
#
# Iteration 210/323
# Processing unified_id 5fbdadc45ad4e402529d483e
# Done!
#
# Iteration 211/323
# Processing unified_id 636a0b47ba94be6966721f6b
# Done!
#
# Iteration 212/323
# Processing unified_id 5da680bb42fa0c4364eb64c8
# Done!
#
# Iteration 213/323
# Processing unified_id 65826151ead12212042f977e
# Done!
#
# Iteration 214/323
# Processing unified_id 64eeb50c0ad52111f17605cd
# Done!
#
# Iteration 215/323
# Processing unified_id 6711c8a804c993fa9f546b30
# Done!
#
# Iteration 216/323
# Processing unified_id 6360cbf2c705ab01d03c9a25
# Done!
#
# Iteration 217/323
# Processing unified_id 5eab99d1d7688302f041bc39
# Done!
#
# Iteration 218/323
# Processing unified_id 5fca66d4eafbc62d524fd94e
# Done!
#
# Iteration 219/323
# Processing unified_id 66db66c817f69ae1b1559809
# Done!
#
# Iteration 220/323
# Processing unified_id 60f151ef6ffae745341f100f
# Done!
#
# Iteration 221/323
# Processing unified_id 64ccf5f86d841b5ecdc14652
# Done!
#
# Iteration 222/323
# Processing unified_id 60b8e4051107bb390293a4bf
# Done!
#
# Iteration 223/323
# Processing unified_id 669dc9d8e04f78d8e9c99c18
# Done!
#
# Iteration 224/323
# Processing unified_id 62fb1587f448b334742c5f77
# Done!
#
# Iteration 225/323
# Processing unified_id 6669c5864b5ce4f9f2239488
# Done!
#
# Iteration 226/323
# Processing unified_id 5d09e4b03ea9836770c1cf5a
# Done!
#
# Iteration 227/323
# Processing unified_id 66b9c4b0e5dfbf0e5fb63f71
# Done!
#
# Iteration 228/323
# Processing unified_id 6305b7cde8b1a2695d89cb12
# Done!
#
# Iteration 229/323
# Processing unified_id 5eaa3bb083de486c48766499
# Done!
#
# Iteration 230/323
# Processing unified_id 5e055822e98ec10b74e9180d
# Done!
#
# Iteration 231/323
# Processing unified_id 6410802d9aac52470e6eaea4
# Done!
#
# Iteration 232/323
# Processing unified_id 66428480f651ec16ec266c57
# Done!
#
# Iteration 233/323
# Processing unified_id 62d5e0a2beb7957a0b786490
# Done!
#
# Iteration 234/323
# Processing unified_id 635cbafc61f4f92db6c56e0d
# Done!
#
# Iteration 235/323
# Processing unified_id 5e841b5bdf90524c5ea661f3
# Done!
#
# Iteration 236/323
# Processing unified_id 654708bd33c4d6468c54b26d
# Done!
#
# Iteration 237/323
# Processing unified_id 5fd7263b1109cd5975dfd66e
# Done!
#
# Iteration 238/323
# Processing unified_id 5d9fd7ea5ea49e7325c44553
# Done!
#
# Iteration 239/323
# Processing unified_id 5f64385428bb87713255c25e
# Done!
#
# Iteration 240/323
# Processing unified_id 60ed1360b3ae27015927896b
# Done!
#
# Iteration 241/323
# Processing unified_id 6389d4782dc2ea240b06a982
# Done!
#
# Iteration 242/323
# Processing unified_id 66029cfcbd40f76228abacd0
# Done!
#
# Iteration 243/323
# Processing unified_id 610454e3c3e5327151b87343
# Done!
#
# Iteration 244/323
# Processing unified_id 620247596b08607cc41e882a
# Done!
#
# Iteration 245/323
# Processing unified_id 5fd097d591e67b7b27422fb0
# Done!
#
# Iteration 246/323
# Processing unified_id 60b9cea9e459e26eb13c2468
# Done!
#
# Iteration 247/323
# Processing unified_id 62ed7f32b3f4a244d482d6c7
# Done!
#
# Iteration 248/323
# Processing unified_id 63882256bfa0280535094a22
# Done!
#
# Iteration 249/323
# Processing unified_id 65e7dda49e2b732e18b4a7ab
# Done!
#
# Iteration 250/323
# Processing unified_id 641031dea3e9543d579181af
# Done!
#
# Iteration 251/323
# Processing unified_id 64ee2f1ac672c360abe808d4
# Done!
#
# Iteration 252/323
# Processing unified_id 65fa75d7fbea7c523c3ab106
# Done!
#
# Iteration 253/323
# Processing unified_id 5d0355893ea9832c13e157d2
# Done!
#
# Iteration 254/323
# Processing unified_id 6626a822a9cba85698402d6b
# Done!
#
# Iteration 255/323
# Processing unified_id 6649dddb43c10c0f7eb290d1
# Done!
#
# Iteration 256/323
# Processing unified_id 62f4cd09367be93fea19fa8a
# Done!
#
# Iteration 257/323
# Processing unified_id 6695e953ff0c1af70c83442a
# Done!
#
# Iteration 258/323
# Processing unified_id 669df767059af1f0653d9d65
# Done!
#
# Iteration 259/323
# Processing unified_id 60965f24c7466a6fcd573d8a
# Done!
#
# Iteration 260/323
# Processing unified_id 64fb5254c397d213263bbe2f
# Done!
#
# Iteration 261/323
# Processing unified_id 64e08f3297c8184aa66a7886
# Done!
#
# Iteration 262/323
# Processing unified_id 66c82d07410ff0a97e039ed3
# Done!
#
# Iteration 263/323
# Processing unified_id 6204f587308b704dbab9a1b1
# Done!
#
# Iteration 264/323
# Processing unified_id 66fb97dffb320cffcfb1e326
# Done!
#
# Iteration 265/323
# Processing unified_id 646c3514990ee340597b4d76
# Done!
#
# Iteration 266/323
# Processing unified_id 64ce95d0697eff2798068618
# Done!
#
# Iteration 267/323
# Processing unified_id 5fa254dc7a8e43733d2b1c03
# Done!
#
# Iteration 268/323
# Processing unified_id 638997fed1a3715c246bb0a3
# Done!
#
# Iteration 269/323
# Processing unified_id 618221c9bdb0471bbdded487
# Done!
#
# Iteration 270/323
# Processing unified_id 66cf467f4a925979c56cd84c
# Done!
#
# Iteration 271/323
# Processing unified_id 65032b7ab4b2520f8e95fd9e
# Done!
#
# Iteration 272/323
# Processing unified_id 662c1c024891f40cacada25f
# Done!
#
# Iteration 273/323
# Processing unified_id 633f2758594b7b63d09751fc
# Done!
#
# Iteration 274/323
# Processing unified_id 61c97a1e467c426c65b2b7b9
# Done!
#
# Iteration 275/323
# Processing unified_id 624221e4aaeb833d98f8b149
# Done!
#
# Iteration 276/323
# Processing unified_id 66877456eff239036696e3eb
# Done!
#
# Iteration 277/323
# Processing unified_id 63afc769278f9e137947186c
# Done!
#
# Iteration 278/323
# Processing unified_id 60f64dbd404f3717c8adacaa
# Done!
#
# Iteration 279/323
# Processing unified_id 6349abc10e277b274584b54b
# Done!
#
# Iteration 280/323
# Processing unified_id 61711804d325802f015b38f3
# Done!
#
# Iteration 281/323
# Processing unified_id 6470444f124b5028b45d9743
# Done!
#
# Iteration 282/323
# Processing unified_id 62f680b10e277b1e1595a7de
# Done!
#
# Iteration 283/323
# Processing unified_id 64c0b3188c85a0522c08a46e
# Done!
#
# Iteration 284/323
# Processing unified_id 664e520a8430ad7b672dd2c2
# Done!
#
# Iteration 285/323
# Processing unified_id 65aa7377294313129e731d32
# Done!
#
# Iteration 286/323
# Processing unified_id 66de8fb77625711859619afa
# Done!
#
# Iteration 287/323
# Processing unified_id 5f2beb6eec1eca1d614abc89
# Done!
#
# Iteration 288/323
# Processing unified_id 61c4303963339964b7852420
# Done!
#
# Iteration 289/323
# Processing unified_id 6656475dac116c46d932c207
# Done!
#
# Iteration 290/323
# Processing unified_id 63bdd6b32d63ee0ecbfc3636
# Done!
#
# Iteration 291/323
# Processing unified_id 666bcd67f399ed2af1464ce2
# Done!
#
# Iteration 292/323
# Processing unified_id 632fe9375b974b3f5f59bfb0
# Done!
#
# Iteration 293/323
# Processing unified_id 6320fb30ad4adb161582e209
# Done!
#
# Iteration 294/323
# Processing unified_id 6518e90143ee8718b7e23fec
# Done!
#
# Iteration 295/323
# Processing unified_id 6115323b7a2fb545e009cfcb
# Done!
#
# Iteration 296/323
# Processing unified_id 64d5f2f9229d840ac6025910
# Done!
#
# Iteration 297/323
# Processing unified_id 6480c3e55b6ccd7d9c1330d6
# Done!
#
# Iteration 298/323
# Processing unified_id 64c7aef06caf79033f98f43a
# Done!
#
# Iteration 299/323
# Processing unified_id 6100f08b1bfb8b36e50a7f66
# Done!
#
# Iteration 300/323
# Processing unified_id 666a7683850648f34fb41216
# Done!
#
# Iteration 301/323
# Processing unified_id 663ffa0564df7d1ea5a06b10
# Done!
#
# Iteration 302/323
# Processing unified_id 5f403686eb829d6d59785db9
# Done!
#
# Iteration 303/323
# Processing unified_id 652f6e39a020f13af057ccec
# Done!
#
# Iteration 304/323
# Processing unified_id 600a69ef830d143079c670d3
# Done!
#
# Iteration 305/323
# Processing unified_id 65e5da34d29202576bdea65a
# Done!
#
# Iteration 306/323
# Processing unified_id 6549cba84251ad48400e50bf
# Done!
#
# Iteration 307/323
# Processing unified_id 6178da8bfb94934d110250cb
# Done!
#
# Iteration 308/323
# Processing unified_id 5e5b1ea5be9c636a6d9d9bad
# Done!
#
# Iteration 309/323
# Processing unified_id 6635c621f748cdf578efb571
# Done!
#
# Iteration 310/323
# Processing unified_id 60f2091f2ccf555d2bc38ba6
# Done!
#
# Iteration 311/323
# Processing unified_id 633679f395b5d1083638c77a
# Done!
#
# Iteration 312/323
# Processing unified_id 60940a23c4ef1c33e2222f99
# Done!
#
# Iteration 313/323
# Processing unified_id 65dc8f9ab5757d2c8dcfafaf
# Done!
#
# Iteration 314/323
# Processing unified_id 664b764d8430adac59525fa6
# Done!
#
# Iteration 315/323
# Processing unified_id 6650dbe7b3ae2736333a1e51
# Done!
#
# Iteration 316/323
# Processing unified_id 6481a456de2518330c01dd93
# Done!
#
# Iteration 317/323
# Processing unified_id 5e6f1195a6800a19ab8866ac
# Done!
#
# Iteration 318/323
# Processing unified_id 5dccab2ade63003f9d41834b
# Done!
#
# Iteration 319/323
# Processing unified_id 601608ff005b1610e85f2ec4
# Done!
#
# Iteration 320/323
# Processing unified_id 665e8f9d8abb1241b09700fc
# Done!
#
# Iteration 321/323
# Processing unified_id 5f3ca1373901921b75c92afe
# Done!
#
# Iteration 322/323
# Processing unified_id 62872474cc9ba5317df026c7
# Done!
#
# Iteration 323/323
# Processing unified_id 65d5913fc22a81162efd50ca
# Done!

# %%
# Calculate the summed daily download of each game

daily_sum_download_df_for_games_released_from_2020_to_2024_from_vn_publisher = []

total_count = len(download_df_for_games_released_from_2020_to_2024_from_vn_publisher)
count = 1

for game in download_df_for_games_released_from_2020_to_2024_from_vn_publisher:
    
    print("Iteration {}/{}".format(count, total_count))
    print("Processing unified_id {}".format(game['unified_app_id']))
    
    daily_sum_download_df_for_games_released_from_2020_to_2024_from_vn_publisher.append(
        {
            'unified_app_id': game['unified_app_id'],
            'daily_download_series': get_daily_download(
                game['performance_df']
            )
        }
    )
    
    print("Done!\n")
    count += 1
# Out:
# Iteration 1/323
# Processing unified_id 60afcafcd691a12d95e60ba0
# Done!
#
# Iteration 2/323
# Processing unified_id 62625a20dff18334c32afb79
# Done!
#
# Iteration 3/323
# Processing unified_id 5ee9e41a60b07c7b7c27170d
# Done!
#
# Iteration 4/323
# Processing unified_id 646939b209db972560a6a24a
# Done!
#
# Iteration 5/323
# Processing unified_id 604355ffec1eca4ecdcb5f91
# Done!
#
# Iteration 6/323
# Processing unified_id 64a91142f08b1411f1c62ffc
# Done!
#
# Iteration 7/323
# Processing unified_id 5fac66403e5ce4073a088ced
# Done!
#
# Iteration 8/323
# Processing unified_id 6539d116d2e5a9284e6a76e2
# Done!
#
# Iteration 9/323
# Processing unified_id 6659e428226b831d7faf84cc
# Done!
#
# Iteration 10/323
# Processing unified_id 63c4d18654b41c6945ddda18
# Done!
#
# Iteration 11/323
# Processing unified_id 609d636a95b5d1366e3c9b7e
# Done!
#
# Iteration 12/323
# Processing unified_id 5c6e53e450795405f48b88cf
# Done!
#
# Iteration 13/323
# Processing unified_id 66a9f962bbe8c80fefe4935d
# Done!
#
# Iteration 14/323
# Processing unified_id 6545db024227cd177700a064
# Done!
#
# Iteration 15/323
# Processing unified_id 62678e2024a36301dc7044ea
# Done!
#
# Iteration 16/323
# Processing unified_id 673880ef1f7c4000ba1ef924
# Done!
#
# Iteration 17/323
# Processing unified_id 5f3b76921392d052ebf0d0ca
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# Done!
#
# Iteration 18/323
# Processing unified_id 66277ad02535561238b4b68d
# Done!
#
# Iteration 19/323
# Processing unified_id 66ae27a7bb7ff7d8b74d55a0
# Done!
#
# Iteration 20/323
# Processing unified_id 65f11fa81107bb6df0b1f78f
# Done!
#
# Iteration 21/323
# Processing unified_id 6434f36d74f648189c0a1f86
# Done!
#
# Iteration 22/323
# Processing unified_id 657926706277693b751c0cb4
# Done!
#
# Iteration 23/323
# Processing unified_id 5fbb699458aaf04004a26d90
# Done!
#
# Iteration 24/323
# Processing unified_id 5f8fc387a8c16d131d6ade64
# Done!
#
# Iteration 25/323
# Processing unified_id 66c50b19fd00e3defecc832e
# Done!
#
# Iteration 26/323
# Processing unified_id 5eddcd2be7e6b81e5ef0f068
# Done!
#
# Iteration 27/323
# Processing unified_id 64399222b1bc2032d36f13d2
# Done!
#
# Iteration 28/323
# Processing unified_id 637b0dc7863b79516a758a69
# Done!
#
# Iteration 29/323
# Processing unified_id 6478a8ca4800d7095fb186d3
# Done!
#
# Iteration 30/323
# Processing unified_id 641ce1cf3169d82cab237c53
# Done!
#
# Iteration 31/323
# Processing unified_id 5d91778c29053f773fdc2346
# Done!
#
# Iteration 32/323
# Processing unified_id 60d04ac6b3ae270609fe554b
# Done!
#
# Iteration 33/323
# Processing unified_id 5e6729514d03db3aeb2d65f8
# Done!
#
# Iteration 34/323
# Processing unified_id 658f9f16623739111651e8a0
# Done!
#
# Iteration 35/323
# Processing unified_id 5da67c09a546ab1edeb6c50d
# Done!
#
# Iteration 36/323
# Processing unified_id 63be498c22d978122038c4a5
# Done!
#
# Iteration 37/323
# Processing unified_id 6640945b0a025f1a7a130e27
# Done!
#
# Iteration 38/323
# Processing unified_id 61c193558b65541c675aa8c0
# Done!
#
# Iteration 39/323
# Processing unified_id 65765f06cb54b62bf7af6a85
# Done!
#
# Iteration 40/323
# Processing unified_id 6214c8b68c588b3c9acd19c7
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# Done!
#
# Iteration 41/323
# Processing unified_id 5f493530b3f4a2190b676f1d
# Done!
#
# Iteration 42/323
# Processing unified_id 65cc5eab69eefb4fad4c1376
# Done!
#
# Iteration 43/323
# Processing unified_id 60645f1554f2382aab21e32d
# Done!
#
# Iteration 44/323
# Processing unified_id 6129532d2d9d223923db3b2d
# Done!
#
# Iteration 45/323
# Processing unified_id 5f852df6a08c4e194dbd707e
# Done!
#
# Iteration 46/323
# Processing unified_id 64bde4c83097596d8e327dae
# Done!
#
# Iteration 47/323
# Processing unified_id 6547962a994f9650c753bb29
# Done!
#
# Iteration 48/323
# Processing unified_id 6603aa389cc7a7189ba7b66d
# Done!
#
# Iteration 49/323
# Processing unified_id 60a0312911c542326e602fd3
# Done!
#
# Iteration 50/323
# Processing unified_id 659778cfa33983212809c751
# Done!
#
# Iteration 51/323
# Processing unified_id 5d560fc327474347a137e0f3
# Done!
#
# Iteration 52/323
# Processing unified_id 5e0ae513b9ab9472634970d8
# Done!
#
# Iteration 53/323
# Processing unified_id 6495c627cbae9739e17bae4c
# Done!
#
# Iteration 54/323
# Processing unified_id 5d2d6caa3ea983183934bc12
# Done!
#
# Iteration 55/323
# Processing unified_id 6439381ea0f47f0e94b71f6f
# Done!
#
# Iteration 56/323
# Processing unified_id 6531fe3cf934b541dfacf3fa
# Done!
#
# Iteration 57/323
# Processing unified_id 5e8fd1732707ba584b92b2ad
# Done!
#
# Iteration 58/323
# Processing unified_id 627a4d23fbd17a6ab4f0b1ac
# Done!
#
# Iteration 59/323
# Processing unified_id 615689dfbdb047784e567718
# Done!
#
# Iteration 60/323
# Processing unified_id 60aa13a370319f6e2508a4dd
# Done!
#
# Iteration 61/323
# Processing unified_id 656ea3db367b4633e6567f8e
# Done!
#
# Iteration 62/323
# Processing unified_id 65b4886afc772143e83c80e9
# Done!
#
# Iteration 63/323
# Processing unified_id 669a8cc0e19c0a72837acc1a
# Done!
#
# Iteration 64/323
# Processing unified_id 6319c4a774d0e67d8de647b2
# Done!
#
# Iteration 65/323
# Processing unified_id 6250ee684174343a71581727
# Done!
#
# Iteration 66/323
# Processing unified_id 5fb89ea2056f101d12123469
# Done!
#
# Iteration 67/323
# Processing unified_id 5d8d51c03ea9832cb48b7090
# Done!
#
# Iteration 68/323
# Processing unified_id 6618cd4754e2531457fd8cb1
# Done!
#
# Iteration 69/323
# Processing unified_id 62f23800666b0f348c89d1e0
# Done!
#
# Iteration 70/323
# Processing unified_id 6679b0ea56287121469ffe1a
# Done!
#
# Iteration 71/323
# Processing unified_id 66a48512e3e8bb583ced30ad
# Done!
#
# Iteration 72/323
# Processing unified_id 60699652c46ae667f2187b41
# Done!
#
# Iteration 73/323
# Processing unified_id 5f378fe871feeb730dbbc0fb
# Done!
#
# Iteration 74/323
# Processing unified_id 614d60492ade4a314bb87a34
# Done!
#
# Iteration 75/323
# Processing unified_id 636886ea24cb101fb00ce22e
# Done!
#
# Iteration 76/323
# Processing unified_id 66ac33d0aa7fb99d2bb5fd46
# Done!
#
# Iteration 77/323
# Processing unified_id 6522ce55fe6cd0517760607e
# Done!
#
# Iteration 78/323
# Processing unified_id 632c0091412495143e4ba92f
# Done!
#
# Iteration 79/323
# Processing unified_id 62ad8df00105e66c1355d59b
# Done!
#
# Iteration 80/323
# Processing unified_id 642ea283c084ff1c6afcc825
# Done!
#
# Iteration 81/323
# Processing unified_id 633b886973f76b48784c36b9
# Done!
#
# Iteration 82/323
# Processing unified_id 666a79b96b79e13f1241593f
# Done!
#
# Iteration 83/323
# Processing unified_id 5db250835a46f07d1cc9702e
# Done!
#
# Iteration 84/323
# Processing unified_id 62f32a5044136e0eba10c9ba
# Done!
#
# Iteration 85/323
# Processing unified_id 5ff6c6de8839f743f46867a1
# Done!
#
# Iteration 86/323
# Processing unified_id 64619ad72e146b39c0fa0a6a
# Done!
#
# Iteration 87/323
# Processing unified_id 5e97db66e425a74cab3ef06d
# Done!
#
# Iteration 88/323
# Processing unified_id 625f6726cebc4a14876fc773
# Done!
#
# Iteration 89/323
# Processing unified_id 6638a848ad4adb4594498e36
# Done!
#
# Iteration 90/323
# Processing unified_id 6220bbe38b9e665095bc83e4
# Done!
#
# Iteration 91/323
# Processing unified_id 66050958ec3c1117710970b9
# Done!
#
# Iteration 92/323
# Processing unified_id 6141c4fd8bb2076d56699e94
# Done!
#
# Iteration 93/323
# Processing unified_id 65523ab8b3ae2717177e6748
# Done!
#
# Iteration 94/323
# Processing unified_id 5eb5b4682bb96d1170ec346b
# Done!
#
# Iteration 95/323
# Processing unified_id 61d414d961a2397948b61f01
# Done!
#
# Iteration 96/323
# Processing unified_id 5fe0662ae795d82242c6e6d2
# Done!
#
# Iteration 97/323
# Processing unified_id 658ccb16e87569306ac36439
# Done!
#
# Iteration 98/323
# Processing unified_id 64dc7ff401a93e0ff44f86db
# Done!
#
# Iteration 99/323
# Processing unified_id 64e5dee58bab0362967d66b0
# Done!
#
# Iteration 100/323
# Processing unified_id 6223305711885471e9b9c0ea
# Done!
#
# Iteration 101/323
# Processing unified_id 610376042cfa1f0edaec093a
# Done!
#
# Iteration 102/323
# Processing unified_id 6440e6b08ce2c13709535dc3
# Done!
#
# Iteration 103/323
# Processing unified_id 651487070b2bad724578b041
# Done!
#
# Iteration 104/323
# Processing unified_id 64c8c3698966bc32a9d8acde
# Done!
#
# Iteration 105/323
# Processing unified_id 634fb6d5915ae947b9c8185a
# Done!
#
# Iteration 106/323
# Processing unified_id 63ecece74760b21b6d8706b2
# Done!
#
# Iteration 107/323
# Processing unified_id 5f08b56697a04220f5899db6
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# ...
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# Done!
#
# Iteration 293/323
# Processing unified_id 6320fb30ad4adb161582e209
# Done!
#
# Iteration 294/323
# Processing unified_id 6518e90143ee8718b7e23fec
# Done!
#
# Iteration 295/323
# Processing unified_id 6115323b7a2fb545e009cfcb
# Done!
#
# Iteration 296/323
# Processing unified_id 64d5f2f9229d840ac6025910
# Done!
#
# Iteration 297/323
# Processing unified_id 6480c3e55b6ccd7d9c1330d6
# Done!
#
# Iteration 298/323
# Processing unified_id 64c7aef06caf79033f98f43a
# Done!
#
# Iteration 299/323
# Processing unified_id 6100f08b1bfb8b36e50a7f66
# Done!
#
# Iteration 300/323
# Processing unified_id 666a7683850648f34fb41216
# Done!
#
# Iteration 301/323
# Processing unified_id 663ffa0564df7d1ea5a06b10
# Done!
#
# Iteration 302/323
# Processing unified_id 5f403686eb829d6d59785db9
# Done!
#
# Iteration 303/323
# Processing unified_id 652f6e39a020f13af057ccec
# Done!
#
# Iteration 304/323
# Processing unified_id 600a69ef830d143079c670d3
# Done!
#
# Iteration 305/323
# Processing unified_id 65e5da34d29202576bdea65a
# Done!
#
# Iteration 306/323
# Processing unified_id 6549cba84251ad48400e50bf
# Done!
#
# Iteration 307/323
# Processing unified_id 6178da8bfb94934d110250cb
# Done!
#
# Iteration 308/323
# Processing unified_id 5e5b1ea5be9c636a6d9d9bad
# Done!
#
# Iteration 309/323
# Processing unified_id 6635c621f748cdf578efb571
# Done!
#
# Iteration 310/323
# Processing unified_id 60f2091f2ccf555d2bc38ba6
# Done!
#
# Iteration 311/323
# Processing unified_id 633679f395b5d1083638c77a
# Done!
#
# Iteration 312/323
# Processing unified_id 60940a23c4ef1c33e2222f99
# Done!
#
# Iteration 313/323
# Processing unified_id 65dc8f9ab5757d2c8dcfafaf
# Done!
#
# Iteration 314/323
# Processing unified_id 664b764d8430adac59525fa6
# Done!
#
# Iteration 315/323
# Processing unified_id 6650dbe7b3ae2736333a1e51
# Done!
#
# Iteration 316/323
# Processing unified_id 6481a456de2518330c01dd93
# Done!
#
# Iteration 317/323
# Processing unified_id 5e6f1195a6800a19ab8866ac
# Done!
#
# Iteration 318/323
# Processing unified_id 5dccab2ade63003f9d41834b
# Done!
#
# Iteration 319/323
# Processing unified_id 601608ff005b1610e85f2ec4
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# Done!
#
# Iteration 320/323
# Processing unified_id 665e8f9d8abb1241b09700fc
# Done!
#
# Iteration 321/323
# Processing unified_id 5f3ca1373901921b75c92afe
# Done!
#
# Iteration 322/323
# Processing unified_id 62872474cc9ba5317df026c7
# Done!
#
# Iteration 323/323
# Processing unified_id 65d5913fc22a81162efd50ca
# Done!
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_9500\2923371211.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)

# %%
# Transform to DataFrame: unified id as index & columns being the date

df_daily_sum_download_of_games_released_from_2020_to_2024_from_vn_publisher = transform_game_download_list_of_dict_to_dataframe(daily_sum_download_df_for_games_released_from_2020_to_2024_from_vn_publisher)

# %%
df_daily_sum_download_of_games_released_from_2020_to_2024_from_vn_publisher.to_csv('data/output/df_daily_sum_download_of_games_released_from_2020_to_2024_from_vn_publisher.csv')

# %%
# Calculate D30, D60, D90, D365 download for each game above

daily_sum_download_df_for_games_released_from_2020_to_2024_from_vn_publisher_aggregated_info = copy.deepcopy(
    daily_sum_download_df_for_games_released_from_2020_to_2024_from_vn_publisher
)

for row in daily_sum_download_df_for_games_released_from_2020_to_2024_from_vn_publisher_aggregated_info:

    row['release_date'] = get_release_date_from_daily_game_download_table(
        daily_sum_download_df_for_games_released_from_2020_to_2024_from_vn_publisher,
        row['unified_app_id']
    )

    row['cleaned_publisher_name'] = list(
        filter(
            lambda x: x['unified_app_id'] == row['unified_app_id'],
            cleaned_publisher_names_per_unified_id_released_from_2020_to_2024_from_vn_publisher
        )
    )[0]['cleaned_publisher_names'][0]
    
    row['download_d30'] = calculate_first_n_day_download(
        daily_sum_download_df_for_games_released_from_2020_to_2024_from_vn_publisher,
        row['unified_app_id'],
        30
    )

    row['download_d60'] = calculate_first_n_day_download(
        daily_sum_download_df_for_games_released_from_2020_to_2024_from_vn_publisher,
        row['unified_app_id'],
        60
    )

    row['download_d90'] = calculate_first_n_day_download(
        daily_sum_download_df_for_games_released_from_2020_to_2024_from_vn_publisher,
        row['unified_app_id'],
        90
    )
    
    row['download_d365'] = calculate_first_n_day_download(
        daily_sum_download_df_for_games_released_from_2020_to_2024_from_vn_publisher,
        row['unified_app_id'],
        365
    )
    row['total download'] = row['daily_download_series'].sum()

# Keys to include in the DataFrame
selected_keys = [
    'unified_app_id', 
    'release_date',
    'cleaned_publisher_name',
    'download_d30',
    'download_d60',
    'download_d90',
    'download_d365',
    'total download'
]

# Filter the dictionaries to include only the selected keys
daily_sum_download_df_for_games_released_from_2020_to_2024_from_vn_publisher_aggregated_info = [
    {key: d[key] for key in selected_keys if key in d} for d in daily_sum_download_df_for_games_released_from_2020_to_2024_from_vn_publisher_aggregated_info
]
# Out:
# Processing unified app id: 60afcafcd691a12d95e60ba0
# Processing for unified app id 60afcafcd691a12d95e60ba0
# Processing for unified app id 60afcafcd691a12d95e60ba0
# Processing for unified app id 60afcafcd691a12d95e60ba0
# Processing for unified app id 60afcafcd691a12d95e60ba0
# Processing unified app id: 62625a20dff18334c32afb79
# Processing for unified app id 62625a20dff18334c32afb79
# Processing for unified app id 62625a20dff18334c32afb79
# Processing for unified app id 62625a20dff18334c32afb79
# Processing for unified app id 62625a20dff18334c32afb79
# Processing unified app id: 5ee9e41a60b07c7b7c27170d
# Processing for unified app id 5ee9e41a60b07c7b7c27170d
# Processing for unified app id 5ee9e41a60b07c7b7c27170d
# Processing for unified app id 5ee9e41a60b07c7b7c27170d
# Processing for unified app id 5ee9e41a60b07c7b7c27170d
# Processing unified app id: 646939b209db972560a6a24a
# Processing for unified app id 646939b209db972560a6a24a
# Processing for unified app id 646939b209db972560a6a24a
# Processing for unified app id 646939b209db972560a6a24a
# Processing for unified app id 646939b209db972560a6a24a
# Processing unified app id: 604355ffec1eca4ecdcb5f91
# Processing for unified app id 604355ffec1eca4ecdcb5f91
# Processing for unified app id 604355ffec1eca4ecdcb5f91
# Processing for unified app id 604355ffec1eca4ecdcb5f91
# Processing for unified app id 604355ffec1eca4ecdcb5f91
# Processing unified app id: 64a91142f08b1411f1c62ffc
# Processing for unified app id 64a91142f08b1411f1c62ffc
# Processing for unified app id 64a91142f08b1411f1c62ffc
# Processing for unified app id 64a91142f08b1411f1c62ffc
# Processing for unified app id 64a91142f08b1411f1c62ffc
# Processing unified app id: 5fac66403e5ce4073a088ced
# Processing for unified app id 5fac66403e5ce4073a088ced
# Processing for unified app id 5fac66403e5ce4073a088ced
# Processing for unified app id 5fac66403e5ce4073a088ced
# Processing for unified app id 5fac66403e5ce4073a088ced
# Processing unified app id: 6539d116d2e5a9284e6a76e2
# Processing for unified app id 6539d116d2e5a9284e6a76e2
# Processing for unified app id 6539d116d2e5a9284e6a76e2
# Processing for unified app id 6539d116d2e5a9284e6a76e2
# Processing for unified app id 61d414d961a2397948b61f01
# Game 61d414d961a2397948b61f01 download series is empty.
# Processing for unified app id 61d414d961a2397948b61f01
# Game 61d414d961a2397948b61f01 download series is empty.
# Processing for unified app id 61d414d961a2397948b61f01
# Game 61d414d961a2397948b61f01 download series is empty.
# Processing unified app id: 5fe0662ae795d82242c6e6d2
# Processing for unified app id 5fe0662ae795d82242c6e6d2
# Processing for unified app id 5fe0662ae795d82242c6e6d2
# Processing for unified app id 5fe0662ae795d82242c6e6d2
# Processing for unified app id 5fe0662ae795d82242c6e6d2
# Processing unified app id: 658ccb16e87569306ac36439
# Processing for unified app id 658ccb16e87569306ac36439
# Processing for unified app id 658ccb16e87569306ac36439
# Processing for unified app id 658ccb16e87569306ac36439
# Processing for unified app id 658ccb16e87569306ac36439
# Processing unified app id: 64dc7ff401a93e0ff44f86db
# Processing for unified app id 64dc7ff401a93e0ff44f86db
# Processing for unified app id 64dc7ff401a93e0ff44f86db
# Processing for unified app id 64dc7ff401a93e0ff44f86db
# Processing for unified app id 64dc7ff401a93e0ff44f86db
# Processing unified app id: 64e5dee58bab0362967d66b0
# Processing for unified app id 64e5dee58bab0362967d66b0
# Processing for unified app id 64e5dee58bab0362967d66b0
# Processing for unified app id 64e5dee58bab0362967d66b0
# Processing for unified app id 64e5dee58bab0362967d66b0
# Processing unified app id: 6223305711885471e9b9c0ea
# Processing for unified app id 6223305711885471e9b9c0ea
# Processing for unified app id 6223305711885471e9b9c0ea
# Processing for unified app id 6223305711885471e9b9c0ea
# Processing for unified app id 6223305711885471e9b9c0ea
# Processing unified app id: 610376042cfa1f0edaec093a
# Processing for unified app id 610376042cfa1f0edaec093a
# Processing for unified app id 610376042cfa1f0edaec093a
# Processing for unified app id 610376042cfa1f0edaec093a
# Processing for unified app id 610376042cfa1f0edaec093a
# Processing unified app id: 6440e6b08ce2c13709535dc3
# Processing for unified app id 6440e6b08ce2c13709535dc3
# Processing for unified app id 6440e6b08ce2c13709535dc3
# Processing for unified app id 6440e6b08ce2c13709535dc3
# Processing for unified app id 6440e6b08ce2c13709535dc3
# Processing unified app id: 651487070b2bad724578b041
# Processing for unified app id 651487070b2bad724578b041
# Processing for unified app id 651487070b2bad724578b041
# Processing for unified app id 651487070b2bad724578b041
# Processing for unified app id 651487070b2bad724578b041
# Processing unified app id: 64c8c3698966bc32a9d8acde
# Processing for unified app id 64c8c3698966bc32a9d8acde
# Processing for unified app id 64c8c3698966bc32a9d8acde
# Processing for unified app id 64c8c3698966bc32a9d8acde
# Processing for unified app id 64c8c3698966bc32a9d8acde
# Processing unified app id: 634fb6d5915ae947b9c8185a
# Processing for unified app id 634fb6d5915ae947b9c8185a
# Processing for unified app id 634fb6d5915ae947b9c8185a
# Processing for unified app id 634fb6d5915ae947b9c8185a
# Processing for unified app id 634fb6d5915ae947b9c8185a
# Processing unified app id: 63ecece74760b21b6d8706b2
# Processing for unified app id 63ecece74760b21b6d8706b2
# Processing for unified app id 63ecece74760b21b6d8706b2
# Processing for unified app id 63ecece74760b21b6d8706b2
# Processing for unified app id 63ecece74760b21b6d8706b2
# Processing unified app id: 5f08b56697a04220f5899db6
# Processing for unified app id 5f08b56697a04220f5899db6
# Processing for unified app id 5f08b56697a04220f5899db6
# Processing for unified app id 5f08b56697a04220f5899db6
# Processing for unified app id 5f08b56697a04220f5899db6
# Processing unified app id: 5fc7392b941f963c99485d0f
# Processing for unified app id 5fc7392b941f963c99485d0f
# Processing for unified app id 5fc7392b941f963c99485d0f
# Processing for unified app id 5fc7392b941f963c99485d0f
# Processing for unified app id 5fc7392b941f963c99485d0f
# Processing unified app id: 64ca96928a678b4349c0bbbb
# Processing for unified app id 64ca96928a678b4349c0bbbb
# Processing for unified app id 64ca96928a678b4349c0bbbb
# Processing for unified app id 64ca96928a678b4349c0bbbb
# Processing for unified app id 64ca96928a678b4349c0bbbb
# Processing unified app id: 5df8ef0cb9ab94547c68c177
# Processing for unified app id 5df8ef0cb9ab94547c68c177
# Processing for unified app id 5df8ef0cb9ab94547c68c177
# Processing for unified app id 5df8ef0cb9ab94547c68c177
# Processing for unified app id 5df8ef0cb9ab94547c68c177
# Processing unified app id: 63578bb99d838447746c5887
# Processing for unified app id 63578bb99d838447746c5887
# Processing for unified app id 63578bb99d838447746c5887
# Processing for unified app id 63578bb99d838447746c5887
# Processing for unified app id 63578bb99d838447746c5887
# Processing unified app id: 60618dba71bcbf53dc936e86
# Processing for unified app id 60618dba71bcbf53dc936e86
# Processing for unified app id 60618dba71bcbf53dc936e86
# Processing for unified app id 60618dba71bcbf53dc936e86
# Processing for unified app id 60618dba71bcbf53dc936e86
# Processing unified app id: 66932d63c787b90e25781175
# Processing for unified app id 66932d63c787b90e25781175
# Processing for unified app id 66932d63c787b90e25781175
# Processing for unified app id 66932d63c787b90e25781175
# Processing for unified app id 66932d63c787b90e25781175
# Game 66932d63c787b90e25781175 does not have a date range spanning 365 days.
# Processing unified app id: 6180f793f5de045560ea9725
# Processing for unified app id 6180f793f5de045560ea9725
# Game 6180f793f5de045560ea9725 download series is empty.
# Processing for unified app id 6180f793f5de045560ea9725
# Game 6180f793f5de045560ea9725 download series is empty.
# Processing for unified app id 6180f793f5de045560ea9725
# Game 6180f793f5de045560ea9725 download series is empty.
# Processing for unified app id 6180f793f5de045560ea9725
# Game 6180f793f5de045560ea9725 download series is empty.
# Processing unified app id: 62e4c2dcaac2e50a05df221a
# Processing for unified app id 62e4c2dcaac2e50a05df221a
# Processing for unified app id 62e4c2dcaac2e50a05df221a
# Processing for unified app id 62e4c2dcaac2e50a05df221a
# Processing for unified app id 62e4c2dcaac2e50a05df221a
# Processing unified app id: 65823471fc3fe50f8e2b14d9
# Processing for unified app id 65823471fc3fe50f8e2b14d9
# Processing for unified app id 65823471fc3fe50f8e2b14d9
# Processing for unified app id 65823471fc3fe50f8e2b14d9
# Processing for unified app id 65823471fc3fe50f8e2b14d9
# Game 65823471fc3fe50f8e2b14d9 does not have a date range spanning 365 days.
# Processing unified app id: 66e5061613e8671e47ff09f0
# Processing for unified app id 62b407bb60b07c1a92d7c847
# Processing for unified app id 62b407bb60b07c1a92d7c847
# Processing for unified app id 62b407bb60b07c1a92d7c847
# Processing for unified app id 62b407bb60b07c1a92d7c847
# Processing unified app id: 6582608575c8970d9fe7b5c2
# Processing for unified app id 6582608575c8970d9fe7b5c2
# Processing for unified app id 6582608575c8970d9fe7b5c2
# Processing for unified app id 6582608575c8970d9fe7b5c2
# Processing for unified app id 6582608575c8970d9fe7b5c2
# Processing unified app id: 6544318d4b273e6406b5a7fb
# Processing for unified app id 6544318d4b273e6406b5a7fb
# Processing for unified app id 6544318d4b273e6406b5a7fb
# Processing for unified app id 6544318d4b273e6406b5a7fb
# Processing for unified app id 6544318d4b273e6406b5a7fb
# Processing unified app id: 6684ef8e31fab6f7c8d0584c
# Processing for unified app id 6684ef8e31fab6f7c8d0584c
# Processing for unified app id 6684ef8e31fab6f7c8d0584c
# Processing for unified app id 6684ef8e31fab6f7c8d0584c
# Processing for unified app id 6684ef8e31fab6f7c8d0584c
# Game 6684ef8e31fab6f7c8d0584c does not have a date range spanning 365 days.
# Processing unified app id: 6201c48dd857b72c1aa096e1
# Processing for unified app id 6201c48dd857b72c1aa096e1
# Processing for unified app id 6201c48dd857b72c1aa096e1
# Processing for unified app id 6201c48dd857b72c1aa096e1
# Processing for unified app id 6201c48dd857b72c1aa096e1
# Processing unified app id: 639ff55ec7f5ec0d1883c726
# Processing for unified app id 639ff55ec7f5ec0d1883c726
# Processing for unified app id 639ff55ec7f5ec0d1883c726
# Processing for unified app id 639ff55ec7f5ec0d1883c726
# Processing for unified app id 639ff55ec7f5ec0d1883c726
# Processing unified app id: 5f073173eafbc65b5d321cf7
# Processing for unified app id 5f073173eafbc65b5d321cf7
# Processing for unified app id 5f073173eafbc65b5d321cf7
# Processing for unified app id 5f073173eafbc65b5d321cf7
# Processing for unified app id 5f073173eafbc65b5d321cf7
# Processing unified app id: 62fc3f7f4fb5ee56485ba131
# Processing for unified app id 62fc3f7f4fb5ee56485ba131
# Processing for unified app id 62fc3f7f4fb5ee56485ba131
# Processing for unified app id 62fc3f7f4fb5ee56485ba131
# Processing for unified app id 62fc3f7f4fb5ee56485ba131
# Processing unified app id: 64405fc98f8f2413f98524c7
# Processing for unified app id 64405fc98f8f2413f98524c7
# Processing for unified app id 64405fc98f8f2413f98524c7
# Processing for unified app id 64405fc98f8f2413f98524c7
# Processing for unified app id 64405fc98f8f2413f98524c7
# Processing unified app id: 5f4dde3ea223317356e00eb9
# Processing for unified app id 5f4dde3ea223317356e00eb9
# Processing for unified app id 5f4dde3ea223317356e00eb9
# Processing for unified app id 5f4dde3ea223317356e00eb9
# Processing for unified app id 5f4dde3ea223317356e00eb9
# Processing unified app id: 6646b58355b6d7105b6b6553
# Processing for unified app id 6646b58355b6d7105b6b6553
# Processing for unified app id 6646b58355b6d7105b6b6553
# Processing for unified app id 6646b58355b6d7105b6b6553
# Processing for unified app id 6646b58355b6d7105b6b6553
# Processing for unified app id 66877456eff239036696e3eb
# Processing for unified app id 66877456eff239036696e3eb
# Processing for unified app id 66877456eff239036696e3eb
# Processing for unified app id 66877456eff239036696e3eb
# Game 66877456eff239036696e3eb does not have a date range spanning 365 days.
# Processing unified app id: 63afc769278f9e137947186c
# Processing for unified app id 63afc769278f9e137947186c
# Processing for unified app id 63afc769278f9e137947186c
# Processing for unified app id 63afc769278f9e137947186c
# Processing for unified app id 63afc769278f9e137947186c
# Processing unified app id: 60f64dbd404f3717c8adacaa
# Processing for unified app id 60f64dbd404f3717c8adacaa
# Processing for unified app id 60f64dbd404f3717c8adacaa
# Processing for unified app id 60f64dbd404f3717c8adacaa
# Processing for unified app id 60f64dbd404f3717c8adacaa
# Processing unified app id: 6349abc10e277b274584b54b
# Processing for unified app id 6349abc10e277b274584b54b
# Processing for unified app id 6349abc10e277b274584b54b
# Processing for unified app id 6349abc10e277b274584b54b
# Processing for unified app id 6349abc10e277b274584b54b
# Processing unified app id: 61711804d325802f015b38f3
# Processing for unified app id 61711804d325802f015b38f3
# Processing for unified app id 61711804d325802f015b38f3
# Processing for unified app id 61711804d325802f015b38f3
# Processing for unified app id 61711804d325802f015b38f3
# Processing unified app id: 6470444f124b5028b45d9743
# Processing for unified app id 6470444f124b5028b45d9743
# Processing for unified app id 6470444f124b5028b45d9743
# Processing for unified app id 6470444f124b5028b45d9743
# Processing for unified app id 6470444f124b5028b45d9743
# Game 6470444f124b5028b45d9743 does not have a date range spanning 365 days.
# Processing unified app id: 62f680b10e277b1e1595a7de
# Processing for unified app id 62f680b10e277b1e1595a7de
# Processing for unified app id 62f680b10e277b1e1595a7de
# Processing for unified app id 62f680b10e277b1e1595a7de
# Processing for unified app id 62f680b10e277b1e1595a7de
# Processing unified app id: 64c0b3188c85a0522c08a46e
# Processing for unified app id 64c0b3188c85a0522c08a46e
# Processing for unified app id 64c0b3188c85a0522c08a46e
# Processing for unified app id 64c0b3188c85a0522c08a46e
# Processing for unified app id 64c0b3188c85a0522c08a46e
# Processing unified app id: 664e520a8430ad7b672dd2c2
# Processing for unified app id 664e520a8430ad7b672dd2c2
# Processing for unified app id 664e520a8430ad7b672dd2c2
# Processing for unified app id 664e520a8430ad7b672dd2c2
# Processing for unified app id 664e520a8430ad7b672dd2c2
# Game 664e520a8430ad7b672dd2c2 does not have a date range spanning 365 days.
# Processing unified app id: 65aa7377294313129e731d32
# Processing for unified app id 65aa7377294313129e731d32
# Processing for unified app id 65aa7377294313129e731d32
# Processing for unified app id 65aa7377294313129e731d32
# Processing for unified app id 65aa7377294313129e731d32
# Processing unified app id: 66de8fb77625711859619afa
# Processing for unified app id 66de8fb77625711859619afa
# Processing for unified app id 66de8fb77625711859619afa
# Processing for unified app id 66de8fb77625711859619afa
# Processing for unified app id 66de8fb77625711859619afa
# Game 66de8fb77625711859619afa does not have a date range spanning 365 days.
# Processing unified app id: 5f2beb6eec1eca1d614abc89
# Processing for unified app id 5f2beb6eec1eca1d614abc89
# Processing for unified app id 5f2beb6eec1eca1d614abc89
# Processing for unified app id 64c7aef06caf79033f98f43a
# Processing for unified app id 64c7aef06caf79033f98f43a
# Processing unified app id: 6100f08b1bfb8b36e50a7f66
# Processing for unified app id 6100f08b1bfb8b36e50a7f66
# Processing for unified app id 6100f08b1bfb8b36e50a7f66
# Processing for unified app id 6100f08b1bfb8b36e50a7f66
# Processing for unified app id 6100f08b1bfb8b36e50a7f66
# Processing unified app id: 666a7683850648f34fb41216
# Processing for unified app id 666a7683850648f34fb41216
# Processing for unified app id 666a7683850648f34fb41216
# Processing for unified app id 666a7683850648f34fb41216
# Processing for unified app id 666a7683850648f34fb41216
# Game 666a7683850648f34fb41216 does not have a date range spanning 365 days.
# Processing unified app id: 663ffa0564df7d1ea5a06b10
# Processing for unified app id 663ffa0564df7d1ea5a06b10
# Processing for unified app id 663ffa0564df7d1ea5a06b10
# Processing for unified app id 663ffa0564df7d1ea5a06b10
# Processing for unified app id 663ffa0564df7d1ea5a06b10
# Game 663ffa0564df7d1ea5a06b10 does not have a date range spanning 365 days.
# Processing unified app id: 5f403686eb829d6d59785db9
# Processing for unified app id 5f403686eb829d6d59785db9
# Processing for unified app id 5f403686eb829d6d59785db9
# Processing for unified app id 5f403686eb829d6d59785db9
# Processing for unified app id 5f403686eb829d6d59785db9
# Processing unified app id: 652f6e39a020f13af057ccec
# Processing for unified app id 652f6e39a020f13af057ccec
# Processing for unified app id 652f6e39a020f13af057ccec
# Processing for unified app id 652f6e39a020f13af057ccec
# Processing for unified app id 652f6e39a020f13af057ccec
# Processing unified app id: 600a69ef830d143079c670d3
# Processing for unified app id 600a69ef830d143079c670d3
# Processing for unified app id 600a69ef830d143079c670d3
# Processing for unified app id 600a69ef830d143079c670d3
# Processing for unified app id 600a69ef830d143079c670d3
# Processing unified app id: 65e5da34d29202576bdea65a
# Processing for unified app id 65e5da34d29202576bdea65a
# Processing for unified app id 65e5da34d29202576bdea65a
# Processing for unified app id 65e5da34d29202576bdea65a
# Processing for unified app id 65e5da34d29202576bdea65a
# Game 65e5da34d29202576bdea65a does not have a date range spanning 365 days.
# Processing unified app id: 6549cba84251ad48400e50bf
# Processing for unified app id 6549cba84251ad48400e50bf
# Processing for unified app id 6549cba84251ad48400e50bf
# Processing for unified app id 6549cba84251ad48400e50bf
# Processing for unified app id 6549cba84251ad48400e50bf
# Processing unified app id: 6178da8bfb94934d110250cb
# Processing for unified app id 6178da8bfb94934d110250cb
# Processing for unified app id 6178da8bfb94934d110250cb
# Processing for unified app id 6178da8bfb94934d110250cb
# Processing for unified app id 6178da8bfb94934d110250cb
# Processing unified app id: 5e5b1ea5be9c636a6d9d9bad
# Processing for unified app id 5e5b1ea5be9c636a6d9d9bad
# Processing for unified app id 5e5b1ea5be9c636a6d9d9bad
# Processing for unified app id 5e5b1ea5be9c636a6d9d9bad
# Processing for unified app id 5e5b1ea5be9c636a6d9d9bad
# Processing unified app id: 6635c621f748cdf578efb571
# Processing for unified app id 6635c621f748cdf578efb571
# Processing for unified app id 6635c621f748cdf578efb571
# Processing for unified app id 6635c621f748cdf578efb571
# Processing for unified app id 6635c621f748cdf578efb571
# Game 6635c621f748cdf578efb571 does not have a date range spanning 365 days.
# Processing unified app id: 60f2091f2ccf555d2bc38ba6
# Processing for unified app id 60f2091f2ccf555d2bc38ba6
# Processing for unified app id 60f2091f2ccf555d2bc38ba6
# Processing for unified app id 60f2091f2ccf555d2bc38ba6
# Processing for unified app id 60f2091f2ccf555d2bc38ba6
# Processing unified app id: 633679f395b5d1083638c77a
# Processing for unified app id 633679f395b5d1083638c77a
# Processing for unified app id 633679f395b5d1083638c77a
# Processing for unified app id 633679f395b5d1083638c77a
# Processing for unified app id 633679f395b5d1083638c77a
# Processing unified app id: 60940a23c4ef1c33e2222f99
# Processing for unified app id 60940a23c4ef1c33e2222f99
# Processing for unified app id 60940a23c4ef1c33e2222f99
# Processing for unified app id 60940a23c4ef1c33e2222f99
# Processing for unified app id 60940a23c4ef1c33e2222f99
# Processing unified app id: 65dc8f9ab5757d2c8dcfafaf
# Processing for unified app id 65dc8f9ab5757d2c8dcfafaf
# Processing for unified app id 65dc8f9ab5757d2c8dcfafaf
# Processing for unified app id 65dc8f9ab5757d2c8dcfafaf
# Processing for unified app id 65dc8f9ab5757d2c8dcfafaf
# Game 65dc8f9ab5757d2c8dcfafaf does not have a date range spanning 365 days.
# Processing unified app id: 664b764d8430adac59525fa6
# Processing for unified app id 664b764d8430adac59525fa6
# Processing for unified app id 664b764d8430adac59525fa6
# Processing for unified app id 664b764d8430adac59525fa6
# Processing for unified app id 664b764d8430adac59525fa6
# Game 664b764d8430adac59525fa6 does not have a date range spanning 365 days.
# Processing unified app id: 6650dbe7b3ae2736333a1e51
# Processing for unified app id 6650dbe7b3ae2736333a1e51
# Processing for unified app id 6650dbe7b3ae2736333a1e51
# Processing for unified app id 6650dbe7b3ae2736333a1e51
# Processing for unified app id 6650dbe7b3ae2736333a1e51
# Game 6650dbe7b3ae2736333a1e51 does not have a date range spanning 365 days.
# Processing unified app id: 6481a456de2518330c01dd93
# Processing for unified app id 6481a456de2518330c01dd93
# Processing for unified app id 6481a456de2518330c01dd93
# Processing for unified app id 6481a456de2518330c01dd93
# Processing for unified app id 6481a456de2518330c01dd93
# Processing unified app id: 5e6f1195a6800a19ab8866ac
# Processing for unified app id 5e6f1195a6800a19ab8866ac
# Processing for unified app id 5e6f1195a6800a19ab8866ac
# Processing for unified app id 5e6f1195a6800a19ab8866ac
# Processing for unified app id 5e6f1195a6800a19ab8866ac
# Processing unified app id: 5dccab2ade63003f9d41834b
# Processing for unified app id 5dccab2ade63003f9d41834b
# Processing for unified app id 5dccab2ade63003f9d41834b
# Processing for unified app id 5dccab2ade63003f9d41834b
# Processing for unified app id 5dccab2ade63003f9d41834b
# Processing unified app id: 601608ff005b1610e85f2ec4
# Processing for unified app id 601608ff005b1610e85f2ec4
# Processing for unified app id 601608ff005b1610e85f2ec4
# Processing for unified app id 601608ff005b1610e85f2ec4
# Processing for unified app id 601608ff005b1610e85f2ec4
# Processing unified app id: 665e8f9d8abb1241b09700fc
# Processing for unified app id 665e8f9d8abb1241b09700fc
# Processing for unified app id 665e8f9d8abb1241b09700fc
# Processing for unified app id 665e8f9d8abb1241b09700fc
# Processing for unified app id 665e8f9d8abb1241b09700fc
# Game 665e8f9d8abb1241b09700fc does not have a date range spanning 365 days.
# Processing unified app id: 5f3ca1373901921b75c92afe
# Processing for unified app id 5f3ca1373901921b75c92afe
# Processing for unified app id 5f3ca1373901921b75c92afe
# Processing for unified app id 5f3ca1373901921b75c92afe
# Processing for unified app id 5f3ca1373901921b75c92afe
# Processing unified app id: 62872474cc9ba5317df026c7
# Processing for unified app id 62872474cc9ba5317df026c7
# Processing for unified app id 62872474cc9ba5317df026c7
# Processing for unified app id 62872474cc9ba5317df026c7
# Processing for unified app id 62872474cc9ba5317df026c7
# Processing unified app id: 65d5913fc22a81162efd50ca
# Processing for unified app id 65d5913fc22a81162efd50ca
# Processing for unified app id 65d5913fc22a81162efd50ca
# Processing for unified app id 65d5913fc22a81162efd50ca
# Processing for unified app id 65d5913fc22a81162efd50ca
# Game 65d5913fc22a81162efd50ca does not have a date range spanning 365 days.

# %%
# Turn into dataframe
df_download_aggregated_info_for_games_released_from_2020_to_2024_from_vn = pd.DataFrame(
    daily_sum_download_df_for_games_released_from_2020_to_2024_from_vn_publisher_aggregated_info
)

# %%
# Export to csv
df_download_aggregated_info_for_games_released_from_2020_to_2024_from_vn.to_csv('data/output/df_download_aggregated_info_for_games_released_from_2020_to_2024_from_vn.csv', index=False)

# %% [markdown]
# # Get Specific Games' Performance Time Series

# %%
# Unified app id

list_unified_ids = ['5ac2bdddcfc03208313848db']

# %%
df_all_app_info_list = pd.read_csv('data/output/df_all_app_info_list.csv')
# Out:
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_6104\467353629.py:1: DtypeWarning: Columns (0,4,25,26,27,34,35,36,39,40,46,47,48) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_all_app_info_list = pd.read_csv('data/output/df_all_app_info_list.csv')

# %%
df_app_info_of_the_games = df_all_app_info_list[
    df_all_app_info_list['unified_app_id'].isin(list_unified_ids)
].copy()

# %%
# Fix app cleaned_publisher and multiplier value

# %%
df_app_info_of_the_games['cleaned_publisher_name'] = np.nan

# %%
df_app_info_of_the_games['revenue_multiplier'] = 1

# %%
vn_app_ids = ['1574489575', 'com.rok.gp.vn']

df_app_info_of_the_games.loc[
    df_app_info_of_the_games['app_id'].isin(vn_app_ids), 'cleaned_publisher_name'
] = 'Gamota'

df_app_info_of_the_games.loc[
    df_app_info_of_the_games['app_id'].isin(vn_app_ids), 'revenue_multiplier'
] = 3
# Out:
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_6104\1184117040.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Gamota' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   df_app_info_of_the_games.loc[

# %%
# SPECIAL CASE: Generate 2 unified app ids & Modify the unified app ids of the performance pieces

# %%
list_unified_ids_modified = ['5ac2bdddcfc03208313848db_vn', '5ac2bdddcfc03208313848db_global']

# %%
mapping_appid_to_modified_uid = {
    '1354260888':'5ac2bdddcfc03208313848db_global',
    '1436964519':'5ac2bdddcfc03208313848db_global',
    '1474599374':'5ac2bdddcfc03208313848db_global',
    '1483025097':'5ac2bdddcfc03208313848db_global',
    '1519945981':'5ac2bdddcfc03208313848db_global',
    '1574489575':'5ac2bdddcfc03208313848db_vn',
    'com.lilithgame.roc.gp':'5ac2bdddcfc03208313848db_global',
    'com.lilithgame.roc.gp.tw':'5ac2bdddcfc03208313848db_global',
    'com.lilithgames.rok.gp.jp':'5ac2bdddcfc03208313848db_global',
    'com.lilithgames.rok.gpkr':'5ac2bdddcfc03208313848db_global',
    'com.rok.gp.vn':'5ac2bdddcfc03208313848db_vn'
}

# %%
df_app_info_of_the_games['unified_app_id'] = df_app_info_of_the_games['app_id'].map(mapping_appid_to_modified_uid)

# %%
# Get the ios and android app ids of these apps

list_app_ids_ios = list(
    map(lambda x: str(x),
        list(
                df_app_info_of_the_games[
                    df_app_info_of_the_games['os'] == 'ios'
                ]['app_id']
            )
        )
    )

list_app_ids_android = list(
    map(lambda x: str(x),
        list(
                df_app_info_of_the_games[
                    df_app_info_of_the_games['os'] == 'android'
                ]['app_id']
            )
        )
    )

# %%
# Query the app performance data (performance piece - each in a period, for an app)

# %%
## query for ios apps

app_performance_data_ios = get_apps_performance(
    api_key, 
    base_url, 
    os = 'ios', 
    app_ids = list_app_ids_ios, 
    country_code = 'VN', 
    granularity = 'daily', 
    max_periods = 10000, 
    start_date = '2018-01-01', 
    end_date = '2024-11-27'
)
# Out:
# Date ranges: [('2018-01-01', '2024-11-27')]
# Requesting Data for Range: 2018-01-01 to 2024-11-27
# making call for chunk number 1
# Data retrieved for 2018-01-01 to 2024-11-27

# %%
## query for android apps

app_performance_data_android = get_apps_performance(
    api_key, 
    base_url, 
    os = 'android', 
    app_ids = list_app_ids_android, 
    country_code = 'VN', 
    granularity = 'daily', 
    max_periods = 10000, 
    start_date = '2018-01-01', 
    end_date = '2024-11-27'
)
# Out:
# Date ranges: [('2018-01-01', '2024-11-27')]
# Requesting Data for Range: 2018-01-01 to 2024-11-27
# making call for chunk number 1
# Data retrieved for 2018-01-01 to 2024-11-27

# %%
## join the 2 lists of performance data together

app_performance_data_of_the_games = app_performance_data_ios + app_performance_data_android

# %%
# Order the performance pieces into app performance data - iOS

app_performance_data_grouped_by_app_ios = []

total_count = len(list_app_ids_ios)
count = 1

for app_id in list_app_ids_ios:
    
    print("Iteration {}/{}".format(count, total_count))
    print("Processing app_id {}".format(app_id))
    
    app_performance_data_grouped_by_app_ios.append(
        {
            'app_id': app_id,
            'os': 'ios',
            'unified_app_id': list(
                df_app_info_of_the_games[
                    df_app_info_of_the_games['app_id'].astype(str) == str(app_id)
                ]['unified_app_id']
            )[0],
            'app_performance': sorted(
                list(
                    filter(
                        lambda x: str(x['aid']) == app_id,
                        app_performance_data_of_the_games
                    )
                ),
                key = lambda x: x['d']
            )
        }
    )
    
    print("Done!")
    
    count += 1
# Out:
# Iteration 1/6
# Processing app_id 1354260888
# Done!
# Iteration 2/6
# Processing app_id 1436964519
# Done!
# Iteration 3/6
# Processing app_id 1474599374
# Done!
# Iteration 4/6
# Processing app_id 1483025097
# Done!
# Iteration 5/6
# Processing app_id 1519945981
# Done!
# Iteration 6/6
# Processing app_id 1574489575
# Done!

# %%
# Order the performance pieces into app performance data - Android

app_performance_data_grouped_by_app_android = []

total_count = len(list_app_ids_android)
count = 1

for app_id in list_app_ids_android:
    
    print("Iteration {}/{}".format(count, total_count))
    print("Processing app_id {}".format(app_id))
    
    app_performance_data_grouped_by_app_android.append(
        {
            'app_id': app_id,
            'os': 'android',
            'unified_app_id': list(
                df_app_info_of_the_games[
                    df_app_info_of_the_games['app_id'].astype(str) == str(app_id)
                ]['unified_app_id']
            )[0],
            'app_performance': sorted(
                list(
                    filter(
                        lambda x: str(x['aid']) == app_id,
                        app_performance_data_of_the_games
                    )
                ),
                key = lambda x: x['d']
            )
        }
    )
    
    print("Done!")
    
    count += 1
# Out:
# Iteration 1/5
# Processing app_id com.lilithgame.roc.gp
# Done!
# Iteration 2/5
# Processing app_id com.lilithgame.roc.gp.tw
# Done!
# Iteration 3/5
# Processing app_id com.lilithgames.rok.gp.jp
# Done!
# Iteration 4/5
# Processing app_id com.lilithgames.rok.gpkr
# Done!
# Iteration 5/5
# Processing app_id com.rok.gp.vn
# Done!

# %%
## Combine the 2 lists

app_performance_data_grouped_by_app = app_performance_data_grouped_by_app_ios + app_performance_data_grouped_by_app_android

# %%
# Order the app performance data into game performance data

game_performance_data = []

total_count = len(list_unified_ids_modified)
count = 1

for unified_app_id in list_unified_ids_modified:

    print("Iteration {}/{}".format(count, total_count))
    print("Processing unified_id {}".format(unified_app_id))
    
    game_performance_data.append(
        {
            'unified_app_id': unified_app_id,
            'performance_streams': list(
                filter(
                    lambda x: x['unified_app_id'] == unified_app_id,
                    app_performance_data_grouped_by_app
                )
            )
        }
    )
    
    print("Done!")
    count += 1
# Out:
# Iteration 1/2
# Processing unified_id 5ac2bdddcfc03208313848db_vn
# Done!
# Iteration 2/2
# Processing unified_id 5ac2bdddcfc03208313848db_global
# Done!

# %%
# Create the download dataframe for each game

download_df_for_the_games = []

total_count = len(game_performance_data)
count = 1

for game in game_performance_data:

    print("Iteration {}/{}".format(count, total_count))
    print("Processing unified_id {}".format(game['unified_app_id']))
    
    download_df_for_the_games.append(
        {
            'unified_app_id': game['unified_app_id'],
            'performance_df': generate_download_streams_df(game['performance_streams'])
        }
    )

    print("Done!\n")
    count += 1
# Out:
# Iteration 1/2
# Processing unified_id 5ac2bdddcfc03208313848db_vn
# Done!
#
# Iteration 2/2
# Processing unified_id 5ac2bdddcfc03208313848db_global
# Done!

# %%
# Calculate the summed daily download of each game

daily_sum_download_df_for_the_games = []

total_count = len(download_df_for_the_games)
count = 1

for game in download_df_for_the_games:
    
    print("Iteration {}/{}".format(count, total_count))
    print("Processing unified_id {}".format(game['unified_app_id']))
    
    daily_sum_download_df_for_the_games.append(
        {
            'unified_app_id': game['unified_app_id'],
            'daily_download_series': get_daily_download(
                game['performance_df']
            )
        }
    )
    
    print("Done!\n")
    count += 1
# Out:
# Iteration 1/2
# Processing unified_id 5ac2bdddcfc03208313848db_vn
# Done!
#
# Iteration 2/2
# Processing unified_id 5ac2bdddcfc03208313848db_global
# Done!
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_6104\3699131905.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)
# C:\Users\VEE0634\AppData\Local\Temp\ipykernel_6104\3699131905.py:4: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   download_df_sum = download_df.fillna(0).sum(axis=0)

# %%
# Transform to DataFrame: unified id as index & columns being the date

df_daily_sum_download_of_the_games = transform_game_download_list_of_dict_to_dataframe(daily_sum_download_df_for_the_games)

# %%
df_daily_sum_download_of_the_games.to_csv('data/output/df_daily_sum_download_of_rise_of_kingdoms.csv')

# %%
# Calculate D30, D60, D90, D365 download for each game above

daily_sum_download_df_for_the_games_aggregated_info = copy.deepcopy(
    daily_sum_download_df_for_the_games
)

for row in daily_sum_download_df_for_the_games_aggregated_info:

    row['release_date'] = get_release_date_from_daily_game_download_table(
        daily_sum_download_df_for_the_games,
        row['unified_app_id']
    )

    row['cleaned_publisher_name'] = ''
    
    row['download_d30'] = calculate_first_n_day_download(
        daily_sum_download_df_for_the_games,
        row['unified_app_id'],
        30
    )

    row['download_d60'] = calculate_first_n_day_download(
        daily_sum_download_df_for_the_games,
        row['unified_app_id'],
        60
    )

    row['download_d90'] = calculate_first_n_day_download(
        daily_sum_download_df_for_the_games,
        row['unified_app_id'],
        90
    )
    
    row['download_d365'] = calculate_first_n_day_download(
        daily_sum_download_df_for_the_games,
        row['unified_app_id'],
        365
    )
    row['total download'] = row['daily_download_series'].sum()

# Keys to include in the DataFrame
selected_keys = [
    'unified_app_id', 
    'release_date',
    'cleaned_publisher_name',
    'download_d30',
    'download_d60',
    'download_d90',
    'download_d365',
    'total download'
]

# Filter the dictionaries to include only the selected keys
daily_sum_download_df_for_the_games_aggregated_info = [
    {key: d[key] for key in selected_keys if key in d} for d in daily_sum_download_df_for_the_games_aggregated_info
]
# Out:
# Processing unified app id: 5ac2bdddcfc03208313848db_vn
# Processing for unified app id 5ac2bdddcfc03208313848db_vn
# Processing for unified app id 5ac2bdddcfc03208313848db_vn
# Processing for unified app id 5ac2bdddcfc03208313848db_vn
# Processing for unified app id 5ac2bdddcfc03208313848db_vn
# Processing unified app id: 5ac2bdddcfc03208313848db_global
# Processing for unified app id 5ac2bdddcfc03208313848db_global
# Processing for unified app id 5ac2bdddcfc03208313848db_global
# Processing for unified app id 5ac2bdddcfc03208313848db_global
# Processing for unified app id 5ac2bdddcfc03208313848db_global

# %%
# Turn into dataframe
df_download_aggregated_info_for_the_games = pd.DataFrame(
    daily_sum_download_df_for_the_games_aggregated_info
)

# %%
# Export to csv
df_download_aggregated_info_for_the_games.to_csv('data/output/df_download_aggregated_info_for_rise_of_kingdoms.csv', index=False)

# %% [markdown]
# # Check Games' Monthly Download Patterns

# %%
df_daily_sum_download_of_games_released_from_2020_to_2024_from_vn_publisher = pd.read_csv('data/output/df_daily_sum_download_of_games_released_from_2020_to_2024_from_vn_publisher.csv', index_col=0)

# %%
df_monthly_sum_download_of_games_released_from_2020_to_2024_from_vn_publisher_adjusted = aggregate_to_monthly_with_projection(df_daily_sum_download_of_games_released_from_2020_to_2024_from_vn_publisher)

# %%
df_monthly_sum_download_of_games_released_from_2020_to_2024_from_vn_publisher_adjusted
# Out:
#                          2020-01 2020-02 2020-03 2020-04 2020-05 2020-06  \
# 60afcafcd691a12d95e60ba0     NaN     NaN     NaN     NaN     NaN     NaN
# 62625a20dff18334c32afb79     NaN     NaN     NaN     NaN     NaN     NaN
# 5ee9e41a60b07c7b7c27170d     NaN     NaN     NaN     NaN     NaN  368865
# 646939b209db972560a6a24a     NaN     NaN     NaN     NaN     NaN     NaN
# 604355ffec1eca4ecdcb5f91     NaN     NaN     NaN     NaN     NaN     NaN
# ...                          ...     ...     ...     ...     ...     ...
# 601608ff005b1610e85f2ec4     NaN     NaN     NaN     NaN     NaN     NaN
# 665e8f9d8abb1241b09700fc     NaN     NaN     NaN     NaN     NaN     NaN
# 5f3ca1373901921b75c92afe     NaN     NaN     NaN     NaN     NaN     NaN
# 62872474cc9ba5317df026c7     NaN     NaN     NaN     NaN     NaN     NaN
# 65d5913fc22a81162efd50ca     NaN     NaN     NaN     NaN     NaN     NaN
#
#                          2020-07 2020-08 2020-09 2020-10  ... 2024-02 2024-03  \
# 60afcafcd691a12d95e60ba0     NaN     NaN     NaN     NaN  ...     NaN     NaN
# 62625a20dff18334c32afb79     NaN     NaN     NaN     NaN  ...    3266     259
# 5ee9e41a60b07c7b7c27170d  150139  100902   92803   54696  ...  103195   48586
# 646939b209db972560a6a24a     NaN     NaN     NaN     NaN  ...       0       0
# 604355ffec1eca4ecdcb5f91     NaN     NaN     NaN     NaN  ...     NaN     NaN
# ...                          ...     ...     ...     ...  ...     ...     ...
# 601608ff005b1610e85f2ec4     NaN     NaN     NaN     NaN  ...       1       1
# 665e8f9d8abb1241b09700fc     NaN     NaN     NaN     NaN  ...     NaN     NaN
# 5f3ca1373901921b75c92afe     NaN     NaN 1048587  839991  ...     398     374
# 62872474cc9ba5317df026c7     NaN     NaN     NaN     NaN  ...    1298     957
# 65d5913fc22a81162efd50ca     NaN     NaN     NaN     NaN  ...     NaN   91215
#
#                          2024-04 2024-05 2024-06 2024-07 2024-08 2024-09  \
# 60afcafcd691a12d95e60ba0     NaN     NaN     NaN     NaN     NaN     NaN
# 62625a20dff18334c32afb79    6853    9780     312     NaN     NaN     NaN
# 5ee9e41a60b07c7b7c27170d    1542   68872    1369    1276   84854  366335
# 646939b209db972560a6a24a       0       0       0       0       0       0
# 604355ffec1eca4ecdcb5f91     NaN     NaN     NaN     NaN     NaN     NaN
# ...                          ...     ...     ...     ...     ...     ...
# 601608ff005b1610e85f2ec4     323     980     507    1152     702     838
# 665e8f9d8abb1241b09700fc     NaN     NaN  416551   69207    8115    1378
# 5f3ca1373901921b75c92afe     422     462      46      24      86       0
# 62872474cc9ba5317df026c7    1071    1179     896    1052     843     804
# 65d5913fc22a81162efd50ca   19385     211       0     978       0       0
#
#                          2024-10 2024-11
# 60afcafcd691a12d95e60ba0     NaN     NaN
# 62625a20dff18334c32afb79     NaN     NaN
# 5ee9e41a60b07c7b7c27170d  453748  183197
# 646939b209db972560a6a24a       0       2
# 604355ffec1eca4ecdcb5f91     NaN     NaN
# ...                          ...     ...
# 601608ff005b1610e85f2ec4     278      73
# 665e8f9d8abb1241b09700fc       0       0
# 5f3ca1373901921b75c92afe     292      47
# 62872474cc9ba5317df026c7    1375     679
# 65d5913fc22a81162efd50ca       0       0
#
# [323 rows x 59 columns]

# %%
df_monthly_sum_download_of_games_released_from_2020_to_2024_from_vn_publisher_adjusted.to_csv('data/output/df_monthly_sum_download_of_games_released_from_2020_to_2024_from_vn_publisher_adjusted.csv', index=False)

# %%
# Step 1: Check General Trends (Mean & Median)

# %%
df_aligned = align_time_series(df_monthly_sum_download_of_games_released_from_2020_to_2024_from_vn_publisher_adjusted)

# %%
df_aligned.to_csv('data/output/df_monthly_sum_download_of_games_released_from_2020_to_2024_from_vn_publisher_adjusted_aligned.csv', index=False)

# %%
# Compute mean and median across aligned months
mean_trend = df_aligned.mean(skipna=True)
median_trend = df_aligned.median(skipna=True)

# Plot aligned mean and median trends
plt.figure(figsize=(12, 6))
plt.plot(mean_trend.index, mean_trend, label="Mean Aligned Downloads", linestyle='-', marker='o')
plt.plot(median_trend.index, median_trend, label="Median Aligned Downloads", linestyle='--', marker='o')
plt.xticks(range(1, len(mean_trend) + 1))  # Show relative months
plt.xlabel("Months Since First Download")
plt.ylabel("Downloads")
plt.title("Mean & Median Aligned Monthly Download Trends")
plt.legend()
plt.grid()
plt.show()

# %%
# Step 2: Percentile Ranges

# %%
# Compute percentiles
p25 = df_aligned.quantile(0.25, axis=0, skipna=True)
p50 = df_aligned.quantile(0.50, axis=0, skipna=True)
p75 = df_aligned.quantile(0.75, axis=0, skipna=True)

# Plot percentiles
plt.figure(figsize=(12, 6))
plt.plot(p25.index, p25, label="25th Percentile", linestyle=':', marker='o')
plt.plot(p50.index, p50, label="50th Percentile (Median)", linestyle='--', marker='o')
plt.plot(p75.index, p75, label="75th Percentile", linestyle='-', marker='o')

plt.xticks(rotation=45)
plt.title("Percentile Trends in Monthly Downloads")
plt.xlabel("Month")
plt.ylabel("Downloads")
plt.legend()
plt.grid()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[119], line 2
#       1 # Compute percentiles
# ----> 2 p25 = df_aligned.quantile(0.25, axis=0, skipna=True)
#       3 p50 = df_aligned.quantile(0.50, axis=0, skipna=True)
#       4 p75 = df_aligned.quantile(0.75, axis=0, skipna=True)
#
# TypeError: DataFrame.quantile() got an unexpected keyword argument 'skipna'

# %%
# def aggregate_to_monthly(df):
#     # Convert columns to datetime format
#     df.columns = pd.to_datetime(df.columns)

#     # Transpose, resample by month-end ('ME'), sum, and transpose back
#     df_monthly = df.T.resample('ME').sum().T

#     # Rename columns to 'YYYY-MM'
#     df_monthly.columns = df_monthly.columns.strftime('%Y-%m')

#     return df_monthly

def aggregate_to_monthly(df):
    # Convert columns to datetime format
    df.columns = pd.to_datetime(df.columns)

    # Transpose, resample by month-end ('ME'), sum, and transpose back
    df_monthly = df.T.resample('ME').sum().T

    # Identify months where all daily data is NaN for each game
    nan_mask = df.T.resample('ME').apply(lambda x: x.isna().all()).T

    # Apply the NaN mask to the aggregated data (preserve NaNs where needed)
    df_monthly[nan_mask] = float('nan')

    # Rename columns to 'YYYY-MM'
    df_monthly.columns = df_monthly.columns.strftime('%Y-%m')

    return df_monthly

# %%
def aggregate_to_monthly_with_projection(df):
    # Convert column names to datetime format
    df.columns = pd.to_datetime(df.columns)

    # Adjust the end date to the last day of its month to ensure inclusion
    start_date = df.columns.min()
    end_date = df.columns.max().to_period('M').to_timestamp('M')  # Adjusts to last day of month

    # Collect all unique months across all games
    all_months = pd.date_range(start=start_date, end=end_date, freq='ME')

    # Initialize DataFrame for monthly aggregated data with consistent columns
    df_monthly = pd.DataFrame(index=df.index, columns=all_months)

    for game_id, game_data in df.iterrows():
        game_data = game_data.dropna()  # Remove NaNs to find valid data range
        
        if game_data.empty:
            continue  # Skip if no data available

        # Resample by month, summing the available daily data
        monthly_data = game_data.resample('ME').sum()

        # Count number of available days in each month
        days_with_data = game_data.resample('ME').count()

        # Get total days in each month (based on the last valid date)
        days_in_month = game_data.index.to_series().resample('ME').max().dt.days_in_month

        # Project only where **some** data exists (avoid filling full NaN months)
        projected_monthly_data = monthly_data.copy()
        valid_mask = days_with_data > 0  # Months with at least some data
        projected_monthly_data[valid_mask] = (monthly_data[valid_mask] * days_in_month[valid_mask] / days_with_data[valid_mask])

        # Align projected data with the full list of months
        projected_monthly_data = projected_monthly_data.reindex(all_months)

        # Store in result DataFrame
        df_monthly.loc[game_id] = projected_monthly_data

    # Rename columns to 'YYYY-MM'
    df_monthly.columns = df_monthly.columns.strftime('%Y-%m')

    return df_monthly

# %%
def align_time_series(df):
    """Aligns game time series based on first non-NaN month while keeping game ID as index."""
    aligned_data = {}

    for game_id, row in df.iterrows():
        # Drop leading NaNs to detect first available month
        non_nan_data = row.dropna()
        if non_nan_data.empty:
            continue  # Skip games with no data

        # Reset index to align based on first available month (Month 1, Month 2, ...)
        aligned_series = pd.Series(non_nan_data.values, index=range(1, len(non_nan_data) + 1))
        aligned_data[game_id] = aligned_series

    # Convert dictionary to DataFrame while keeping game IDs as index
    df_aligned = pd.DataFrame.from_dict(aligned_data, orient='index')

    return df_aligned

# %% [markdown]
# # Adhoc Analysis Site

# %%
plot_performance_streams_df(
    test_performance_df
)

# %%
# Why Open World Adventure subgenre jumps in revenue hugely 2019 - 2020?

# %%
df_game_revenue_adjusted_with_genre_info[
    df_game_revenue_adjusted_with_genre_info['game_subgenre'] == 'Idle RPG'
].sort_values(by = 2024, ascending = False)
# Out:
#                                  game_class game_genre game_subgenre  2014  \
# Unified ID
# 6539d116d2e5a9284e6a76e2  Action & Strategy        RPG      Idle RPG   NaN
# 64d262a510a3142a25912bd2  Action & Strategy        RPG      Idle RPG   NaN
# 64a91142f08b1411f1c62ffc  Action & Strategy        RPG      Idle RPG   NaN
# 6320fb30ad4adb161582e209  Action & Strategy        RPG      Idle RPG   NaN
# 63578bb99d838447746c5887  Action & Strategy        RPG      Idle RPG   NaN
# ...                                     ...        ...           ...   ...
# 6535dfd78636176c51d89db4  Action & Strategy        RPG      Idle RPG   NaN
# 653b30f39c7c3e380cc0b71c  Action & Strategy        RPG      Idle RPG   NaN
# 654d78f787b2754c24cf45ba  Action & Strategy        RPG      Idle RPG   NaN
# 654edf4c58f59b6d1d3cb27b  Action & Strategy        RPG      Idle RPG   NaN
# 6553620e93f17f5bdb2e120e  Action & Strategy        RPG      Idle RPG   NaN
#
#                           2015  2016  2017  2018  2019  2020  2021   2022  \
# Unified ID
# 6539d116d2e5a9284e6a76e2   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 64d262a510a3142a25912bd2   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 64a91142f08b1411f1c62ffc   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 6320fb30ad4adb161582e209   NaN   NaN   NaN   NaN   NaN   NaN 99753  18178
# 63578bb99d838447746c5887   NaN   NaN   NaN   NaN   NaN   NaN   NaN 183234
# ...                        ...   ...   ...   ...   ...   ...   ...    ...
# 6535dfd78636176c51d89db4   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 653b30f39c7c3e380cc0b71c   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 654d78f787b2754c24cf45ba   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 654edf4c58f59b6d1d3cb27b   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
# 6553620e93f17f5bdb2e120e   NaN   NaN   NaN   NaN   NaN   NaN   NaN    NaN
#
#                             2023    2024
# Unified ID
# 6539d116d2e5a9284e6a76e2     NaN 7601709
# 64d262a510a3142a25912bd2     NaN 7211842
# 64a91142f08b1411f1c62ffc 2826016 2787271
# 6320fb30ad4adb161582e209 1919770 2676618
# 63578bb99d838447746c5887 1747840 1753168
# ...                          ...     ...
# 6535dfd78636176c51d89db4      39     NaN
# 653b30f39c7c3e380cc0b71c     796     NaN
# 654d78f787b2754c24cf45ba      86     NaN
# 654edf4c58f59b6d1d3cb27b     569     NaN
# 6553620e93f17f5bdb2e120e     134     NaN
#
# [971 rows x 14 columns]

# %% [markdown]
# # Draft
