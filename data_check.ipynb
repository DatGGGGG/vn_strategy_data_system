# %%
import json

# %% [markdown]
# **Check: App Full Info & App Full Info (Adjusted) (NDJSON version)**

# %%
# Specify file path
path = r"data\draft\st_app_full_info_adjusted_1771834387.ndjson"

# %%
# Count the number of rows in the file
with open(path, "rb") as f:
    n_rows = sum(1 for _ in f)

print(n_rows)
# Out:
# 89026

# %%
# Specify the number of first rows in the file to read
n = 10

# %%
# Print out the first N rows in the file
with open(path, "r", encoding="utf-8") as f:
    for i, line in enumerate(f):
        obj = json.loads(line)
        print(obj)
        if i == n:
            break
# Out:
# {'unified_app_id': '55d9397e02ac645ad20193cb', 'canonical_app_id': '370789436', 'name': 'Tap Puzzle 2 Lite', 'cohort_id': None, 'itunes_apps': [{'app_id': 370789436}], 'android_apps': [], 'unified_publisher_ids': ['55f88f5d8ac350426b027407'], 'itunes_publisher_ids': [314590778], 'android_publisher_ids': [], 'game_class': 'Lifestyle & Puzzle', 'game_genre': 'Puzzle', 'game_subgenre': 'Match Blast', 'game_art_style': '2D Cartoon', 'game_camera_pov': 'Side', 'game_setting': None, 'game_theme': 'Bubbles / Tiles / Colors', 'game_product_model': 'Casual', 'game_ip_corporate_parent': None, 'game_ip_operator': None, 'game_ip_media_type': None, 'game_licensed_ip': None, 'game_earliest_release_date': '2010/05/08', 'game_release_date_ww': '2010/05/08', 'game_release_date_us': '2010/05/08', 'game_release_date_jp': '2010/05/08', 'game_release_date_cn': '2010/05/08'}
# ...

# %%
# Print out the key fields of the first N rows in the file
with open(path, "r", encoding="utf-8") as f:
    for i, line in enumerate(f):
        obj = json.loads(line)
        print(obj.get("app_id"), obj.get("os"), obj.get("name"), obj.get("unified_app_id"))
        if i == n:
            break
# Out:
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# None None None None
# ...

# %%
# Print out all fields of a certain app_id
target_app_id = "1597222643"
with open(path, "r", encoding="utf-8") as f:
    for line in f:
        obj = json.loads(line)
        if str(obj.get("app_id")) == str(target_app_id):
            print(json.dumps(obj, ensure_ascii=False, indent=2))
            break
